# %% [markdown]
# # Darcy equation
#
# In this tutorial we present how to solve a Darcy equation with [PyGeoN](https://github.com/compgeo-mox/pygeon) in themoving domain case (the upper boundary will move).  The unkwons are the velocity $u$, the elevation head $h$ and the height of the upper boundary $\eta$.
#
# Let $\Omega=(0,1)\times(0,\eta)$ with boundary $\partial \Omega$ and outward unit normal ${\nu}$. Given
# $K$ the matrix permeability, we want to solve the following problem: find $(\bm{u}, h)$ such that
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# K^{-1} {\bm{u}} + \nabla h = {0}\\
# S_s \frac{\partial{h}}{\partial t} + \nabla \cdot {u} = f
# \end{array}
# &\text{in } \Omega
# \end{array}
# \right.
# $$

# %% [markdown]
# In order to solve the problem, we will perfom a change of coordinates to a reference domain $\hat{\Omega}=(0,1)^2$ through the (linear) trasnformation $R : \Omega \rightarrow \hat{\Omega}$ (and its inverse function $D : \hat{\Omega} \rightarrow \Omega$).
# Recall that $\hat{\nabla}R=(\nabla D)^{-1}$.
#
# Let $\hat{h}$ and $\hat{\bm{u}}$ be $h$ and $\bm{u}$ respectevely in the reference domain and let $\hat{K}$ be the transformed permeability matrix, defined as $\hat{K}=det(\hat{\nabla}D) (\hat{\nabla} D)^{-1} K (\hat{\nabla} D)^{-T}$.
#
# The equation describing the motion of $\partial_{top}\Omega$ is:
# $$
#
# \phi \frac{\partial \eta}{\partial t} = \hat{u_3} + I(t)
#
# $$

# %% [markdown]
# The transformed equations in $\hat{\Omega}$ is:
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# \hat{K}({\eta})^{-1} {\hat{u}} + \hat{\nabla} \hat{h} = {0}\\
# \hat{S}_s \frac{\partial{\hat{h}}}{\partial t} + \hat{\nabla} \cdot {\hat{\bm{u}}} = f
# \end{array}
# &\text{in } \hat{\Omega}
# \end{array}
# \right.
# $$
# with boundary conditions:
# $$ \hat{h} = \eta \text{ on } \Gamma \qquad \hat{h} = \ell \text{ on } \Gamma_D \qquad \hat{\bm{\nu}} \cdot \hat{\bm{u}} = 0 \text{ on } \Gamma_N$$

# %% [markdown]
# The weak formulation will be:
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# \int_{\Omega}\hat{K}(\eta)^{-1} {\bm{\hat{u}}} \cdot \bm{v} \, d\Omega - \int_{\Omega} h \hat{\nabla} \cdot {\hat{\bm{v}}} \, d\Omega = - \int_{\Gamma_D} h \bm{v} \cdot \bm{\nu} \, d\Omega - \int_{\Gamma} \eta \bm{v} \cdot \bm{\nu} \, d\Omega\\
# \int_{\Omega} \hat{S}_s \frac{\partial{\hat{h}}}{\partial t} v \, d\Omega + \int_{\Omega} \hat{\nabla} \cdot {\hat{\bm{u}}} v \, d\Omega = \int_{\Omega} fv \, d\Omega\\
# \int_{\Gamma} \phi \frac{\partial \eta}{\partial t} v \, d\sigma = \int_{\Gamma} \hat{u_3} v \, d\sigma + \int_{\Gamma} I(t) v \, d\sigma
# \end{array}
# \end{array}
# \right.
# $$

# %% [markdown]
# For the time discretization, we will employ a backward Euler scheme:
#
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# \int_{\Omega}\hat{K}(\eta^{n+1})^{-1} {\bm{\hat{u}}^{n+1}} \cdot \bm{v} \, d\Omega - \int_{\Omega} h^{n+1} \hat{\nabla} \cdot {\hat{\bm{v}}} \, d\Omega = - \int_{\Gamma_D} h^{n+1} \bm{v} \cdot \bm{\nu} \, d\Omega - \int_{\Gamma} \eta^{n+1} \bm{v} \cdot \bm{\nu} \, d\Omega\\
# \int_{\Omega} \hat{S}_s^{n+1} \frac{\hat{h}^{n+1} - \hat{h}^{n}}{\Delta t} v \, d\Omega + \int_{\Omega} \hat{\nabla} \cdot {\hat{\bm{u}}^{n+1}} v \, d\Omega = \int_{\Omega} f^{n+1}v \, d\Omega\\
# \int_{\Gamma} \phi \eta^{n+1} v \, d\sigma = \Delta t \int_{\Gamma} \hat{\bm{u}}^{n+1} \cdot \bm{\nu} v \, d\sigma + \int_{\Gamma} \phi \eta^{n} v \, d\sigma + \Delta t \int_{\Gamma} I^{n+1} v \, d\sigma
# \end{array}
# \end{array}
# \right.
# $$

# %% [markdown]
# To deal with the non-linear term, we will employ a simple Picard scheme:
#
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# \int_{\Omega}\hat{K}(\eta^{n+1}_k)^{-1} {\bm{\hat{u}_{k+1}^{n+1}}} \cdot \bm{v} \, d\Omega - \int_{\Omega} h^{n+1}_{k+1} \hat{\nabla} \cdot {\hat{\bm{v}}} \, d\Omega + \int_{\Gamma} \eta^{n+1}_{k+1} \bm{v} \cdot \bm{\nu} \, d\Omega= - \int_{\Gamma_D} h^{n+1} \bm{v} \cdot \bm{\nu} \, d\Omega\\
# \Delta t \int_{\Omega} \hat{\nabla} \cdot {\hat{\bm{u}}^{n+1}_{k+1}} v \, d\Omega + \int_{\Omega} \hat{S}_s \hat{h}^{n+1}_{k+1} v \, d\Omega = \int_{\Omega} \hat{S}_s \hat{h}^{n} v \, d\Omega + \Delta t \int_{\Omega} f^{n+1}v \, d\Omega\\
# - \Delta t \int_{\Gamma} \hat{\bm{u}}^{n+1}_{k+1} \cdot \bm{\nu} v \, d\sigma + \int_{\Gamma} \phi \eta^{n+1}_{k+1} v \, d\sigma = \int_{\Gamma} \phi \eta^{n} v \, d\sigma + \Delta t \int_{\Gamma} I^{n+1} v \, d\sigma
# \end{array}
# \end{array}
# \right.
# $$

# %% [markdown]
# The matrix formulation will be:
#
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# M_u(\bm{\eta}^{n+1}_{k}) \bm{u}^{n+1}_{k+1} + B^T\bm{h}^{n+1}_{k+1} + B_{\Gamma}^T \bm{\eta}^{n+1}_{k+1}= \bm{BC}^{n+1}\\
# - \Delta t B \hat{\bm{u}}^{n+1}_{k+1} + S_s M_{h} \bm{\hat{h}^{n+1}_{k+1}} = \Delta t \bm{F}^{n+1} + S_s M_{h} \bm{\hat{h}^{n}}\\
# - \Delta t B_{\Gamma} \hat{\bm{u}}^{n+1}_{k+1} + \phi M_{\Gamma} \bm{\eta^{n+1}_{k+1}} = \phi M_{\Gamma} \bm{\eta^{n}} + \Delta t \bm{I}^{n+1}
# \end{array}
# \end{array}
# \right.
# $$

# %% [markdown]
# $$
# \left(
# \begin{array}{cc}
# M_u(\bm{\eta^{n+1}_k}) & B^T & B_{\Gamma}^T\\
# -\Delta t B & S_s M_h & 0\\
# -\Delta t B_{\Gamma} & 0 & \phi M_{\Gamma}
# \end{array}
# \right)
# \left(
# \begin{array}{c}
# \bm{u^{n+1}_{k+1}}\\
# \bm{h^{n+1}_{k+1}}\\
# \bm{\eta^{n+1}_{k+1}}
# \end{array}
# \right)
# =\left(
# \begin{array}{c}
# \bm{BC}^{n+1}\\
# \Delta t \bm{F}^{n+1} + S_s M_h \bm{h}^n\\
# \phi M_{\Gamma} \bm{\eta}^n + \Delta t \bm{I}^{n+1}
# \end{array}
# \right)
# $$

# %% [markdown]
# We will start to test the method in the case $M_u(\bm{h_k}^{n+1})=\bm{I}$

# %%
# %load_ext Cython

# %%
import shutil
import os

import numpy as np
import scipy.sparse as sps
from scipy.sparse import linalg
import scipy.integrate as integrate
import sympy as sp

import porepy as pp
import pygeon as pg

import time
from math import ceil, floor, log10, exp

import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.11/site-packages/porepy/numerics/nonlinear/nonlinear_solvers.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange  # type: ignore

# %% [markdown]
# We create now the grid, since we will use a Raviart-Thomas approximation for ${q}$ we are restricted to simplices. In this example we consider a 2-dimensional structured grid, but the presented code will work also in 1d and 3d. PyGeoN works with mixed-dimensional grids, so we need to convert the grid.

# %%
# Set the maximum number of iterations of the non-linear solver
K = 50

# L-scheme parameter
L = 3.501e-2

# Porosity
phi = 0.1

# Real domain dimensions
A = 3 # Height
B = 2 # Domain

# Initial water table height
def init_eta(x): return 1

# Set the mesh refinment
N = 40

# Order for the quadrature formulae
quad_order = 5

# Set the number of steps (excluding the initial condition)
num_steps = 9

# Simulation time length
T = 9/48

# Time switch conditions (for the boundary condition)
dt_D = 1/16

# Fluid density
rho = 1000

# Relative and absolute tolerances for the non-linear solver
abs_tol = 1e-6
rel_tol = 1e-6

# Domain tolerance
domain_tolerance = 1 / (10 * N)

# Output directory
output_directory = str(ceil(time.time())) + '_' + 'ind_grids'

# %%
# Time step
dt   = (T-0)/num_steps

# %%
# Van Genuchten model parameters ( relative permeability model )
theta_s = 0.396
theta_r = 0.131

alpha = 0.423

n = 2.06
K_s = 4.96e-2

m = 1 - 1/n

# %% [markdown]
# ### $\theta$ and $K$

# %% [markdown]
# In order to evaluate analytically both $\theta$ and $K$, we will make use of the python package $\textit{sympy}$, that allow us to write down a mathematical expression in symbolic form (and that can also be used to compute their derivatives).

# %%
# Symbolic psi
psi_var = sp.Symbol('psi', negative=True)

# Symbolic Theta
theta_expression = theta_r + (theta_s - theta_r) / (1 + (-alpha * psi_var) ** n) ** m
effective_saturation = (theta_expression - theta_r) / (theta_s - theta_r)

# Symbolic Conductivity K
hydraulic_conductivity_expression = K_s * (effective_saturation ** 0.5) * ( 1 - (1 - effective_saturation ** (1 / m)) ** m ) ** 2

# %%
# Theta lambda
theta_lambda = sp.lambdify(psi_var, theta_expression, 'numpy')

# Conductivity tensor lambda
conductivity_lambda = sp.lambdify(psi_var, hydraulic_conductivity_expression, 'numpy')

# %%
# Actual (and final) theta function
def theta(psi):
    mask = np.where(psi < 0)
    res = np.ones_like(psi) * theta_s
    res[mask] = theta_lambda(psi[mask])

    return res

# %%
# %%cython
# K_s = 4.96e-2
#
#
# def D_K11(x, y):
#     return K_s
#
# def D_K12(x, y):
#     return 0
#
# def D_K21(x, y):
#     return 0
#
# def D_K22(x, y):
#     return K_s

# %%
# %%cython
#
# theta_s = 0.396
# theta_r = 0.131
#
# alpha = 0.423
#
# n = 2.06
# K_s = 4.96e-2
#
# m = 1 - 1/n
#
# def R_effective_saturation(psi):
#     return ((theta_r + (theta_s - theta_r) / (1 + (-alpha * psi) ** n) ** m) - theta_r) / (theta_s - theta_r)
#
#
# def R_K11(x, y, psi):
#     if psi >= 0:
#         return K_s
#     tmp = R_effective_saturation(psi)
#     return K_s * (tmp ** 0.5) * ( 1 - (1 - tmp ** (1 / m)) ** m ) ** 2
#
# def R_K12(x, y, psi):
#     return 0
#
# def R_K21(x, y, psi):
#     return 0
#
# def R_K22(x, y, psi):
#     if psi >= 0:
#         return K_s
#     tmp = R_effective_saturation(psi)
#     return K_s * (tmp ** 0.5) * ( 1 - (1 - tmp ** (1 / m)) ** m ) ** 2

# %% [markdown]
# ### Domain preparation and boundary conditions

# %%
darcy_grid    = pp.StructuredTriangleGrid([ceil(B) * N,   N], [B, 1])
richards_grid = pp.StructuredTriangleGrid([ceil(B) * N, 2*N], [B, 1])

# %%
darcy_grid.compute_geometry()
richards_grid.compute_geometry()

# %%
boundary_grid, boundary_face_map, boundary_node_map  = pp.partition.extract_subgrid(darcy_grid, 
                                                                                    darcy_grid.face_centers[1, :] == np.max(darcy_grid.face_centers[1, :]), 
                                                                                    faces=True)

# %%
key = "flow"

# Collection of boundary conditions for the Darcy problem
bc_value = []
bc_essential = []

# Initial pressure
initial_pressure = []

# %%
darcy_q_field     = pg.RT0(key)
richards_q_field  = pg.RT0(key)

# %%
gamma_field = pg.Lagrange1(key)

# %%
darcy_h_field     = pg.PwConstants(key)
richards_h_field  = pg.PwConstants(key)

# %%
darcy_q    = darcy_q_field.ndof( darcy_grid )
darcy_h    = darcy_h_field.ndof( darcy_grid )

richards_q = richards_q_field.ndof( richards_grid )
richards_h = richards_h_field.ndof( richards_grid )

dof_eta = gamma_field.ndof( boundary_grid )

# %%
darcy_restrictor = np.zeros(shape=(darcy_q - (dof_eta-1), darcy_q))
darcy_restrictor[np.array( list(range(darcy_q - (dof_eta-1))) ), darcy_grid.face_centers[1, :] < 1-domain_tolerance] = 1

# %%
def initial_h_func(x): return 1

# %%
darcy_bc_dirichlet = darcy_grid.face_centers[0, :] > B-domain_tolerance
darcy_bc_val       = - darcy_q_field.assemble_nat_bc(darcy_grid, lambda x: 1, darcy_bc_dirichlet)

darcy_bc_neumann   = np.hstack(( 
        np.array(darcy_restrictor @ np.logical_or( darcy_grid.face_centers[0, :] < 0+domain_tolerance, darcy_grid.face_centers[1, :] < 0+domain_tolerance ), dtype=bool), 
        np.zeros(shape=(darcy_h), dtype=bool) 
    ))
darcy_ess_neumann  = np.hstack(( np.array(darcy_restrictor @ np.zeros(shape=(darcy_q)), dtype=bool), np.zeros(shape=(darcy_h), dtype=bool)))

# %%
richards_bc_dirichlet = np.logical_and(richards_grid.face_centers[0, :] < 1+domain_tolerance, richards_grid.face_centers[1, :] > 1-domain_tolerance)
richards_bc_val       = lambda t: - richards_q_field.assemble_nat_bc(richards_grid, lambda x: min( 0.2, -2 + 2.2 * t / dt_D ) + 3, richards_bc_dirichlet)

richards_bc_neumann   = np.hstack(( 
        np.logical_or( richards_grid.face_centers[0, :] < 0+domain_tolerance, 
        np.logical_or( richards_grid.face_centers[0, :] > B-domain_tolerance, 
                       np.logical_and(richards_grid.face_centers[1, :] > 1-domain_tolerance, 
                                      richards_grid.face_centers[0, :] > 1-domain_tolerance)) ), 
        np.zeros(shape=(richards_h), dtype=bool) 
    ))
richards_ess_neumann  = np.zeros(shape=(richards_q + richards_h))

# %%
bc_ess_flag = np.hstack( (darcy_bc_neumann,  
                          richards_bc_neumann, 
                          np.zeros(shape=(dof_eta,), dtype=bool)) )

bc_ess_val  = np.hstack( (darcy_ess_neumann, 
                          richards_ess_neumann, 
                          np.zeros(shape=(dof_eta,))) )

# %%
darcy_restrictor = sps.csr_matrix(darcy_restrictor)

# %% [markdown]
# ### Matrix assembly

# %% [markdown]
# The $RT_0$ elements are constructed in such a wat that, on the non-diagonal faces, $\bm{v} \cdot \nu = 0$. Then, since $\Gamma$ is made by one of the two catheti of each boundary facing element, the only non-zero terms will be associated to the basis functions associated to the ``boundary'' cathetus. Then:

# %%
def assemble_B_gamma(domain, threshold):
    data = []
    row = []
    col = []

    face, _, sign = sps.find(domain.cell_faces)

    # Look for the boundary faces ids
    index_up_face = np.where(np.logical_and(threshold-domain_tolerance < domain.face_centers[1, :], 
                                            domain.face_centers[1, :] < threshold+domain_tolerance))[0]

    # Loop thorough the boundary faces
    for i in range( boundary_grid.num_cells ):
        s = sign[ np.where(face == index_up_face[i]) ][0]

        # s-element
        col.append(index_up_face[i])
        row.append(i)
        data.append( s / 2 )

        # (1-s)-element
        col.append(index_up_face[i])
        row.append(i+1)
        data.append( s / 2 )

    return sps.coo_matrix( (data, (row, col)), shape=(boundary_grid.num_nodes, domain.num_faces) ).tocsr()

# %%
eta_diff = gamma_field.assemble_diff_matrix(boundary_grid)
eta_diff[0,0] = -1

# %%
darcy_B_gamma    = assemble_B_gamma(darcy_grid, threshold=1)
richards_B_gamma = assemble_B_gamma(richards_grid, threshold=0)

# %%
M_gamma = gamma_field.assemble_mass_matrix( boundary_grid )

# %%
darcy_M_h    = darcy_h_field.assemble_mass_matrix( darcy_grid )
richards_M_h = richards_h_field.assemble_mass_matrix( richards_grid )

# %%
# B matrix
darcy_B    = - darcy_h_field.assemble_mass_matrix(darcy_grid)       @ pg.div(darcy_grid)
richards_B = - richards_h_field.assemble_mass_matrix(richards_grid) @ pg.div(richards_grid)

# %%
def vertical_projection_matrix(domain):
    data = []
    row = []
    col = []

    for c in range(domain.num_cells):
        x_center = domain.cell_centers[:, c]
        id = np.max(np.where( boundary_grid.nodes[0, :] < x_center[0] ))

        data.append(1)
        row.append(c)
        col.append(id)

    return sps.coo_matrix( (data, (row, col)), shape=(domain.num_cells, boundary_grid.num_cells) ).tocsr()

# %% [markdown]
# ### Solving stage

# %%
darcy_q, richards_q
# Out:
# (9720, 19360)

# %%
false_mask = np.zeros(shape=(darcy_h + darcy_q-(dof_eta-1) + dof_eta + richards_h + richards_q), dtype=bool)

darcy_q_mask = false_mask.copy()
darcy_q_mask[:(darcy_q-(dof_eta-1))] = True
darcy_q_mask[(darcy_q-(dof_eta-1) + darcy_h) + np.where(richards_grid.face_centers[1, :] < 0+domain_tolerance)[0]] = True
darcy_q_mask = np.where(darcy_q_mask)

darcy_h_mask = false_mask.copy()
darcy_h_mask[(darcy_q-(dof_eta-1)):(darcy_q-(dof_eta-1) + darcy_h)] = True
darcy_h_mask = np.where(darcy_h_mask)

richards_q_mask = false_mask.copy()
richards_q_mask[(darcy_q-(dof_eta-1) + darcy_h):(darcy_q-(dof_eta-1) + darcy_h + richards_q)] = True
richards_q_mask = np.where(richards_q_mask)

richards_h_mask = false_mask.copy()
richards_h_mask[(darcy_q-(dof_eta-1) + darcy_h + richards_q):(darcy_q-(dof_eta-1) + darcy_h + richards_q + richards_h)] = True
richards_h_mask = np.where(richards_h_mask)

eta_mask = false_mask.copy()
eta_mask[-dof_eta:] = True
eta_mask = np.where(eta_mask)

# %%
def cell_eta(eta_dof):
    _rows = []

    for c in range( richards_grid.num_cells):
        eta_pos = np.max(np.where( boundary_grid.nodes[0, :] < richards_grid.cell_centers[0, c] ))
        coeff = (richards_grid.cell_centers[0, c] - boundary_grid.nodes[0, eta_pos]) / (boundary_grid.nodes[0, eta_pos+1] - boundary_grid.nodes[0, eta_pos])

        _rows.append(eta_dof[eta_pos + 1] * (1-coeff) + eta_dof[eta_pos + 1] * coeff)

    return np.hstack((_rows))

# %%
cell_proj_eta = [vertical_projection_matrix(darcy_grid), vertical_projection_matrix(richards_grid)]

# Helper function to save the given solution to a VTU file
def save_step(sol, proj_q, proj_h, proj_eta, saver, i):
    for sav, actual_proj_q, actual_proj_h, actual_cell_proj_eta, dom, q_mask, h_mask in zip(saver, proj_q, proj_h, cell_proj_eta, [darcy_grid, richards_grid], [darcy_q_mask, richards_q_mask], [darcy_h_mask, richards_h_mask]):
        ins = list()

        ins.append((dom, "cell_q", ( actual_proj_q @ sol[q_mask] ).reshape((3, -1), order="F")))
        ins.append((dom, "cell_h",   actual_proj_h @ sol[h_mask]))

        etas = cell_eta( sol[eta_mask] )
        dom_height = ((A - etas ) * richards_grid.cell_centers[1,:] + etas) if dom == richards_grid else darcy_grid.cell_centers[1,:]

        ins.append((dom, "cell_p",   actual_proj_h @ sol[h_mask] -  dom_height))
        ins.append((dom, "cell_eta", actual_cell_proj_eta @ proj_eta @ sol[eta_mask]))

        sav.write_vtu(ins, time_step=i)

# %%
if os.path.exists(output_directory):
    shutil.rmtree(output_directory)

# %%
# Initial conditions
sol = [np.zeros(shape=(darcy_h + darcy_q + dof_eta + richards_h + richards_q,))]

sol[-1][darcy_h_mask]    = darcy_h_field.interpolate(   darcy_grid, initial_h_func)
sol[-1][richards_h_mask] = richards_h_field.interpolate(richards_grid, initial_h_func)

sol[-1][eta_mask] = gamma_field.interpolate(boundary_grid, init_eta)

# %%
# Prepare helper matrices
proj_q   = [darcy_q_field.eval_at_cell_centers(darcy_grid), richards_q_field.eval_at_cell_centers(richards_grid)]
proj_h   = [darcy_h_field.eval_at_cell_centers(darcy_grid), richards_h_field.eval_at_cell_centers(richards_grid)]
proj_eta = gamma_field.eval_at_cell_centers(boundary_grid)

# %%
# Save the initial solution
saver = [pp.Exporter(darcy_grid, 'sol_D', folder_name=output_directory), pp.Exporter(richards_grid, 'sol_R', folder_name=output_directory)]
save_step(sol[-1], proj_q, proj_h, proj_eta, saver, 0)

# %%
# Fixed rhs
fixed_rhs = np.zeros(shape=(darcy_h + darcy_q + richards_h + richards_q + dof_eta - (dof_eta-1),))

# %%
# %%cython
# import numpy as np
#
# def q1(x: float, y: float):
#     return np.array([-x, -y])
#
# def q2(x: float, y: float):
#     return np.array([x-1, y])
#
# def q3(x: float, y: float):
#     return np.array([-x, 1-y])
#
# def find_ordering(coord: np.array, N):
#     lx = np.argmin(coord[0, :])
#     rx = np.argmax(coord[0, :])
#     mx = np.setdiff1d(np.array([0,1,2]), np.array([lx, rx]))[0]
#
#     # Vertical Alignment
#     if np.abs( coord[0, lx] - coord[0, mx] ) < 1 / (2 * N):
#         # lx and mx vertical aligned, rx no
#         up =   lx if np.argmax(coord[1, np.array([lx, mx])]) == 0 else mx
#         down = lx if np.argmin(coord[1, np.array([lx, mx])]) == 0 else mx
#
#         if np.abs( coord[1, up] - coord[1, rx] ) < 1 / (2 * N):
#             return [up, down, rx]
#         else:
#             return [down, rx, up]
#     else:
#         # rx and mx vertical aligned, lx no
#         up =   rx if np.argmax(coord[1, np.array([rx, mx])]) == 0 else mx
#         down = rx if np.argmin(coord[1, np.array([rx, mx])]) == 0 else mx
#
#         if np.abs( coord[1, up] - coord[1, lx] ) < 1 / (2 * N):
#             return [up, lx, down]
#         else:
#             return [down, up, lx]

# %%
# %%cython
# import numpy as np
#
#
# def generic_K_func(chi_eta, chi_x3, grad_eta, K11, K12, K21, K22):
#     k11 = lambda x,y: ( K22(x,y) + chi_eta(x,y) * grad_eta * ( chi_eta(x,y) * grad_eta * K11(x,y) - K12(x,y) - K21(x,y) ) ) / chi_x3(x,y)
#     k12 = lambda x,y: chi_eta(x,y) * grad_eta * K11(x,y) - K12(x,y)
#     k21 = lambda x,y: chi_eta(x,y) * grad_eta * K11(x,y) - K21(x,y)
#     k22 = lambda x,y: chi_x3(x,y) * K11(x,y)
#
#     return lambda x,y: np.array([[k11(x,y), k12(x,y)],
#                                  [k21(x,y), k22(x,y)]]) / ( K11(x,y) * K22(x,y) - K12(x,y) * K21(x,y) )
#
#
# def Darcy_K_func(base_height: float, element_height: float, m: int, ls_eta: float, rs_eta: float, grad_eta: float, K11, K12, K21, K22):
#     coord = lambda t: ((m+1) * (1-t) - (m-1) * t) / 2
#
#     chi_x3  = lambda x,y: (1-coord(y)) * ls_eta + coord(y) * rs_eta
#     chi_eta = lambda x,y: base_height + (1 - coord(x)) * element_height
#
#     return generic_K_func( chi_eta, chi_x3, grad_eta, K11, K12, K21, K22 )
#
#
# def Richards_K_func(base_height: float, element_height: float, m: int, ls_eta: float, rs_eta: float, grad_eta: float, psi: float, K11, K12, K21, K22, A):
#     coord = lambda t: ((m+1) * (1-t) - (m-1) * t) / 2
#
#     chi_x3  = lambda x,y: A - ((1-coord(y)) * ls_eta + coord(y) * rs_eta)
#     chi_eta = lambda x,y: 2 - (base_height + (1-coord(x)) * element_height)
#
#     return generic_K_func( chi_eta, chi_x3, grad_eta, lambda x,y: K11(x,y,psi), lambda x,y: K12(x,y,psi), lambda x,y: K21(x,y,psi), lambda x,y: K22(x,y,psi) )

# %%
def Darcy_local_q(coord, sign, ls_eta, rs_eta, grad_eta):
    M = np.zeros(shape=(3,3))

    ordering = find_ordering(coord, boundary_grid.num_nodes-1)
    orientation = [-1, 1, -1] * sign[ordering]

    q_funcs = [q1, q2, q3]

    K_local = Darcy_K_func(np.min(coord[1,:]), (np.max(coord[1, :]) - np.min(coord[1, :])), np.prod(sign), ls_eta, rs_eta, grad_eta, D_K11, D_K12, D_K21, D_K22)

    for i in range(3):
        for j in range(3):
            integrand = lambda ys,x: np.array([q_funcs[j](x,y).T @ K_local(x, y) @ q_funcs[i](x,y) for y in np.array(ys)])
            inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
            M[ordering[i], ordering[j]] = orientation[j] * orientation[i] * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
    
    return M

# %%
def Richards_local_q(coord, sign, ls_eta, rs_eta, grad_eta, psi):
    M = np.zeros(shape=(3,3))

    ordering = find_ordering(coord, boundary_grid.num_nodes-1)
    orientation = [-1, 1, -1] * sign[ordering]

    q_funcs = [q1, q2, q3]

    K_local = Richards_K_func(np.min(coord[1,:])+1, (np.max(coord[1, :]) - np.min(coord[1, :])), np.prod(sign), ls_eta, rs_eta, grad_eta, psi, R_K11, R_K12, R_K21, R_K22, A)


    for i in range(3):
        for j in range(3):
            integrand = lambda ys,x: np.array([q_funcs[j](x,y).T @ K_local(x, y) @ q_funcs[i](x,y) for y in np.array(ys)])
            inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
            M[ordering[i], ordering[j]] = orientation[j] * orientation[i] * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
    
    return M

# %%
# %%timeit
Darcy_local_q(np.array([[0, 1, 0], [0, 0, 1]]), np.array([-1, -1, 1]), 2, 1, -1)
# Out:
# 4.55 ms ± 138 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
Richards_local_q(np.array([[0, 1, 0], [0, 0, 1]]), np.array([-1, -1, 1]), 2, 1, -1, 0.75)
# Out:
# 4.75 ms ± 43.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
darcy_data = {}
richards_data = {}

# %%
def mass_q(eta_dofs, h_dofs, darcy):

    if darcy:
        int_data = darcy_data
        int_subdomain = darcy_grid
        int_q_field = darcy_q_field
    else:
        int_data = richards_data
        int_subdomain = richards_grid
        int_q_field = richards_q_field


    # Gradient of eta and pointwise value
    grad_eta   = eta_diff @ eta_dofs

    faces, _, sign = sps.find(int_subdomain.cell_faces)


    _, _, _, _, _, node_coords = pp.map_geometry.map_grid(
            int_subdomain, int_data.get("deviation_from_plane_tol", 1e-5)
        )
    
    dim = int_subdomain.dim
    
    node_coords = node_coords[: dim, :]

    int_q_field._compute_cell_face_to_opposite_node(int_subdomain, int_data)
    cell_face_to_opposite_node = int_data[int_q_field.cell_face_to_opposite_node]
    
    size_A = np.power(int_subdomain.dim + 1, 2) * int_subdomain.num_cells
    rows_A = np.empty(size_A, dtype=int)
    cols_A = np.empty(size_A, dtype=int)
    data_A = np.empty(size_A)
    idx_A = 0

    for c in range(int_subdomain.num_cells):
        # For the current cell retrieve its faces
        loc = slice(int_subdomain.cell_faces.indptr[c], int_subdomain.cell_faces.indptr[c + 1])
        faces_loc = faces[loc]
    
        eta_cell = np.max(np.where( boundary_grid.nodes[0, :] < int_subdomain.cell_centers[0, c] ))

        node = np.flip(np.sort(cell_face_to_opposite_node[c, :]))

        coord_loc = node_coords[:, node]

        if darcy:
            local = Darcy_local_q(coord_loc, sign[loc], eta_dofs[eta_cell], eta_dofs[eta_cell+1], grad_eta[eta_cell])
        else:
            coeff = (int_subdomain.cell_centers[0, c] - boundary_grid.face_centers[0, eta_cell]) / (boundary_grid.face_centers[0, eta_cell+1] - boundary_grid.face_centers[0, eta_cell])
            eta_mean = eta_dofs[eta_cell] * (1 - coeff) + eta_dofs[eta_cell+1] * coeff
            
            local = Richards_local_q(coord_loc, sign[loc], eta_dofs[eta_cell], eta_dofs[eta_cell+1], grad_eta[eta_cell], h_dofs[c]-( (A-eta_mean) * int_subdomain.cell_centers[1, c] + eta_mean))

        # Save values for Hdiv-mass local matrix in the global structure
        cols = np.concatenate(faces_loc.size * [[faces_loc]])
        loc_idx = slice(idx_A, idx_A + local.size)
        rows_A[loc_idx] = cols.T.ravel()
        cols_A[loc_idx] = cols.ravel()
        data_A[loc_idx] = local.ravel()
        idx_A += local.size

        #print('')
    
    return sps.coo_matrix((data_A, (rows_A, cols_A))).tocsr()

# %%
# Helper function to project a function evaluated in the cell center to FEM (scalar)
def project_psi_to_fe(to_project, region):
    return to_project * region.cell_volumes

# %% [markdown]
# $$
# \left(
# \begin{array}{cc}
# R^D M_u^D (R^D)^T & R^D (B^D)^T & R^D M_u^D R_{(R\, to \,D)} (I - R^R) & 0 & 0\\
# -B^D (R^D)^T & 0 & -B^D R_{(R\, to \,D)} (I - R^R) & 0 & 0\\
# 0 & 0 & M_u^R & (B^R)^T & B_{\Gamma}^T\\
# 0 & 0 & - B^R & \frac{L}{\Delta t} M^R_h & 0\\
# 0 & 0 & -B_{\Gamma} & 0 & \frac{\phi}{\Delta t} M_{\Gamma}
# \end{array}
# \right)
# \left(
# \begin{array}{c}
# \bm{(q_D)^{n+1}_{k+1}}\\
# \bm{(h_D)^{n+1}_{k+1}}\\
# \bm{(q_R)^{n+1}_{k+1}}\\
# \bm{(h_R)^{n+1}_{k+1}}\\
# \bm{\eta^{n+1}_{k+1}}
# \end{array}
# \right)
# =
# \left(
# \begin{array}{c}
# \bm{BC}^{n+1}_D\\
# 0\\
# \bm{BC}^{n+1}_R\\
# \frac{L}{\Delta t} M_h^R \bm{h}^n + M_h \frac{\Theta(h^{n}) - \Theta(h^{n+1}_{k})}{\Delta t}\\
# \frac{\phi}{\Delta t} M_{\Gamma}^R \bm{\eta^{n}}
# \end{array}
# \right)
# $$

# %%
richards_restrict_to_gamma = np.zeros(shape=(richards_q, richards_q))
rest = richards_grid.face_centers[1, :] < 0+domain_tolerance
richards_restrict_to_gamma[rest, rest] = 1
richards_restrict_to_gamma = sps.csr_matrix(richards_restrict_to_gamma)

# %%
darcy_richards_boundary = np.zeros(shape=(darcy_q, richards_q))
darcy_richards_boundary[ np.where(darcy_grid.face_centers[1,:] > 1-domain_tolerance), np.where(richards_grid.face_centers[1, :] < 0+domain_tolerance) ] = 1
darcy_richards_boundary = sps.csr_matrix(darcy_richards_boundary)

# %%
from_richards_boundary_to_darcy_boundary = darcy_richards_boundary @ richards_restrict_to_gamma
darcy_B_restricted = sps.csr_matrix( darcy_restrictor @ darcy_B.T )

# %%
# Time Loop
for i in range(1, int(T/dt)+1):
    start_time = time.time()
    tmp_time = start_time

    current_time = i * dt
    print('Time ' + str(round(current_time, 5)))

    # Prepare the solution at the previous time step and ...
    prev = sol[-1].copy()

    print('--- Preparing time_fixed rhs...... ', end='')

    # Prepare the rhs
    time_rhs = fixed_rhs.copy()
    
    time_rhs[darcy_q_mask]    += darcy_bc_val
    time_rhs[richards_q_mask] += richards_bc_val(current_time)

    time_rhs[eta_mask] += (phi / dt * M_gamma @ prev[eta_mask])

    print(f'OK (Time: {round(time.time() - tmp_time, 5)} s)')

    tmp_time = time.time()
    print('--- Preparing step debug savers... ', end='')

    debug_saver = [pp.Exporter(darcy_grid, str(i) + '_sol_D', folder_name=os.path.join(output_directory, 'debug')), 
                   pp.Exporter(richards_grid, str(i) + '_sol_R', folder_name=os.path.join(output_directory, 'debug'))]
    save_step(sol[-1], proj_q, proj_h, proj_eta, debug_saver, 0)
    
    print(f'OK (Time: {round(time.time() - tmp_time, 5)} s)')
    print('--- Starting non-linear solver:')
    print('')

    # Non-linear loop
    for k in range(K):
        iteration_time = time.time()

        print(f'--- Iteration {k+1}')
        rhs = time_rhs.copy()

        tmp_time = time.time()
        print('------ Computation of cell-wise eta............... ', end='')
        etas = cell_eta( prev[eta_mask] )
        real_heights = (A - etas) * richards_grid.cell_centers[1,:] + etas

        print(f'OK (Time: {round(time.time() - tmp_time, 5)} s)')
        print(f'------ Assembling rhs for iteration............... ', end='')

        tmp_time = time.time()
        rhs[richards_h_mask] += richards_M_h @ (L * prev[richards_h_mask] 
                                                + project_psi_to_fe( theta(proj_h[1] @ sol[-1][richards_h_mask] - real_heights), richards_grid ) 
                                                - project_psi_to_fe( theta(proj_h[1] @ prev[richards_h_mask] - real_heights), richards_grid ) ) / dt
        
        print(f'OK (Time: {round(time.time() - tmp_time, 5)} s)')
        print('------ Assembling Darcy mass matrix (with K)...... ', end='')

        tmp_time = time.time()
        darcy_M_u = darcy_restrictor @ mass_q(prev[eta_mask], proj_h[0] @    prev[darcy_h_mask], darcy=True) # pg.face_mass(mdg, q_field)

        print(f'OK (Time: {round(time.time() - tmp_time, 5)} s)')
        print('------ Assembling Richards mass matrix (with K)... ', end='')

        tmp_time = time.time()
        richards_M_u = mass_q(prev[eta_mask], proj_h[1] @ prev[richards_h_mask], darcy=False) # pg.face_mass(mdg, q_field)

        print(f'OK (Time: {round(time.time() - tmp_time, 5)} s)')
        print('------ Assembling final system.................... ', end='')

        # Assemble the saddle point problem
        tmp_time = time.time()
        spp = sps.bmat( [[darcy_M_u @ darcy_restrictor.T, darcy_B_restricted, -darcy_M_u @ from_richards_boundary_to_darcy_boundary,              None,               None],
                         [         -darcy_B_restricted.T,               None,  -darcy_B @ from_richards_boundary_to_darcy_boundary,              None,               None],
                         [                          None,               None,                                         richards_M_u,      richards_B.T, richards_B_gamma.T],
                         [                          None,               None,                                          -richards_B, L/dt*richards_M_h,               None],
                         [                          None,               None,                                    -richards_B_gamma,              None,     phi/dt*M_gamma]], format="csc" )
        
        # Prepare the solver
        ls = pg.LinearSystem(spp, rhs)
        ls.flag_ess_bc(bc_ess_flag, bc_ess_val)

        print(f'OK (Time: {round(time.time() - tmp_time, 5)} s)')
        print('------ Solving.................................... ', end='')

        tmp_time = time.time()
        current = ls.solve()
        
        print(f'OK (Time: {round(time.time() - tmp_time, 5)} s)')

        # Compute the errors (with eta). Should I consider only psi? Should I compute the error on the "actual" psi values or on the dofs
        abs_err_psi  = np.sqrt(np.sum(np.power(current[darcy_h_mask] - prev[darcy_h_mask], 2)) 
                               + np.sum(np.power(current[richards_h_mask] - prev[richards_h_mask], 2)) 
                               + np.sum(np.power(current[eta_mask] - prev[eta_mask], 2)))
        
        abs_err_prev = np.sqrt(np.sum(np.power(prev[darcy_h_mask], 2)) 
                               + np.sum(np.power(prev[richards_h_mask], 2)) 
                               + np.sum(np.power(prev[eta_mask], 2)))
        
        print(f'--- Iteration time: {round(time.time() - iteration_time, 5)} s')
        
        print('--- Iteration #' + format(k+1, '0' + str(ceil(log10(K)) + 1) + 'd') 
              + ', error L2 relative psi: ' + format(abs_err_psi, str(5 + ceil(log10(1 / abs_tol)) + 4) 
                                                     + '.' + str(ceil(log10(1 / abs_tol)) + 4) + 'f') )
        
        print('')
        
        save_step(current, proj_q, proj_h, proj_eta, debug_saver, k+1)

        if abs_err_psi < abs_tol + rel_tol * abs_err_prev:
            break
        else:
            prev = None
            prev = current.copy()

    sol.append( current.copy() )

    save_step(sol[-1], proj_q, proj_h, proj_eta, saver, i)

    print(f'OK (Total Time: {round(time.time() - start_time, 5)} s)')

for s in saver:
    s.write_pvd([t * dt for t in range(int(T/dt)+1)])
# Out:
# Time 0.02083
# --- Preparing time_fixed rhs...... OK (Time: 0.01931 s)
# --- Preparing step debug savers... OK (Time: 0.43117 s)
# --- Starting non-linear solver:
#
# --- Iteration 1
# ------ Computation of cell-wise eta............... OK (Time: 0.13562 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00132 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 27.48412 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 68.70351 s)
# ------ Assembling final system.................... OK (Time: 0.00986 s)
# ------ Solving.................................... OK (Time: 0.3628 s)
# --- Iteration time: 96.69916 s
# --- Iteration #001, error L2 relative psi:    1.0327791685
#
# --- Iteration 2
# ------ Computation of cell-wise eta............... OK (Time: 0.13179 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00127 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.90734 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.72663 s)
# ------ Assembling final system.................... OK (Time: 0.00843 s)
# ------ Solving.................................... OK (Time: 0.35453 s)
# --- Iteration time: 93.13402 s
# --- Iteration #002, error L2 relative psi:    0.5898527575
#
# --- Iteration 3
# ------ Computation of cell-wise eta............... OK (Time: 0.12558 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00127 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.78152 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.67628 s)
# ------ Assembling final system.................... OK (Time: 0.00832 s)
# ------ Solving.................................... OK (Time: 0.35548 s)
# --- Iteration time: 92.95066 s
# --- Iteration #003, error L2 relative psi:    0.0579830377
#
# --- Iteration 4
# ------ Computation of cell-wise eta............... OK (Time: 0.12489 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00129 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.93328 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 67.00239 s)
# ------ Assembling final system.................... OK (Time: 0.00786 s)
# ------ Solving.................................... OK (Time: 0.32612 s)
# --- Iteration time: 93.40225 s
# --- Iteration #004, error L2 relative psi:    0.0100722952
#
# --- Iteration 5
# ------ Computation of cell-wise eta............... OK (Time: 0.1245 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00127 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.94364 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 67.17575 s)
# ------ Assembling final system.................... OK (Time: 0.00954 s)
# ------ Solving.................................... OK (Time: 0.34491 s)
# --- Iteration time: 93.60136 s
# --- Iteration #005, error L2 relative psi:    0.0060073391
#
# --- Iteration 6
# ------ Computation of cell-wise eta............... OK (Time: 0.12576 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00128 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 26.04995 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.90348 s)
# ------ Assembling final system.................... OK (Time: 0.00785 s)
# ------ Solving.................................... OK (Time: 0.34514 s)
# --- Iteration time: 93.43553 s
# --- Iteration #006, error L2 relative psi:    0.0001217862
#
# --- Iteration 7
# ------ Computation of cell-wise eta............... OK (Time: 0.12441 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.0023 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.74521 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.64622 s)
# ------ Assembling final system.................... OK (Time: 0.00769 s)
# ------ Solving.................................... OK (Time: 0.33106 s)
# --- Iteration time: 92.85932 s
# --- Iteration #007, error L2 relative psi:    0.0005118430
#
# --- Iteration 8
# ------ Computation of cell-wise eta............... OK (Time: 0.12498 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00127 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.76489 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.9126 s)
# ------ Assembling final system.................... OK (Time: 0.00831 s)
# ------ Solving.................................... OK (Time: 0.33785 s)
# --- Iteration time: 93.15439 s
# --- Iteration #008, error L2 relative psi:    0.0000772002
#
# --- Iteration 9
# ------ Computation of cell-wise eta............... OK (Time: 0.12418 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.0016 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.86839 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.91635 s)
# ------ Assembling final system.................... OK (Time: 0.00915 s)
# ------ Solving.................................... OK (Time: 0.34973 s)
# --- Iteration time: 93.27097 s
# --- Iteration #009, error L2 relative psi:    0.0000357472
#
# --- Iteration 10
# ------ Computation of cell-wise eta............... OK (Time: 0.12635 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00127 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.89011 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 67.03552 s)
# ------ Assembling final system.................... OK (Time: 0.00765 s)
# ------ Solving.................................... OK (Time: 0.31537 s)
# --- Iteration time: 93.37795 s
# --- Iteration #010, error L2 relative psi:    0.0000118170
#
# --- Iteration 11
# ------ Computation of cell-wise eta............... OK (Time: 0.12516 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00166 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.83971 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.77444 s)
# ------ Assembling final system.................... OK (Time: 0.00761 s)
# ------ Solving.................................... OK (Time: 0.33967 s)
# --- Iteration time: 93.0907 s
# --- Iteration #011, error L2 relative psi:    0.0000016629
#
# OK (Total Time: 1035.03247 s)
# Time 0.04167
# --- Preparing time_fixed rhs...... OK (Time: 0.01775 s)
# --- Preparing step debug savers... OK (Time: 0.46193 s)
# --- Starting non-linear solver:
#
# --- Iteration 1
# ------ Computation of cell-wise eta............... OK (Time: 0.12483 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00128 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.85589 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.81461 s)
# ------ Assembling final system.................... OK (Time: 0.00911 s)
# ------ Solving.................................... OK (Time: 0.34327 s)
# --- Iteration time: 93.15068 s
# --- Iteration #001, error L2 relative psi:    0.2928821547
#
# --- Iteration 2
# ------ Computation of cell-wise eta............... OK (Time: 0.12503 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00129 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.84801 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.79706 s)
# ------ Assembling final system.................... OK (Time: 0.0077 s)
# ------ Solving.................................... OK (Time: 0.32781 s)
# --- Iteration time: 93.11044 s
# --- Iteration #002, error L2 relative psi:    0.0291085145
#
# --- Iteration 3
# ------ Computation of cell-wise eta............... OK (Time: 0.12698 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.0018 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.75792 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.53428 s)
# ------ Assembling final system.................... OK (Time: 0.008 s)
# ------ Solving.................................... OK (Time: 0.32655 s)
# --- Iteration time: 92.75869 s
# --- Iteration #003, error L2 relative psi:    0.0019111368
#
# --- Iteration 4
# ------ Computation of cell-wise eta............... OK (Time: 0.12493 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00133 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.81686 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.91257 s)
# ------ Assembling final system.................... OK (Time: 0.00815 s)
# ------ Solving.................................... OK (Time: 0.3212 s)
# --- Iteration time: 93.18755 s
# --- Iteration #004, error L2 relative psi:    0.0011161623
#
# --- Iteration 5
# ------ Computation of cell-wise eta............... OK (Time: 0.12922 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00132 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 26.03019 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 67.03261 s)
# ------ Assembling final system.................... OK (Time: 0.00806 s)
# ------ Solving.................................... OK (Time: 0.34974 s)
# --- Iteration time: 93.55281 s
# --- Iteration #005, error L2 relative psi:    0.0000722006
#
# --- Iteration 6
# ------ Computation of cell-wise eta............... OK (Time: 0.12506 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00246 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.77545 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.70357 s)
# ------ Assembling final system.................... OK (Time: 0.00805 s)
# ------ Solving.................................... OK (Time: 0.36919 s)
# --- Iteration time: 92.98536 s
# --- Iteration #006, error L2 relative psi:    0.0000531919
#
# --- Iteration 7
# ------ Computation of cell-wise eta............... OK (Time: 0.12505 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00134 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.76588 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.67927 s)
# ------ Assembling final system.................... OK (Time: 0.00772 s)
# ------ Solving.................................... OK (Time: 0.30518 s)
# --- Iteration time: 92.88718 s
# --- Iteration #007, error L2 relative psi:    0.0000108721
#
# --- Iteration 8
# ------ Computation of cell-wise eta............... OK (Time: 0.12452 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00129 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.72682 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.44574 s)
# ------ Assembling final system.................... OK (Time: 0.00776 s)
# ------ Solving.................................... OK (Time: 0.34298 s)
# --- Iteration time: 92.65071 s
# --- Iteration #008, error L2 relative psi:    0.0000018852
#
# OK (Total Time: 749.26037 s)
# Time 0.0625
# --- Preparing time_fixed rhs...... OK (Time: 0.01737 s)
# --- Preparing step debug savers... OK (Time: 0.68131 s)
# --- Starting non-linear solver:
#
# --- Iteration 1
# ------ Computation of cell-wise eta............... OK (Time: 0.12737 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00137 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.82922 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.49519 s)
# ------ Assembling final system.................... OK (Time: 0.00766 s)
# ------ Solving.................................... OK (Time: 0.30599 s)
# --- Iteration time: 92.76868 s
# --- Iteration #001, error L2 relative psi:    0.2025533215
#
# --- Iteration 2
# ------ Computation of cell-wise eta............... OK (Time: 0.12521 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00178 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.68517 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.14611 s)
# ------ Assembling final system.................... OK (Time: 0.0078 s)
# ------ Solving.................................... OK (Time: 0.33273 s)
# --- Iteration time: 92.30107 s
# --- Iteration #002, error L2 relative psi:    0.0069423718
#
# --- Iteration 3
# ------ Computation of cell-wise eta............... OK (Time: 0.12461 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00149 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.72783 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.21567 s)
# ------ Assembling final system.................... OK (Time: 0.00777 s)
# ------ Solving.................................... OK (Time: 0.35345 s)
# --- Iteration time: 92.43245 s
# --- Iteration #003, error L2 relative psi:    0.0009718521
#
# --- Iteration 4
# ------ Computation of cell-wise eta............... OK (Time: 0.12849 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00134 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.70937 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.19668 s)
# ------ Assembling final system.................... OK (Time: 0.00784 s)
# ------ Solving.................................... OK (Time: 0.31136 s)
# --- Iteration time: 92.3567 s
# --- Iteration #004, error L2 relative psi:    0.0003836072
#
# --- Iteration 5
# ------ Computation of cell-wise eta............... OK (Time: 0.13211 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00128 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.7736 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.30378 s)
# ------ Assembling final system.................... OK (Time: 0.00771 s)
# ------ Solving.................................... OK (Time: 0.35421 s)
# --- Iteration time: 92.57437 s
# --- Iteration #005, error L2 relative psi:    0.0000243880
#
# --- Iteration 6
# ------ Computation of cell-wise eta............... OK (Time: 0.12465 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.0018 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.90645 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.74493 s)
# ------ Assembling final system.................... OK (Time: 0.008 s)
# ------ Solving.................................... OK (Time: 0.34558 s)
# --- Iteration time: 93.13304 s
# --- Iteration #006, error L2 relative psi:    0.0000131719
#
# --- Iteration 7
# ------ Computation of cell-wise eta............... OK (Time: 0.12591 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00127 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.93659 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.57193 s)
# ------ Assembling final system.................... OK (Time: 0.00826 s)
# ------ Solving.................................... OK (Time: 0.32356 s)
# --- Iteration time: 92.96917 s
# --- Iteration #007, error L2 relative psi:    0.0000024276
#
# OK (Total Time: 653.43574 s)
# Time 0.08333
# --- Preparing time_fixed rhs...... OK (Time: 0.01732 s)
# --- Preparing step debug savers... OK (Time: 0.65405 s)
# --- Starting non-linear solver:
#
# --- Iteration 1
# ------ Computation of cell-wise eta............... OK (Time: 0.12474 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00136 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.81877 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.523 s)
# ------ Assembling final system.................... OK (Time: 0.00791 s)
# ------ Solving.................................... OK (Time: 0.663 s)
# --- Iteration time: 93.14158 s
# --- Iteration #001, error L2 relative psi:    0.1654720914
#
# --- Iteration 2
# ------ Computation of cell-wise eta............... OK (Time: 0.12504 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00129 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.94992 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.25977 s)
# ------ Assembling final system.................... OK (Time: 0.00768 s)
# ------ Solving.................................... OK (Time: 0.33014 s)
# --- Iteration time: 92.67558 s
# --- Iteration #002, error L2 relative psi:    0.0019564941
#
# --- Iteration 3
# ------ Computation of cell-wise eta............... OK (Time: 0.12484 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00126 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.88156 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.45579 s)
# ------ Assembling final system.................... OK (Time: 0.00803 s)
# ------ Solving.................................... OK (Time: 0.33586 s)
# --- Iteration time: 92.80884 s
# --- Iteration #003, error L2 relative psi:    0.0003191737
#
# --- Iteration 4
# ------ Computation of cell-wise eta............... OK (Time: 0.12567 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00126 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.71724 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.91511 s)
# ------ Assembling final system.................... OK (Time: 0.00761 s)
# ------ Solving.................................... OK (Time: 0.3372 s)
# --- Iteration time: 92.10587 s
# --- Iteration #004, error L2 relative psi:    0.0002268554
#
# --- Iteration 5
# ------ Computation of cell-wise eta............... OK (Time: 0.12481 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00136 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.8093 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.1392 s)
# ------ Assembling final system.................... OK (Time: 0.00779 s)
# ------ Solving.................................... OK (Time: 0.34307 s)
# --- Iteration time: 92.42722 s
# --- Iteration #005, error L2 relative psi:    0.0000226896
#
# --- Iteration 6
# ------ Computation of cell-wise eta............... OK (Time: 0.12562 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00127 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.79252 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.09032 s)
# ------ Assembling final system.................... OK (Time: 0.00783 s)
# ------ Solving.................................... OK (Time: 0.33791 s)
# --- Iteration time: 92.35844 s
# --- Iteration #006, error L2 relative psi:    0.0000039360
#
# OK (Total Time: 559.37337 s)
# Time 0.10417
# --- Preparing time_fixed rhs...... OK (Time: 0.01726 s)
# --- Preparing step debug savers... OK (Time: 0.58699 s)
# --- Starting non-linear solver:
#
# --- Iteration 1
# ------ Computation of cell-wise eta............... OK (Time: 0.12475 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00125 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.73834 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.12102 s)
# ------ Assembling final system.................... OK (Time: 0.00796 s)
# ------ Solving.................................... OK (Time: 0.35179 s)
# --- Iteration time: 92.34891 s
# --- Iteration #001, error L2 relative psi:    0.1450985223
#
# --- Iteration 2
# ------ Computation of cell-wise eta............... OK (Time: 0.12584 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00153 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.75518 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.9915 s)
# ------ Assembling final system.................... OK (Time: 0.00787 s)
# ------ Solving.................................... OK (Time: 0.34643 s)
# --- Iteration time: 92.22996 s
# --- Iteration #002, error L2 relative psi:    0.0013889510
#
# --- Iteration 3
# ------ Computation of cell-wise eta............... OK (Time: 0.12684 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00125 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.83211 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.90728 s)
# ------ Assembling final system.................... OK (Time: 0.00764 s)
# ------ Solving.................................... OK (Time: 0.32235 s)
# --- Iteration time: 92.19919 s
# --- Iteration #003, error L2 relative psi:    0.0003070995
#
# --- Iteration 4
# ------ Computation of cell-wise eta............... OK (Time: 0.13318 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00202 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.80615 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.941 s)
# ------ Assembling final system.................... OK (Time: 0.00778 s)
# ------ Solving.................................... OK (Time: 0.32943 s)
# --- Iteration time: 92.22114 s
# --- Iteration #004, error L2 relative psi:    0.0002481460
#
# --- Iteration 5
# ------ Computation of cell-wise eta............... OK (Time: 0.12508 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00126 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.86129 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.13809 s)
# ------ Assembling final system.................... OK (Time: 0.0092 s)
# ------ Solving.................................... OK (Time: 0.35114 s)
# --- Iteration time: 92.48795 s
# --- Iteration #005, error L2 relative psi:    0.0000524172
#
# --- Iteration 6
# ------ Computation of cell-wise eta............... OK (Time: 0.12698 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00191 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.84101 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.01289 s)
# ------ Assembling final system.................... OK (Time: 0.00783 s)
# ------ Solving.................................... OK (Time: 0.3466 s)
# --- Iteration time: 92.33921 s
# --- Iteration #006, error L2 relative psi:    0.0000098708
#
# --- Iteration 7
# ------ Computation of cell-wise eta............... OK (Time: 0.12565 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00128 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.89399 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.12478 s)
# ------ Assembling final system.................... OK (Time: 0.00798 s)
# ------ Solving.................................... OK (Time: 0.41223 s)
# --- Iteration time: 92.56754 s
# --- Iteration #007, error L2 relative psi:    0.0000018252
#
# OK (Total Time: 650.8689 s)
# Time 0.125
# --- Preparing time_fixed rhs...... OK (Time: 0.01768 s)
# --- Preparing step debug savers... OK (Time: 0.48721 s)
# --- Starting non-linear solver:
#
# --- Iteration 1
# ------ Computation of cell-wise eta............... OK (Time: 0.13264 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00218 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.76339 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.06756 s)
# ------ Assembling final system.................... OK (Time: 0.00828 s)
# ------ Solving.................................... OK (Time: 0.35886 s)
# --- Iteration time: 92.33523 s
# --- Iteration #001, error L2 relative psi:    0.1345350542
#
# --- Iteration 2
# ------ Computation of cell-wise eta............... OK (Time: 0.12433 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00122 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.93037 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.02334 s)
# ------ Assembling final system.................... OK (Time: 0.00792 s)
# ------ Solving.................................... OK (Time: 0.36614 s)
# --- Iteration time: 92.45482 s
# --- Iteration #002, error L2 relative psi:    0.0030702371
#
# --- Iteration 3
# ------ Computation of cell-wise eta............... OK (Time: 0.12458 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00222 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.97478 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.05736 s)
# ------ Assembling final system.................... OK (Time: 0.00825 s)
# ------ Solving.................................... OK (Time: 0.35272 s)
# --- Iteration time: 92.52165 s
# --- Iteration #003, error L2 relative psi:    0.0006304753
#
# --- Iteration 4
# ------ Computation of cell-wise eta............... OK (Time: 0.12567 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00122 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.86872 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.03817 s)
# ------ Assembling final system.................... OK (Time: 0.0081 s)
# ------ Solving.................................... OK (Time: 0.35535 s)
# --- Iteration time: 92.3988 s
# --- Iteration #004, error L2 relative psi:    0.0003174536
#
# --- Iteration 5
# ------ Computation of cell-wise eta............... OK (Time: 0.13186 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00123 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.80363 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.79119 s)
# ------ Assembling final system.................... OK (Time: 0.00772 s)
# ------ Solving.................................... OK (Time: 0.34345 s)
# --- Iteration time: 92.08077 s
# --- Iteration #005, error L2 relative psi:    0.0000870763
#
# --- Iteration 6
# ------ Computation of cell-wise eta............... OK (Time: 0.12507 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00206 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.84501 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.89818 s)
# ------ Assembling final system.................... OK (Time: 0.00794 s)
# ------ Solving.................................... OK (Time: 0.32255 s)
# --- Iteration time: 92.20244 s
# --- Iteration #006, error L2 relative psi:    0.0000226149
#
# --- Iteration 7
# ------ Computation of cell-wise eta............... OK (Time: 0.13164 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00123 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.79032 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.78234 s)
# ------ Assembling final system.................... OK (Time: 0.0083 s)
# ------ Solving.................................... OK (Time: 0.3232 s)
# --- Iteration time: 92.03869 s
# --- Iteration #007, error L2 relative psi:    0.0000066523
#
# OK (Total Time: 650.476 s)
# Time 0.14583
# --- Preparing time_fixed rhs...... OK (Time: 0.01749 s)
# --- Preparing step debug savers... OK (Time: 0.44306 s)
# --- Starting non-linear solver:
#
# --- Iteration 1
# ------ Computation of cell-wise eta............... OK (Time: 0.12536 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00123 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.96237 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.05784 s)
# ------ Assembling final system.................... OK (Time: 0.00788 s)
# ------ Solving.................................... OK (Time: 0.34344 s)
# --- Iteration time: 92.50023 s
# --- Iteration #001, error L2 relative psi:    0.1320563220
#
# --- Iteration 2
# ------ Computation of cell-wise eta............... OK (Time: 0.12449 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00121 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.86126 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.90243 s)
# ------ Assembling final system.................... OK (Time: 0.00791 s)
# ------ Solving.................................... OK (Time: 0.35939 s)
# --- Iteration time: 92.25835 s
# --- Iteration #002, error L2 relative psi:    0.0053680455
#
# --- Iteration 3
# ------ Computation of cell-wise eta............... OK (Time: 0.12497 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00223 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 26.00663 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.19461 s)
# ------ Assembling final system.................... OK (Time: 0.00776 s)
# ------ Solving.................................... OK (Time: 0.33421 s)
# --- Iteration time: 92.67497 s
# --- Iteration #003, error L2 relative psi:    0.0009611042
#
# --- Iteration 4
# ------ Computation of cell-wise eta............... OK (Time: 0.12522 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00121 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.94858 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.92345 s)
# ------ Assembling final system.................... OK (Time: 0.00824 s)
# ------ Solving.................................... OK (Time: 0.372 s)
# --- Iteration time: 92.38029 s
# --- Iteration #004, error L2 relative psi:    0.0003484914
#
# --- Iteration 5
# ------ Computation of cell-wise eta............... OK (Time: 0.12529 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00122 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.91041 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.91765 s)
# ------ Assembling final system.................... OK (Time: 0.00806 s)
# ------ Solving.................................... OK (Time: 0.34151 s)
# --- Iteration time: 92.30575 s
# --- Iteration #005, error L2 relative psi:    0.0001029206
#
# --- Iteration 6
# ------ Computation of cell-wise eta............... OK (Time: 0.12514 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00124 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.76825 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.37127 s)
# ------ Assembling final system.................... OK (Time: 0.00813 s)
# ------ Solving.................................... OK (Time: 0.35126 s)
# --- Iteration time: 91.62997 s
# --- Iteration #006, error L2 relative psi:    0.0000317260
#
# --- Iteration 7
# ------ Computation of cell-wise eta............... OK (Time: 0.12445 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00195 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.67621 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.34365 s)
# ------ Assembling final system.................... OK (Time: 0.00769 s)
# ------ Solving.................................... OK (Time: 0.36165 s)
# --- Iteration time: 91.51767 s
# --- Iteration #007, error L2 relative psi:    0.0000115325
#
# --- Iteration 8
# ------ Computation of cell-wise eta............... OK (Time: 0.12485 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00121 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.98393 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.96691 s)
# ------ Assembling final system.................... OK (Time: 0.00946 s)
# ------ Solving.................................... OK (Time: 0.35717 s)
# --- Iteration time: 92.44507 s
# --- Iteration #008, error L2 relative psi:    0.0000043487
#
# OK (Total Time: 742.24927 s)
# Time 0.16667
# --- Preparing time_fixed rhs...... OK (Time: 0.01735 s)
# --- Preparing step debug savers... OK (Time: 0.4202 s)
# --- Starting non-linear solver:
#
# --- Iteration 1
# ------ Computation of cell-wise eta............... OK (Time: 0.12519 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00123 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.80108 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.74771 s)
# ------ Assembling final system.................... OK (Time: 0.00767 s)
# ------ Solving.................................... OK (Time: 0.36199 s)
# --- Iteration time: 92.04699 s
# --- Iteration #001, error L2 relative psi:    0.1368435686
#
# --- Iteration 2
# ------ Computation of cell-wise eta............... OK (Time: 0.1257 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00121 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.79006 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.79612 s)
# ------ Assembling final system.................... OK (Time: 0.0077 s)
# ------ Solving.................................... OK (Time: 0.36027 s)
# --- Iteration time: 92.08262 s
# --- Iteration #002, error L2 relative psi:    0.0078972566
#
# --- Iteration 3
# ------ Computation of cell-wise eta............... OK (Time: 0.1249 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00126 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.79225 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.31834 s)
# ------ Assembling final system.................... OK (Time: 0.00791 s)
# ------ Solving.................................... OK (Time: 0.2998 s)
# --- Iteration time: 91.5479 s
# --- Iteration #003, error L2 relative psi:    0.0011700498
#
# --- Iteration 4
# ------ Computation of cell-wise eta............... OK (Time: 0.12533 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00121 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.85144 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.71078 s)
# ------ Assembling final system.................... OK (Time: 0.00848 s)
# ------ Solving.................................... OK (Time: 0.31312 s)
# --- Iteration time: 92.01213 s
# --- Iteration #004, error L2 relative psi:    0.0003011184
#
# --- Iteration 5
# ------ Computation of cell-wise eta............... OK (Time: 0.12642 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.0012 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.84412 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.73952 s)
# ------ Assembling final system.................... OK (Time: 0.00812 s)
# ------ Solving.................................... OK (Time: 0.35628 s)
# --- Iteration time: 92.07726 s
# --- Iteration #005, error L2 relative psi:    0.0000907902
#
# --- Iteration 6
# ------ Computation of cell-wise eta............... OK (Time: 0.12515 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00204 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.7211 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.5179 s)
# ------ Assembling final system.................... OK (Time: 0.00805 s)
# ------ Solving.................................... OK (Time: 0.36231 s)
# --- Iteration time: 91.73832 s
# --- Iteration #006, error L2 relative psi:    0.0000328587
#
# --- Iteration 7
# ------ Computation of cell-wise eta............... OK (Time: 0.1253 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00124 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.77657 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.59778 s)
# ------ Assembling final system.................... OK (Time: 0.00884 s)
# ------ Solving.................................... OK (Time: 0.36187 s)
# --- Iteration time: 91.87478 s
# --- Iteration #007, error L2 relative psi:    0.0000132477
#
# --- Iteration 8
# ------ Computation of cell-wise eta............... OK (Time: 0.12529 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00128 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.85689 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.75327 s)
# ------ Assembling final system.................... OK (Time: 0.00788 s)
# ------ Solving.................................... OK (Time: 0.36268 s)
# --- Iteration time: 92.10889 s
# --- Iteration #008, error L2 relative psi:    0.0000054611
#
# OK (Total Time: 740.36756 s)
# Time 0.1875
# --- Preparing time_fixed rhs...... OK (Time: 0.0174 s)
# --- Preparing step debug savers... OK (Time: 0.68815 s)
# --- Starting non-linear solver:
#
# --- Iteration 1
# ------ Computation of cell-wise eta............... OK (Time: 0.12492 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00121 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 26.05807 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.87885 s)
# ------ Assembling final system.................... OK (Time: 0.00783 s)
# ------ Solving.................................... OK (Time: 0.392 s)
# --- Iteration time: 92.46474 s
# --- Iteration #001, error L2 relative psi:    0.1471651270
#
# --- Iteration 2
# ------ Computation of cell-wise eta............... OK (Time: 0.12455 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00184 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.89574 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.5187 s)
# ------ Assembling final system.................... OK (Time: 0.00765 s)
# ------ Solving.................................... OK (Time: 0.33738 s)
# --- Iteration time: 91.88748 s
# --- Iteration #002, error L2 relative psi:    0.0100165849
#
# --- Iteration 3
# ------ Computation of cell-wise eta............... OK (Time: 0.12477 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.0012 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.77706 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 65.44468 s)
# ------ Assembling final system.................... OK (Time: 0.00782 s)
# ------ Solving.................................... OK (Time: 0.33052 s)
# --- Iteration time: 91.68769 s
# --- Iteration #003, error L2 relative psi:    0.0011454230
#
# --- Iteration 4
# ------ Computation of cell-wise eta............... OK (Time: 0.12484 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00157 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.82169 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.41504 s)
# ------ Assembling final system.................... OK (Time: 0.00826 s)
# ------ Solving.................................... OK (Time: 0.41936 s)
# --- Iteration time: 92.79254 s
# --- Iteration #004, error L2 relative psi:    0.0001948542
#
# --- Iteration 5
# ------ Computation of cell-wise eta............... OK (Time: 0.12639 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00131 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 25.98633 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 66.14779 s)
# ------ Assembling final system.................... OK (Time: 0.01442 s)
# ------ Solving.................................... OK (Time: 3.69642 s)
# --- Iteration time: 95.97426 s
# --- Iteration #005, error L2 relative psi:    0.0000609819
#
# --- Iteration 6
# ------ Computation of cell-wise eta............... OK (Time: 0.13394 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00183 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 26.30475 s)
# ------ Assembling Richards mass matrix (with K)... OK (Time: 69.28004 s)
# ------ Assembling final system.................... OK (Time: 0.00809 s)
# ------ Solving.................................... OK (Time: 0.41709 s)
# --- Iteration time: 96.14776 s
# --- Iteration #006, error L2 relative psi:    0.0000259864
#
# --- Iteration 7
# ------ Computation of cell-wise eta............... OK (Time: 0.12527 s)
# ------ Assembling rhs for iteration............... OK (Time: 0.00129 s)
# ------ Assembling Darcy mass matrix (with K)...... OK (Time: 27.30775 s)
# ------ Assembling Richards mass matrix (with K)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/richards/tests/coupling_test/actual_coupling/ind_grids.ipynb Cell 70 line 6
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=61'>62</a> print('------ Assembling Richards mass matrix (with K)... ', end='')
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=63'>64</a> tmp_time = time.time()
# ---> <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=64'>65</a> richards_M_u = mass_q(prev[eta_mask], proj_h[1] @ prev[richards_h_mask], darcy=False) # pg.face_mass(mdg, q_field)
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=66'>67</a> print(f'OK (Time: {round(time.time() - tmp_time, 5)} s)')
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=67'>68</a> print('------ Assembling final system.................... ', end='')
#
# /workspaces/richards/tests/coupling_test/actual_coupling/ind_grids.ipynb Cell 70 line 5
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=49'>50</a>     coeff = (int_subdomain.cell_centers[0, c] - boundary_grid.face_centers[0, eta_cell]) / (boundary_grid.face_centers[0, eta_cell+1] - boundary_grid.face_centers[0, eta_cell])
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=50'>51</a>     eta_mean = eta_dofs[eta_cell] * (1 - coeff) + eta_dofs[eta_cell+1] * coeff
# ---> <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=52'>53</a>     local = Richards_local_q(coord_loc, sign[loc], eta_dofs[eta_cell], eta_dofs[eta_cell+1], grad_eta[eta_cell], h_dofs[c]-( (A-eta_mean) * int_subdomain.cell_centers[1, c] + eta_mean))
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=54'>55</a> # Save values for Hdiv-mass local matrix in the global structure
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=55'>56</a> cols = np.concatenate(faces_loc.size * [[faces_loc]])
#
# /workspaces/richards/tests/coupling_test/actual_coupling/ind_grids.ipynb Cell 70 line 1
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>         integrand = lambda ys,x: np.array([q_funcs[j](x,y).T @ K_local(x, y) @ q_funcs[i](x,y) for y in np.array(ys)])
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>         inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
# ---> <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>         M[ordering[i], ordering[j]] = orientation[j] * orientation[i] * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> return M
#
# File /opt/conda/lib/python3.11/site-packages/scipy/integrate/_quadrature.py:155, in fixed_quad(func, a, b, args, n)
#     152     raise ValueError("Gaussian quadrature is only available for "
#     153                      "finite limits.")
#     154 y = (b-a)*(x+1)/2.0 + a
# --> 155 return (b-a)/2.0 * np.sum(w*func(y, *args), axis=-1), None
#
# /workspaces/richards/tests/coupling_test/actual_coupling/ind_grids.ipynb Cell 70 line 1
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     for j in range(3):
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>         integrand = lambda ys,x: np.array([q_funcs[j](x,y).T @ K_local(x, y) @ q_funcs[i](x,y) for y in np.array(ys)])
# ---> <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>         inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>         M[ordering[i], ordering[j]] = orientation[j] * orientation[i] * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> return M
#
# /workspaces/richards/tests/coupling_test/actual_coupling/ind_grids.ipynb Cell 70 line 1
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     for j in range(3):
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>         integrand = lambda ys,x: np.array([q_funcs[j](x,y).T @ K_local(x, y) @ q_funcs[i](x,y) for y in np.array(ys)])
# ---> <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>         inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>         M[ordering[i], ordering[j]] = orientation[j] * orientation[i] * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
#      <a href='vscode-notebook-cell://dev-container%..._test/actual_coupling/ind_grids.ipynb#Y126sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> return M
#
# File /opt/conda/lib/python3.11/site-packages/scipy/integrate/_quadrature.py:155, in fixed_quad(func, a, b, args, n)
#     152     raise ValueError("Gaussian quadrature is only available for "
#     153                      "finite limits.")
#     154 y = (b-a)*(x+1)/2.0 + a
# --> 155 return (b-a)/2.0 * np.sum(w*func(y, *args), axis=-1), None
#
# File <__array_function__ internals>:177, in sum(*args, **kwargs)
#
# KeyboardInterrupt:
