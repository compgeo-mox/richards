# %% [markdown]
# # Darcy equation
#
# In this tutorial we present how to solve an evolutionary Darcy equation with [PyGeoN](https://github.com/compgeo-mox/pygeon).  The unkwons are the velocity $q$ and the pressure $p$.
#
# Let $\Omega=(0,1)^2$ with boundary $\partial \Omega$ and outward unit normal ${\nu}$. Let $(0,T)$ with $10=T>0$ be the overall simulation period. Given
# $k$ the matrix permeability, we want to solve the following problem: find $({q}, p)$ such that
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# k^{-1} {q} + \nabla p = {- \rho g \nabla y}\\
# p_t + \nabla \cdot {q} = f
# \end{array}
# &\text{in } \Omega \times (0,T)
# \end{array}
# \right.
# $$
# with boundary conditions:
# $$ p = 0 \text{ on } \partial_{top} \Omega \times (0,T] \qquad p = \rho g \text{ on } \partial_{bottom} \Omega \times (0,T] \qquad \nu \cdot q = 0 \text{ on } \partial_{left} \Omega \cup \partial_{right} \Omega \times (0,T] $$
# and initial conditions:
# $$ p|_{t=0} = (1-y) \rho g \text{ in } \Omega \qquad q|_{t=0} = 0 \text{ in } \Omega $$
#
# We present *step-by-step* how to create the grid, declare the problem data, and finally solve the problem.

# %% [markdown]
# First we import some of the standard modules, like `numpy` and `scipy.sparse`. Since PyGeoN is based on [PorePy](https://github.com/pmgbergen/porepy) we import both modules.

# %%
# %load_ext Cython

# %%
import shutil
import os

import numpy as np
import scipy.sparse as sps
import scipy.integrate as integrate

import porepy as pp
import pygeon as pg

import sympy as sp

from math import ceil, floor, log10, exp
# Out:
# /opt/conda/lib/python3.11/site-packages/porepy/numerics/nonlinear/nonlinear_solvers.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange  # type: ignore

# %% [markdown]
# For a manual import:
#
# import sys
# sys.path.append('/path/to/repository')

# %%
from utilities.assembly_utilities import find_ordering, experimental_local_A, experimental_local_Mh, transoform_nodal_func_to_physical_element
from richards.model_params import Model_Data

# %% [markdown]
# ### Parameters

# %%
# Set the maximum number of iterations of the non-linear solver
K = 500

# L-scheme parameter
L = 3.501e-2 #0.1

# Set the mesh refinment
N = 10

# Set the number of steps (excluding the initial condition)
num_steps = 27

quad_order = 3

# Simulation time length
T = num_steps/48

# Time switch conditions (for the boundary condition)
dt_D = 3/48

# Fluid density
rho = 1000

# Relative and absolute tolerances for the non-linear solver
abs_tol = 1e-10
rel_tol = 1e-5

# Domain tolerance
domain_tolerance = 1 / (10 * N)

# Output directory
output_directory = 'lagrange_hard_coupling'

# %%
def initial_h(x): return 1

# %%
# Van Genuchten model parameters ( relative permeability model )
model_data = Model_Data(theta_r=0.131, theta_s=0.396, alpha=0.423, n=2.06, K_s=4.96e-2, T=T, num_steps=num_steps)

# %%
# Time step
dt   = (T-0)/num_steps

# %% [markdown]
# ### Mesh

# %%
bottom_grid =   pp.StructuredTriangleGrid([2*N, N], [2, 1])
bottom_grid.compute_geometry()

# %%
top_grid    = pp.StructuredTriangleGrid([2*N, 2*N], [2, 2])
top_grid.compute_geometry()

# %%
boundary_grid, boundary_face_map, boundary_node_map  = pp.partition.extract_subgrid(bottom_grid, 
                                                                                    bottom_grid.face_centers[1, :] == 1, 
                                                                                    faces=True)

# %% [markdown]
# ### Discretization

# %%
key = "flow"

# %%
top_field = pg.Lagrange1(key)
top_data = {}

top_dof =  top_field.ndof( top_grid )

# %%
bottom_field = pg.Lagrange1(key)
bottom_data = {}

bottom_dof = bottom_field.ndof( bottom_grid )

# %%
boundary_field = pg.Lagrange1(key)
boundary_data = {}

boundary_dof = boundary_field.ndof( boundary_grid )

# %% [markdown]
# ### Restrictor Matrices

# %%
bottom_delete_boundary_dof = np.zeros( shape=(bottom_dof - boundary_dof, bottom_dof) )
bottom_delete_boundary_dof[np.arange(bottom_dof - boundary_dof), bottom_grid.nodes[1, :] < 1] = 1
bottom_delete_boundary_dof = sps.csr_matrix(bottom_delete_boundary_dof)

# %%
bottom_isolate_boundary_dof = np.zeros(shape=(boundary_dof, bottom_dof))
bottom_isolate_boundary_dof[np.arange(boundary_dof), bottom_grid.nodes[1, :] == 1] = 1
bottom_isolate_boundary_dof = sps.csr_matrix(bottom_isolate_boundary_dof)

# %%
top_delete_boundary_dof = np.zeros( shape=(top_dof - boundary_dof, top_dof) )
top_delete_boundary_dof[np.arange(top_dof - boundary_dof), top_grid.nodes[1, :] > 0] = 1
top_delete_boundary_dof = sps.csr_matrix(top_delete_boundary_dof)

# %%
top_isolate_boundary_dof = np.zeros(shape=(boundary_dof, top_dof))
top_isolate_boundary_dof[np.arange(boundary_dof), top_grid.nodes[1, :] == 0] = 1
top_isolate_boundary_dof = sps.csr_matrix(top_isolate_boundary_dof)

# %% [markdown]
# ### BCs

# %%
bot_dirichlet_flag  = np.array(np.logical_and( bottom_grid.nodes[0, :] == 2, bottom_grid.nodes[1, :] <= 1 ), dtype=bool)
bot_dirichlet_value = np.array(bot_dirichlet_flag, dtype=float)

# %%
top_dirichlet_flag  = np.array(np.logical_and( top_grid.nodes[1, :] == 2, top_grid.nodes[0, :] <= 1 ), dtype=bool)
top_dirichlet_value = lambda t: np.array(top_dirichlet_flag, dtype=float) * min( 6.2, 1 + 5.2 * t / dt_D )

# %%
dirichlet_flag  = np.hstack(( bot_dirichlet_flag, top_dirichlet_flag, np.zeros(shape=boundary_dof, dtype=bool)))
dirichlet_value = lambda t: np.hstack(( bot_dirichlet_value, top_dirichlet_value(t), np.zeros(shape=boundary_dof, dtype=bool)))

# %% [markdown]
# ### Matrix Assembly

# %% [markdown]
# ##### Projection matrices

# %%
top_proj    = top_field.eval_at_cell_centers( top_grid )
bottom_proj = bottom_field.eval_at_cell_centers( bottom_grid )

# %% [markdown]
# ##### Stifness

# %%
def bottom_stifness_gen():
    size = np.power(bottom_grid.dim + 1, 2) * bottom_grid.num_cells
    rows_I = np.empty(size, dtype=int)
    cols_J = np.empty(size, dtype=int)
    data_IJ = np.empty(size)
    idx = 0

    _, _, _, _, _, node_coords = pp.map_geometry.map_grid(bottom_grid)

    # Allocate the data to store matrix entries, that's the most efficient
    # way to create a sparse matrix.

    cell_nodes = bottom_grid.cell_nodes()

    for c in np.arange(bottom_grid.num_cells):
        # For the current cell retrieve its nodes
        loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

        nodes_loc = cell_nodes.indices[loc]
        coord_loc = node_coords[:, nodes_loc]

        # Compute the stiff-H1 local matrix

        A = experimental_local_A(coord_loc, lambda x,y: model_data.K_s * np.eye(2), quad_order)
        
        # Save values for stiff-H1 local matrix in the global structure
        cols = np.tile(nodes_loc, (nodes_loc.size, 1))

        loc_idx = slice(idx, idx + cols.size)
        rows_I[loc_idx] = cols.T.ravel()
        cols_J[loc_idx] = cols.ravel()
        data_IJ[loc_idx] = A.ravel()
        idx += cols.size

    # Construct the global matrices
    return sps.csc_matrix((data_IJ, (rows_I, cols_J)))

# %%
def top_stifness_gen(h_dofs):
    size = np.power(top_grid.dim + 1, 2) * top_grid.num_cells
    rows_I = np.empty(size, dtype=int)
    cols_J = np.empty(size, dtype=int)
    data_IJ = np.empty(size)
    idx = 0

    _, _, _, _, _, node_coords = pp.map_geometry.map_grid(top_grid)

    # Allocate the data to store matrix entries, that's the most efficient
    # way to create a sparse matrix.

    cell_nodes = top_grid.cell_nodes()

    for c in np.arange(top_grid.num_cells):
        # For the current cell retrieve its nodes
        loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

        nodes_loc = cell_nodes.indices[loc]
        coord_loc = node_coords[:, nodes_loc]

        # Compute the stiff-H1 local matrix

        h_func = transoform_nodal_func_to_physical_element(h_dofs[nodes_loc], coord_loc)
        A = experimental_local_A(coord_loc, lambda x,y: model_data.hydraulic_conductivity_coefficient(h_func(x,y), 1+y) * np.eye(2), quad_order)
        
        # Save values for stiff-H1 local matrix in the global structure
        cols = np.tile(nodes_loc, (nodes_loc.size, 1))

        loc_idx = slice(idx, idx + cols.size)
        rows_I[loc_idx] = cols.T.ravel()
        cols_J[loc_idx] = cols.ravel()
        data_IJ[loc_idx] = A.ravel()
        idx += cols.size

    # Construct the global matrices
    return sps.csc_matrix((data_IJ, (rows_I, cols_J)))

# %% [markdown]
# ##### Mass

# %%
def bottom_mass_gen():
    size = np.power(bottom_grid.dim + 1, 2) * bottom_grid.num_cells
    rows_I = np.empty(size, dtype=int)
    cols_J = np.empty(size, dtype=int)
    data_IJ = np.empty(size)
    idx = 0

    _, _, _, _, _, node_coords = pp.map_geometry.map_grid(bottom_grid)

    # Allocate the data to store matrix entries, that's the most efficient
    # way to create a sparse matrix.

    cell_nodes = bottom_grid.cell_nodes()

    for c in np.arange(bottom_grid.num_cells):
        # For the current cell retrieve its nodes
        loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

        nodes_loc = cell_nodes.indices[loc]
        coord_loc = node_coords[:, nodes_loc]

        # Compute the stiff-H1 local matrix
        A = experimental_local_Mh(coord_loc, lambda x,y: 1, quad_order)

        # Save values for stiff-H1 local matrix in the global structure
        cols = np.tile(nodes_loc, (nodes_loc.size, 1))

        loc_idx = slice(idx, idx + cols.size)
        rows_I[loc_idx] = cols.T.ravel()
        cols_J[loc_idx] = cols.ravel()
        data_IJ[loc_idx] = A.ravel()
        idx += cols.size

    # Construct the global matrices
    return sps.csc_matrix((data_IJ, (rows_I, cols_J)))

# %%
def top_mass_gen():
    size = np.power(top_grid.dim + 1, 2) * top_grid.num_cells
    rows_I = np.empty(size, dtype=int)
    cols_J = np.empty(size, dtype=int)
    data_IJ = np.empty(size)
    idx = 0

    _, _, _, _, _, node_coords = pp.map_geometry.map_grid(top_grid)

    # Allocate the data to store matrix entries, that's the most efficient
    # way to create a sparse matrix.

    cell_nodes = top_grid.cell_nodes()

    for c in np.arange(top_grid.num_cells):
        # For the current cell retrieve its nodes
        loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

        nodes_loc = cell_nodes.indices[loc]
        coord_loc = node_coords[:, nodes_loc]

        # Compute the stiff-H1 local matrix
        A = experimental_local_Mh(coord_loc, lambda x,y: 1, quad_order)

        # Save values for stiff-H1 local matrix in the global structure
        cols = np.tile(nodes_loc, (nodes_loc.size, 1))

        loc_idx = slice(idx, idx + cols.size)
        rows_I[loc_idx] = cols.T.ravel()
        cols_J[loc_idx] = cols.ravel()
        data_IJ[loc_idx] = A.ravel()
        idx += cols.size

    # Construct the global matrices
    return sps.csc_matrix((data_IJ, (rows_I, cols_J)))

# %% [markdown]
# ### Solving stage

# %%
# assemble initial solution
initial_solution = np.zeros(top_dof + bottom_dof + boundary_dof)

# %%
bottom_mask = np.zeros_like(initial_solution, dtype=bool)
bottom_mask[ : (bottom_dof) ] = True

top_mask = np.zeros_like(initial_solution, dtype=bool)
top_mask[(bottom_dof) : (bottom_dof + top_dof)] = True

lambda_mask = np.zeros_like(bottom_mask, dtype=bool)
lambda_mask[(bottom_dof + top_dof):] = True

# %%
initial_solution[top_mask]    =    top_field.interpolate(   top_grid, lambda x: 1)
initial_solution[bottom_mask] = bottom_field.interpolate(bottom_grid, lambda x: 1)

# %%
top_saver    = pp.Exporter(top_grid,    "top_sol", folder_name=output_directory)
bottom_saver = pp.Exporter(bottom_grid, "bottom_sol", folder_name=output_directory)

def save_step(current_sol, step):
    ins = list()

    ins.append((top_grid, "cell_h", top_proj @ current_sol[top_mask]))
    ins.append((top_grid, "cell_p", top_proj @ (current_sol[top_mask] - 1 - top_grid.nodes[1, :])))
    top_saver.write_vtu(ins, time_step=step)

    ins = list()

    ins.append((bottom_grid, "cell_h", bottom_proj @ current_sol[bottom_mask]))
    ins.append((bottom_grid, "cell_p", bottom_proj @ (current_sol[bottom_mask] - bottom_grid.nodes[1, :])))
    bottom_saver.write_vtu(ins, time_step=step)

# %%
if os.path.exists(output_directory):
    shutil.rmtree(output_directory)

# %%
# solve the problem

sol = [initial_solution]

t = 0

save_step(sol[-1], 0)

# %%
csv_base = os.path.join(output_directory, 'csv')

if os.path.exists(csv_base):
    shutil.rmtree(csv_base)
    
os.mkdir(csv_base)

# %%
def bottom_normal_continuity_matrix():
    data = []
    cols = []
    rows = []
    _, _, _, _, _, node_coords = pp.map_geometry.map_grid(bottom_grid)

    # Allocate the data to store matrix entries, that's the most efficient
    # way to create a sparse matrix.

    cell_nodes = bottom_grid.cell_nodes()

    for c in np.arange(bottom_grid.num_cells):
        # For the current cell retrieve its nodes
        loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

        nodes_loc = cell_nodes.indices[loc]
        coord_loc = node_coords[:, nodes_loc]

        if np.abs(np.max(coord_loc[1, :]) - 1) < 1e-7:
            
            ordering, m = find_ordering(coord_loc)

            if m < 0:
                eta_cell = np.max(np.where( boundary_grid.nodes[0, :] < bottom_grid.cell_centers[0, c] ))

                ordered_coords = coord_loc[:, ordering]

                x0 = ordered_coords[:, 0]
                x1 = ordered_coords[:, 1]
                x2 = ordered_coords[:, 2]
                
                q_funcs = [model_data.K_s * np.array([-1/(x2[0] - x0[0]), -1/(x1[1] - x0[1])]), 
                           model_data.K_s * np.array([                 0,  1/(x1[1] - x0[1])]), 
                           model_data.K_s * np.array([ 1/(x2[0] - x0[0]),                  0])]
            
                for i in range(3):
                    rows.append(eta_cell)
                    cols.append(nodes_loc[ ordering[i] ])
                    data.append(q_funcs[i].T @ np.array([0, 1]) * (x2[0] - x0[0]) / 2)

                    rows.append(eta_cell+1)
                    cols.append(nodes_loc[ ordering[i] ])
                    data.append(q_funcs[i].T @ np.array([0, 1]) * (x2[0] - x0[0]) / 2)

    
    return sps.coo_matrix((np.array(data), (np.array(rows), np.array(cols))), shape=(boundary_dof, bottom_grid.num_nodes))

# %%
def top_normal_continuity_matrix(h_dofs):
    data = []
    cols = []
    rows = []
    _, _, _, _, _, node_coords = pp.map_geometry.map_grid(top_grid)

    # Allocate the data to store matrix entries, that's the most efficient
    # way to create a sparse matrix.

    cell_nodes = top_grid.cell_nodes()

    for c in np.arange(top_grid.num_cells):
        # For the current cell retrieve its nodes
        loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

        nodes_loc = cell_nodes.indices[loc]
        coord_loc = node_coords[:, nodes_loc]

        if np.abs(np.min(coord_loc[1, :]) - 0) < 1e-7:
            ordering, m = find_ordering(coord_loc)

            if m > 0:
                eta_cell = np.max(np.where( boundary_grid.nodes[0, :] < top_grid.cell_centers[0, c] ))

                ordered_coords = coord_loc[:, ordering]

                h_ord = h_dofs[nodes_loc][ordering]

                x0 = ordered_coords[:, 0]
                x1 = ordered_coords[:, 1]
                x2 = ordered_coords[:, 2]

                h_mean = (h_ord[0] + h_ord[2]) / 2

                q_funcs = [model_data.hydraulic_conductivity_coefficient(h_mean, 1) * np.array([-1/(x2[0] - x0[0]), -1/(x1[1] - x0[1])]), 
                           model_data.hydraulic_conductivity_coefficient(h_mean, 1) * np.array([                 0,  1/(x1[1] - x0[1])]), 
                           model_data.hydraulic_conductivity_coefficient(h_mean, 1) * np.array([ 1/(x2[0] - x0[0]),                  0])]
            
                for i in range(3):
                    rows.append(eta_cell)
                    cols.append(nodes_loc[ ordering[i] ])
                    data.append(q_funcs[i].T @ np.array([0, 1]) * (x2[0] - x0[0]) / 2)

                    rows.append(eta_cell+1)
                    cols.append(nodes_loc[ ordering[i] ])
                    data.append(q_funcs[i].T @ np.array([0, 1]) * (x2[0] - x0[0]) / 2)

    
    return sps.coo_matrix((np.array(data), (np.array(rows), np.array(cols))), shape=(boundary_dof, top_grid.num_nodes))

# %%
top_mass = top_mass_gen()
bottom_mass_gen = bottom_mass_gen()

# %%
bottom_stifness = bottom_stifness_gen()

# %%
bottom_vel = bottom_normal_continuity_matrix()

# %%
# Time Loop
for step in range(1, ceil(T/dt) + 1):
    current_time = step * dt
    print('Time ' + str(round(current_time, 5)))
    
    time_rhs = np.zeros_like(sol[-1])

    time_rhs[top_mask] += top_mass @ model_data.theta(sol[-1][top_mask], 1 + top_grid.nodes[1,:]) / dt

    prev = sol[-1]

    for k in range(K):
        rhs = time_rhs.copy()

        rhs[top_mask] += L * top_mass @ prev[top_mask] / dt
        rhs[top_mask] -= top_mass @ model_data.theta(prev[top_mask], 1 + top_grid.nodes[1,:]) / dt

        bottom_mat = bottom_stifness
        top_stifness = top_stifness_gen(prev[top_mask])

        top_mat = top_stifness + L / dt * top_mass
        top_vel = top_normal_continuity_matrix(prev[top_mask])

        spp = sps.bmat([[                 bottom_mat,                      None, bottom_isolate_boundary_dof.T],
                        [                       None,                   top_mat,   -top_isolate_boundary_dof.T],
                        [bottom_isolate_boundary_dof, -top_isolate_boundary_dof,                          None]], format='csc')
        
        ls = pg.LinearSystem(spp, rhs)

        #print(spp, rhs)

        ls.flag_ess_bc(dirichlet_flag, dirichlet_value(current_time))

        current = ls.solve()

        # Check if we have reached convergence
        rel_err_psi  = np.sqrt( (current - prev).T @ (current - prev) )
        abs_err_prev = np.sqrt( prev.T @ prev )

        # Log message with error and current iteration
        print('Iteration #' + format(k+1, '0' + str(ceil(log10(K)) + 1) + 'd') + ', error L2 relative psi: ' 
              + format(rel_err_psi, str(5 + ceil(log10(1 / abs_tol)) + 4) + '.' + str(ceil(log10(1 / abs_tol)) + 4) + 'f') )
        
        if rel_err_psi > abs_tol + rel_tol * abs_err_prev:
            prev = current.copy()
        else:
            break

    sol.append( current )

    save_step(sol[-1], step)
    print('')
# Out:
# Time 0.02083
# Iteration #0001, error L2 relative psi:    5.81082990976450
# <lambdifygenerated-1>:2: RuntimeWarning: invalid value encountered in power
#   return select([less(h, z),True], [0.265*(0.1699265174169*(-h + z)**2.06 + 1)**(-0.514563106796116) + 0.131,0.396], default=nan)
# <lambdifygenerated-2>:2: RuntimeWarning: invalid value encountered in scalar power
#   return select([less(h, z),True], [0.0496*(1 - (1 - 1.0*(0.1699265174169*(-h + z)**2.06 + 1)**(-1.0))**0.514563106796116)**2*(0.1699265174169*(-h + z)**2.06 + 1)**(-0.257281553398058),0.0496], default=nan)
# Iteration #0002, error L2 relative psi:    1.85220640097616
# Iteration #0003, error L2 relative psi:    0.27731022909162
# Iteration #0004, error L2 relative psi:    0.01844888899250
# Iteration #0005, error L2 relative psi:    0.00339835609219
# Iteration #0006, error L2 relative psi:    0.00049269964707
# Iteration #0007, error L2 relative psi:    0.00004047629196
#
# Time 0.04167
# Iteration #0001, error L2 relative psi:    7.50744633618925
# Iteration #0002, error L2 relative psi:    2.75617895132764
# Iteration #0003, error L2 relative psi:    0.94191865636499
# Iteration #0004, error L2 relative psi:    0.21402123241571
# Iteration #0005, error L2 relative psi:    0.07967841800755
# Iteration #0006, error L2 relative psi:    0.02452486856682
# Iteration #0007, error L2 relative psi:    0.00558836153812
# Iteration #0008, error L2 relative psi:    0.00198684563946
# Iteration #0009, error L2 relative psi:    0.00051285066009
# Iteration #0010, error L2 relative psi:    0.00014826896506
#
# Time 0.0625
# Iteration #0001, error L2 relative psi:    9.15242173780647
# Iteration #0002, error L2 relative psi:    2.70887893880741
# Iteration #0003, error L2 relative psi:    1.02857444124602
# Iteration #0004, error L2 relative psi:    0.32642301028955
# Iteration #0005, error L2 relative psi:    0.09032540840319
# Iteration #0006, error L2 relative psi:    0.02731523802007
# Iteration #0007, error L2 relative psi:    0.01168162940836
# Iteration #0008, error L2 relative psi:    0.00528761493247
# Iteration #0009, error L2 relative psi:    0.00224436468232
# Iteration #0010, error L2 relative psi:    0.00090605030215
# Iteration #0011, error L2 relative psi:    0.00036368944026
#
# Time 0.08333
# Iteration #0001, error L2 relative psi:    3.78485483968117
# Iteration #0002, error L2 relative psi:    1.45941220212114
# Iteration #0003, error L2 relative psi:    0.66724095090836
# Iteration #0004, error L2 relative psi:    0.33108822298549
# Iteration #0005, error L2 relative psi:    0.18081426451219
# Iteration #0006, error L2 relative psi:    0.10454812346311
# Iteration #0007, error L2 relative psi:    0.06143099198384
# Iteration #0008, error L2 relative psi:    0.03614615713508
# Iteration #0009, error L2 relative psi:    0.02126575436476
# Iteration #0010, error L2 relative psi:    0.01251519640644
# Iteration #0011, error L2 relative psi:    0.00736722810563
# Iteration #0012, error L2 relative psi:    0.00433693196872
# Iteration #0013, error L2 relative psi:    0.00255324904552
# Iteration #0014, error L2 relative psi:    0.00150338530126
# Iteration #0015, error L2 relative psi:    0.00088528756880
# Iteration #0016, error L2 relative psi:    0.00052131254596
# Iteration #0017, error L2 relative psi:    0.00030697461748
#
# Time 0.10417
# Iteration #0001, error L2 relative psi:    2.73421051970399
# Iteration #0002, error L2 relative psi:    1.02346390887633
# Iteration #0003, error L2 relative psi:    0.54213816288433
# Iteration #0004, error L2 relative psi:    0.33428159789400
# Iteration #0005, error L2 relative psi:    0.22166268779028
# Iteration #0006, error L2 relative psi:    0.15118363832014
# Iteration #0007, error L2 relative psi:    0.10416848957160
# Iteration #0008, error L2 relative psi:    0.07206698973681
# Iteration #0009, error L2 relative psi:    0.04997466033673
# Iteration #0010, error L2 relative psi:    0.03470130272422
# Iteration #0011, error L2 relative psi:    0.02411273339288
# Iteration #0012, error L2 relative psi:    0.01676066821583
# Iteration #0013, error L2 relative psi:    0.01165206694182
# Iteration #0014, error L2 relative psi:    0.00810138130960
# Iteration #0015, error L2 relative psi:    0.00563383163278
# Iteration #0016, error L2 relative psi:    0.00391837416723
# Iteration #0017, error L2 relative psi:    0.00272541326304
# Iteration #0018, error L2 relative psi:    0.00189566182900
# Iteration #0019, error L2 relative psi:    0.00131851339391
# Iteration #0020, error L2 relative psi:    0.00091707098925
# Iteration #0021, error L2 relative psi:    0.00063784819545
# Iteration #0022, error L2 relative psi:    0.00044363823028
#
# Time 0.125
# Iteration #0001, error L2 relative psi:    2.17104802831782
# Iteration #0002, error L2 relative psi:    0.81765411721128
# Iteration #0003, error L2 relative psi:    0.47846620725584
# Iteration #0004, error L2 relative psi:    0.32716198803576
# Iteration #0005, error L2 relative psi:    0.23834037288427
# Iteration #0006, error L2 relative psi:    0.17804975825445
# Iteration #0007, error L2 relative psi:    0.13452677450767
# Iteration #0008, error L2 relative psi:    0.10223270762569
# Iteration #0009, error L2 relative psi:    0.07794837133739
# Iteration #0010, error L2 relative psi:    0.05954560876165
# Iteration #0011, error L2 relative psi:    0.04553548933339
# Iteration #0012, error L2 relative psi:    0.03484758872410
# Iteration #0013, error L2 relative psi:    0.02668678060392
# Iteration #0014, error L2 relative psi:    0.02044557331854
# Iteration #0015, error L2 relative psi:    0.01566791349145
# Iteration #0016, error L2 relative psi:    0.01200825698574
# Iteration #0017, error L2 relative psi:    0.00920476354157
# Iteration #0018, error L2 relative psi:    0.00705631352153
# Iteration #0019, error L2 relative psi:    0.00540957057446
# Iteration #0020, error L2 relative psi:    0.00414725751125
# Iteration #0021, error L2 relative psi:    0.00317956555427
# Iteration #0022, error L2 relative psi:    0.00243769210115
# Iteration #0023, error L2 relative psi:    0.00186892757155
# Iteration #0024, error L2 relative psi:    0.00143288004459
# Iteration #0025, error L2 relative psi:    0.00109858044195
# Iteration #0026, error L2 relative psi:    0.00084229447558
# Iteration #0027, error L2 relative psi:    0.00064581008596
# Iteration #0028, error L2 relative psi:    0.00049516495994
#
# Time 0.14583
# Iteration #0001, error L2 relative psi:    1.80237444387516
# Iteration #0002, error L2 relative psi:    0.71503372110121
# Iteration #0003, error L2 relative psi:    0.45695076802631
# Iteration #0004, error L2 relative psi:    0.33643266612015
# Iteration #0005, error L2 relative psi:    0.26250980527526
# Iteration #0006, error L2 relative psi:    0.21014212808342
# Iteration #0007, error L2 relative psi:    0.17037005502452
# Iteration #0008, error L2 relative psi:    0.13906608978723
# Iteration #0009, error L2 relative psi:    0.11397302675138
# Iteration #0010, error L2 relative psi:    0.09363476091512
# Iteration #0011, error L2 relative psi:    0.07706758902720
# Iteration #0012, error L2 relative psi:    0.06352199147533
# Iteration #0013, error L2 relative psi:    0.05241474949487
# Iteration #0014, error L2 relative psi:    0.04328394206505
# Iteration #0015, error L2 relative psi:    0.03576638496833
# Iteration #0016, error L2 relative psi:    0.02956896224587
# Iteration #0017, error L2 relative psi:    0.02445500716998
# Iteration #0018, error L2 relative psi:    0.02023212670019
# Iteration #0019, error L2 relative psi:    0.01674204744484
# Iteration #0020, error L2 relative psi:    0.01385629380672
# Iteration #0021, error L2 relative psi:    0.01146971196713
# Iteration #0022, error L2 relative psi:    0.00949511910573
# Iteration #0023, error L2 relative psi:    0.00786077629730
# Iteration #0024, error L2 relative psi:    0.00650782676873
# Iteration #0025, error L2 relative psi:    0.00538772212387
# Iteration #0026, error L2 relative psi:    0.00446039006334
# Iteration #0027, error L2 relative psi:    0.00369262977149
# Iteration #0028, error L2 relative psi:    0.00305701523264
# Iteration #0029, error L2 relative psi:    0.00253074228033
# Iteration #0030, error L2 relative psi:    0.00209500248788
# Iteration #0031, error L2 relative psi:    0.00173422642520
# Iteration #0032, error L2 relative psi:    0.00143553011924
# Iteration #0033, error L2 relative psi:    0.00118824773941
# Iteration #0034, error L2 relative psi:    0.00098355949216
# Iteration #0035, error L2 relative psi:    0.00081411355805
# Iteration #0036, error L2 relative psi:    0.00067384221132
# Iteration #0037, error L2 relative psi:    0.00055772412379
# Iteration #0038, error L2 relative psi:    0.00046160313770
#
# Time 0.16667
# Iteration #0001, error L2 relative psi:    1.53889559482651
# Iteration #0002, error L2 relative psi:    0.68302849736482
# Iteration #0003, error L2 relative psi:    0.51527794017437
# Iteration #0004, error L2 relative psi:    0.43698024295967
# Iteration #0005, error L2 relative psi:    0.38693996488285
# Iteration #0006, error L2 relative psi:    0.34888789145183
# Iteration #0007, error L2 relative psi:    0.31737273329783
# Iteration #0008, error L2 relative psi:    0.28992490272383
# Iteration #0009, error L2 relative psi:    0.26539943911470
# Iteration #0010, error L2 relative psi:    0.24333762971670
# Iteration #0011, error L2 relative psi:    0.22344601760747
# Iteration #0012, error L2 relative psi:    0.20546768056841
# Iteration #0013, error L2 relative psi:    0.18916785102468
# Iteration #0014, error L2 relative psi:    0.17433005249508
# Iteration #0015, error L2 relative psi:    0.16078904785249
# Iteration #0016, error L2 relative psi:    0.14840956491973
# Iteration #0017, error L2 relative psi:    0.13706798070171
# Iteration #0018, error L2 relative psi:    0.12665720107372
# Iteration #0019, error L2 relative psi:    0.11708749324265
# Iteration #0020, error L2 relative psi:    0.10828052997319
# Iteration #0021, error L2 relative psi:    0.10016813179258
# Iteration #0022, error L2 relative psi:    0.09268985978787
# Iteration #0023, error L2 relative psi:    0.08579127835917
# Iteration #0024, error L2 relative psi:    0.07942433662527
# Iteration #0025, error L2 relative psi:    0.07354400444145
# Iteration #0026, error L2 relative psi:    0.06811053164156
# Iteration #0027, error L2 relative psi:    0.06308678633898
# Iteration #0028, error L2 relative psi:    0.05843967766838
# Iteration #0029, error L2 relative psi:    0.05414030674356
# Iteration #0030, error L2 relative psi:    0.05016227940174
# Iteration #0031, error L2 relative psi:    0.04648088761520
# Iteration #0032, error L2 relative psi:    0.04307342012709
# Iteration #0033, error L2 relative psi:    0.03991912664197
# Iteration #0034, error L2 relative psi:    0.03699896149404
# Iteration #0035, error L2 relative psi:    0.03429499909371
# Iteration #0036, error L2 relative psi:    0.03179093920231
# Iteration #0037, error L2 relative psi:    0.02947156168756
# Iteration #0038, error L2 relative psi:    0.02732287365432
# Iteration #0039, error L2 relative psi:    0.02533214764520
# Iteration #0040, error L2 relative psi:    0.02348765020713
# Iteration #0041, error L2 relative psi:    0.02177853008719
# Iteration #0042, error L2 relative psi:    0.02019487844481
# Iteration #0043, error L2 relative psi:    0.01872725563791
# Iteration #0044, error L2 relative psi:    0.01736699356128
# Iteration #0045, error L2 relative psi:    0.01610613987344
# Iteration #0046, error L2 relative psi:    0.01493730379452
# Iteration #0047, error L2 relative psi:    0.01385368305229
# Iteration #0048, error L2 relative psi:    0.01284899856239
# Iteration #0049, error L2 relative psi:    0.01191745144026
# Iteration #0050, error L2 relative psi:    0.01105369384098
# Iteration #0051, error L2 relative psi:    0.01025279561008
# Iteration #0052, error L2 relative psi:    0.00951011328931
# Iteration #0053, error L2 relative psi:    0.00882137663706
# Iteration #0054, error L2 relative psi:    0.00818264256100
# Iteration #0055, error L2 relative psi:    0.00759026855273
# Iteration #0056, error L2 relative psi:    0.00704088892308
# Iteration #0057, error L2 relative psi:    0.00653136385112
# Iteration #0058, error L2 relative psi:    0.00605878233504
# Iteration #0059, error L2 relative psi:    0.00562045260311
# Iteration #0060, error L2 relative psi:    0.00521388955213
# Iteration #0061, error L2 relative psi:    0.00483678165794
# Iteration #0062, error L2 relative psi:    0.00448699224252
# Iteration #0063, error L2 relative psi:    0.00416254287849
# Iteration #0064, error L2 relative psi:    0.00386159215603
# Iteration #0065, error L2 relative psi:    0.00358243016943
# Iteration #0066, error L2 relative psi:    0.00332347718447
# Iteration #0067, error L2 relative psi:    0.00308326725547
# Iteration #0068, error L2 relative psi:    0.00286043989601
# Iteration #0069, error L2 relative psi:    0.00265373355130
# Iteration #0070, error L2 relative psi:    0.00246197880464
# Iteration #0071, error L2 relative psi:    0.00228409166527
# Iteration #0072, error L2 relative psi:    0.00211906723152
# Iteration #0073, error L2 relative psi:    0.00196597381457
# Iteration #0074, error L2 relative psi:    0.00182394751683
# Iteration #0075, error L2 relative psi:    0.00169218723181
# Iteration #0076, error L2 relative psi:    0.00156995002921
# Iteration #0077, error L2 relative psi:    0.00145654688910
# Iteration #0078, error L2 relative psi:    0.00135133863504
# Iteration #0079, error L2 relative psi:    0.00125373200027
# Iteration #0080, error L2 relative psi:    0.00116317750303
# Iteration #0081, error L2 relative psi:    0.00107916705550
# Iteration #0082, error L2 relative psi:    0.00100122801089
# Iteration #0083, error L2 relative psi:    0.00092892113575
# Iteration #0084, error L2 relative psi:    0.00086183881550
# Iteration #0085, error L2 relative psi:    0.00079960300035
# Iteration #0086, error L2 relative psi:    0.00074186310656
# Iteration #0087, error L2 relative psi:    0.00068829400993
# Iteration #0088, error L2 relative psi:    0.00063859417539
# Iteration #0089, error L2 relative psi:    0.00059248392602
# Iteration #0090, error L2 relative psi:    0.00054970384381
#
# Time 0.1875
# Iteration #0001, error L2 relative psi:    1.34835795824727
# Iteration #0002, error L2 relative psi:    0.62250329742152
# Iteration #0003, error L2 relative psi:    0.52389924673754
# Iteration #0004, error L2 relative psi:    0.48046550788103
# Iteration #0005, error L2 relative psi:    0.44942670110750
# Iteration #0006, error L2 relative psi:    0.42227597701784
# Iteration #0007, error L2 relative psi:    0.39713268040646
# Iteration #0008, error L2 relative psi:    0.37350860951062
# Iteration #0009, error L2 relative psi:    0.35128389578142
# Iteration #0010, error L2 relative psi:    0.33041337326011
# Iteration #0011, error L2 relative psi:    0.31083610280375
# Iteration #0012, error L2 relative psi:    0.29247968128616
# Iteration #0013, error L2 relative psi:    0.27527363087910
# Iteration #0014, error L2 relative psi:    0.25914412166265
# Iteration #0015, error L2 relative psi:    0.24401802829396
# Iteration #0016, error L2 relative psi:    0.22982831093647
# Iteration #0017, error L2 relative psi:    0.21651176724411
# Iteration #0018, error L2 relative psi:    0.20400832376425
# Iteration #0019, error L2 relative psi:    0.19226531613881
# Iteration #0020, error L2 relative psi:    0.18123231969458
# Iteration #0021, error L2 relative psi:    0.17086163396451
# Iteration #0022, error L2 relative psi:    0.16111055757841
# Iteration #0023, error L2 relative psi:    0.15193852786772
# Iteration #0024, error L2 relative psi:    0.14330706535060
# Iteration #0025, error L2 relative psi:    0.13518145930656
# Iteration #0026, error L2 relative psi:    0.12752992058441
# Iteration #0027, error L2 relative psi:    0.12032263108609
# Iteration #0028, error L2 relative psi:    0.11353284929551
# Iteration #0029, error L2 relative psi:    0.10713500524986
# Iteration #0030, error L2 relative psi:    0.10110467500790
# Iteration #0031, error L2 relative psi:    0.09542004538269
# Iteration #0032, error L2 relative psi:    0.09006088561861
# Iteration #0033, error L2 relative psi:    0.08500796679202
# Iteration #0034, error L2 relative psi:    0.08024315768442
# Iteration #0035, error L2 relative psi:    0.07575001290519
# Iteration #0036, error L2 relative psi:    0.07151199439743
# Iteration #0037, error L2 relative psi:    0.06751432447870
# Iteration #0038, error L2 relative psi:    0.06374289472776
# Iteration #0039, error L2 relative psi:    0.06018460418394
# Iteration #0040, error L2 relative psi:    0.05682703616696
# Iteration #0041, error L2 relative psi:    0.05365868466721
# Iteration #0042, error L2 relative psi:    0.05066885413427
# Iteration #0043, error L2 relative psi:    0.04784721232093
# Iteration #0044, error L2 relative psi:    0.04518399692526
# Iteration #0045, error L2 relative psi:    0.04267009703599
# Iteration #0046, error L2 relative psi:    0.04029697098871
# Iteration #0047, error L2 relative psi:    0.03805660219177
# Iteration #0048, error L2 relative psi:    0.03594145377282
# Iteration #0049, error L2 relative psi:    0.03394444757279
# Iteration #0050, error L2 relative psi:    0.03205897576020
# Iteration #0051, error L2 relative psi:    0.03027877371310
# Iteration #0052, error L2 relative psi:    0.02859784440111
# Iteration #0053, error L2 relative psi:    0.02701060176298
# Iteration #0054, error L2 relative psi:    0.02551177188119
# Iteration #0055, error L2 relative psi:    0.02409636805476
# Iteration #0056, error L2 relative psi:    0.02275969905084
# Iteration #0057, error L2 relative psi:    0.02149737216675
# Iteration #0058, error L2 relative psi:    0.02030522363837
# Iteration #0059, error L2 relative psi:    0.01917938527623
# Iteration #0060, error L2 relative psi:    0.01811610387124
# Iteration #0061, error L2 relative psi:    0.01711188708416
# Iteration #0062, error L2 relative psi:    0.01616344090810
# Iteration #0063, error L2 relative psi:    0.01526765603883
# Iteration #0064, error L2 relative psi:    0.01442159770366
# Iteration #0065, error L2 relative psi:    0.01362249644825
# Iteration #0066, error L2 relative psi:    0.01286775200484
# Iteration #0067, error L2 relative psi:    0.01215490450374
# Iteration #0068, error L2 relative psi:    0.01148161897158
# Iteration #0069, error L2 relative psi:    0.01084569627328
# Iteration #0070, error L2 relative psi:    0.01024505025451
# Iteration #0071, error L2 relative psi:    0.00967772596380
# Iteration #0072, error L2 relative psi:    0.00914186122430
# Iteration #0073, error L2 relative psi:    0.00863569974619
# Iteration #0074, error L2 relative psi:    0.00815759118621
# Iteration #0075, error L2 relative psi:    0.00770597777331
# Iteration #0076, error L2 relative psi:    0.00727938806842
# Iteration #0077, error L2 relative psi:    0.00687643914166
# Iteration #0078, error L2 relative psi:    0.00649582107138
# Iteration #0079, error L2 relative psi:    0.00613628944235
# Iteration #0080, error L2 relative psi:    0.00579668148600
# Iteration #0081, error L2 relative psi:    0.00547588769419
# Iteration #0082, error L2 relative psi:    0.00517285822370
# Iteration #0083, error L2 relative psi:    0.00488660658496
# Iteration #0084, error L2 relative psi:    0.00461620255067
# Iteration #0085, error L2 relative psi:    0.00436076792330
# Iteration #0086, error L2 relative psi:    0.00411947333208
# Iteration #0087, error L2 relative psi:    0.00389153544858
# Iteration #0088, error L2 relative psi:    0.00367621441174
# Iteration #0089, error L2 relative psi:    0.00347281140995
# Iteration #0090, error L2 relative psi:    0.00328066640377
# Iteration #0091, error L2 relative psi:    0.00309915598839
# Iteration #0092, error L2 relative psi:    0.00292769143916
# Iteration #0093, error L2 relative psi:    0.00276572130485
# Iteration #0094, error L2 relative psi:    0.00261271873699
# Iteration #0095, error L2 relative psi:    0.00246818447709
# Iteration #0096, error L2 relative psi:    0.00233164893604
# Iteration #0097, error L2 relative psi:    0.00220266874610
# Iteration #0098, error L2 relative psi:    0.00208082530999
# Iteration #0099, error L2 relative psi:    0.00196572336786
# Iteration #0100, error L2 relative psi:    0.00185698965052
# Iteration #0101, error L2 relative psi:    0.00175427162328
# Iteration #0102, error L2 relative psi:    0.00165723631261
# Iteration #0103, error L2 relative psi:    0.00156556920691
# Iteration #0104, error L2 relative psi:    0.00147897322377
# Iteration #0105, error L2 relative psi:    0.00139716773822
# Iteration #0106, error L2 relative psi:    0.00131988766713
# Iteration #0107, error L2 relative psi:    0.00124688260569
# Iteration #0108, error L2 relative psi:    0.00117791601273
# Iteration #0109, error L2 relative psi:    0.00111276444184
# Iteration #0110, error L2 relative psi:    0.00105121681533
# Iteration #0111, error L2 relative psi:    0.00099307373877
# Iteration #0112, error L2 relative psi:    0.00093814685375
# Iteration #0113, error L2 relative psi:    0.00088625822648
# Iteration #0114, error L2 relative psi:    0.00083723977042
# Iteration #0115, error L2 relative psi:    0.00079093270092
# Iteration #0116, error L2 relative psi:    0.00074718702026
# Iteration #0117, error L2 relative psi:    0.00070586103097
# Iteration #0118, error L2 relative psi:    0.00066682087637
# Iteration #0119, error L2 relative psi:    0.00062994010649
#
# Time 0.20833
# Iteration #0001, error L2 relative psi:    1.26543523276068
# Iteration #0002, error L2 relative psi:    0.47435767735705
# Iteration #0003, error L2 relative psi:    0.34151529306461
# Iteration #0004, error L2 relative psi:    0.28072020500864
# Iteration #0005, error L2 relative psi:    0.24440371578750
# Iteration #0006, error L2 relative psi:    0.21906895199596
# Iteration #0007, error L2 relative psi:    0.19991885733984
# Iteration #0008, error L2 relative psi:    0.18464950349321
# Iteration #0009, error L2 relative psi:    0.17198442108836
# Iteration #0010, error L2 relative psi:    0.16114325716983
# Iteration #0011, error L2 relative psi:    0.15161924860173
# Iteration #0012, error L2 relative psi:    0.14307858956342
# Iteration #0013, error L2 relative psi:    0.13529624113194
# Iteration #0014, error L2 relative psi:    0.12811981120853
# Iteration #0015, error L2 relative psi:    0.12144456770463
# Iteration #0016, error L2 relative psi:    0.11519607817785
# Iteration #0017, error L2 relative psi:    0.10932012895532
# Iteration #0018, error L2 relative psi:    0.10377741008121
# Iteration #0019, error L2 relative psi:    0.09853821640022
# Iteration #0020, error L2 relative psi:    0.09357878090275
# Iteration #0021, error L2 relative psi:    0.08887958260262
# Iteration #0022, error L2 relative psi:    0.08442393779375
# Iteration #0023, error L2 relative psi:    0.08019686459366
# Iteration #0024, error L2 relative psi:    0.07618542433707
# Iteration #0025, error L2 relative psi:    0.07237776216735
# Iteration #0026, error L2 relative psi:    0.06876280544720
# Iteration #0027, error L2 relative psi:    0.06533032960697
# Iteration #0028, error L2 relative psi:    0.06207082058612
# Iteration #0029, error L2 relative psi:    0.05897538427661
# Iteration #0030, error L2 relative psi:    0.05603561948342
# Iteration #0031, error L2 relative psi:    0.05324371124546
# Iteration #0032, error L2 relative psi:    0.05059206625987
# Iteration #0033, error L2 relative psi:    0.04807343992235
# Iteration #0034, error L2 relative psi:    0.04568100988525
# Iteration #0035, error L2 relative psi:    0.04340837814616
# Iteration #0036, error L2 relative psi:    0.04124944522593
# Iteration #0037, error L2 relative psi:    0.03919845029677
# Iteration #0038, error L2 relative psi:    0.03725003194651
# Iteration #0039, error L2 relative psi:    0.03539899753213
# Iteration #0040, error L2 relative psi:    0.03364037563982
# Iteration #0041, error L2 relative psi:    0.03196950283273
# Iteration #0042, error L2 relative psi:    0.03038196130796
# Iteration #0043, error L2 relative psi:    0.02887355154693
# Iteration #0044, error L2 relative psi:    0.02744031598669
# Iteration #0045, error L2 relative psi:    0.02607847516660
# Iteration #0046, error L2 relative psi:    0.02478443091540
# Iteration #0047, error L2 relative psi:    0.02355478354939
# Iteration #0048, error L2 relative psi:    0.02238630950609
# Iteration #0049, error L2 relative psi:    0.02127598698140
# Iteration #0050, error L2 relative psi:    0.02022089972564
# Iteration #0051, error L2 relative psi:    0.01921828675939
# Iteration #0052, error L2 relative psi:    0.01826550607880
# Iteration #0053, error L2 relative psi:    0.01736008308032
# Iteration #0054, error L2 relative psi:    0.01649963145105
# Iteration #0055, error L2 relative psi:    0.01568190387919
# Iteration #0056, error L2 relative psi:    0.01490476851149
# Iteration #0057, error L2 relative psi:    0.01416621164936
# Iteration #0058, error L2 relative psi:    0.01346431003289
# Iteration #0059, error L2 relative psi:    0.01279723772056
# Iteration #0060, error L2 relative psi:    0.01216326875508
# Iteration #0061, error L2 relative psi:    0.01156074709306
# Iteration #0062, error L2 relative psi:    0.01098810646175
# Iteration #0063, error L2 relative psi:    0.01044386018087
# Iteration #0064, error L2 relative psi:    0.00992659666808
# Iteration #0065, error L2 relative psi:    0.00943497522220
# Iteration #0066, error L2 relative psi:    0.00896772225625
# Iteration #0067, error L2 relative psi:    0.00852362888608
# Iteration #0068, error L2 relative psi:    0.00810154851517
# Iteration #0069, error L2 relative psi:    0.00770038471555
# Iteration #0070, error L2 relative psi:    0.00731909848154
# Iteration #0071, error L2 relative psi:    0.00695670341365
# Iteration #0072, error L2 relative psi:    0.00661226250345
# Iteration #0073, error L2 relative psi:    0.00628488559677
# Iteration #0074, error L2 relative psi:    0.00597373468823
# Iteration #0075, error L2 relative psi:    0.00567800323561
# Iteration #0076, error L2 relative psi:    0.00539692245215
# Iteration #0077, error L2 relative psi:    0.00512976431769
# Iteration #0078, error L2 relative psi:    0.00487583774342
# Iteration #0079, error L2 relative psi:    0.00463448635327
# Iteration #0080, error L2 relative psi:    0.00440508659510
# Iteration #0081, error L2 relative psi:    0.00418704601187
# Iteration #0082, error L2 relative psi:    0.00397980163696
# Iteration #0083, error L2 relative psi:    0.00378281849275
# Iteration #0084, error L2 relative psi:    0.00359558817884
# Iteration #0085, error L2 relative psi:    0.00341762754123
# Iteration #0086, error L2 relative psi:    0.00324847742259
# Iteration #0087, error L2 relative psi:    0.00308770189841
# Iteration #0088, error L2 relative psi:    0.00293488833671
# Iteration #0089, error L2 relative psi:    0.00278963997021
# Iteration #0090, error L2 relative psi:    0.00265158159437
# Iteration #0091, error L2 relative psi:    0.00252035703217
# Iteration #0092, error L2 relative psi:    0.00239562788492
# Iteration #0093, error L2 relative psi:    0.00227707254462
# Iteration #0094, error L2 relative psi:    0.00216438533787
# Iteration #0095, error L2 relative psi:    0.00205727573276
# Iteration #0096, error L2 relative psi:    0.00195546758911
# Iteration #0097, error L2 relative psi:    0.00185869844683
# Iteration #0098, error L2 relative psi:    0.00176671884986
# Iteration #0099, error L2 relative psi:    0.00167929170628
# Iteration #0100, error L2 relative psi:    0.00159619168888
# Iteration #0101, error L2 relative psi:    0.00151720480570
# Iteration #0102, error L2 relative psi:    0.00144213048892
# Iteration #0103, error L2 relative psi:    0.00137077206816
# Iteration #0104, error L2 relative psi:    0.00130294553506
# Iteration #0105, error L2 relative psi:    0.00123847607302
# Iteration #0106, error L2 relative psi:    0.00117719759512
# Iteration #0107, error L2 relative psi:    0.00111895190605
# Iteration #0108, error L2 relative psi:    0.00106358869542
# Iteration #0109, error L2 relative psi:    0.00101096518681
# Iteration #0110, error L2 relative psi:    0.00096094573128
# Iteration #0111, error L2 relative psi:    0.00091340141658
# Iteration #0112, error L2 relative psi:    0.00086820972100
# Iteration #0113, error L2 relative psi:    0.00082525419394
# Iteration #0114, error L2 relative psi:    0.00078442415404
# Iteration #0115, error L2 relative psi:    0.00074561440258
# Iteration #0116, error L2 relative psi:    0.00070872495122
# Iteration #0117, error L2 relative psi:    0.00067366076340
#
# Time 0.22917
# Iteration #0001, error L2 relative psi:    1.23057228387678
# Iteration #0002, error L2 relative psi:    0.39709995490490
# Iteration #0003, error L2 relative psi:    0.26882311631921
# Iteration #0004, error L2 relative psi:    0.21132137282278
# Iteration #0005, error L2 relative psi:    0.17820569275911
# Iteration #0006, error L2 relative psi:    0.15593360521569
# Iteration #0007, error L2 relative psi:    0.13964342370504
# Iteration #0008, error L2 relative psi:    0.12709673668419
# Iteration #0009, error L2 relative psi:    0.11707029843126
# Iteration #0010, error L2 relative psi:    0.10881779603052
# Iteration #0011, error L2 relative psi:    0.10184903402309
# Iteration #0012, error L2 relative psi:    0.09582739463155
# Iteration #0013, error L2 relative psi:    0.09051688421843
# Iteration #0014, error L2 relative psi:    0.08575057335434
# Iteration #0015, error L2 relative psi:    0.08140959549080
# Iteration #0016, error L2 relative psi:    0.07740880275647
# Iteration #0017, error L2 relative psi:    0.07368735645047
# Iteration #0018, error L2 relative psi:    0.07020096512425
# Iteration #0019, error L2 relative psi:    0.06691726383230
# Iteration #0020, error L2 relative psi:    0.06381225502536
# Iteration #0021, error L2 relative psi:    0.06086793245758
# Iteration #0022, error L2 relative psi:    0.05807043892603
# Iteration #0023, error L2 relative psi:    0.05540861569510
# Iteration #0024, error L2 relative psi:    0.05287342419217
# Iteration #0025, error L2 relative psi:    0.05045702791410
# Iteration #0026, error L2 relative psi:    0.04815275432016
# Iteration #0027, error L2 relative psi:    0.04595471015472
# Iteration #0028, error L2 relative psi:    0.04385766247586
# Iteration #0029, error L2 relative psi:    0.04185668424734
# Iteration #0030, error L2 relative psi:    0.03994720871703
# Iteration #0031, error L2 relative psi:    0.03812498284802
# Iteration #0032, error L2 relative psi:    0.03638596007258
# Iteration #0033, error L2 relative psi:    0.03472632936481
# Iteration #0034, error L2 relative psi:    0.03314248042019
# Iteration #0035, error L2 relative psi:    0.03163096214213
# Iteration #0036, error L2 relative psi:    0.03018850166827
# Iteration #0037, error L2 relative psi:    0.02881193153292
# Iteration #0038, error L2 relative psi:    0.02749823485399
# Iteration #0039, error L2 relative psi:    0.02624455654344
# Iteration #0040, error L2 relative psi:    0.02504819506979
# Iteration #0041, error L2 relative psi:    0.02390650428494
# Iteration #0042, error L2 relative psi:    0.02281697165165
# Iteration #0043, error L2 relative psi:    0.02177720426266
# Iteration #0044, error L2 relative psi:    0.02078492254320
# Iteration #0045, error L2 relative psi:    0.01983795590385
# Iteration #0046, error L2 relative psi:    0.01893422925286
# Iteration #0047, error L2 relative psi:    0.01807175932640
# Iteration #0048, error L2 relative psi:    0.01724865333739
# Iteration #0049, error L2 relative psi:    0.01646310812220
# Iteration #0050, error L2 relative psi:    0.01571340591753
# Iteration #0051, error L2 relative psi:    0.01499790771594
# Iteration #0052, error L2 relative psi:    0.01431504598544
# Iteration #0053, error L2 relative psi:    0.01366332616243
# Iteration #0054, error L2 relative psi:    0.01304132287204
# Iteration #0055, error L2 relative psi:    0.01244767672600
# Iteration #0056, error L2 relative psi:    0.01188109267481
# Iteration #0057, error L2 relative psi:    0.01134033513418
# Iteration #0058, error L2 relative psi:    0.01082422261910
# Iteration #0059, error L2 relative psi:    0.01033163452799
# Iteration #0060, error L2 relative psi:    0.00986149667299
# Iteration #0061, error L2 relative psi:    0.00941277840240
# Iteration #0062, error L2 relative psi:    0.00898449973307
# Iteration #0063, error L2 relative psi:    0.00857572699911
# Iteration #0064, error L2 relative psi:    0.00818556979746
# Iteration #0065, error L2 relative psi:    0.00781317862441
# Iteration #0066, error L2 relative psi:    0.00745774291685
# Iteration #0067, error L2 relative psi:    0.00711848926388
# Iteration #0068, error L2 relative psi:    0.00679467971186
# Iteration #0069, error L2 relative psi:    0.00648561015913
# Iteration #0070, error L2 relative psi:    0.00619060891742
# Iteration #0071, error L2 relative psi:    0.00590904118861
# Iteration #0072, error L2 relative psi:    0.00564029495219
# Iteration #0073, error L2 relative psi:    0.00538378309429
# Iteration #0074, error L2 relative psi:    0.00513894601234
# Iteration #0075, error L2 relative psi:    0.00490525031290
# Iteration #0076, error L2 relative psi:    0.00468218801937
# Iteration #0077, error L2 relative psi:    0.00446927456348
# Iteration #0078, error L2 relative psi:    0.00426604744499
# Iteration #0079, error L2 relative psi:    0.00407206540175
# Iteration #0080, error L2 relative psi:    0.00388690740752
# Iteration #0081, error L2 relative psi:    0.00371017170152
# Iteration #0082, error L2 relative psi:    0.00354147487728
# Iteration #0083, error L2 relative psi:    0.00338045103331
# Iteration #0084, error L2 relative psi:    0.00322675098224
# Iteration #0085, error L2 relative psi:    0.00308004197233
# Iteration #0086, error L2 relative psi:    0.00294000817344
# Iteration #0087, error L2 relative psi:    0.00280634453614
# Iteration #0088, error L2 relative psi:    0.00267875977653
# Iteration #0089, error L2 relative psi:    0.00255697694996
# Iteration #0090, error L2 relative psi:    0.00244073205856
# Iteration #0091, error L2 relative psi:    0.00232977316998
# Iteration #0092, error L2 relative psi:    0.00222385980695
# Iteration #0093, error L2 relative psi:    0.00212276242668
# Iteration #0094, error L2 relative psi:    0.00202626193107
# Iteration #0095, error L2 relative psi:    0.00193414919655
# Iteration #0096, error L2 relative psi:    0.00184622462244
# Iteration #0097, error L2 relative psi:    0.00176229769792
# Iteration #0098, error L2 relative psi:    0.00168218658766
# Iteration #0099, error L2 relative psi:    0.00160571773595
# Iteration #0100, error L2 relative psi:    0.00153272548888
# Iteration #0101, error L2 relative psi:    0.00146305173346
# Iteration #0102, error L2 relative psi:    0.00139654555361
# Iteration #0103, error L2 relative psi:    0.00133306290177
# Iteration #0104, error L2 relative psi:    0.00127246628560
# Iteration #0105, error L2 relative psi:    0.00121462446913
# Iteration #0106, error L2 relative psi:    0.00115941218753
# Iteration #0107, error L2 relative psi:    0.00110670987505
# Iteration #0108, error L2 relative psi:    0.00105640340531
# Iteration #0109, error L2 relative psi:    0.00100838384354
# Iteration #0110, error L2 relative psi:    0.00096254721017
# Iteration #0111, error L2 relative psi:    0.00091879425510
# Iteration #0112, error L2 relative psi:    0.00087703024252
# Iteration #0113, error L2 relative psi:    0.00083716474520
# Iteration #0114, error L2 relative psi:    0.00079911144857
# Iteration #0115, error L2 relative psi:    0.00076278796338
# Iteration #0116, error L2 relative psi:    0.00072811564718
#
# Time 0.25
# Iteration #0001, error L2 relative psi:    1.26503972786884
# Iteration #0002, error L2 relative psi:    0.39672962129402
# Iteration #0003, error L2 relative psi:    0.26677793616775
# Iteration #0004, error L2 relative psi:    0.20916704016365
# Iteration #0005, error L2 relative psi:    0.17571128993623
# Iteration #0006, error L2 relative psi:    0.15317752668876
# Iteration #0007, error L2 relative psi:    0.13665631096406
# Iteration #0008, error L2 relative psi:    0.12390117812163
# Iteration #0009, error L2 relative psi:    0.11370243104715
# Iteration #0010, error L2 relative psi:    0.10532692989162
# Iteration #0011, error L2 relative psi:    0.09829448415495
# Iteration #0012, error L2 relative psi:    0.09227897112734
# Iteration #0013, error L2 relative psi:    0.08704411810830
# Iteration #0014, error L2 relative psi:    0.08241557166446
# Iteration #0015, error L2 relative psi:    0.07826454778757
# Iteration #0016, error L2 relative psi:    0.07449435296641
# Iteration #0017, error L2 relative psi:    0.07103254187382
# Iteration #0018, error L2 relative psi:    0.06782502096596
# Iteration #0019, error L2 relative psi:    0.06483032424477
# Iteration #0020, error L2 relative psi:    0.06201681775742
# Iteration #0021, error L2 relative psi:    0.05936041481436
# Iteration #0022, error L2 relative psi:    0.05684259246304
# Iteration #0023, error L2 relative psi:    0.05444896702429
# Iteration #0024, error L2 relative psi:    0.05216822203485
# Iteration #0025, error L2 relative psi:    0.04999134346827
# Iteration #0026, error L2 relative psi:    0.04791104586593
# Iteration #0027, error L2 relative psi:    0.04592108333682
# Iteration #0028, error L2 relative psi:    0.04401619481561
# Iteration #0029, error L2 relative psi:    0.04219178855358
# Iteration #0030, error L2 relative psi:    0.04044378250457
# Iteration #0031, error L2 relative psi:    0.03876855489177
# Iteration #0032, error L2 relative psi:    0.03716280359606
# Iteration #0033, error L2 relative psi:    0.03562348252903
# Iteration #0034, error L2 relative psi:    0.03414775231481
# Iteration #0035, error L2 relative psi:    0.03273296581978
# Iteration #0036, error L2 relative psi:    0.03137657705178
# Iteration #0037, error L2 relative psi:    0.03007619320593
# Iteration #0038, error L2 relative psi:    0.02882954361165
# Iteration #0039, error L2 relative psi:    0.02763441952921
# Iteration #0040, error L2 relative psi:    0.02648869778963
# Iteration #0041, error L2 relative psi:    0.02539035337553
# Iteration #0042, error L2 relative psi:    0.02433744815217
# Iteration #0043, error L2 relative psi:    0.02332812975631
# Iteration #0044, error L2 relative psi:    0.02236062164469
# Iteration #0045, error L2 relative psi:    0.02143320690577
# Iteration #0046, error L2 relative psi:    0.02054423197101
# Iteration #0047, error L2 relative psi:    0.01969211986078
# Iteration #0048, error L2 relative psi:    0.01887535370636
# Iteration #0049, error L2 relative psi:    0.01809247816038
# Iteration #0050, error L2 relative psi:    0.01734209625287
# Iteration #0051, error L2 relative psi:    0.01662285836037
# Iteration #0052, error L2 relative psi:    0.01593346923429
# Iteration #0053, error L2 relative psi:    0.01527268952138
# Iteration #0054, error L2 relative psi:    0.01463933253051
# Iteration #0055, error L2 relative psi:    0.01403226114346
# Iteration #0056, error L2 relative psi:    0.01345038512296
# Iteration #0057, error L2 relative psi:    0.01289265910634
# Iteration #0058, error L2 relative psi:    0.01235808140077
# Iteration #0059, error L2 relative psi:    0.01184569526542
# Iteration #0060, error L2 relative psi:    0.01135457877953
# Iteration #0061, error L2 relative psi:    0.01088384505802
# Iteration #0062, error L2 relative psi:    0.01043264625304
# Iteration #0063, error L2 relative psi:    0.01000017044768
# Iteration #0064, error L2 relative psi:    0.00958563967421
# Iteration #0065, error L2 relative psi:    0.00918830846688
# Iteration #0066, error L2 relative psi:    0.00880746602431
# Iteration #0067, error L2 relative psi:    0.00844242899253
# Iteration #0068, error L2 relative psi:    0.00809253780726
# Iteration #0069, error L2 relative psi:    0.00775716085822
# Iteration #0070, error L2 relative psi:    0.00743569453359
# Iteration #0071, error L2 relative psi:    0.00712756095074
# Iteration #0072, error L2 relative psi:    0.00683220639153
# Iteration #0073, error L2 relative psi:    0.00654910017222
# Iteration #0074, error L2 relative psi:    0.00627773367102
# Iteration #0075, error L2 relative psi:    0.00601761941713
# Iteration #0076, error L2 relative psi:    0.00576829021818
# Iteration #0077, error L2 relative psi:    0.00552929832091
# Iteration #0078, error L2 relative psi:    0.00530021460403
# Iteration #0079, error L2 relative psi:    0.00508062780318
# Iteration #0080, error L2 relative psi:    0.00487014376715
# Iteration #0081, error L2 relative psi:    0.00466838474541
# Iteration #0082, error L2 relative psi:    0.00447498870656
# Iteration #0083, error L2 relative psi:    0.00428960868971
# Iteration #0084, error L2 relative psi:    0.00411191220417
# Iteration #0085, error L2 relative psi:    0.00394158204045
# Iteration #0086, error L2 relative psi:    0.00377831324434
# Iteration #0087, error L2 relative psi:    0.00362181224862
# Iteration #0088, error L2 relative psi:    0.00347179779010
# Iteration #0089, error L2 relative psi:    0.00332800266047
# Iteration #0090, error L2 relative psi:    0.00319016776251
# Iteration #0091, error L2 relative psi:    0.00305804568208
# Iteration #0092, error L2 relative psi:    0.00293139870564
# Iteration #0093, error L2 relative psi:    0.00280999915203
# Iteration #0094, error L2 relative psi:    0.00269362918216
# Iteration #0095, error L2 relative psi:    0.00258208017947
# Iteration #0096, error L2 relative psi:    0.00247515225391
# Iteration #0097, error L2 relative psi:    0.00237265383721
# Iteration #0098, error L2 relative psi:    0.00227440132371
# Iteration #0099, error L2 relative psi:    0.00218021873997
# Iteration #0100, error L2 relative psi:    0.00208993753492
# Iteration #0101, error L2 relative psi:    0.00200339703286
# Iteration #0102, error L2 relative psi:    0.00192044189570
# Iteration #0103, error L2 relative psi:    0.00184092298128
# Iteration #0104, error L2 relative psi:    0.00176469762528
# Iteration #0105, error L2 relative psi:    0.00169162927146
# Iteration #0106, error L2 relative psi:    0.00162158708777
# Iteration #0107, error L2 relative psi:    0.00155444567954
# Iteration #0108, error L2 relative psi:    0.00149008485229
# Iteration #0109, error L2 relative psi:    0.00142838939503
# Iteration #0110, error L2 relative psi:    0.00136924887419
# Iteration #0111, error L2 relative psi:    0.00131255743604
# Iteration #0112, error L2 relative psi:    0.00125821361690
# Iteration #0113, error L2 relative psi:    0.00120612016105
# Iteration #0114, error L2 relative psi:    0.00115618384588
# Iteration #0115, error L2 relative psi:    0.00110831531425
# Iteration #0116, error L2 relative psi:    0.00106242891390
# Iteration #0117, error L2 relative psi:    0.00101844254350
# Iteration #0118, error L2 relative psi:    0.00097627750503
# Iteration #0119, error L2 relative psi:    0.00093585836246
# Iteration #0120, error L2 relative psi:    0.00089711280631
# Iteration #0121, error L2 relative psi:    0.00085997152371
# Iteration #0122, error L2 relative psi:    0.00082436807416
# Iteration #0123, error L2 relative psi:    0.00079023877023
# Iteration #0124, error L2 relative psi:    0.00075752256329
#
# Time 0.27083
# Iteration #0001, error L2 relative psi:    1.30914293815788
# Iteration #0002, error L2 relative psi:    0.46405998760538
# Iteration #0003, error L2 relative psi:    0.31921670999079
# Iteration #0004, error L2 relative psi:    0.25431045125128
# Iteration #0005, error L2 relative psi:    0.21541180220644
# Iteration #0006, error L2 relative psi:    0.18874494961108
# Iteration #0007, error L2 relative psi:    0.16895246398991
# Iteration #0008, error L2 relative psi:    0.15350943989875
# Iteration #0009, error L2 relative psi:    0.14106804894061
# Iteration #0010, error L2 relative psi:    0.13079797989637
# Iteration #0011, error L2 relative psi:    0.12215994860656
# Iteration #0012, error L2 relative psi:    0.11477336909434
# Iteration #0013, error L2 relative psi:    0.10836316069745
# Iteration #0014, error L2 relative psi:    0.10272668221657
# Iteration #0015, error L2 relative psi:    0.09771148011758
# Iteration #0016, error L2 relative psi:    0.09319589104999
# Iteration #0017, error L2 relative psi:    0.08908669244066
# Iteration #0018, error L2 relative psi:    0.08531244838627
# Iteration #0019, error L2 relative psi:    0.08181683188811
# Iteration #0020, error L2 relative psi:    0.07855546625138
# Iteration #0021, error L2 relative psi:    0.07549347539204
# Iteration #0022, error L2 relative psi:    0.07260287459281
# Iteration #0023, error L2 relative psi:    0.06986219190628
# Iteration #0024, error L2 relative psi:    0.06725372643426
# Iteration #0025, error L2 relative psi:    0.06476371695022
# Iteration #0026, error L2 relative psi:    0.06238110948423
# Iteration #0027, error L2 relative psi:    0.06009682446087
# Iteration #0028, error L2 relative psi:    0.05790347951348
# Iteration #0029, error L2 relative psi:    0.05579503983912
# Iteration #0030, error L2 relative psi:    0.05376638301895
# Iteration #0031, error L2 relative psi:    0.05181314188216
# Iteration #0032, error L2 relative psi:    0.04993161941754
# Iteration #0033, error L2 relative psi:    0.04811854754480
# Iteration #0034, error L2 relative psi:    0.04637102406431
# Iteration #0035, error L2 relative psi:    0.04468640266545
# Iteration #0036, error L2 relative psi:    0.04306218514917
# Iteration #0037, error L2 relative psi:    0.04149609621711
# Iteration #0038, error L2 relative psi:    0.03998594609985
# Iteration #0039, error L2 relative psi:    0.03852971870065
# Iteration #0040, error L2 relative psi:    0.03712551781024
# Iteration #0041, error L2 relative psi:    0.03577153757595
# Iteration #0042, error L2 relative psi:    0.03446605464396
# Iteration #0043, error L2 relative psi:    0.03320743454872
# Iteration #0044, error L2 relative psi:    0.03199408948810
# Iteration #0045, error L2 relative psi:    0.03082444811945
# Iteration #0046, error L2 relative psi:    0.02969697315038
# Iteration #0047, error L2 relative psi:    0.02861020952475
# Iteration #0048, error L2 relative psi:    0.02756274486366
# Iteration #0049, error L2 relative psi:    0.02655320522597
# Iteration #0050, error L2 relative psi:    0.02558026230970
# Iteration #0051, error L2 relative psi:    0.02464263224009
# Iteration #0052, error L2 relative psi:    0.02373908703202
# Iteration #0053, error L2 relative psi:    0.02286843654447
# Iteration #0054, error L2 relative psi:    0.02202949918464
# Iteration #0055, error L2 relative psi:    0.02122114474670
# Iteration #0056, error L2 relative psi:    0.02044228356752
# Iteration #0057, error L2 relative psi:    0.01969186244409
# Iteration #0058, error L2 relative psi:    0.01896886311372
# Iteration #0059, error L2 relative psi:    0.01827230128235
# Iteration #0060, error L2 relative psi:    0.01760122576810
# Iteration #0061, error L2 relative psi:    0.01695471790598
# Iteration #0062, error L2 relative psi:    0.01633189157500
# Iteration #0063, error L2 relative psi:    0.01573188935402
# Iteration #0064, error L2 relative psi:    0.01515388279715
# Iteration #0065, error L2 relative psi:    0.01459707828729
# Iteration #0066, error L2 relative psi:    0.01406070250220
# Iteration #0067, error L2 relative psi:    0.01354401080223
# Iteration #0068, error L2 relative psi:    0.01304628506557
# Iteration #0069, error L2 relative psi:    0.01256683183543
# Iteration #0070, error L2 relative psi:    0.01210498346475
# Iteration #0071, error L2 relative psi:    0.01166009661717
# Iteration #0072, error L2 relative psi:    0.01123155110469
# Iteration #0073, error L2 relative psi:    0.01081874810527
# Iteration #0074, error L2 relative psi:    0.01042111824085
# Iteration #0075, error L2 relative psi:    0.01003810255964
# Iteration #0076, error L2 relative psi:    0.00966916317956
# Iteration #0077, error L2 relative psi:    0.00931378317397
# Iteration #0078, error L2 relative psi:    0.00897146486031
# Iteration #0079, error L2 relative psi:    0.00864172879093
# Iteration #0080, error L2 relative psi:    0.00832411302203
# Iteration #0081, error L2 relative psi:    0.00801817247057
# Iteration #0082, error L2 relative psi:    0.00772347830909
# Iteration #0083, error L2 relative psi:    0.00743961738459
# Iteration #0084, error L2 relative psi:    0.00716619165772
# Iteration #0085, error L2 relative psi:    0.00690281766096
# Iteration #0086, error L2 relative psi:    0.00664912597507
# Iteration #0087, error L2 relative psi:    0.00640476072390
# Iteration #0088, error L2 relative psi:    0.00616937908743
# Iteration #0089, error L2 relative psi:    0.00594265083533
# ...
# Iteration #0123, error L2 relative psi:    0.01124801095243
# Iteration #0124, error L2 relative psi:    0.01095184051905
# Iteration #0125, error L2 relative psi:    0.01066345849106
# Iteration #0126, error L2 relative psi:    0.01038266086520
# Iteration #0127, error L2 relative psi:    0.01010924891678
# Iteration #0128, error L2 relative psi:    0.00984302906822
# Iteration #0129, error L2 relative psi:    0.00958381276061
# Iteration #0130, error L2 relative psi:    0.00933141632789
# Iteration #0131, error L2 relative psi:    0.00908566087409
# Iteration #0132, error L2 relative psi:    0.00884637215306
# Iteration #0133, error L2 relative psi:    0.00861338045111
# Iteration #0134, error L2 relative psi:    0.00838652047229
# Iteration #0135, error L2 relative psi:    0.00816563122627
# Iteration #0136, error L2 relative psi:    0.00795055591888
# Iteration #0137, error L2 relative psi:    0.00774114184525
# Iteration #0138, error L2 relative psi:    0.00753724028539
# Iteration #0139, error L2 relative psi:    0.00733870640228
# Iteration #0140, error L2 relative psi:    0.00714539914247
# Iteration #0141, error L2 relative psi:    0.00695718113897
# Iteration #0142, error L2 relative psi:    0.00677391861649
# Iteration #0143, error L2 relative psi:    0.00659548129914
# Iteration #0144, error L2 relative psi:    0.00642174232017
# Iteration #0145, error L2 relative psi:    0.00625257813404
# Iteration #0146, error L2 relative psi:    0.00608786843066
# Iteration #0147, error L2 relative psi:    0.00592749605176
# Iteration #0148, error L2 relative psi:    0.00577134690923
# Iteration #0149, error L2 relative psi:    0.00561930990559
# Iteration #0150, error L2 relative psi:    0.00547127685651
# Iteration #0151, error L2 relative psi:    0.00532714241509
# Iteration #0152, error L2 relative psi:    0.00518680399817
# Iteration #0153, error L2 relative psi:    0.00505016171450
# Iteration #0154, error L2 relative psi:    0.00491711829469
# Iteration #0155, error L2 relative psi:    0.00478757902291
# Iteration #0156, error L2 relative psi:    0.00466145167037
# Iteration #0157, error L2 relative psi:    0.00453864643049
# Iteration #0158, error L2 relative psi:    0.00441907585572
# Iteration #0159, error L2 relative psi:    0.00430265479593
# Iteration #0160, error L2 relative psi:    0.00418930033841
# Iteration #0161, error L2 relative psi:    0.00407893174946
# Iteration #0162, error L2 relative psi:    0.00397147041738
# Iteration #0163, error L2 relative psi:    0.00386683979699
# Iteration #0164, error L2 relative psi:    0.00376496535557
# Iteration #0165, error L2 relative psi:    0.00366577452016
# Iteration #0166, error L2 relative psi:    0.00356919662626
# Iteration #0167, error L2 relative psi:    0.00347516286786
# Iteration #0168, error L2 relative psi:    0.00338360624873
# Iteration #0169, error L2 relative psi:    0.00329446153499
# Iteration #0170, error L2 relative psi:    0.00320766520887
# Iteration #0171, error L2 relative psi:    0.00312315542378
# Iteration #0172, error L2 relative psi:    0.00304087196040
# Iteration #0173, error L2 relative psi:    0.00296075618402
# Iteration #0174, error L2 relative psi:    0.00288275100295
# Iteration #0175, error L2 relative psi:    0.00280680082799
# Iteration #0176, error L2 relative psi:    0.00273285153303
# Iteration #0177, error L2 relative psi:    0.00266085041660
# Iteration #0178, error L2 relative psi:    0.00259074616443
# Iteration #0179, error L2 relative psi:    0.00252248881304
# Iteration #0180, error L2 relative psi:    0.00245602971422
# Iteration #0181, error L2 relative psi:    0.00239132150053
# Iteration #0182, error L2 relative psi:    0.00232831805155
# Iteration #0183, error L2 relative psi:    0.00226697446116
# Iteration #0184, error L2 relative psi:    0.00220724700560
# Iteration #0185, error L2 relative psi:    0.00214909311238
# Iteration #0186, error L2 relative psi:    0.00209247133001
# Iteration #0187, error L2 relative psi:    0.00203734129851
# Iteration #0188, error L2 relative psi:    0.00198366372072
# Iteration #0189, error L2 relative psi:    0.00193140033433
# Iteration #0190, error L2 relative psi:    0.00188051388466
# Iteration #0191, error L2 relative psi:    0.00183096809814
# Iteration #0192, error L2 relative psi:    0.00178272765653
# Iteration #0193, error L2 relative psi:    0.00173575817174
# Iteration #0194, error L2 relative psi:    0.00169002616137
# Iteration #0195, error L2 relative psi:    0.00164549902488
# Iteration #0196, error L2 relative psi:    0.00160214502039
# Iteration #0197, error L2 relative psi:    0.00155993324205
# Iteration #0198, error L2 relative psi:    0.00151883359807
# Iteration #0199, error L2 relative psi:    0.00147881678925
# Iteration #0200, error L2 relative psi:    0.00143985428817
# Iteration #0201, error L2 relative psi:    0.00140191831881
# Iteration #0202, error L2 relative psi:    0.00136498183681
# Iteration #0203, error L2 relative psi:    0.00132901851022
# Iteration #0204, error L2 relative psi:    0.00129400270068
# Iteration #0205, error L2 relative psi:    0.00125990944523
# Iteration #0206, error L2 relative psi:    0.00122671443846
# Iteration #0207, error L2 relative psi:    0.00119439401526
# Iteration #0208, error L2 relative psi:    0.00116292513391
# Iteration #0209, error L2 relative psi:    0.00113228535969
# Iteration #0210, error L2 relative psi:    0.00110245284886
# Iteration #0211, error L2 relative psi:    0.00107340633316
# Iteration #0212, error L2 relative psi:    0.00104512510459
# Iteration #0213, error L2 relative psi:    0.00101758900070
# Iteration #0214, error L2 relative psi:    0.00099077839018
# Iteration #0215, error L2 relative psi:    0.00096467415891
# Iteration #0216, error L2 relative psi:    0.00093925769632
#
# Time 0.33333
# Iteration #0001, error L2 relative psi:    0.28817741514028
# Iteration #0002, error L2 relative psi:    0.18939671207624
# Iteration #0003, error L2 relative psi:    0.14736760355598
# Iteration #0004, error L2 relative psi:    0.12359082015889
# Iteration #0005, error L2 relative psi:    0.10780093351145
# Iteration #0006, error L2 relative psi:    0.09624667231810
# Iteration #0007, error L2 relative psi:    0.08725162481141
# Iteration #0008, error L2 relative psi:    0.07995475786853
# Iteration #0009, error L2 relative psi:    0.07386532551107
# Iteration #0010, error L2 relative psi:    0.06867988978596
# Iteration #0011, error L2 relative psi:    0.06419814381475
# Iteration #0012, error L2 relative psi:    0.06028058615803
# Iteration #0013, error L2 relative psi:    0.05682564356426
# Iteration #0014, error L2 relative psi:    0.05375655321840
# Iteration #0015, error L2 relative psi:    0.05101346844688
# Iteration #0016, error L2 relative psi:    0.04854851405076
# Iteration #0017, error L2 relative psi:    0.04632258204299
# Iteration #0018, error L2 relative psi:    0.04430319140326
# Iteration #0019, error L2 relative psi:    0.04246301716963
# Iteration #0020, error L2 relative psi:    0.04077885050267
# Iteration #0021, error L2 relative psi:    0.03923084181667
# Iteration #0022, error L2 relative psi:    0.03780193330745
# Iteration #0023, error L2 relative psi:    0.03647742066341
# Iteration #0024, error L2 relative psi:    0.03524460483450
# Iteration #0025, error L2 relative psi:    0.03409250822056
# Iteration #0026, error L2 relative psi:    0.03301163833990
# Iteration #0027, error L2 relative psi:    0.03199378766783
# Iteration #0028, error L2 relative psi:    0.03103186197590
# Iteration #0029, error L2 relative psi:    0.03011973185050
# Iteration #0030, error L2 relative psi:    0.02925210358094
# Iteration #0031, error L2 relative psi:    0.02842440657916
# Iteration #0032, error L2 relative psi:    0.02763269512372
# Iteration #0033, error L2 relative psi:    0.02687356263596
# Iteration #0034, error L2 relative psi:    0.02614406698012
# Iteration #0035, error L2 relative psi:    0.02544166548220
# Iteration #0036, error L2 relative psi:    0.02476415851714
# Iteration #0037, error L2 relative psi:    0.02410964063970
# Iteration #0038, error L2 relative psi:    0.02347645834235
# Iteration #0039, error L2 relative psi:    0.02286317361890
# Iteration #0040, error L2 relative psi:    0.02226853260003
# Iteration #0041, error L2 relative psi:    0.02169143860689
# Iteration #0042, error L2 relative psi:    0.02113092904205
# Iteration #0043, error L2 relative psi:    0.02058615560537
# Iteration #0044, error L2 relative psi:    0.02005636738270
# Iteration #0045, error L2 relative psi:    0.01954089641209
# Iteration #0046, error L2 relative psi:    0.01903914538151
# Iteration #0047, error L2 relative psi:    0.01855057715722
# Iteration #0048, error L2 relative psi:    0.01807470588148
# Iteration #0049, error L2 relative psi:    0.01761108941360
# Iteration #0050, error L2 relative psi:    0.01715932291919
# Iteration #0051, error L2 relative psi:    0.01671903343922
# Iteration #0052, error L2 relative psi:    0.01628987529437
# Iteration #0053, error L2 relative psi:    0.01587152620069
# Iteration #0054, error L2 relative psi:    0.01546368398988
# Iteration #0055, error L2 relative psi:    0.01506606384331
# Iteration #0056, error L2 relative psi:    0.01467839596191
# Iteration #0057, error L2 relative psi:    0.01430042360534
# Iteration #0058, error L2 relative psi:    0.01393190144394
# Iteration #0059, error L2 relative psi:    0.01357259417492
# Iteration #0060, error L2 relative psi:    0.01322227536181
# Iteration #0061, error L2 relative psi:    0.01288072646221
# Iteration #0062, error L2 relative psi:    0.01254773601386
# Iteration #0063, error L2 relative psi:    0.01222309895421
# Iteration #0064, error L2 relative psi:    0.01190661605162
# Iteration #0065, error L2 relative psi:    0.01159809343049
# Iteration #0066, error L2 relative psi:    0.01129734217457
# Iteration #0067, error L2 relative psi:    0.01100417799572
# Iteration #0068, error L2 relative psi:    0.01071842095713
# Iteration #0069, error L2 relative psi:    0.01043989524162
# Iteration #0070, error L2 relative psi:    0.01016842895731
# Iteration #0071, error L2 relative psi:    0.00990385397416
# Iteration #0072, error L2 relative psi:    0.00964600578578
# Iteration #0073, error L2 relative psi:    0.00939472339195
# Iteration #0074, error L2 relative psi:    0.00914984919799
# Iteration #0075, error L2 relative psi:    0.00891122892779
# Iteration #0076, error L2 relative psi:    0.00867871154769
# Iteration #0077, error L2 relative psi:    0.00845214919932
# Iteration #0078, error L2 relative psi:    0.00823139713915
# Iteration #0079, error L2 relative psi:    0.00801631368347
# Iteration #0080, error L2 relative psi:    0.00780676015765
# Iteration #0081, error L2 relative psi:    0.00760260084856
# Iteration #0082, error L2 relative psi:    0.00740370295914
# Iteration #0083, error L2 relative psi:    0.00720993656496
# Iteration #0084, error L2 relative psi:    0.00702117457178
# Iteration #0085, error L2 relative psi:    0.00683729267393
# Iteration #0086, error L2 relative psi:    0.00665816931320
# Iteration #0087, error L2 relative psi:    0.00648368563787
# Iteration #0088, error L2 relative psi:    0.00631372546191
# Iteration #0089, error L2 relative psi:    0.00614817522398
# Iteration #0090, error L2 relative psi:    0.00598692394636
# Iteration #0091, error L2 relative psi:    0.00582986319367
# Iteration #0092, error L2 relative psi:    0.00567688703128
# Iteration #0093, error L2 relative psi:    0.00552789198363
# Iteration #0094, error L2 relative psi:    0.00538277699215
# Iteration #0095, error L2 relative psi:    0.00524144337316
# Iteration #0096, error L2 relative psi:    0.00510379477556
# Iteration #0097, error L2 relative psi:    0.00496973713827
# Iteration #0098, error L2 relative psi:    0.00483917864789
# Iteration #0099, error L2 relative psi:    0.00471202969605
# Iteration #0100, error L2 relative psi:    0.00458820283697
# Iteration #0101, error L2 relative psi:    0.00446761274513
# Iteration #0102, error L2 relative psi:    0.00435017617282
# Iteration #0103, error L2 relative psi:    0.00423581190829
# Iteration #0104, error L2 relative psi:    0.00412444073374
# Iteration #0105, error L2 relative psi:    0.00401598538382
# Iteration #0106, error L2 relative psi:    0.00391037050435
# Iteration #0107, error L2 relative psi:    0.00380752261146
# Iteration #0108, error L2 relative psi:    0.00370737005109
# Iteration #0109, error L2 relative psi:    0.00360984295890
# Iteration #0110, error L2 relative psi:    0.00351487322065
# Iteration #0111, error L2 relative psi:    0.00342239443315
# Iteration #0112, error L2 relative psi:    0.00333234186555
# Iteration #0113, error L2 relative psi:    0.00324465242135
# Iteration #0114, error L2 relative psi:    0.00315926460085
# Iteration #0115, error L2 relative psi:    0.00307611846417
# Iteration #0116, error L2 relative psi:    0.00299515559491
# Iteration #0117, error L2 relative psi:    0.00291631906441
# Iteration #0118, error L2 relative psi:    0.00283955339653
# Iteration #0119, error L2 relative psi:    0.00276480453314
# Iteration #0120, error L2 relative psi:    0.00269201980021
# Iteration #0121, error L2 relative psi:    0.00262114787449
# Iteration #0122, error L2 relative psi:    0.00255213875089
# Iteration #0123, error L2 relative psi:    0.00248494371039
# Iteration #0124, error L2 relative psi:    0.00241951528870
# Iteration #0125, error L2 relative psi:    0.00235580724548
# Iteration #0126, error L2 relative psi:    0.00229377453419
# Iteration #0127, error L2 relative psi:    0.00223337327263
# Iteration #0128, error L2 relative psi:    0.00217456071400
# Iteration #0129, error L2 relative psi:    0.00211729521870
# Iteration #0130, error L2 relative psi:    0.00206153622665
# Iteration #0131, error L2 relative psi:    0.00200724423024
# Iteration #0132, error L2 relative psi:    0.00195438074796
# Iteration #0133, error L2 relative psi:    0.00190290829844
# Iteration #0134, error L2 relative psi:    0.00185279037533
# Iteration #0135, error L2 relative psi:    0.00180399142249
# Iteration #0136, error L2 relative psi:    0.00175647681000
# Iteration #0137, error L2 relative psi:    0.00171021281051
# Iteration #0138, error L2 relative psi:    0.00166516657634
# Iteration #0139, error L2 relative psi:    0.00162130611692
# Iteration #0140, error L2 relative psi:    0.00157860027701
# Iteration #0141, error L2 relative psi:    0.00153701871515
# Iteration #0142, error L2 relative psi:    0.00149653188291
# Iteration #0143, error L2 relative psi:    0.00145711100445
# Iteration #0144, error L2 relative psi:    0.00141872805664
# Iteration #0145, error L2 relative psi:    0.00138135574971
# Iteration #0146, error L2 relative psi:    0.00134496750826
# Iteration #0147, error L2 relative psi:    0.00130953745292
# Iteration #0148, error L2 relative psi:    0.00127504038222
# Iteration #0149, error L2 relative psi:    0.00124145175513
# Iteration #0150, error L2 relative psi:    0.00120874767395
# Iteration #0151, error L2 relative psi:    0.00117690486755
# Iteration #0152, error L2 relative psi:    0.00114590067522
# Iteration #0153, error L2 relative psi:    0.00111571303068
# Iteration #0154, error L2 relative psi:    0.00108632044674
# Iteration #0155, error L2 relative psi:    0.00105770200017
# Iteration #0156, error L2 relative psi:    0.00102983731704
# Iteration #0157, error L2 relative psi:    0.00100270655836
# Iteration #0158, error L2 relative psi:    0.00097629040622
# Iteration #0159, error L2 relative psi:    0.00095057005012
#
# Time 0.35417
# Iteration #0001, error L2 relative psi:    0.00092552717375
#
# Time 0.375
# Iteration #0001, error L2 relative psi:    0.00090114394210
#
# Time 0.39583
# Iteration #0001, error L2 relative psi:    0.00087740298885
#
# Time 0.41667
# Iteration #0001, error L2 relative psi:    0.00085428740416
#
# Time 0.4375
# Iteration #0001, error L2 relative psi:    0.00083178072271
#
# Time 0.45833
# Iteration #0001, error L2 relative psi:    0.00080986691204
#
# Time 0.47917
# Iteration #0001, error L2 relative psi:    0.00078853036128
#
# Time 0.5
# Iteration #0001, error L2 relative psi:    0.00076775587008
#
# Time 0.52083
# Iteration #0001, error L2 relative psi:    0.00074752863785
#
# Time 0.54167
# Iteration #0001, error L2 relative psi:    0.00072783425329
#
# Time 0.5625
# Iteration #0001, error L2 relative psi:    0.00070865868419

# %%
prev
# Out:
# array([ 2.80801741e+00,  2.80357888e+00,  2.79025095e+00,  2.76799685e+00,
#         2.73675607e+00,  2.69644575e+00,  2.64696313e+00,  2.58818958e+00,
#         2.51999700e+00,  2.44225753e+00,  2.35485799e+00,  2.25772054e+00,
#         2.15083118e+00,  2.03427754e+00,  1.90829659e+00,  1.77333056e+00,
#         1.63008662e+00,  1.47959031e+00,  1.32321773e+00,  1.16268795e+00,
#         1.00000000e+00,  2.81245594e+00,  2.80802357e+00,  2.79471403e+00,
#         2.77249020e+00,  2.74129084e+00,  2.70103190e+00,  2.65160859e+00,
#         2.59289910e+00,  2.52477044e+00,  2.44708756e+00,  2.35972695e+00,
#         2.26259650e+00,  2.15566331e+00,  2.03899121e+00,  1.91278912e+00,
#         1.77746951e+00,  1.63371281e+00,  1.48252845e+00,  1.32529633e+00,
#         1.16376704e+00,  1.00000000e+00,  2.82575921e+00,  2.82134544e+00,
#         2.80809142e+00,  2.78595905e+00,  2.75488521e+00,  2.71478241e+00,
#         2.66554023e+00,  2.60702778e+00,  2.53909812e+00,  2.46159531e+00,
#         2.37436574e+00,  2.27727521e+00,  2.17023435e+00,  2.05323485e+00,
#         1.92639919e+00,  1.79004556e+00,  1.64476665e+00,  1.49151433e+00,
#         1.33167211e+00,  1.16708387e+00,  1.00000000e+00,  2.84789000e+00,
#         2.84350756e+00,  2.83034715e+00,  2.80836939e+00,  2.77750853e+00,
#         2.73767232e+00,  2.68874212e+00,  2.63057368e+00,  2.56299893e+00,
#         2.48582985e+00,  2.39886548e+00,  2.30190423e+00,  2.19476404e+00,
#         2.07731467e+00,  1.94952720e+00,  1.81154689e+00,  1.66379390e+00,
#         1.50709012e+00,  1.34279392e+00,  1.17289632e+00,  1.00000000e+00,
#         2.87878568e+00,  2.87444767e+00,  2.86142021e+00,  2.83966282e+00,
#         2.80910721e+00,  2.76965620e+00,  2.72118227e+00,  2.66352589e+00,
#         2.59649409e+00,  2.51985966e+00,  2.43336212e+00,  2.33671220e+00,
#         2.22960291e+00,  2.11173258e+00,  1.98284807e+00,  1.84282090e+00,
#         1.69177194e+00,  1.53025832e+00,  1.35951714e+00,  1.18170748e+00,
#         1.00000000e+00,  2.91835738e+00,  2.91407721e+00,  2.90122322e+00,
#         2.87975447e+00,  2.84960128e+00,  2.81066302e+00,  2.76280486e+00,
#         2.70585352e+00,  2.63959187e+00,  2.56375257e+00,  2.47801114e+00,
#         2.38197952e+00,  2.27520284e+00,  2.15716466e+00,  2.02731160e+00,
#         1.88511671e+00,  1.73021462e+00,  1.56265409e+00,  1.38330885e+00,
#         1.19441646e+00,  1.00000000e+00,  2.96648940e+00,  2.96228059e+00,
#         2.94964099e+00,  2.92853056e+00,  2.89888043e+00,  2.86058973e+00,
#         2.81352063e+00,  2.75749146e+00,  2.69226729e+00,  2.61754762e+00,
#         2.53295035e+00,  2.43799191e+00,  2.33206424e+00,  2.21441164e+00,
#         2.08411696e+00,  1.94011971e+00,  1.78131575e+00,  1.60683458e+00,
#         1.41664769e+00,  1.21264951e+00,  1.00000000e+00,  3.02303904e+00,
#         3.01891474e+00,  3.00652961e+00,  2.98584633e+00,  2.95680015e+00,
#         2.91929484e+00,  2.87319649e+00,  2.81832438e+00,  2.75443822e+00,
#         2.68122028e+00,  2.59825071e+00,  2.50497353e+00,  2.40065058e+00,
#         2.28430071e+00,  2.15462488e+00,  2.00992942e+00,  1.84809409e+00,
#         1.66672078e+00,  1.46379783e+00,  1.23953390e+00,  1.00000000e+00,
#         3.08783729e+00,  3.08380971e+00,  3.07171639e+00,  3.05152501e+00,
#         3.02317898e+00,  2.98659300e+00,  2.94164610e+00,  2.88817135e+00,
#         2.82594092e+00,  2.75464458e+00,  2.67385868e+00,  2.58300092e+00,
#         2.48126385e+00,  2.36751573e+00,  2.24015242e+00,  2.09687902e+00,
#         1.93441039e+00,  1.74815663e+00,  1.53228894e+00,  1.28168826e+00,
#         1.00000000e+00,  3.16069071e+00,  3.15677042e+00,  3.14500124e+00,
#         3.12535834e+00,  3.09779776e+00,  3.06225207e+00,  3.01862357e+00,
#         2.96677401e+00,  2.90650953e+00,  2.83755844e+00,  2.75953850e+00,
#         2.67190764e+00,  2.57388816e+00,  2.46434595e+00,  2.34159004e+00,
#         2.20302384e+00,  2.04451183e+00,  1.85920640e+00,  1.63551304e+00,
#         1.35493019e+00,  1.00000000e+00,  3.24138473e+00,  3.23758000e+00,
#         3.22615980e+00,  3.20710935e+00,  3.18040165e+00,  3.14599397e+00,
#         3.10382210e+00,  3.05379160e+00,  2.99576474e+00,  2.92954116e+00,
#         2.85482924e+00,  2.77120297e+00,  2.67803518e+00,  2.57438988e+00,
#         2.45883796e+00,  2.32911448e+00,  2.18140670e+00,  2.00864410e+00,
#         1.79562665e+00,  1.50251946e+00,  1.00000000e+00,  3.24138473e+00,
#         3.23758000e+00,  3.22615980e+00,  3.20710935e+00,  3.18040165e+00,
#         3.14599397e+00,  3.10382210e+00,  3.05379160e+00,  2.99576474e+00,
#         2.92954116e+00,  2.85482924e+00,  2.77120297e+00,  2.67803518e+00,
#         2.57438988e+00,  2.45883796e+00,  2.32911448e+00,  2.18140670e+00,
#         2.00864410e+00,  1.79562665e+00,  1.50251946e+00,  1.00000000e+00,
#         3.32969595e+00,  3.32601086e+00,  3.31495437e+00,  3.29652333e+00,
#         3.27071119e+00,  3.23750564e+00,  3.19688475e+00,  3.14881095e+00,
#         3.09322193e+00,  3.03001733e+00,  2.95903929e+00,  2.88004458e+00,
#         2.79266423e+00,  2.69634472e+00,  2.59026141e+00,  2.47319306e+00,
#         2.34335966e+00,  2.19833950e+00,  2.03583225e+00,  1.85952259e+00,
#         1.71268858e+00,  3.42538925e+00,  3.42182495e+00,  3.41113528e+00,
#         3.39333013e+00,  3.36842576e+00,  3.33644414e+00,  3.29741163e+00,
#         3.25135662e+00,  3.19830560e+00,  3.13827754e+00,  3.07127630e+00,
#         2.99728176e+00,  2.91624198e+00,  2.82807240e+00,  2.73267847e+00,
#         2.63004463e+00,  2.52050669e+00,  2.40552851e+00,  2.28984597e+00,
#         2.18705485e+00,  2.13171284e+00,  3.52822332e+00,  3.52477652e+00,
#         3.51444373e+00,  3.49724816e+00,  3.47322949e+00,  3.44244532e+00,
#         3.40497269e+00,  3.36090977e+00,  3.31037758e+00,  3.25352199e+00,
#         3.19051738e+00,  3.12157464e+00,  3.04695961e+00,  2.96703413e+00,
#         2.88234467e+00,  2.79380906e+00,  2.70310214e+00,  2.61342949e+00,
#         2.53097527e+00,  2.46714447e+00,  2.44005897e+00,  3.63796331e+00,
#         3.63462640e+00,  3.62462726e+00,  3.60800149e+00,  3.58481089e+00,
#         3.55514703e+00,  3.51913596e+00,  3.47694399e+00,  3.42878457e+00,
#         3.37492686e+00,  3.31570775e+00,  3.25155073e+00,  3.18299831e+00,
#         3.11077010e+00,  3.03586692e+00,  2.95975428e+00,  2.88467241e+00,
#         2.81412068e+00,  2.75348936e+00,  2.71049669e+00,  2.69424159e+00,
#         3.75438956e+00,  3.75115091e+00,  3.74144980e+00,  3.72533200e+00,
#         3.70287783e+00,  3.67420815e+00,  3.63949225e+00,  3.59895768e+00,
#         3.55290171e+00,  3.50170483e+00,  3.44584756e+00,  3.38593353e+00,
#         3.32272388e+00,  3.25719182e+00,  3.19060916e+00,  3.12467893e+00,
#         3.06172239e+00,  3.00490103e+00,  2.95837406e+00,  2.92712037e+00,
#         2.91592282e+00,  3.87730553e+00,  3.87415029e+00,  3.86470145e+00,
#         3.84901125e+00,  3.82717264e+00,  3.79932776e+00,  3.76567941e+00,
#         3.72650491e+00,  3.68217182e+00,  3.63315509e+00,  3.58005592e+00,
#         3.52362356e+00,  3.46478332e+00,  3.40467541e+00,  3.34470999e+00,
#         3.28664068e+00,  3.23264778e+00,  3.18539733e+00,  3.14799561e+00,
#         3.12369795e+00,  3.11521875e+00,  4.00654426e+00,  4.00345562e+00,
#         3.99420676e+00,  3.97885122e+00,  3.95748600e+00,  3.93026310e+00,
#         3.89740495e+00,  3.85922290e+00,  3.81613767e+00,  3.76869985e+00,
#         3.71760942e+00,  3.66373333e+00,  3.60812217e+00,  3.55202811e+00,
#         3.49692619e+00,  3.44453736e+00,  3.39684186e+00,  3.35605593e+00,
#         3.32452400e+00,  3.30446789e+00,  3.29756690e+00,  4.14197239e+00,
#         4.13893327e+00,  4.12983090e+00,  4.11471299e+00,  4.09366917e+00,
#         4.06684583e+00,  4.03446648e+00,  3.99685620e+00,  3.95446819e+00,
#         3.90790928e+00,  3.85796062e+00,  3.80559017e+00,  3.75195588e+00,
#         3.69840055e+00,  3.64644113e+00,  3.59775243e+00,  3.55413802e+00,
#         3.51747209e+00,  3.48958806e+00,  3.47209414e+00,  3.46612442e+00,
#         4.28349048e+00,  4.28048601e+00,  4.27148239e+00,  4.25651253e+00,
#         4.23564369e+00,  4.20899644e+00,  4.17677086e+00,  4.13927915e+00,
#         4.09698157e+00,  4.05052048e+00,  4.00074562e+00,  3.94872291e+00,
#         3.89572270e+00,  3.84318913e+00,  3.79269743e+00,  3.74590525e+00,
#         3.70449773e+00,  3.67011835e+00,  3.64427397e+00,  3.62820814e+00,
#         3.62275437e+00,  4.43102883e+00,  4.42804928e+00,  4.41911154e+00,
#         4.40422246e+00,  4.38340812e+00,  4.35673690e+00,  4.32435293e+00,
#         4.28651965e+00,  4.24367017e+00,  4.19645726e+00,  4.14579038e+00,
#         4.09284513e+00,  4.03903494e+00,  3.98594799e+00,  3.93526640e+00,
#         3.88868566e+00,  3.84784160e+00,  3.81424191e+00,  3.78919365e+00,
#         3.77372243e+00,  3.76848903e+00,  4.58453704e+00,  4.58158158e+00,
#         4.57270292e+00,  4.55786858e+00,  4.53704041e+00,  4.51020116e+00,
#         4.47739548e+00,  4.43878759e+00,  4.39473359e+00,  4.34585954e+00,
#         4.29312517e+00,  4.23784411e+00,  4.18163593e+00,  4.12631358e+00,
#         4.07374679e+00,  4.02574174e+00,  3.98395357e+00,  3.94982656e+00,
#         3.92454887e+00,  3.90901152e+00,  3.90376946e+00,  4.74396626e+00,
#         4.74104726e+00,  4.73226023e+00,  4.71751880e+00,  4.69669416e+00,
#         4.66964229e+00,  4.63625083e+00,  4.59651238e+00,  4.55062796e+00,
#         4.49913325e+00,  4.44301799e+00,  4.38378175e+00,  4.32336286e+00,
#         4.26393563e+00,  4.20767762e+00,  4.15659332e+00,  4.11241693e+00,
#         4.07657453e+00,  4.05017651e+00,  4.03401810e+00,  4.02857854e+00,
#         4.90924275e+00,  4.90639041e+00,  4.89778141e+00,  4.88326178e+00,
#         4.86258476e+00,  4.83543277e+00,  4.80146309e+00,  4.76039324e+00,
#         4.71214296e+00,  4.65703808e+00,  4.59604264e+00,  4.53091322e+00,
#         4.46410960e+00,  4.39840024e+00,  4.33644679e+00,  4.28054932e+00,
#         4.23255880e+00,  4.19389083e+00,  4.16557734e+00,  4.14831873e+00,
#         4.14252142e+00,  5.08023232e+00,  5.07749877e+00,  5.06922183e+00,
#         5.05517081e+00,  5.03495911e+00,  5.00804987e+00,  4.97378463e+00,
#         4.93146386e+00,  4.88052216e+00,  4.82084341e+00,  4.75321158e+00,
#         4.67972954e+00,  4.60377318e+00,  4.52912041e+00,  4.45917181e+00,
#         4.39661053e+00,  4.34339058e+00,  4.30086533e+00,  4.26993613e+00,
#         4.25117098e+00,  4.24488264e+00,  5.25669635e+00,  5.25415809e+00,
#         5.24644396e+00,  5.23324819e+00,  5.21403883e+00,  5.18803094e+00,
#         5.15416988e+00,  5.11116383e+00,  5.05764719e+00,  4.99261095e+00,
#         4.91624033e+00,  4.83103028e+00,  4.74214374e+00,  4.65514752e+00,
#         4.57452106e+00,  4.50334236e+00,  4.44353996e+00,  4.39625636e+00,
#         4.36214366e+00,  4.34155932e+00,  4.33468013e+00,  5.43824318e+00,
#         5.43599976e+00,  5.42915425e+00,  5.41734580e+00,  5.39992378e+00,
#         5.37587208e+00,  5.34370723e+00,  5.30138181e+00,  5.24629957e+00,
#         5.17572110e+00,  5.08811727e+00,  4.98601690e+00,  4.87863398e+00,
#         4.77481549e+00,  4.68043374e+00,  4.59870963e+00,  4.53118268e+00,
#         4.47848894e+00,  4.44083555e+00,  4.41825537e+00,  4.41073213e+00,
#         5.62428194e+00,  5.62244883e+00,  5.61683283e+00,  5.60706239e+00,
#         5.59244396e+00,  5.57183207e+00,  5.54341107e+00,  5.50436284e+00,
#         5.45045479e+00,  5.37586374e+00,  5.27449854e+00,  5.14629462e+00,
#         5.01156914e+00,  4.88505685e+00,  4.77369961e+00,  4.67989116e+00,
#         4.60400414e+00,  4.54569351e+00,  4.50446684e+00,  4.47990724e+00,
#         4.47175052e+00,  5.81399073e+00,  5.81268487e+00,  5.80866992e+00,
#         5.80163114e+00,  5.79096183e+00,  5.77560557e+00,  5.75374673e+00,
#         5.72220856e+00,  5.67529830e+00,  5.60278639e+00,  5.48772515e+00,
#         5.31310152e+00,  5.13629976e+00,  4.98015275e+00,  4.84942713e+00,
#         4.74316244e+00,  4.65926093e+00,  4.59582631e+00,  4.55144355e+00,
#         4.52516895e+00,  4.51646822e+00,  6.00631375e+00,  6.00563271e+00,
#         6.00353362e+00,  5.99983322e+00,  5.99416956e+00,  5.98588462e+00,
#         5.97376487e+00,  5.95542972e+00,  5.92574719e+00,  5.87226267e+00,
#         5.76051938e+00,  5.48209312e+00,  5.24038351e+00,  5.04983638e+00,
#         4.90070379e+00,  4.78408146e+00,  4.69406242e+00,  4.62691933e+00,
#         4.58032452e+00,  4.55286942e+00,  4.54379715e+00,  6.20000000e+00,
#         6.20000000e+00,  6.20000000e+00,  6.20000000e+00,  6.20000000e+00,
#         6.20000000e+00,  6.20000000e+00,  6.20000000e+00,  6.20000000e+00,
#         6.20000000e+00,  6.20000000e+00,  5.61437352e+00,  5.29331202e+00,
#         5.07811413e+00,  4.91948003e+00,  4.79840795e+00,  4.70599939e+00,
#         4.63747607e+00,  4.59007812e+00,  4.56219965e+00,  4.55299419e+00,
#        -2.09556884e-03, -4.19701937e-03, -4.21469469e-03, -4.24474980e-03,
#        -4.28811251e-03, -4.34614970e-03, -4.42074071e-03, -4.51438209e-03,
#        -4.63033697e-03, -4.77285346e-03, -4.94749692e-03, -5.16167838e-03,
#        -5.42553445e-03, -5.75346334e-03, -6.16695117e-03, -6.70010585e-03,
#        -7.41134491e-03, -8.41043059e-03, -9.92785970e-03, -1.25138524e-02,
#        -3.01371459e-02])
