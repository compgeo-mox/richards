# %% [markdown]
# # Darcy equation
#
# In this tutorial we present how to solve an evolutionary Darcy equation with [PyGeoN](https://github.com/compgeo-mox/pygeon).  The unkwons are the velocity $q$ and the pressure $p$.
#
# Let $\Omega=(0,1)^2$ with boundary $\partial \Omega$ and outward unit normal ${\nu}$. Let $(0,T)$ with $10=T>0$ be the overall simulation period. Given
# $k$ the matrix permeability, we want to solve the following problem: find $({q}, p)$ such that
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# k^{-1} {q} + \nabla p = {- \rho g \nabla y}\\
# p_t + \nabla \cdot {q} = f
# \end{array}
# &\text{in } \Omega \times (0,T)
# \end{array}
# \right.
# $$
# with boundary conditions:
# $$ p = 0 \text{ on } \partial_{top} \Omega \times (0,T] \qquad p = \rho g \text{ on } \partial_{bottom} \Omega \times (0,T] \qquad \nu \cdot q = 0 \text{ on } \partial_{left} \Omega \cup \partial_{right} \Omega \times (0,T] $$
# and initial conditions:
# $$ p|_{t=0} = (1-y) \rho g \text{ in } \Omega \qquad q|_{t=0} = 0 \text{ in } \Omega $$
#
# We present *step-by-step* how to create the grid, declare the problem data, and finally solve the problem.

# %% [markdown]
# First we import some of the standard modules, like `numpy` and `scipy.sparse`. Since PyGeoN is based on [PorePy](https://github.com/pmgbergen/porepy) we import both modules.

# %%
# %load_ext Cython

# %%
import shutil
import os

import numpy as np
import scipy.sparse as sps
import scipy.integrate as integrate

import porepy as pp
import pygeon as pg

import sympy as sp

from math import ceil, floor, log10, exp
# Out:
# /opt/conda/lib/python3.11/site-packages/porepy/numerics/nonlinear/nonlinear_solvers.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange  # type: ignore

# %% [markdown]
# ### Initial parameters definition

# %%
# Set the maximum number of iterations of the non-linear solver
K = 50

# L-scheme parameter
L = 3.501e-2

# Set the mesh refinment
N = 20

# Set the number of steps (excluding the initial condition)
num_steps = 100

quad_order = 1

# Simulation time length
T = 100/48

# Time switch conditions (for the boundary condition)
dt_D = 3/48

# Fluid density
rho = 1000

# Relative and absolute tolerances for the non-linear solver
abs_tol = 1e-10
rel_tol = 1e-5

# Domain tolerance
domain_tolerance = 1 / (10 * N)

# Output directory
output_directory = 'primal_test'

# %%
def initial_h(x): return 1

# %%
# Van Genuchten model parameters ( relative permeability model )
theta_s = 0.396
theta_r = 0.131

alpha = 0.423

n = 2.06
K_s = 4.96e-2

m = 1 - 1/n

# %%
# Time step
dt   = (T-0)/num_steps

# %% [markdown]
# ### $\theta$ and $K$

# %%
# Symbolic psi
psi_var = sp.Symbol('psi', negative=True)

# Symbolic Theta
theta_expression = theta_r + (theta_s - theta_r) / (1 + (-alpha * psi_var) ** n) ** m
effective_saturation = (theta_expression - theta_r) / (theta_s - theta_r)

# Symbolic Conductivity K
hydraulic_conductivity_expression = K_s * (effective_saturation ** 0.5) * ( 1 - (1 - effective_saturation ** (1 / m)) ** m ) ** 2

# %%
# Theta lambda
theta_lambda = sp.lambdify(psi_var, theta_expression, 'numpy')

# Conductivity tensor lambda
conductivity_lambda = sp.lambdify(psi_var, hydraulic_conductivity_expression, 'numpy')

# %%
# Actual (and final) theta function
def theta(psi):
    mask = np.where(psi < 0)
    res = np.ones_like(psi) * theta_s
    res[mask] = theta_lambda(psi[mask])

    return res

# %%
# Actual (and final) theta function
def conductivity(psi):
    if psi < 0:
        return conductivity_lambda(psi)
    else:
        return K_s

# %% [markdown]
# ### Mesh and $V_h$

# %%
key = "flow"

# %%
# Prepare the domain and its mesh
subdomain = pp.StructuredTriangleGrid([2*N, 3*N], [2,3])

# Convert it to a mixed-dimensional grid
mdg = pp.meshing.subdomains_to_mdg([subdomain])

# %%
h_field = pg.Lagrange1(key)

# %%
dof_h = darcy_dof = h_field.ndof(subdomain)

# %% [markdown]
# ### BC

# %% [markdown]
# #### Dirichlet (essential)

# %%
right_bot = np.logical_and( subdomain.nodes[0, :] == 2, subdomain.nodes[1, :] < 1 )
left_top  = np.logical_and( subdomain.nodes[1, :] == 3, subdomain.nodes[0, :] < 1 )

dirichlet_flag  = np.logical_or(left_top, right_bot)
dirichlet_value = lambda t: np.array(right_bot, dtype=float) + np.array(left_top, dtype=float) * min( 3.2, 1 + 2.2 * t / dt_D )

# %% [markdown]
# #### Neumann (natural)

# %% [markdown]
# ### Matrix Assembly

# %%
# %%cython
# import numpy as np
#
# def find_ordering(coord: np.array):
#     lx = np.argmin(coord[0, :])
#     rx = np.argmax(coord[0, :])
#     mx = np.setdiff1d(np.array([0,1,2]), np.array([lx, rx]))[0]
#
#     # Vertical Alignment
#     if np.abs( coord[0, lx] - coord[0, mx] ) < 1e-7:
#         # lx and mx vertical aligned, rx no
#         up =   lx if np.argmax(coord[1, np.array([lx, mx])]) == 0 else mx
#         down = lx if np.argmin(coord[1, np.array([lx, mx])]) == 0 else mx
#
#         if np.abs( coord[1, up] - coord[1, rx] ) < 1e-7:
#             return [up, down, rx]
#         else:
#             return [down, rx, up]
#     else:
#         # rx and mx vertical aligned, lx no
#         up =   rx if np.argmax(coord[1, np.array([rx, mx])]) == 0 else mx
#         down = rx if np.argmin(coord[1, np.array([rx, mx])]) == 0 else mx
#
#         if np.abs( coord[1, up] - coord[1, lx] ) < 1e-7:
#             return [up, lx, down]
#         else:
#             return [down, up, lx]

# %%
# %%cython
# import numpy as np
#
# def q1():
#     return np.array([-1, -1])
#
# def q2():
#     return np.array([ 1, 0])
#
# def q3():
#     return np.array([0,  1])

# %%
def local_A(coord, psi):

    element_height = (np.max(coord[1, :]) - np.min(coord[1, :]))
    element_width  = (np.max(coord[0, :]) - np.min(coord[0, :]))

    ordering = find_ordering(coord)

    x0 = coord[:, ordering][:, 0]
    x1 = coord[:, ordering][:, 1]
    x2 = coord[:, ordering][:, 2]
    
    J_T_1_T = np.array([[x2[1]-x0[1], x0[1]-x1[1]],
                        [x0[0]-x2[0], x1[0]-x0[0]]]) / ((x1[0]-x0[0]) * (x2[1]-x0[1]) - (x2[0]-x0[0]) * (x1[1]-x0[1]))
    

    q_funcs = [J_T_1_T @ q1(), J_T_1_T @ q2(), J_T_1_T @ q3()]

    M = np.zeros(shape=(3,3))

    jacobian = 1 / np.linalg.det( J_T_1_T.T )
    ordered_psi = psi[ordering]

    psi_fun = lambda x,y: ordered_psi[0] + (ordered_psi[1] - ordered_psi[0]) * x + (ordered_psi[2] - ordered_psi[0]) * y

    for i in range(3):
        for j in range(3):
            integrand = lambda ys,x: np.array([conductivity(psi_fun(x,y)) for y in np.array(ys)])
            inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
            tmp = integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]

            M[ ordering[i], ordering[j] ] = tmp * q_funcs[j].T @ np.array([[1, 0], [0, 1]]) @ q_funcs[i] * jacobian

    return M

# %%
def stifness(psi):

    # Map the domain to a reference geometry (i.e. equivalent to compute
    # surface coordinates in 1d and 2d)

    _, _, _, _, _, node_coords = pp.map_geometry.map_grid(subdomain)

    # Allocate the data to store matrix entries, that's the most efficient
    # way to create a sparse matrix.
    size = np.power(subdomain.dim + 1, 2) * subdomain.num_cells
    rows_I = np.empty(size, dtype=int)
    cols_J = np.empty(size, dtype=int)
    data_IJ = np.empty(size)
    idx = 0

    cell_nodes = subdomain.cell_nodes()

    for c in np.arange(subdomain.num_cells):
        # For the current cell retrieve its nodes
        loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

        nodes_loc = cell_nodes.indices[loc]
        coord_loc = node_coords[:, nodes_loc]


        # Compute the stiff-H1 local matrix
        A = local_A(coord_loc, psi[nodes_loc])

        # Save values for stiff-H1 local matrix in the global structure
        cols = np.tile(nodes_loc, (nodes_loc.size, 1))
        loc_idx = slice(idx, idx + cols.size)
        rows_I[loc_idx] = cols.T.ravel()
        cols_J[loc_idx] = cols.ravel()
        data_IJ[loc_idx] = A.ravel()
        idx += cols.size

    # Construct the global matrices
    return sps.csc_matrix((data_IJ, (rows_I, cols_J)))

# %%
M_h = h_field.assemble_mass_matrix(subdomain)

# %%
proj_psi = h_field.eval_at_cell_centers(subdomain)

# %% [markdown]
# ### Solve system

# %%
if os.path.exists(output_directory):
    shutil.rmtree(output_directory)

# %%
def save_step(sol, saver, i):
    ins = list()

    ins.append((subdomain, "cell_h", proj_psi @ sol))
    ins.append((subdomain, "cell_p", proj_psi @ (sol - subdomain.nodes[1,:])))

    saver.write_vtu(ins, time_step=i)

# %%
sol = h_field.interpolate(subdomain, initial_h)

# %%
# Save the initial solution
saver = pp.Exporter(mdg, 'sol', folder_name=output_directory)
save_step(sol, saver, 0)

# %%
csv_base = os.path.join(output_directory, 'csv')

if os.path.exists(csv_base):
    shutil.rmtree(csv_base)
    
os.mkdir(csv_base)

# %%
for time_instant_index in range(1, num_steps+1):

    time = time_instant_index * dt
    print('Time ' + str(round(time, 5)))

    prev = sol

    time_rhs = np.zeros(dof_h)
    time_rhs = M_h @ theta(prev - subdomain.nodes[1,:])

    for k in range(K):
        spp = L * M_h + dt * stifness(prev - subdomain.nodes[1,:])
        rhs = time_rhs.copy()

        rhs += L * M_h @ prev - M_h @ theta(prev - subdomain.nodes[1,:])

        ls = pg.LinearSystem(spp, rhs)
        ls.flag_ess_bc( dirichlet_flag, dirichlet_value(time) )

        current = ls.solve()

        # Check if we have reached convergence
        rel_err_psi  = np.sqrt( (current - prev).T @ M_h @ (current - prev) )
        abs_err_prev = np.sqrt( prev.T @ M_h @ prev )

        # Log message with error and current iteration
        print('Iteration #' + format(k+1, '0' + str(ceil(log10(K)) + 1) + 'd') + ', error L2 relative psi: ' 
              + format(rel_err_psi, str(5 + ceil(log10(1 / abs_tol)) + 4) + '.' + str(ceil(log10(1 / abs_tol)) + 4) + 'f') )
        
        if rel_err_psi > abs_tol + rel_tol * abs_err_prev:
            prev = current.copy()
        else:
            break
        
    print('')    
    sol = current
    
    save_step(sol, saver, time_instant_index)

    export_name = os.path.join(csv_base, str(time_instant_index) + '.csv')

    with open( export_name, 'w' ) as file:

        file.write('x,y,h,p\n')

        for x,y,h,p in zip( subdomain.nodes[0, :], subdomain.nodes[1, :], sol, sol - subdomain.nodes[1, :]):
            file.write(f'{x},{y},{h},{p}\n')



saver.write_pvd([n * dt for n in range(num_steps + 1)])
# Out:
# Time 0.02083
# Iteration #001, error L2 relative psi:    0.12889757065075
# Iteration #002, error L2 relative psi:    0.01920670674581
# Iteration #003, error L2 relative psi:    0.00077469684117
# Iteration #004, error L2 relative psi:    0.00006918225340
# Iteration #005, error L2 relative psi:    0.00000269705545
#
# Time 0.04167
# Iteration #001, error L2 relative psi:    0.19350293213301
# Iteration #002, error L2 relative psi:    0.05103853422104
# Iteration #003, error L2 relative psi:    0.00891432434349
# Iteration #004, error L2 relative psi:    0.00091136652437
# Iteration #005, error L2 relative psi:    0.00030128635689
# Iteration #006, error L2 relative psi:    0.00002875816909
# Iteration #007, error L2 relative psi:    0.00000961381556
#
# Time 0.0625
# Iteration #001, error L2 relative psi:    0.27423154897709
# Iteration #002, error L2 relative psi:    0.09241203696787
# Iteration #003, error L2 relative psi:    0.02483493701958
# Iteration #004, error L2 relative psi:    0.00417987732358
# Iteration #005, error L2 relative psi:    0.00173390964494
# Iteration #006, error L2 relative psi:    0.00039126306616
# Iteration #007, error L2 relative psi:    0.00010749295116
# Iteration #008, error L2 relative psi:    0.00003338325530
# Iteration #009, error L2 relative psi:    0.00000698502785
#
# Time 0.08333
# Iteration #001, error L2 relative psi:    0.18277114579504
# Iteration #002, error L2 relative psi:    0.02925560032656
# Iteration #003, error L2 relative psi:    0.00539300107018
# Iteration #004, error L2 relative psi:    0.00192986508729
# Iteration #005, error L2 relative psi:    0.00043357035961
# Iteration #006, error L2 relative psi:    0.00009449711773
# Iteration #007, error L2 relative psi:    0.00002877104330
# Iteration #008, error L2 relative psi:    0.00000598086418
#
# Time 0.10417
# Iteration #001, error L2 relative psi:    0.14307464074533
# Iteration #002, error L2 relative psi:    0.01559383374330
# Iteration #003, error L2 relative psi:    0.00263983658344
# Iteration #004, error L2 relative psi:    0.00076620437778
# Iteration #005, error L2 relative psi:    0.00015914771125
# Iteration #006, error L2 relative psi:    0.00002667083132
#
# Time 0.125
# Iteration #001, error L2 relative psi:    0.11901854002006
# Iteration #002, error L2 relative psi:    0.01064069077442
# Iteration #003, error L2 relative psi:    0.00147244103579
# Iteration #004, error L2 relative psi:    0.00027314823855
# Iteration #005, error L2 relative psi:    0.00006054861507
# Iteration #006, error L2 relative psi:    0.00000899241088
#
# Time 0.14583
# Iteration #001, error L2 relative psi:    0.10238175586670
# Iteration #002, error L2 relative psi:    0.00899302572600
# Iteration #003, error L2 relative psi:    0.00140766360527
# Iteration #004, error L2 relative psi:    0.00023153793422
# Iteration #005, error L2 relative psi:    0.00005130803832
# Iteration #006, error L2 relative psi:    0.00001305872436
#
# Time 0.16667
# Iteration #001, error L2 relative psi:    0.09015209438746
# Iteration #002, error L2 relative psi:    0.00855193749395
# Iteration #003, error L2 relative psi:    0.00170871145427
# Iteration #004, error L2 relative psi:    0.00042813530373
# Iteration #005, error L2 relative psi:    0.00012351742302
# Iteration #006, error L2 relative psi:    0.00003859062040
# Iteration #007, error L2 relative psi:    0.00001799109568
#
# Time 0.1875
# Iteration #001, error L2 relative psi:    0.08065870031233
# Iteration #002, error L2 relative psi:    0.00854523439502
# Iteration #003, error L2 relative psi:    0.00202020083216
# Iteration #004, error L2 relative psi:    0.00061643163719
# Iteration #005, error L2 relative psi:    0.00021071560504
# Iteration #006, error L2 relative psi:    0.00007953653127
# Iteration #007, error L2 relative psi:    0.00004123900741
# Iteration #008, error L2 relative psi:    0.00003168344234
# Iteration #009, error L2 relative psi:    0.00002844665277
#
# Time 0.20833
# Iteration #001, error L2 relative psi:    0.07301831475668
# Iteration #002, error L2 relative psi:    0.00876033129624
# Iteration #003, error L2 relative psi:    0.00231399092511
# Iteration #004, error L2 relative psi:    0.00079588293889
# Iteration #005, error L2 relative psi:    0.00030894793401
# Iteration #006, error L2 relative psi:    0.00013604252909
# Iteration #007, error L2 relative psi:    0.00007968868584
# Iteration #008, error L2 relative psi:    0.00006293038817
# Iteration #009, error L2 relative psi:    0.00005646395728
# Iteration #010, error L2 relative psi:    0.00005245752056
# Iteration #011, error L2 relative psi:    0.00004925037376
# Iteration #012, error L2 relative psi:    0.00004644557791
# Iteration #013, error L2 relative psi:    0.00004390678929
# Iteration #014, error L2 relative psi:    0.00004156767963
# Iteration #015, error L2 relative psi:    0.00003938941094
# Iteration #016, error L2 relative psi:    0.00003734717554
# Iteration #017, error L2 relative psi:    0.00003542418578
# Iteration #018, error L2 relative psi:    0.00003360845042
# Iteration #019, error L2 relative psi:    0.00003189092337
# Iteration #020, error L2 relative psi:    0.00003026441385
#
# Time 0.22917
# Iteration #001, error L2 relative psi:    0.06672128486604
# Iteration #002, error L2 relative psi:    0.00907515208555
# Iteration #003, error L2 relative psi:    0.00256781916413
# Iteration #004, error L2 relative psi:    0.00094978683048
# Iteration #005, error L2 relative psi:    0.00040397315209
# Iteration #006, error L2 relative psi:    0.00019982609871
# Iteration #007, error L2 relative psi:    0.00012804488706
# Iteration #008, error L2 relative psi:    0.00010338884938
# Iteration #009, error L2 relative psi:    0.00009255900249
# Iteration #010, error L2 relative psi:    0.00008569411763
# Iteration #011, error L2 relative psi:    0.00008028602234
# Iteration #012, error L2 relative psi:    0.00007562322917
# Iteration #013, error L2 relative psi:    0.00007144026052
# Iteration #014, error L2 relative psi:    0.00006760760092
# Iteration #015, error L2 relative psi:    0.00006405091231
# Iteration #016, error L2 relative psi:    0.00006072367782
# Iteration #017, error L2 relative psi:    0.00005759504794
# Iteration #018, error L2 relative psi:    0.00005464344610
# Iteration #019, error L2 relative psi:    0.00005185293999
# Iteration #020, error L2 relative psi:    0.00004921111768
# Iteration #021, error L2 relative psi:    0.00004670782602
# Iteration #022, error L2 relative psi:    0.00004433441291
# Iteration #023, error L2 relative psi:    0.00004208326700
# Iteration #024, error L2 relative psi:    0.00003994753384
# Iteration #025, error L2 relative psi:    0.00003792093768
# Iteration #026, error L2 relative psi:    0.00003599766673
# Iteration #027, error L2 relative psi:    0.00003417229694
# Iteration #028, error L2 relative psi:    0.00003243973961
# Iteration #029, error L2 relative psi:    0.00003079520364
#
# Time 0.25
# Iteration #001, error L2 relative psi:    0.06140734647053
# Iteration #002, error L2 relative psi:    0.00945317562180
# Iteration #003, error L2 relative psi:    0.00283216621082
# Iteration #004, error L2 relative psi:    0.00111703888202
# Iteration #005, error L2 relative psi:    0.00051971047432
# Iteration #006, error L2 relative psi:    0.00028618663107
# Iteration #007, error L2 relative psi:    0.00019698745086
# Iteration #008, error L2 relative psi:    0.00016175863375
# Iteration #009, error L2 relative psi:    0.00014447035551
# Iteration #010, error L2 relative psi:    0.00013325964917
# Iteration #011, error L2 relative psi:    0.00012454886422
# Iteration #012, error L2 relative psi:    0.00011715027195
# Iteration #013, error L2 relative psi:    0.00011058104726
# Iteration #014, error L2 relative psi:    0.00010460163243
# Iteration #015, error L2 relative psi:    0.00009907609720
# Iteration #016, error L2 relative psi:    0.00009392084242
# Iteration #017, error L2 relative psi:    0.00008908145018
# Iteration #018, error L2 relative psi:    0.00008452062131
# Iteration #019, error L2 relative psi:    0.00008021139780
# Iteration #020, error L2 relative psi:    0.00007613321831
# Iteration #021, error L2 relative psi:    0.00007226958203
# Iteration #022, error L2 relative psi:    0.00006860664890
# Iteration #023, error L2 relative psi:    0.00006513239172
# Iteration #024, error L2 relative psi:    0.00006183607584
# Iteration #025, error L2 relative psi:    0.00005870793447
# Iteration #026, error L2 relative psi:    0.00005573896176
# Iteration #027, error L2 relative psi:    0.00005292077709
# Iteration #028, error L2 relative psi:    0.00005024553311
# Iteration #029, error L2 relative psi:    0.00004770585086
# Iteration #030, error L2 relative psi:    0.00004529477198
# Iteration #031, error L2 relative psi:    0.00004300572188
# Iteration #032, error L2 relative psi:    0.00004083248018
# Iteration #033, error L2 relative psi:    0.00003876915604
# Iteration #034, error L2 relative psi:    0.00003681016701
# Iteration #035, error L2 relative psi:    0.00003495022030
# Iteration #036, error L2 relative psi:    0.00003318429603
# Iteration #037, error L2 relative psi:    0.00003150763191
#
# Time 0.27083
# Iteration #001, error L2 relative psi:    0.05685122256588
# Iteration #002, error L2 relative psi:    0.00989533697088
# Iteration #003, error L2 relative psi:    0.00315056556178
# Iteration #004, error L2 relative psi:    0.00131804757928
# Iteration #005, error L2 relative psi:    0.00066548405448
# Iteration #006, error L2 relative psi:    0.00040179052753
# Iteration #007, error L2 relative psi:    0.00029318376363
# Iteration #008, error L2 relative psi:    0.00024485401614
# Iteration #009, error L2 relative psi:    0.00021879443620
# Iteration #010, error L2 relative psi:    0.00020138628433
# Iteration #011, error L2 relative psi:    0.00018790726299
# Iteration #012, error L2 relative psi:    0.00017656704896
# Iteration #013, error L2 relative psi:    0.00016657531887
# Iteration #014, error L2 relative psi:    0.00015752810901
# Iteration #015, error L2 relative psi:    0.00014919586714
# Iteration #016, error L2 relative psi:    0.00014143858851
# Iteration #017, error L2 relative psi:    0.00013416618385
# Iteration #018, error L2 relative psi:    0.00012731772853
# Iteration #019, error L2 relative psi:    0.00012084984169
# Iteration #020, error L2 relative psi:    0.00011472994407
# Iteration #021, error L2 relative psi:    0.00010893227080
# Iteration #022, error L2 relative psi:    0.00010343548423
# Iteration #023, error L2 relative psi:    0.00009822122885
# Iteration #024, error L2 relative psi:    0.00009327324620
# Iteration #025, error L2 relative psi:    0.00008857682422
# Iteration #026, error L2 relative psi:    0.00008411844817
# Iteration #027, error L2 relative psi:    0.00007988557355
# Iteration #028, error L2 relative psi:    0.00007586647377
# Iteration #029, error L2 relative psi:    0.00007205013409
# Iteration #030, error L2 relative psi:    0.00006842617456
# Iteration #031, error L2 relative psi:    0.00006498479163
# Iteration #032, error L2 relative psi:    0.00006171671189
# Iteration #033, error L2 relative psi:    0.00005861315391
# Iteration #034, error L2 relative psi:    0.00005566579592
# Iteration #035, error L2 relative psi:    0.00005286674739
# Iteration #036, error L2 relative psi:    0.00005020852382
# Iteration #037, error L2 relative psi:    0.00004768402374
# Iteration #038, error L2 relative psi:    0.00004528650770
# Iteration #039, error L2 relative psi:    0.00004300957877
# Iteration #040, error L2 relative psi:    0.00004084716443
# Iteration #041, error L2 relative psi:    0.00003879349954
# Iteration #042, error L2 relative psi:    0.00003684311041
# Iteration #043, error L2 relative psi:    0.00003499079978
# Iteration #044, error L2 relative psi:    0.00003323163264
# Iteration #045, error L2 relative psi:    0.00003156092283
#
# Time 0.29167
# Iteration #001, error L2 relative psi:    0.05291010082402
# Iteration #002, error L2 relative psi:    0.01038252518232
# Iteration #003, error L2 relative psi:    0.00353838125352
# Iteration #004, error L2 relative psi:    0.00156661738277
# Iteration #005, error L2 relative psi:    0.00084962579359
# Iteration #006, error L2 relative psi:    0.00055259295250
# Iteration #007, error L2 relative psi:    0.00042184532559
# Iteration #008, error L2 relative psi:    0.00035761162165
# Iteration #009, error L2 relative psi:    0.00032018869862
# Iteration #010, error L2 relative psi:    0.00029440951039
# Iteration #011, error L2 relative psi:    0.00027439270226
# Iteration #012, error L2 relative psi:    0.00025764530256
# Iteration #013, error L2 relative psi:    0.00024297732584
# Iteration #014, error L2 relative psi:    0.00022975615330
# Iteration #015, error L2 relative psi:    0.00021761742543
# Iteration #016, error L2 relative psi:    0.00020633877761
# Iteration #017, error L2 relative psi:    0.00019577791500
# Iteration #018, error L2 relative psi:    0.00018583949428
# Iteration #019, error L2 relative psi:    0.00017645642988
# Iteration #020, error L2 relative psi:    0.00016757901194
# Iteration #021, error L2 relative psi:    0.00015916845683
# Iteration #022, error L2 relative psi:    0.00015119303832
# Iteration #023, error L2 relative psi:    0.00014362574258
# Iteration #024, error L2 relative psi:    0.00013644283105
# Iteration #025, error L2 relative psi:    0.00012962294741
# Iteration #026, error L2 relative psi:    0.00012314655305
# Iteration #027, error L2 relative psi:    0.00011699556202
# Iteration #028, error L2 relative psi:    0.00011115309811
# Iteration #029, error L2 relative psi:    0.00010560332766
# Iteration #030, error L2 relative psi:    0.00010033133973
# Iteration #031, error L2 relative psi:    0.00009532305654
# Iteration #032, error L2 relative psi:    0.00009056516356
# Iteration #033, error L2 relative psi:    0.00008604505277
# Iteration #034, error L2 relative psi:    0.00008175077484
# Iteration #035, error L2 relative psi:    0.00007767099780
# Iteration #036, error L2 relative psi:    0.00007379497032
# Iteration #037, error L2 relative psi:    0.00007011248865
# Iteration #038, error L2 relative psi:    0.00006661386626
# Iteration #039, error L2 relative psi:    0.00006328990077
# Iteration #040, error L2 relative psi:    0.00006013185070
# Iteration #041, error L2 relative psi:    0.00005713142952
# Iteration #042, error L2 relative psi:    0.00005428076665
# Iteration #043, error L2 relative psi:    0.00005157237862
# Iteration #044, error L2 relative psi:    0.00004899916421
# Iteration #045, error L2 relative psi:    0.00004655436706
# Iteration #046, error L2 relative psi:    0.00004423157891
# Iteration #047, error L2 relative psi:    0.00004202470882
# Iteration #048, error L2 relative psi:    0.00003992796804
# Iteration #049, error L2 relative psi:    0.00003793585497
# Iteration #050, error L2 relative psi:    0.00003604315095
#
# Time 0.3125
# Iteration #001, error L2 relative psi:    0.04946816273303
# Iteration #002, error L2 relative psi:    0.01089536146029
# Iteration #003, error L2 relative psi:    0.00402193599071
# Iteration #004, error L2 relative psi:    0.00189960418033
# Iteration #005, error L2 relative psi:    0.00110004034654
# Iteration #006, error L2 relative psi:    0.00075679782432
# Iteration #007, error L2 relative psi:    0.00059534247355
# Iteration #008, error L2 relative psi:    0.00050956182166
# Iteration #009, error L2 relative psi:    0.00045680871488
# Iteration #010, error L2 relative psi:    0.00041970326781
# Iteration #011, error L2 relative psi:    0.00039084464635
# Iteration #012, error L2 relative psi:    0.00036681261954
# Iteration #013, error L2 relative psi:    0.00034587480658
# Iteration #014, error L2 relative psi:    0.00032708057943
# Iteration #015, error L2 relative psi:    0.00030987514506
# Iteration #016, error L2 relative psi:    0.00029391883449
# Iteration #017, error L2 relative psi:    0.00027899480224
# Iteration #018, error L2 relative psi:    0.00026495867524
# Iteration #019, error L2 relative psi:    0.00025170982866
# Iteration #020, error L2 relative psi:    0.00023917457021
# Iteration #021, error L2 relative psi:    0.00022729613539
# Iteration #022, error L2 relative psi:    0.00021602865590
# Iteration #023, error L2 relative psi:    0.00020533350101
# Iteration #024, error L2 relative psi:    0.00019517701935
# Iteration #025, error L2 relative psi:    0.00018552913322
# Iteration #026, error L2 relative psi:    0.00017636245415
# Iteration #027, error L2 relative psi:    0.00016765171188
# Iteration #028, error L2 relative psi:    0.00015937337686
# Iteration #029, error L2 relative psi:    0.00015150540269
# Iteration #030, error L2 relative psi:    0.00014402704180
# Iteration #031, error L2 relative psi:    0.00013691871827
# Iteration #032, error L2 relative psi:    0.00013016191849
# Iteration #033, error L2 relative psi:    0.00012373910984
# Iteration #034, error L2 relative psi:    0.00011763367251
# Iteration #035, error L2 relative psi:    0.00011182984091
# Iteration #036, error L2 relative psi:    0.00010631265217
# Iteration #037, error L2 relative psi:    0.00010106790004
# Iteration #038, error L2 relative psi:    0.00009608209284
# Iteration #039, error L2 relative psi:    0.00009134241495
# Iteration #040, error L2 relative psi:    0.00008683669101
# Iteration #041, error L2 relative psi:    0.00008255335249
# Iteration #042, error L2 relative psi:    0.00007848140648
# Iteration #043, error L2 relative psi:    0.00007461040623
# Iteration #044, error L2 relative psi:    0.00007093042332
# Iteration #045, error L2 relative psi:    0.00006743202185
# Iteration #046, error L2 relative psi:    0.00006410623356
# Iteration #047, error L2 relative psi:    0.00006094453426
# Iteration #048, error L2 relative psi:    0.00005793882166
# Iteration #049, error L2 relative psi:    0.00005508139431
# Iteration #050, error L2 relative psi:    0.00005236493171
#
# Time 0.33333
# Iteration #001, error L2 relative psi:    0.04644802295623
# Iteration #002, error L2 relative psi:    0.01141742750595
# Iteration #003, error L2 relative psi:    0.00460619628492
# Iteration #004, error L2 relative psi:    0.00233451554329
# Iteration #005, error L2 relative psi:    0.00143233538434
# Iteration #006, error L2 relative psi:    0.00102690938019
# Iteration #007, error L2 relative psi:    0.00082475394487
# Iteration #008, error L2 relative psi:    0.00071092643785
# Iteration #009, error L2 relative psi:    0.00063817156495
# Iteration #010, error L2 relative psi:    0.00058616842502
# Iteration #011, error L2 relative psi:    0.00054563298154
# Iteration #012, error L2 relative psi:    0.00051198796738
# Iteration #013, error L2 relative psi:    0.00048280303727
# Iteration #014, error L2 relative psi:    0.00045670507405
# Iteration #015, error L2 relative psi:    0.00043287989743
# Iteration #016, error L2 relative psi:    0.00041082530567
# Iteration #017, error L2 relative psi:    0.00039022012771
# Iteration #018, error L2 relative psi:    0.00037085109130
# Iteration #019, error L2 relative psi:    0.00035257061575
# Iteration #020, error L2 relative psi:    0.00033527177655
# Iteration #021, error L2 relative psi:    0.00031887325103
# Iteration #022, error L2 relative psi:    0.00030331019701
# Iteration #023, error L2 relative psi:    0.00028852867103
# Iteration #024, error L2 relative psi:    0.00027448215747
# Iteration #025, error L2 relative psi:    0.00026112941201
# Iteration #026, error L2 relative psi:    0.00024843309918
# Iteration #027, error L2 relative psi:    0.00023635892074
# Iteration #028, error L2 relative psi:    0.00022487503526
# Iteration #029, error L2 relative psi:    0.00021395165964
# Iteration #030, error L2 relative psi:    0.00020356079571
# Iteration #031, error L2 relative psi:    0.00019367603207
# Iteration #032, error L2 relative psi:    0.00018427239453
# Iteration #033, error L2 relative psi:    0.00017532622859
# Iteration #034, error L2 relative psi:    0.00016681510357
# Iteration #035, error L2 relative psi:    0.00015871773358
# Iteration #036, error L2 relative psi:    0.00015101390570
# Iteration #037, error L2 relative psi:    0.00014368440898
# Iteration #038, error L2 relative psi:    0.00013671099211
# Iteration #039, error L2 relative psi:    0.00013007630607
# Iteration #040, error L2 relative psi:    0.00012376385655
# Iteration #041, error L2 relative psi:    0.00011775795965
# Iteration #042, error L2 relative psi:    0.00011204370046
# Iteration #043, error L2 relative psi:    0.00010660689366
# Iteration #044, error L2 relative psi:    0.00010143404643
# Iteration #045, error L2 relative psi:    0.00009651232668
# Iteration #046, error L2 relative psi:    0.00009182952865
# Iteration #047, error L2 relative psi:    0.00008737404172
# Iteration #048, error L2 relative psi:    0.00008313482106
# Iteration #049, error L2 relative psi:    0.00007910135984
# Iteration #050, error L2 relative psi:    0.00007526366278
#
# Time 0.35417
# Iteration #001, error L2 relative psi:    0.04379083636102
# Iteration #002, error L2 relative psi:    0.01192121069656
# Iteration #003, error L2 relative psi:    0.00527305583848
# Iteration #004, error L2 relative psi:    0.00287212204672
# Iteration #005, error L2 relative psi:    0.00185364685335
# Iteration #006, error L2 relative psi:    0.00136938956028
# Iteration #007, error L2 relative psi:    0.00111421659914
# Iteration #008, error L2 relative psi:    0.00096390647121
# Iteration #009, error L2 relative psi:    0.00086521304864
# Iteration #010, error L2 relative psi:    0.00079397506863
# Iteration #011, error L2 relative psi:    0.00073848423238
# Iteration #012, error L2 relative psi:    0.00069266066262
# Iteration #013, error L2 relative psi:    0.00065314755524
# Iteration #014, error L2 relative psi:    0.00061799746390
# Iteration #015, error L2 relative psi:    0.00058603611065
# Iteration #016, error L2 relative psi:    0.00055653195427
# Iteration #017, error L2 relative psi:    0.00052901555411
# Iteration #018, error L2 relative psi:    0.00050317526254
# Iteration #019, error L2 relative psi:    0.00047879720845
# Iteration #020, error L2 relative psi:    0.00045572800989
# Iteration #021, error L2 relative psi:    0.00043385262512
# Iteration #022, error L2 relative psi:    0.00041308092790
# Iteration #023, error L2 relative psi:    0.00039333922578
# Iteration #024, error L2 relative psi:    0.00037456481617
# Iteration #025, error L2 relative psi:    0.00035670275981
# Iteration #026, error L2 relative psi:    0.00033970370835
# Iteration #027, error L2 relative psi:    0.00032352272012
# Iteration #028, error L2 relative psi:    0.00030811825724
# Iteration #029, error L2 relative psi:    0.00029345154493
# Iteration #030, error L2 relative psi:    0.00027948620170
# Iteration #031, error L2 relative psi:    0.00026618794984
# Iteration #032, error L2 relative psi:    0.00025352439156
# Iteration #033, error L2 relative psi:    0.00024146479443
# Iteration #034, error L2 relative psi:    0.00022998009289
# Iteration #035, error L2 relative psi:    0.00021904268357
# Iteration #036, error L2 relative psi:    0.00020862631674
# Iteration #037, error L2 relative psi:    0.00019870603695
# Iteration #038, error L2 relative psi:    0.00018925811041
# Iteration #039, error L2 relative psi:    0.00018025995887
# Iteration #040, error L2 relative psi:    0.00017169009870
# Iteration #041, error L2 relative psi:    0.00016352808437
# Iteration #042, error L2 relative psi:    0.00015575445574
# Iteration #043, error L2 relative psi:    0.00014835068854
# Iteration #044, error L2 relative psi:    0.00014129914722
# Iteration #045, error L2 relative psi:    0.00013458301278
# Iteration #046, error L2 relative psi:    0.00012818633077
# Iteration #047, error L2 relative psi:    0.00012209389326
# Iteration #048, error L2 relative psi:    0.00011629120416
# Iteration #049, error L2 relative psi:    0.00011076446400
# Iteration #050, error L2 relative psi:    0.00010550053342
#
# Time 0.375
# Iteration #001, error L2 relative psi:    0.04144649830133
# Iteration #002, error L2 relative psi:    0.01237355763013
# Iteration #003, error L2 relative psi:    0.00599410248206
# Iteration #004, error L2 relative psi:    0.00350764146667
# Iteration #005, error L2 relative psi:    0.00237184505998
# Iteration #006, error L2 relative psi:    0.00179501644465
# Iteration #007, error L2 relative psi:    0.00147369571267
# Iteration #008, error L2 relative psi:    0.00127686846519
# Iteration #009, error L2 relative psi:    0.00114488981301
# Iteration #010, error L2 relative psi:    0.00104901843856
# Iteration #011, error L2 relative psi:    0.00097453820851
# Iteration #012, error L2 relative psi:    0.00091345248542
# Iteration #013, error L2 relative psi:    0.00086118842897
# Iteration #014, error L2 relative psi:    0.00081502286774
# Iteration #015, error L2 relative psi:    0.00077328200304
# Iteration #016, error L2 relative psi:    0.00073490972929
# Iteration #017, error L2 relative psi:    0.00069922271134
# Iteration #018, error L2 relative psi:    0.00066576699692
# Iteration #019, error L2 relative psi:    0.00063423183944
# Iteration #020, error L2 relative psi:    0.00060439701240
# Iteration #021, error L2 relative psi:    0.00057610018485
# Iteration #022, error L2 relative psi:    0.00054921651624
# Iteration #023, error L2 relative psi:    0.00052364604768
# Iteration #024, error L2 relative psi:    0.00049930556425
# Iteration #025, error L2 relative psi:    0.00047612343406
# Iteration #026, error L2 relative psi:    0.00045403632010
# Iteration #027, error L2 relative psi:    0.00043298703436
# Iteration #028, error L2 relative psi:    0.00041292313121
# Iteration #029, error L2 relative psi:    0.00039379597065
# Iteration #030, error L2 relative psi:    0.00037556007910
# Iteration #031, error L2 relative psi:    0.00035817270201
# Iteration #032, error L2 relative psi:    0.00034159348088
# Iteration #033, error L2 relative psi:    0.00032578421193
# Iteration #034, error L2 relative psi:    0.00031070865823
# Iteration #035, error L2 relative psi:    0.00029633236558
# Iteration #036, error L2 relative psi:    0.00028262234131
# Iteration #037, error L2 relative psi:    0.00026954765239
# Iteration #038, error L2 relative psi:    0.00025707869446
# Iteration #039, error L2 relative psi:    0.00024518737912
# Iteration #040, error L2 relative psi:    0.00023384673154
# Iteration #041, error L2 relative psi:    0.00022303129899
# Iteration #042, error L2 relative psi:    0.00021271667047
# Iteration #043, error L2 relative psi:    0.00020287945334
# Iteration #044, error L2 relative psi:    0.00019349763341
# Iteration #045, error L2 relative psi:    0.00018455008396
# Iteration #046, error L2 relative psi:    0.00017601665913
# Iteration #047, error L2 relative psi:    0.00016787812305
# Iteration #048, error L2 relative psi:    0.00016011611224
# Iteration #049, error L2 relative psi:    0.00015271326199
# Iteration #050, error L2 relative psi:    0.00014565292897
#
# Time 0.39583
# Iteration #001, error L2 relative psi:    0.03937701411837
# Iteration #002, error L2 relative psi:    0.01273399681816
# Iteration #003, error L2 relative psi:    0.00671753319466
# Iteration #004, error L2 relative psi:    0.00420655707065
# Iteration #005, error L2 relative psi:    0.00297123160563
# Iteration #006, error L2 relative psi:    0.00229933745419
# Iteration #007, error L2 relative psi:    0.00190330253794
# Iteration #008, error L2 relative psi:    0.00165104309208
# Iteration #009, error L2 relative psi:    0.00147822070725
# Iteration #010, error L2 relative psi:    0.00135175086380
# Iteration #011, error L2 relative psi:    0.00125369773765
# Iteration #012, error L2 relative psi:    0.00117385020055
# Iteration #013, error L2 relative psi:    0.00110614622916
# Iteration #014, error L2 relative psi:    0.00104686918548
# Iteration #015, error L2 relative psi:    0.00099367992737
# Iteration #016, error L2 relative psi:    0.00094507415611
# Iteration #017, error L2 relative psi:    0.00090006577830
# Iteration #018, error L2 relative psi:    0.00085799505806
# Iteration #019, error L2 relative psi:    0.00081840986203
# Iteration #020, error L2 relative psi:    0.00078099201145
# Iteration #021, error L2 relative psi:    0.00074551020053
# Iteration #022, error L2 relative psi:    0.00071179023152
# Iteration #023, error L2 relative psi:    0.00067969611572
# Iteration #024, error L2 relative psi:    0.00064911735433
# Iteration #025, error L2 relative psi:    0.00061996107059
# Iteration #026, error L2 relative psi:    0.00059214693928
# Iteration #027, error L2 relative psi:    0.00056560370332
# Iteration #028, error L2 relative psi:    0.00054026682196
# Iteration #029, error L2 relative psi:    0.00051607704160
# Iteration #030, error L2 relative psi:    0.00049297934105
# Iteration #031, error L2 relative psi:    0.00047092223225
# Iteration #032, error L2 relative psi:    0.00044985737031
# Iteration #033, error L2 relative psi:    0.00042973873825
# Iteration #034, error L2 relative psi:    0.00041052267486
# Iteration #035, error L2 relative psi:    0.00039216839156
# Iteration #036, error L2 relative psi:    0.00037463698023
# Iteration #037, error L2 relative psi:    0.00035789106808
# Iteration #038, error L2 relative psi:    0.00034189531669
# Iteration #039, error L2 relative psi:    0.00032661600431
# Iteration #040, error L2 relative psi:    0.00031202067066
# Iteration #041, error L2 relative psi:    0.00029807860116
# Iteration #042, error L2 relative psi:    0.00028476054284
# Iteration #043, error L2 relative psi:    0.00027203845373
# Iteration #044, error L2 relative psi:    0.00025988555421
# Iteration #045, error L2 relative psi:    0.00024827606519
# Iteration #046, error L2 relative psi:    0.00023718583669
# Iteration #047, error L2 relative psi:    0.00022659159042
# Iteration #048, error L2 relative psi:    0.00021647110437
# Iteration #049, error L2 relative psi:    0.00020680310454
# Iteration #050, error L2 relative psi:    0.00019756733129
#
# Time 0.41667
# Iteration #001, error L2 relative psi:    0.03754717218938
# Iteration #002, error L2 relative psi:    0.01294936114903
# Iteration #003, error L2 relative psi:    0.00737311490024
# Iteration #004, error L2 relative psi:    0.00491489502197
# Iteration #005, error L2 relative psi:    0.00362024714271
# Iteration #006, error L2 relative psi:    0.00286714767040
# Iteration #007, error L2 relative psi:    0.00239678279564
# Iteration #008, error L2 relative psi:    0.00208409496266
# Iteration #009, error L2 relative psi:    0.00186413626217
# Iteration #010, error L2 relative psi:    0.00170117630246
# Iteration #011, error L2 relative psi:    0.00157461493227
# Iteration #012, error L2 relative psi:    0.00147206713630
# Iteration #013, error L2 relative psi:    0.00138586870542
# Iteration #014, error L2 relative psi:    0.00131114333022
# Iteration #015, error L2 relative psi:    0.00124472405723
# Iteration #016, error L2 relative psi:    0.00118451915639
# Iteration #017, error L2 relative psi:    0.00112912703276
# Iteration #018, error L2 relative psi:    0.00107759657514
# Iteration #019, error L2 relative psi:    0.00102926976063
# Iteration #020, error L2 relative psi:    0.00098368305523
# Iteration #021, error L2 relative psi:    0.00094050264267
# Iteration #022, error L2 relative psi:    0.00089947966221
# Iteration #023, error L2 relative psi:    0.00086042480253
# Iteration #024, error L2 relative psi:    0.00082318877455
# Iteration #025, error L2 relative psi:    0.00078764965484
# Iteration #026, error L2 relative psi:    0.00075370441350
# Iteration #027, error L2 relative psi:    0.00072126392139
# Iteration #028, error L2 relative psi:    0.00069025022321
# Iteration #029, error L2 relative psi:    0.00066059239966
# Iteration #030, error L2 relative psi:    0.00063222547931
# Iteration #031, error L2 relative psi:    0.00060508926349
# Iteration #032, error L2 relative psi:    0.00057912742070
# Iteration #033, error L2 relative psi:    0.00055428661549
# Iteration #034, error L2 relative psi:    0.00053051749166
# Iteration #035, error L2 relative psi:    0.00050777261286
# Iteration #036, error L2 relative psi:    0.00048600704410
# Iteration #037, error L2 relative psi:    0.00046517802924
# Iteration #038, error L2 relative psi:    0.00044524478605
# Iteration #039, error L2 relative psi:    0.00042616833172
# Iteration #040, error L2 relative psi:    0.00040791150887
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/richards/tests/primal_test/Simple Coupling/Darcy-Richards/primal_time.ipynb Cell 38 line 1
#       <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> time_rhs = M_h @ theta(prev - subdomain.nodes[1,:])
#      <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> for k in range(K):
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     spp = L * M_h + dt * stifness(prev - subdomain.nodes[1,:])
#      <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     rhs = time_rhs.copy()
#      <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     rhs += L * M_h @ prev - M_h @ theta(prev - subdomain.nodes[1,:])
#
# /workspaces/richards/tests/primal_test/Simple Coupling/Darcy-Richards/primal_time.ipynb Cell 38 line 2
#      <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> coord_loc = node_coords[:, nodes_loc]
#      <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> # Compute the stiff-H1 local matrix
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> A = local_A(coord_loc, psi[nodes_loc])
#      <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> # Save values for stiff-H1 local matrix in the global structure
#      <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> cols = np.tile(nodes_loc, (nodes_loc.size, 1))
#
# /workspaces/richards/tests/primal_test/Simple Coupling/Darcy-Richards/primal_time.ipynb Cell 38 line 3
#      <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a>         inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
#      <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>         tmp = integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a>         M[ ordering[i], ordering[j] ] = tmp * q_funcs[j].T @ np.array([[1, 0], [0, 1]]) @ q_funcs[i] * jacobian
#      <a href='vscode-notebook-cell://dev-container%..._test/Simple%20Coupling/Darcy-Richards/primal_time.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a> return M
#
# KeyboardInterrupt:
