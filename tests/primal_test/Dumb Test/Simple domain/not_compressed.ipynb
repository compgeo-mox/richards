# %% [markdown]
# # Darcy equation
#
# In this tutorial we present how to solve an evolutionary Darcy equation with [PyGeoN](https://github.com/compgeo-mox/pygeon).  The unkwons are the velocity $q$ and the pressure $p$.
#
# Let $\Omega=(0,1)^2$ with boundary $\partial \Omega$ and outward unit normal ${\nu}$. Let $(0,T)$ with $10=T>0$ be the overall simulation period. Given
# $k$ the matrix permeability, we want to solve the following problem: find $({q}, p)$ such that
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# k^{-1} {q} + \nabla p = {- \rho g \nabla y}\\
# p_t + \nabla \cdot {q} = f
# \end{array}
# &\text{in } \Omega \times (0,T)
# \end{array}
# \right.
# $$
# with boundary conditions:
# $$ p = 0 \text{ on } \partial_{top} \Omega \times (0,T] \qquad p = \rho g \text{ on } \partial_{bottom} \Omega \times (0,T] \qquad \nu \cdot q = 0 \text{ on } \partial_{left} \Omega \cup \partial_{right} \Omega \times (0,T] $$
# and initial conditions:
# $$ p|_{t=0} = (1-y) \rho g \text{ in } \Omega \qquad q|_{t=0} = 0 \text{ in } \Omega $$
#
# We present *step-by-step* how to create the grid, declare the problem data, and finally solve the problem.

# %% [markdown]
# First we import some of the standard modules, like `numpy` and `scipy.sparse`. Since PyGeoN is based on [PorePy](https://github.com/pmgbergen/porepy) we import both modules.

# %%
# %load_ext Cython

# %%
import shutil
import os

import numpy as np
import scipy.sparse as sps
import scipy.integrate as integrate

import porepy as pp
import pygeon as pg

import sympy as sp

from math import ceil, floor, log10, exp
# Out:
# /opt/conda/lib/python3.11/site-packages/porepy/numerics/nonlinear/nonlinear_solvers.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange  # type: ignore

# %% [markdown]
# ### Initial parameters definition

# %%
# Set the maximum number of iterations of the non-linear solver
K = 50

# L-scheme parameter
L = 3.5e-2

# Set the mesh refinment
N = 10

# Set the number of steps (excluding the initial condition)
num_steps = 100

quad_order = 1

# Simulation time length
T = num_steps/48

# Time switch conditions (for the boundary condition)
dt_D = 3/48

# Fluid density
rho = 1000

# Relative and absolute tolerances for the non-linear solver
abs_tol = 1e-10
rel_tol = 1e-5

# Domain tolerance
domain_tolerance = 1 / (10 * N)

# Output directory
output_directory = 'not_compressed'

# %%
def initial_h(x): return 1

# %%
# Van Genuchten model parameters ( relative permeability model )
theta_s = 0.396
theta_r = 0.131

alpha = 0.423

n = 2.06
K_s = 4.96e-2

m = 1 - 1/n

# %%
# Time step
dt   = (T-0)/num_steps

# %% [markdown]
# ### $\theta$ and $K$

# %%
# Symbolic psi
psi_var = sp.Symbol('psi', negative=True)

# Symbolic Theta
theta_expression = theta_r + (theta_s - theta_r) / (1 + (-alpha * psi_var) ** n) ** m
effective_saturation = (theta_expression - theta_r) / (theta_s - theta_r)

# Symbolic Conductivity K
hydraulic_conductivity_expression = K_s * (effective_saturation ** 0.5) * ( 1 - (1 - effective_saturation ** (1 / m)) ** m ) ** 2

# %%
# Theta lambda
theta_lambda = sp.lambdify(psi_var, theta_expression, 'numpy')

# Conductivity tensor lambda
conductivity_lambda = sp.lambdify(psi_var, hydraulic_conductivity_expression, 'numpy')

# %%
# Actual (and final) theta function
def theta(psi):
    mask = np.where(psi < 0)
    res = np.ones_like(psi) * theta_s
    res[mask] = theta_lambda(psi[mask])

    return res

# %%
# Actual (and final) theta function
def conductivity(psi):
    if psi < 0:
        return conductivity_lambda(psi)
    else:
        return K_s

# %% [markdown]
# ### Mesh and $V_h$

# %%
key = "flow"

# %%
# Prepare the domain and its mesh
subdomain = pp.StructuredTriangleGrid([2*N, 3*N], [2,3])
subdomain.compute_geometry()


# Convert it to a mixed-dimensional grid
mdg = pp.meshing.subdomains_to_mdg([subdomain])
mdg = pg.as_mdg(mdg)

# %%
h_field = pg.Lagrange1(key)

# %%
dof_h = darcy_dof = h_field.ndof(subdomain)

# %% [markdown]
# ### BC

# %% [markdown]
# #### Dirichlet (essential)

# %%
right_bot = np.logical_and( subdomain.nodes[0, :] == 2, subdomain.nodes[1, :] < 1 )
left_top  = np.logical_and( subdomain.nodes[1, :] == 3, subdomain.nodes[0, :] < 1 )

dirichlet_flag  = np.logical_or(right_bot, left_top)
dirichlet_value = lambda t: np.array(right_bot, dtype=float) + np.array(left_top, dtype=float) * min( 3.2, 1 + 2.2 * t / dt_D )

# %% [markdown]
# #### Neumann (natural)

# %% [markdown]
# ### Matrix Assembly

# %%
# %%cython
# import numpy as np
#
# def find_ordering(coord: np.array):
#     lx = np.argmin(coord[0, :])
#     rx = np.argmax(coord[0, :])
#     mx = np.setdiff1d(np.array([0,1,2]), np.array([lx, rx]))[0]
#
#     # Vertical Alignment
#     if np.abs( coord[0, lx] - coord[0, mx] ) < 1e-7:
#         # lx and mx vertical aligned, rx no
#         up =   lx if np.argmax(coord[1, np.array([lx, mx])]) == 0 else mx
#         down = lx if np.argmin(coord[1, np.array([lx, mx])]) == 0 else mx
#
#         if np.abs( coord[1, up] - coord[1, rx] ) < 1e-7:
#             return [up, down, rx]
#         else:
#             return [down, rx, up]
#     else:
#         # rx and mx vertical aligned, lx no
#         up =   rx if np.argmax(coord[1, np.array([rx, mx])]) == 0 else mx
#         down = rx if np.argmin(coord[1, np.array([rx, mx])]) == 0 else mx
#
#         if np.abs( coord[1, up] - coord[1, lx] ) < 1e-7:
#             return [up, lx, down]
#         else:
#             return [down, up, lx]

# %%
def local_A(coord, psi):

    ordering = find_ordering(coord)

    x0 = coord[:, ordering][:, 0]
    x1 = coord[:, ordering][:, 1]
    x2 = coord[:, ordering][:, 2]
    
    J_T_1_T = np.array([[x2[1]-x0[1], x0[1]-x1[1]],
                        [x0[0]-x2[0], x1[0]-x0[0]]]) / ((x1[0]-x0[0]) * (x2[1]-x0[1]) - (x2[0]-x0[0]) * (x1[1]-x0[1]))
    

    q_funcs = [J_T_1_T @ np.array([-1, -1]), J_T_1_T @ np.array([ 1, 0]), J_T_1_T @ np.array([0,  1])]

    M = np.zeros(shape=(3,3))

    jacobian = 1 / np.linalg.det( J_T_1_T.T )
    ordered_psi = psi[ordering]

    psi_fun = lambda x,y: ordered_psi[0] + (ordered_psi[1] - ordered_psi[0]) * x + (ordered_psi[2] - ordered_psi[0]) * y

    for i in range(3):
        for j in range(3):
            integrand = lambda ys,x: np.array([conductivity(psi_fun(x,y)) for y in np.array(ys)]) # conductivity(psi_fun(x,y))
            inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
            tmp = integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]

            M[ ordering[i], ordering[j] ] = q_funcs[j].T @ np.array([[1, 0], [0, 1]]) @ q_funcs[i] * jacobian * tmp

    return M

# %%
local_A(np.array([[0, 1, 0], [0, 0, 1]]), np.array([1,1,1]))
# Out:
# array([[ 0.0496, -0.0248, -0.0248],
#        [-0.0248,  0.0248,  0.    ],
#        [-0.0248,  0.    ,  0.0248]])

# %%
def stifness(psi):

    # Map the domain to a reference geometry (i.e. equivalent to compute
    # surface coordinates in 1d and 2d)

    _, _, _, _, _, node_coords = pp.map_geometry.map_grid(subdomain)

    # Allocate the data to store matrix entries, that's the most efficient
    # way to create a sparse matrix.
    size = np.power(subdomain.dim + 1, 2) * subdomain.num_cells
    rows_I = np.empty(size, dtype=int)
    cols_J = np.empty(size, dtype=int)
    data_IJ = np.empty(size)
    idx = 0

    cell_nodes = subdomain.cell_nodes()

    for c in np.arange(subdomain.num_cells):
        # For the current cell retrieve its nodes
        loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

        nodes_loc = cell_nodes.indices[loc]
        coord_loc = node_coords[:, nodes_loc]


        # Compute the stiff-H1 local matrix
        A = local_A(coord_loc, psi[nodes_loc])

        # Save values for stiff-H1 local matrix in the global structure
        cols = np.tile(nodes_loc, (nodes_loc.size, 1))
        loc_idx = slice(idx, idx + cols.size)
        rows_I[loc_idx] = cols.T.ravel()
        cols_J[loc_idx] = cols.ravel()
        data_IJ[loc_idx] = A.ravel()
        idx += cols.size

    # Construct the global matrices
    return sps.csc_matrix((data_IJ, (rows_I, cols_J)))

# %%
M_h = h_field.assemble_mass_matrix(subdomain)

# %%
proj_psi = h_field.eval_at_cell_centers(subdomain)

# %% [markdown]
# ### Solve system

# %%
if os.path.exists(output_directory):
    shutil.rmtree(output_directory)

# %%
def save_step(sol, saver, i):
    ins = list()

    ins.append((subdomain, "cell_h", proj_psi @ sol))
    ins.append((subdomain, "cell_p", proj_psi @ (sol - subdomain.nodes[1,:])))

    saver.write_vtu(ins, time_step=i)

# %%
sol = h_field.interpolate(subdomain, initial_h)

# %%
# Save the initial solution
saver = pp.Exporter(mdg, 'sol', folder_name=output_directory)
save_step(sol, saver, 0)

# %%
csv_base = os.path.join(output_directory, 'csv')

if os.path.exists(csv_base):
    shutil.rmtree(csv_base)
    
os.mkdir(csv_base)

# %%
stifness(np.ones_like(subdomain.nodes[1, :]) - subdomain.nodes[1, :]).todense()
# Out:
# matrix([[ 0.0496    , -0.0248    ,  0.        , ...,  0.        ,
#           0.        ,  0.        ],
#         [-0.0248    ,  0.0992    , -0.0248    , ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.        , -0.0248    ,  0.0992    , ...,  0.        ,
#           0.        ,  0.        ],
#         ...,
#         [ 0.        ,  0.        ,  0.        , ...,  0.01217088,
#          -0.00304272,  0.        ],
#         [ 0.        ,  0.        ,  0.        , ..., -0.00304272,
#           0.01217088, -0.00304272],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          -0.00304272,  0.00608544]])

# %%
M_h.todense()
# Out:
# matrix([[0.00166667, 0.00041667, 0.        , ..., 0.        , 0.        ,
#          0.        ],
#         [0.00041667, 0.0025    , 0.00041667, ..., 0.        , 0.        ,
#          0.        ],
#         [0.        , 0.00041667, 0.0025    , ..., 0.        , 0.        ,
#          0.        ],
#         ...,
#         [0.        , 0.        , 0.        , ..., 0.0025    , 0.00041667,
#          0.        ],
#         [0.        , 0.        , 0.        , ..., 0.00041667, 0.0025    ,
#          0.00041667],
#         [0.        , 0.        , 0.        , ..., 0.        , 0.00041667,
#          0.00166667]])

# %%
for time_instant_index in range(1, num_steps+1):

    time = time_instant_index * dt
    print('Time ' + str(round(time, 5)))

    prev = sol

    time_rhs = np.zeros(dof_h)
    time_rhs = M_h @ theta(prev - subdomain.nodes[1,:]) / dt

    for k in range(K):
        spp = L * M_h / dt + stifness(prev - subdomain.nodes[1,:])

        rhs = time_rhs.copy()

        rhs += L * M_h @ prev / dt - M_h @ theta(prev - subdomain.nodes[1,:]) / dt

        ls = pg.LinearSystem(spp, rhs)
        ls.flag_ess_bc( dirichlet_flag, dirichlet_value(time) )

        current = ls.solve()

        # Check if we have reached convergence
        rel_err_psi  = np.sqrt( (current - prev).T @ M_h @ (current - prev) )
        abs_err_prev = np.sqrt( prev.T @ M_h @ prev )

        # Log message with error and current iteration
        print('Iteration #' + format(k+1, '0' + str(ceil(log10(K)) + 1) + 'd') + ', error L2 relative psi: ' 
              + format(rel_err_psi, str(5 + ceil(log10(1 / abs_tol)) + 4) + '.' + str(ceil(log10(1 / abs_tol)) + 4) + 'f') )
        
        if rel_err_psi > abs_tol + rel_tol * abs_err_prev:
            prev = current.copy()
        else:
            break
        
    print('')    
    sol = current
    
    save_step(sol, saver, time_instant_index)

    export_name = os.path.join(csv_base, str(time_instant_index) + '.csv')

    with open( export_name, 'w' ) as file:

        file.write('x,y,h,p\n')

        for x,y,h,p in zip( subdomain.nodes[0, :], subdomain.nodes[1, :], sol, sol - subdomain.nodes[1, :]):
            file.write(f'{x},{y},{h},{p}\n')



saver.write_pvd([n * dt for n in range(num_steps + 1)])
# Out:
# Time 0.02083
# Iteration #001, error L2 relative psi:    0.14042996328160
# Iteration #002, error L2 relative psi:    0.01405500494854
# Iteration #003, error L2 relative psi:    0.00045972834674
# Iteration #004, error L2 relative psi:    0.00007222426800
# Iteration #005, error L2 relative psi:    0.00001410519866
#
# Time 0.04167
# Iteration #001, error L2 relative psi:    0.19030121059864
# Iteration #002, error L2 relative psi:    0.04786472619601
# Iteration #003, error L2 relative psi:    0.00580576440410
# Iteration #004, error L2 relative psi:    0.00020215002994
# Iteration #005, error L2 relative psi:    0.00004515842655
# Iteration #006, error L2 relative psi:    0.00000506054829
#
# Time 0.0625
# Iteration #001, error L2 relative psi:    0.26625843627788
# Iteration #002, error L2 relative psi:    0.09209286311784
# Iteration #003, error L2 relative psi:    0.02554887500980
# Iteration #004, error L2 relative psi:    0.00351870463700
# Iteration #005, error L2 relative psi:    0.00127748088660
# Iteration #006, error L2 relative psi:    0.00034002704523
# Iteration #007, error L2 relative psi:    0.00004576061238
# Iteration #008, error L2 relative psi:    0.00001973887184
#
# Time 0.08333
# Iteration #001, error L2 relative psi:    0.17839609291961
# Iteration #002, error L2 relative psi:    0.02739188424224
# Iteration #003, error L2 relative psi:    0.00455849183355
# Iteration #004, error L2 relative psi:    0.00165044351927
# Iteration #005, error L2 relative psi:    0.00031387996477
# Iteration #006, error L2 relative psi:    0.00007316673627
# Iteration #007, error L2 relative psi:    0.00002059295124
#
# Time 0.10417
# Iteration #001, error L2 relative psi:    0.14008014958527
# Iteration #002, error L2 relative psi:    0.01463816267940
# Iteration #003, error L2 relative psi:    0.00262277604490
# Iteration #004, error L2 relative psi:    0.00083784766686
# Iteration #005, error L2 relative psi:    0.00016344691137
# Iteration #006, error L2 relative psi:    0.00002661760798
#
# Time 0.125
# Iteration #001, error L2 relative psi:    0.11639978066876
# Iteration #002, error L2 relative psi:    0.01011365831101
# Iteration #003, error L2 relative psi:    0.00144039200519
# Iteration #004, error L2 relative psi:    0.00030534774735
# Iteration #005, error L2 relative psi:    0.00006800375776
# Iteration #006, error L2 relative psi:    0.00001050595095
#
# Time 0.14583
# Iteration #001, error L2 relative psi:    0.10027178812735
# Iteration #002, error L2 relative psi:    0.00858900663806
# Iteration #003, error L2 relative psi:    0.00131722125151
# Iteration #004, error L2 relative psi:    0.00019900938967
# Iteration #005, error L2 relative psi:    0.00003733697086
# Iteration #006, error L2 relative psi:    0.00000867291302
#
# Time 0.16667
# Iteration #001, error L2 relative psi:    0.08840428521896
# Iteration #002, error L2 relative psi:    0.00821498201877
# Iteration #003, error L2 relative psi:    0.00162916814954
# Iteration #004, error L2 relative psi:    0.00040131463679
# Iteration #005, error L2 relative psi:    0.00011429149058
# Iteration #006, error L2 relative psi:    0.00003497446703
# Iteration #007, error L2 relative psi:    0.00001521568032
#
# Time 0.1875
# Iteration #001, error L2 relative psi:    0.07920484487041
# Iteration #002, error L2 relative psi:    0.00826105572531
# Iteration #003, error L2 relative psi:    0.00195151353767
# Iteration #004, error L2 relative psi:    0.00058755556754
# Iteration #005, error L2 relative psi:    0.00019624566019
# Iteration #006, error L2 relative psi:    0.00007128828126
# Iteration #007, error L2 relative psi:    0.00003543634964
# Iteration #008, error L2 relative psi:    0.00002684331239
#
# Time 0.20833
# Iteration #001, error L2 relative psi:    0.07180150397468
# Iteration #002, error L2 relative psi:    0.00842271710306
# Iteration #003, error L2 relative psi:    0.00215988014902
# Iteration #004, error L2 relative psi:    0.00071058604766
# Iteration #005, error L2 relative psi:    0.00026490897219
# Iteration #006, error L2 relative psi:    0.00011416148403
# Iteration #007, error L2 relative psi:    0.00006834139629
# Iteration #008, error L2 relative psi:    0.00005533858263
# Iteration #009, error L2 relative psi:    0.00005007128060
# Iteration #010, error L2 relative psi:    0.00004660732405
# Iteration #011, error L2 relative psi:    0.00004377564989
# Iteration #012, error L2 relative psi:    0.00004128776890
# Iteration #013, error L2 relative psi:    0.00003903430049
# Iteration #014, error L2 relative psi:    0.00003695812175
# Iteration #015, error L2 relative psi:    0.00003502485577
# Iteration #016, error L2 relative psi:    0.00003321238092
# Iteration #017, error L2 relative psi:    0.00003150571438
# Iteration #018, error L2 relative psi:    0.00002989416495
#
# Time 0.22917
# Iteration #001, error L2 relative psi:    0.06563874954743
# Iteration #002, error L2 relative psi:    0.00870903945393
# Iteration #003, error L2 relative psi:    0.00240631682009
# Iteration #004, error L2 relative psi:    0.00086495471004
# Iteration #005, error L2 relative psi:    0.00036031894846
# Iteration #006, error L2 relative psi:    0.00017731215842
# Iteration #007, error L2 relative psi:    0.00011554398738
# Iteration #008, error L2 relative psi:    0.00009477877543
# Iteration #009, error L2 relative psi:    0.00008540777441
# Iteration #010, error L2 relative psi:    0.00007925309242
# Iteration #011, error L2 relative psi:    0.00007431905380
# Iteration #012, error L2 relative psi:    0.00007003581616
# Iteration #013, error L2 relative psi:    0.00006618189363
# Iteration #014, error L2 relative psi:    0.00006264511565
# Iteration #015, error L2 relative psi:    0.00005935979596
# Iteration #016, error L2 relative psi:    0.00005628443938
# Iteration #017, error L2 relative psi:    0.00005339137043
# Iteration #018, error L2 relative psi:    0.00005066113933
# Iteration #019, error L2 relative psi:    0.00004807931639
# Iteration #020, error L2 relative psi:    0.00004563460976
# Iteration #021, error L2 relative psi:    0.00004331774636
# Iteration #022, error L2 relative psi:    0.00004112079935
# Iteration #023, error L2 relative psi:    0.00003903677918
# Iteration #024, error L2 relative psi:    0.00003705938114
# Iteration #025, error L2 relative psi:    0.00003518282645
# Iteration #026, error L2 relative psi:    0.00003340175958
# Iteration #027, error L2 relative psi:    0.00003171117988
# Iteration #028, error L2 relative psi:    0.00003010639430
#
# Time 0.25
# Iteration #001, error L2 relative psi:    0.06044174909764
# Iteration #002, error L2 relative psi:    0.00908031937142
# Iteration #003, error L2 relative psi:    0.00267248878737
# Iteration #004, error L2 relative psi:    0.00103234854263
# Iteration #005, error L2 relative psi:    0.00047337719657
# Iteration #006, error L2 relative psi:    0.00025992617109
# Iteration #007, error L2 relative psi:    0.00018076134665
# Iteration #008, error L2 relative psi:    0.00014990404539
# Iteration #009, error L2 relative psi:    0.00013451547487
# Iteration #010, error L2 relative psi:    0.00012430969250
# Iteration #011, error L2 relative psi:    0.00011627579092
# Iteration #012, error L2 relative psi:    0.00010941228657
# Iteration #013, error L2 relative psi:    0.00010330203808
# Iteration #014, error L2 relative psi:    0.00009773274652
# Iteration #015, error L2 relative psi:    0.00009258200723
# Iteration #016, error L2 relative psi:    0.00008777390827
# Iteration #017, error L2 relative psi:    0.00008325880234
# Iteration #018, error L2 relative psi:    0.00007900254015
# Iteration #019, error L2 relative psi:    0.00007498035868
# Iteration #020, error L2 relative psi:    0.00007117331004
# Iteration #021, error L2 relative psi:    0.00006756614378
# Iteration #022, error L2 relative psi:    0.00006414603757
# Iteration #023, error L2 relative psi:    0.00006090182797
# Iteration #024, error L2 relative psi:    0.00005782353812
# Iteration #025, error L2 relative psi:    0.00005490208260
# Iteration #026, error L2 relative psi:    0.00005212907893
# Iteration #027, error L2 relative psi:    0.00004949672364
# Iteration #028, error L2 relative psi:    0.00004699770804
# Iteration #029, error L2 relative psi:    0.00004462515853
# Iteration #030, error L2 relative psi:    0.00004237259256
# Iteration #031, error L2 relative psi:    0.00004023388454
# Iteration #032, error L2 relative psi:    0.00003820323847
# Iteration #033, error L2 relative psi:    0.00003627516501
# Iteration #034, error L2 relative psi:    0.00003444446181
# Iteration #035, error L2 relative psi:    0.00003270619610
# Iteration #036, error L2 relative psi:    0.00003105568913
#
# Time 0.27083
# Iteration #001, error L2 relative psi:    0.05599631366829
# Iteration #002, error L2 relative psi:    0.00950923290821
# Iteration #003, error L2 relative psi:    0.00297748038448
# Iteration #004, error L2 relative psi:    0.00122419016317
# Iteration #005, error L2 relative psi:    0.00061196592660
# Iteration #006, error L2 relative psi:    0.00036963990070
# Iteration #007, error L2 relative psi:    0.00027201344640
# Iteration #008, error L2 relative psi:    0.00022884977975
# Iteration #009, error L2 relative psi:    0.00020527559460
# Iteration #010, error L2 relative psi:    0.00018926304316
# Iteration #011, error L2 relative psi:    0.00017673052800
# Iteration #012, error L2 relative psi:    0.00016612844752
# Iteration #013, error L2 relative psi:    0.00015676129988
# Iteration #014, error L2 relative psi:    0.00014826699249
# Iteration #015, error L2 relative psi:    0.00014043707879
# Iteration #016, error L2 relative psi:    0.00013314344757
# Iteration #017, error L2 relative psi:    0.00012630327544
# Iteration #018, error L2 relative psi:    0.00011986035192
# Iteration #019, error L2 relative psi:    0.00011377451899
# Iteration #020, error L2 relative psi:    0.00010801551734
# Iteration #021, error L2 relative psi:    0.00010255934162
# Iteration #022, error L2 relative psi:    0.00009738605730
# Iteration #023, error L2 relative psi:    0.00009247847915
# Iteration #024, error L2 relative psi:    0.00008782136131
# Iteration #025, error L2 relative psi:    0.00008340089304
# Iteration #026, error L2 relative psi:    0.00007920437846
# Iteration #027, error L2 relative psi:    0.00007522002775
# Iteration #028, error L2 relative psi:    0.00007143681665
# Iteration #029, error L2 relative psi:    0.00006784438826
# Iteration #030, error L2 relative psi:    0.00006443298151
# Iteration #031, error L2 relative psi:    0.00006119337669
# Iteration #032, error L2 relative psi:    0.00005811685215
# Iteration #033, error L2 relative psi:    0.00005519514870
# Iteration #034, error L2 relative psi:    0.00005242043913
# Iteration #035, error L2 relative psi:    0.00004978530165
# Iteration #036, error L2 relative psi:    0.00004728269611
# Iteration #037, error L2 relative psi:    0.00004490594243
# Iteration #038, error L2 relative psi:    0.00004264870088
# Iteration #039, error L2 relative psi:    0.00004050495370
# Iteration #040, error L2 relative psi:    0.00003846898814
# Iteration #041, error L2 relative psi:    0.00003653538041
# Iteration #042, error L2 relative psi:    0.00003469898076
# Iteration #043, error L2 relative psi:    0.00003295489933
# Iteration #044, error L2 relative psi:    0.00003129849286
#
# Time 0.29167
# Iteration #001, error L2 relative psi:    0.05214887800945
# Iteration #002, error L2 relative psi:    0.00998103769443
# Iteration #003, error L2 relative psi:    0.00335103377395
# Iteration #004, error L2 relative psi:    0.00146571947875
# Iteration #005, error L2 relative psi:    0.00079090467199
# Iteration #006, error L2 relative psi:    0.00051500933541
# Iteration #007, error L2 relative psi:    0.00039497611830
# Iteration #008, error L2 relative psi:    0.00033615558413
# Iteration #009, error L2 relative psi:    0.00030166770264
# Iteration #010, error L2 relative psi:    0.00027770626324
# Iteration #011, error L2 relative psi:    0.00025898071539
# Iteration #012, error L2 relative psi:    0.00024325070602
# Iteration #013, error L2 relative psi:    0.00022944043887
# Iteration #014, error L2 relative psi:    0.00021697375733
# Iteration #015, error L2 relative psi:    0.00020551689857
# Iteration #016, error L2 relative psi:    0.00019486536818
# Iteration #017, error L2 relative psi:    0.00018488791700
# Iteration #018, error L2 relative psi:    0.00017549634891
# Iteration #019, error L2 relative psi:    0.00016662840582
# Iteration #020, error L2 relative psi:    0.00015823778835
# Iteration #021, error L2 relative psi:    0.00015028824092
# Iteration #022, error L2 relative psi:    0.00014275000550
# Iteration #023, error L2 relative psi:    0.00013559767340
# Iteration #024, error L2 relative psi:    0.00012880886894
# Iteration #025, error L2 relative psi:    0.00012236343127
# Iteration #026, error L2 relative psi:    0.00011624289652
# Iteration #027, error L2 relative psi:    0.00011043016211
# Iteration #028, error L2 relative psi:    0.00010490926279
# Iteration #029, error L2 relative psi:    0.00009966521587
# Iteration #030, error L2 relative psi:    0.00009468390980
# Iteration #031, error L2 relative psi:    0.00008995202055
# Iteration #032, error L2 relative psi:    0.00008545694608
# Iteration #033, error L2 relative psi:    0.00008118675296
# Iteration #034, error L2 relative psi:    0.00007713013133
# Iteration #035, error L2 relative psi:    0.00007327635581
# Iteration #036, error L2 relative psi:    0.00006961525084
# Iteration #037, error L2 relative psi:    0.00006613715939
# Iteration #038, error L2 relative psi:    0.00006283291436
# Iteration #039, error L2 relative psi:    0.00005969381216
# Iteration #040, error L2 relative psi:    0.00005671158814
# Iteration #041, error L2 relative psi:    0.00005387839367
# Iteration #042, error L2 relative psi:    0.00005118677459
# Iteration #043, error L2 relative psi:    0.00004862965095
# Iteration #044, error L2 relative psi:    0.00004620029793
# Iteration #045, error L2 relative psi:    0.00004389232773
# Iteration #046, error L2 relative psi:    0.00004169967255
# Iteration #047, error L2 relative psi:    0.00003961656840
# Iteration #048, error L2 relative psi:    0.00003763753980
# Iteration #049, error L2 relative psi:    0.00003575738523
# Iteration #050, error L2 relative psi:    0.00003397116341
#
# Time 0.3125
# Iteration #001, error L2 relative psi:    0.04879042374775
# Iteration #002, error L2 relative psi:    0.01047851950612
# Iteration #003, error L2 relative psi:    0.00381206174679
# Iteration #004, error L2 relative psi:    0.00178023960210
# Iteration #005, error L2 relative psi:    0.00102536524291
# Iteration #006, error L2 relative psi:    0.00070561541360
# Iteration #007, error L2 relative psi:    0.00055699765589
# Iteration #008, error L2 relative psi:    0.00047826673311
# Iteration #009, error L2 relative psi:    0.00042962055380
# Iteration #010, error L2 relative psi:    0.00039515597575
# Iteration #011, error L2 relative psi:    0.00036818858739
# Iteration #012, error L2 relative psi:    0.00034563899742
# Iteration #013, error L2 relative psi:    0.00032594129053
# Iteration #014, error L2 relative psi:    0.00030823094045
# Iteration #015, error L2 relative psi:    0.00029200072587
# Iteration #016, error L2 relative psi:    0.00027693892938
# Iteration #017, error L2 relative psi:    0.00026284598088
# Iteration #018, error L2 relative psi:    0.00024958862735
# Iteration #019, error L2 relative psi:    0.00023707369095
# Iteration #020, error L2 relative psi:    0.00022523267622
# Iteration #021, error L2 relative psi:    0.00021401260521
# Iteration #022, error L2 relative psi:    0.00020337050174
# Iteration #023, error L2 relative psi:    0.00019327003978
# Iteration #024, error L2 relative psi:    0.00018367948539
# Iteration #025, error L2 relative psi:    0.00017457041683
# Iteration #026, error L2 relative psi:    0.00016591691549
# Iteration #027, error L2 relative psi:    0.00015769504364
# Iteration #028, error L2 relative psi:    0.00014988249832
# Iteration #029, error L2 relative psi:    0.00014245837444
# Iteration #030, error L2 relative psi:    0.00013540299643
# Iteration #031, error L2 relative psi:    0.00012869779355
# Iteration #032, error L2 relative psi:    0.00012232520367
# Iteration #033, error L2 relative psi:    0.00011626859587
# Iteration #034, error L2 relative psi:    0.00011051220592
# Iteration #035, error L2 relative psi:    0.00010504108090
# Iteration #036, error L2 relative psi:    0.00009984103040
# Iteration #037, error L2 relative psi:    0.00009489858278
# Iteration #038, error L2 relative psi:    0.00009020094531
# Iteration #039, error L2 relative psi:    0.00008573596752
# Iteration #040, error L2 relative psi:    0.00008149210720
# Iteration #041, error L2 relative psi:    0.00007745839867
# Iteration #042, error L2 relative psi:    0.00007362442307
# Iteration #043, error L2 relative psi:    0.00006998028037
# Iteration #044, error L2 relative psi:    0.00006651656305
# Iteration #045, error L2 relative psi:    0.00006322433118
# Iteration #046, error L2 relative psi:    0.00006009508891
# Iteration #047, error L2 relative psi:    0.00005712076218
# Iteration #048, error L2 relative psi:    0.00005429367763
# Iteration #049, error L2 relative psi:    0.00005160654252
# Iteration #050, error L2 relative psi:    0.00004905242584
#
# Time 0.33333
# Iteration #001, error L2 relative psi:    0.04583923868076
# Iteration #002, error L2 relative psi:    0.01097670631349
# Iteration #003, error L2 relative psi:    0.00435545204329
# Iteration #004, error L2 relative psi:    0.00217915157098
# Iteration #005, error L2 relative psi:    0.00133051233761
# Iteration #006, error L2 relative psi:    0.00095513588701
# Iteration #007, error L2 relative psi:    0.00076984698728
# Iteration #008, error L2 relative psi:    0.00066564977406
# Iteration #009, error L2 relative psi:    0.00059870334466
# Iteration #010, error L2 relative psi:    0.00055051389439
# Iteration #011, error L2 relative psi:    0.00051272065676
# Iteration #012, error L2 relative psi:    0.00048121127940
# Iteration #013, error L2 relative psi:    0.00045379459310
# Iteration #014, error L2 relative psi:    0.00042922741027
# Iteration #015, error L2 relative psi:    0.00040676936294
# Iteration #016, error L2 relative psi:    0.00038596241687
# Iteration #017, error L2 relative psi:    0.00036651344092
# Iteration #018, error L2 relative psi:    0.00034822694952
# Iteration #019, error L2 relative psi:    0.00033096683476
# Iteration #020, error L2 relative psi:    0.00031463438133
# Iteration #021, error L2 relative psi:    0.00029915418778
# Iteration #022, error L2 relative psi:    0.00028446563517
# Iteration #023, error L2 relative psi:    0.00027051802197
# Iteration #024, error L2 relative psi:    0.00025726744502
# Iteration #025, error L2 relative psi:    0.00024467481380
# Iteration #026, error L2 relative psi:    0.00023270451686
# Iteration #027, error L2 relative psi:    0.00022132420261
# Iteration #028, error L2 relative psi:    0.00021050357614
# Iteration #029, error L2 relative psi:    0.00020021427756
# Iteration #030, error L2 relative psi:    0.00019042963600
# Iteration #031, error L2 relative psi:    0.00018112448859
# Iteration #032, error L2 relative psi:    0.00017227504222
# Iteration #033, error L2 relative psi:    0.00016385876375
# Iteration #034, error L2 relative psi:    0.00015585428968
# Iteration #035, error L2 relative psi:    0.00014824134934
# Iteration #036, error L2 relative psi:    0.00014100069777
# Iteration #037, error L2 relative psi:    0.00013411405525
# Iteration #038, error L2 relative psi:    0.00012756399534
# Iteration #039, error L2 relative psi:    0.00012133402677
# Iteration #040, error L2 relative psi:    0.00011540852893
# Iteration #041, error L2 relative psi:    0.00010977259598
# Iteration #042, error L2 relative psi:    0.00010441205477
# Iteration #043, error L2 relative psi:    0.00009931342899
# Iteration #044, error L2 relative psi:    0.00009446390453
# Iteration #045, error L2 relative psi:    0.00008985129657
# Iteration #046, error L2 relative psi:    0.00008546401834
# Iteration #047, error L2 relative psi:    0.00008129105138
# Iteration #048, error L2 relative psi:    0.00007732191744
# Iteration #049, error L2 relative psi:    0.00007354665176
# Iteration #050, error L2 relative psi:    0.00006995577771
#
# Time 0.35417
# Iteration #001, error L2 relative psi:    0.04323080297645
# Iteration #002, error L2 relative psi:    0.01145425027344
# Iteration #003, error L2 relative psi:    0.00498204787191
# Iteration #004, error L2 relative psi:    0.00268182039089
# Iteration #005, error L2 relative psi:    0.00172339432297
# Iteration #006, error L2 relative psi:    0.00127413904530
# Iteration #007, error L2 relative psi:    0.00103948932733
# Iteration #008, error L2 relative psi:    0.00090150308469
# Iteration #009, error L2 relative psi:    0.00081061553383
# Iteration #010, error L2 relative psi:    0.00074467969125
# Iteration #011, error L2 relative psi:    0.00069306110463
# Iteration #012, error L2 relative psi:    0.00065025613937
# Iteration #013, error L2 relative psi:    0.00061322629961
# Iteration #014, error L2 relative psi:    0.00058020693958
# Iteration #015, error L2 relative psi:    0.00055013290634
# Iteration #016, error L2 relative psi:    0.00052234013777
# Iteration #017, error L2 relative psi:    0.00049640172030
# Iteration #018, error L2 relative psi:    0.00047203400376
# Iteration #019, error L2 relative psi:    0.00044904131066
# Iteration #020, error L2 relative psi:    0.00042728278616
# Iteration #021, error L2 relative psi:    0.00040665228096
# Iteration #022, error L2 relative psi:    0.00038706603231
# Iteration #023, error L2 relative psi:    0.00036845506037
# Iteration #024, error L2 relative psi:    0.00035076043655
# Iteration #025, error L2 relative psi:    0.00033393029825
# Iteration #026, error L2 relative psi:    0.00031791799093
# Iteration #027, error L2 relative psi:    0.00030268083953
# Iteration #028, error L2 relative psi:    0.00028817933542
# Iteration #029, error L2 relative psi:    0.00027437659869
# Iteration #030, error L2 relative psi:    0.00026123800585
# Iteration #031, error L2 relative psi:    0.00024873092236
# Iteration #032, error L2 relative psi:    0.00023682450303
# Iteration #033, error L2 relative psi:    0.00022548953739
# Iteration #034, error L2 relative psi:    0.00021469832518
# Iteration #035, error L2 relative psi:    0.00020442457271
# Iteration #036, error L2 relative psi:    0.00019464330381
# Iteration #037, error L2 relative psi:    0.00018533078173
# Iteration #038, error L2 relative psi:    0.00017646443903
# Iteration #039, error L2 relative psi:    0.00016802281392
# Iteration #040, error L2 relative psi:    0.00015998549161
# Iteration #041, error L2 relative psi:    0.00015233305007
# Iteration #042, error L2 relative psi:    0.00014504700934
# Iteration #043, error L2 relative psi:    0.00013810978402
# Iteration #044, error L2 relative psi:    0.00013150463858
# Iteration #045, error L2 relative psi:    0.00012521564530
# Iteration #046, error L2 relative psi:    0.00011922764436
# Iteration #047, error L2 relative psi:    0.00011352620626
# Iteration #048, error L2 relative psi:    0.00010809759605
# Iteration #049, error L2 relative psi:    0.00010292873954
# Iteration #050, error L2 relative psi:    0.00009800719113
#
# Time 0.375
# Iteration #001, error L2 relative psi:    0.04092511090286
# Iteration #002, error L2 relative psi:    0.01188599255370
# Iteration #003, error L2 relative psi:    0.00566034583081
# Iteration #004, error L2 relative psi:    0.00327400641977
# Iteration #005, error L2 relative psi:    0.00220401077680
# Iteration #006, error L2 relative psi:    0.00166881459433
# Iteration #007, error L2 relative psi:    0.00137357905310
# Iteration #008, error L2 relative psi:    0.00119326720221
# Iteration #009, error L2 relative psi:    0.00107212803136
# Iteration #010, error L2 relative psi:    0.00098374276223
# Iteration #011, error L2 relative psi:    0.00091473307018
# Iteration #012, error L2 relative psi:    0.00085787072850
# Iteration #013, error L2 relative psi:    0.00080903066704
# Iteration #014, error L2 relative psi:    0.00076575797902
# Iteration #015, error L2 relative psi:    0.00072654322421
# Iteration #016, error L2 relative psi:    0.00069043346310
# Iteration #017, error L2 relative psi:    0.00065681253623
# Iteration #018, error L2 relative psi:    0.00062527059899
# Iteration #019, error L2 relative psi:    0.00059552632653
# Iteration #020, error L2 relative psi:    0.00056737949059
# Iteration #021, error L2 relative psi:    0.00054068168694
# Iteration #022, error L2 relative psi:    0.00051531812097
# Iteration #023, error L2 relative psi:    0.00049119619773
# Iteration #024, error L2 relative psi:    0.00046823832713
# Iteration #025, error L2 relative psi:    0.00044637735403
# Iteration #026, error L2 relative psi:    0.00042555362991
# Iteration #027, error L2 relative psi:    0.00040571311550
# Iteration #028, error L2 relative psi:    0.00038680613419
# Iteration #029, error L2 relative psi:    0.00036878653936
# Iteration #030, error L2 relative psi:    0.00035161124117
# Iteration #031, error L2 relative psi:    0.00033523951039
# Iteration #032, error L2 relative psi:    0.00031963293344
# Iteration #033, error L2 relative psi:    0.00030475517789
# Iteration #034, error L2 relative psi:    0.00029057178162
# Iteration #035, error L2 relative psi:    0.00027705001418
# Iteration #036, error L2 relative psi:    0.00026415876028
# Iteration #037, error L2 relative psi:    0.00025186839361
# Iteration #038, error L2 relative psi:    0.00024015072717
# Iteration #039, error L2 relative psi:    0.00022897895399
# Iteration #040, error L2 relative psi:    0.00021832754391
# Iteration #041, error L2 relative psi:    0.00020817217762
# Iteration #042, error L2 relative psi:    0.00019848968551
# Iteration #043, error L2 relative psi:    0.00018925799064
# Iteration #044, error L2 relative psi:    0.00018045605514
# Iteration #045, error L2 relative psi:    0.00017206382974
# Iteration #046, error L2 relative psi:    0.00016406220613
# Iteration #047, error L2 relative psi:    0.00015643297186
# Iteration #048, error L2 relative psi:    0.00014915876756
# Iteration #049, error L2 relative psi:    0.00014222304642
# Iteration #050, error L2 relative psi:    0.00013561003568
#
# Time 0.39583
# Iteration #001, error L2 relative psi:    0.03888696034510
# Iteration #002, error L2 relative psi:    0.01223322727569
# Iteration #003, error L2 relative psi:    0.00633952906598
# Iteration #004, error L2 relative psi:    0.00391960344924
# Iteration #005, error L2 relative psi:    0.00275097090391
# Iteration #006, error L2 relative psi:    0.00212539326593
# Iteration #007, error L2 relative psi:    0.00176094623122
# Iteration #008, error L2 relative psi:    0.00153026461677
# Iteration #009, error L2 relative psi:    0.00137248445347
# Iteration #010, error L2 relative psi:    0.00125682414660
# Iteration #011, error L2 relative psi:    0.00116682335093
# Iteration #012, error L2 relative psi:    0.00109321753584
# Iteration #013, error L2 relative psi:    0.00103054155286
# Iteration #014, error L2 relative psi:    0.00097546214377
# Iteration #015, error L2 relative psi:    0.00092588476009
# Iteration #016, error L2 relative psi:    0.00088047344594
# Iteration #017, error L2 relative psi:    0.00083835103200
# Iteration #018, error L2 relative psi:    0.00079892908816
# Iteration #019, error L2 relative psi:    0.00076180637536
# Iteration #020, error L2 relative psi:    0.00072670115130
# Iteration #021, error L2 relative psi:    0.00069340666765
# Iteration #022, error L2 relative psi:    0.00066176549081
# Iteration #023, error L2 relative psi:    0.00063165381414
# Iteration #024, error L2 relative psi:    0.00060297028559
# Iteration #025, error L2 relative psi:    0.00057562819158
# Iteration #026, error L2 relative psi:    0.00054955258001
# Iteration #027, error L2 relative psi:    0.00052467785307
# Iteration #028, error L2 relative psi:    0.00050094328812
# Iteration #029, error L2 relative psi:    0.00047829289976
# Iteration #030, error L2 relative psi:    0.00045667457283
# Iteration #031, error L2 relative psi:    0.00043603945425
# Iteration #032, error L2 relative psi:    0.00041634151809
# Iteration #033, error L2 relative psi:    0.00039753724607
# Iteration #034, error L2 relative psi:    0.00037958538559
# Iteration #035, error L2 relative psi:    0.00036244676016
# Iteration #036, error L2 relative psi:    0.00034608411597
# Iteration #037, error L2 relative psi:    0.00033046199352
# Iteration #038, error L2 relative psi:    0.00031554661687
# Iteration #039, error L2 relative psi:    0.00030130579396
# Iteration #040, error L2 relative psi:    0.00028770872023
# Iteration #041, error L2 relative psi:    0.00027472564343
# Iteration #042, error L2 relative psi:    0.00026232933988
# Iteration #043, error L2 relative psi:    0.00025049321351
# Iteration #044, error L2 relative psi:    0.00023919187174
# Iteration #045, error L2 relative psi:    0.00022840107855
# Iteration #046, error L2 relative psi:    0.00021809770329
# Iteration #047, error L2 relative psi:    0.00020825967020
# Iteration #048, error L2 relative psi:    0.00019886590968
# Iteration #049, error L2 relative psi:    0.00018989631173
# Iteration #050, error L2 relative psi:    0.00018133168156
#
# Time 0.41667
# Iteration #001, error L2 relative psi:    0.03707962685607
# Iteration #002, error L2 relative psi:    0.01245125394652
# Iteration #003, error L2 relative psi:    0.00696231329798
# Iteration #004, error L2 relative psi:    0.00457741804251
# Iteration #005, error L2 relative psi:    0.00334383386827
# Iteration #006, error L2 relative psi:    0.00263826852269
# Iteration #007, error L2 relative psi:    0.00220390313556
# Iteration #008, error L2 relative psi:    0.00191807570162
# Iteration #009, error L2 relative psi:    0.00171807480854
# Iteration #010, error L2 relative psi:    0.00157010224299
# Iteration #011, error L2 relative psi:    0.00145501045068
# Iteration #012, error L2 relative psi:    0.00136147539274
# Iteration #013, error L2 relative psi:    0.00128254997978
# Iteration #014, error L2 relative psi:    0.00121385355526
# Iteration #015, error L2 relative psi:    0.00115256153785
# Iteration #016, error L2 relative psi:    0.00109682429776
# Iteration #017, error L2 relative psi:    0.00104541032541
# Iteration #018, error L2 relative psi:    0.00099748713883
# Iteration #019, error L2 relative psi:    0.00095248019008
# Iteration #020, error L2 relative psi:    0.00090998432592
# Iteration #021, error L2 relative psi:    0.00086970657893
# Iteration #022, error L2 relative psi:    0.00083142888900
# Iteration #023, error L2 relative psi:    0.00079498342341
# Iteration #024, error L2 relative psi:    0.00076023652219
# Iteration #025, error L2 relative psi:    0.00072707811499
# Iteration #026, error L2 relative psi:    0.00069541471421
# Iteration #027, error L2 relative psi:    0.00066516475239
# Iteration #028, error L2 relative psi:    0.00063625545980
# Iteration #029, error L2 relative psi:    0.00060862075703
# Iteration #030, error L2 relative psi:    0.00058219981772
# Iteration #031, error L2 relative psi:    0.00055693607540
# Iteration #032, error L2 relative psi:    0.00053277651274
# Iteration #033, error L2 relative psi:    0.00050967104411
# Iteration #034, error L2 relative psi:    0.00048757242718
# Iteration #035, error L2 relative psi:    0.00046643589718
# Iteration #036, error L2 relative psi:    0.00044621876874
# Iteration #037, error L2 relative psi:    0.00042688072530
# Iteration #038, error L2 relative psi:    0.00040838309654
# Iteration #039, error L2 relative psi:    0.00039068902407
# Iteration #040, error L2 relative psi:    0.00037376334697
# Iteration #041, error L2 relative psi:    0.00035757248470
# Iteration #042, error L2 relative psi:    0.00034208435791
# Iteration #043, error L2 relative psi:    0.00032726831456
# Iteration #044, error L2 relative psi:    0.00031309506116
# Iteration #045, error L2 relative psi:    0.00029953659847
# Iteration #046, error L2 relative psi:    0.00028656616117
# Iteration #047, error L2 relative psi:    0.00027415816104
# Iteration #048, error L2 relative psi:    0.00026228813332
# Iteration #049, error L2 relative psi:    0.00025093268584
# Iteration #050, error L2 relative psi:    0.00024006945082
#
# Time 0.4375
# Iteration #001, error L2 relative psi:    0.03548212904294
# Iteration #002, error L2 relative psi:    0.01248908641574
# Iteration #003, error L2 relative psi:    0.00744903024537
# Iteration #004, error L2 relative psi:    0.00517207614135
# Iteration #005, error L2 relative psi:    0.00392413967194
# Iteration #006, error L2 relative psi:    0.00316596301804
# Iteration #007, error L2 relative psi:    0.00267321778941
# Iteration #008, error L2 relative psi:    0.00233491498038
# Iteration #009, error L2 relative psi:    0.00209132189536
# Iteration #010, error L2 relative psi:    0.00190820449693
# Iteration #011, error L2 relative psi:    0.00176499928856
# Iteration #012, error L2 relative psi:    0.00164886054698
# Iteration #013, error L2 relative psi:    0.00155152327524
# Iteration #014, error L2 relative psi:    0.00146755879716
# Iteration #015, error L2 relative psi:    0.00139335853507
# Iteration #016, error L2 relative psi:    0.00132647930280
# Iteration #017, error L2 relative psi:    0.00126525116922
# Iteration #018, error L2 relative psi:    0.00120851940464
# Iteration #019, error L2 relative psi:    0.00115547549450
# Iteration #020, error L2 relative psi:    0.00110554475443
# Iteration #021, error L2 relative psi:    0.00105831134412
# Iteration #022, error L2 relative psi:    0.00101346449412
# Iteration #023, error L2 relative psi:    0.00097077662888
# Iteration #024, error L2 relative psi:    0.00093006727768
# Iteration #025, error L2 relative psi:    0.00089119182843
# Iteration #026, error L2 relative psi:    0.00085403097606
# Iteration #027, error L2 relative psi:    0.00081848350859
# Iteration #028, error L2 relative psi:    0.00078446175511
# Iteration #029, error L2 relative psi:    0.00075188792177
# Iteration #030, error L2 relative psi:    0.00072069170315
# Iteration #031, error L2 relative psi:    0.00069080842413
# Iteration #032, error L2 relative psi:    0.00066217839485
# Iteration #033, error L2 relative psi:    0.00063474594620
# Iteration #034, error L2 relative psi:    0.00060845872176
# Iteration #035, error L2 relative psi:    0.00058326738924
# Iteration #036, error L2 relative psi:    0.00055912500971
# Iteration #037, error L2 relative psi:    0.00053598677879
# Iteration #038, error L2 relative psi:    0.00051381019519
# Iteration #039, error L2 relative psi:    0.00049255471430
# Iteration #040, error L2 relative psi:    0.00047218161453
# Iteration #041, error L2 relative psi:    0.00045265388667
# Iteration #042, error L2 relative psi:    0.00043393613758
# Iteration #043, error L2 relative psi:    0.00041599450426
# Iteration #044, error L2 relative psi:    0.00039879657515
# Iteration #045, error L2 relative psi:    0.00038231131271
# Iteration #046, error L2 relative psi:    0.00036650855034
# Iteration #047, error L2 relative psi:    0.00035135987664
# Iteration #048, error L2 relative psi:    0.00033683858733
# Iteration #049, error L2 relative psi:    0.00032291860144
# Iteration #050, error L2 relative psi:    0.00030957492378
#
# Time 0.45833
# Iteration #001, error L2 relative psi:    0.03408319303616
# Iteration #002, error L2 relative psi:    0.01229995663137
# Iteration #003, error L2 relative psi:    0.00771747475420
# Iteration #004, error L2 relative psi:    0.00561610647929
# Iteration #005, error L2 relative psi:    0.00441423331986
# Iteration #006, error L2 relative psi:    0.00364591142157
# Iteration #007, error L2 relative psi:    0.00312129422324
# Iteration #008, error L2 relative psi:    0.00274529062994
# Iteration #009, error L2 relative psi:    0.00246528978225
# Iteration #010, error L2 relative psi:    0.00224978082054
# Iteration #011, error L2 relative psi:    0.00207886237246
# Iteration #012, error L2 relative psi:    0.00193945737737
# Iteration #013, error L2 relative psi:    0.00182271979999
# Iteration #014, error L2 relative psi:    0.00172255844657
# Iteration #015, error L2 relative psi:    0.00163473961455
# Iteration #016, error L2 relative psi:    0.00155627805281
# Iteration #017, error L2 relative psi:    0.00148505714156
# Iteration #018, error L2 relative psi:    0.00141956599777
# Iteration #019, error L2 relative psi:    0.00135871757058
# Iteration #020, error L2 relative psi:    0.00130171418614
# Iteration #021, error L2 relative psi:    0.00124798766738
# Iteration #022, error L2 relative psi:    0.00119710942126
# Iteration #023, error L2 relative psi:    0.00114875560660
# Iteration #024, error L2 relative psi:    0.00110267704867
# Iteration #025, error L2 relative psi:    0.00105867788503
# Iteration #026, error L2 relative psi:    0.00101660048386
# Iteration #027, error L2 relative psi:    0.00097631527629
# Iteration #028, error L2 relative psi:    0.00093771375514
# Iteration #029, error L2 relative psi:    0.00090070254353
# Iteration #030, error L2 relative psi:    0.00086519929110
# Iteration #031, error L2 relative psi:    0.00083113048917
# Iteration #032, error L2 relative psi:    0.00079842966386
# Iteration #033, error L2 relative psi:    0.00076703569696
# Iteration #034, error L2 relative psi:    0.00073689183164
# Iteration #035, error L2 relative psi:    0.00070794494133
# Iteration #036, error L2 relative psi:    0.00068014496733
# Iteration #037, error L2 relative psi:    0.00065344320369
# Iteration #038, error L2 relative psi:    0.00062779443775
# Iteration #039, error L2 relative psi:    0.00060315791977
# Iteration #040, error L2 relative psi:    0.00057949291970
# Iteration #041, error L2 relative psi:    0.00055676084151
# Iteration #042, error L2 relative psi:    0.00053492422908
# Iteration #043, error L2 relative psi:    0.00051394716029
# Iteration #044, error L2 relative psi:    0.00049379544814
# Iteration #045, error L2 relative psi:    0.00047443632613
# Iteration #046, error L2 relative psi:    0.00045583837279
# Iteration #047, error L2 relative psi:    0.00043797144688
# Iteration #048, error L2 relative psi:    0.00042080662839
# Iteration #049, error L2 relative psi:    0.00040431616394
# Iteration #050, error L2 relative psi:    0.00038847341585
#
# Time 0.47917
# Iteration #001, error L2 relative psi:    0.03289821399024
# Iteration #002, error L2 relative psi:    0.01185859612511
# Iteration #003, error L2 relative psi:    0.00768450094449
# Iteration #004, error L2 relative psi:    0.00580059542979
# Iteration #005, error L2 relative psi:    0.00470210874896
# Iteration #006, error L2 relative psi:    0.00397424423036
# Iteration #007, error L2 relative psi:    0.00345660266639
# Iteration #008, error L2 relative psi:    0.00307098698922
# Iteration #009, error L2 relative psi:    0.00277391356836
# Iteration #010, error L2 relative psi:    0.00253890757591
# Iteration #011, error L2 relative psi:    0.00234865957846
# Iteration #012, error L2 relative psi:    0.00219134733121
# Iteration #013, error L2 relative psi:    0.00205862939882
# Iteration #014, error L2 relative psi:    0.00194450687321
# Iteration #015, error L2 relative psi:    0.00184463546929
# Iteration #016, error L2 relative psi:    0.00175581937314
# Iteration #017, error L2 relative psi:    0.00167568474279
# Iteration #018, error L2 relative psi:    0.00160249550447
# Iteration #019, error L2 relative psi:    0.00153493599137
# Iteration #020, error L2 relative psi:    0.00147202566495
# Iteration #021, error L2 relative psi:    0.00141302649339
# Iteration #022, error L2 relative psi:    0.00135737763597
# Iteration #023, error L2 relative psi:    0.00130464918609
# Iteration #024, error L2 relative psi:    0.00125450814899
# Iteration #025, error L2 relative psi:    0.00120669336415
# Iteration #026, error L2 relative psi:    0.00116099729616
# Iteration #027, error L2 relative psi:    0.00111725167469
# Iteration #028, error L2 relative psi:    0.00107531811443
# Iteration #029, error L2 relative psi:    0.00103508072353
# Iteration #030, error L2 relative psi:    0.00099643843449
# Iteration #031, error L2 relative psi:    0.00095930583832
# Iteration #032, error L2 relative psi:    0.00092360968181
# Iteration #033, error L2 relative psi:    0.00088928207100
# Iteration #034, error L2 relative psi:    0.00085626133291
# Iteration #035, error L2 relative psi:    0.00082449082937
# Iteration #036, error L2 relative psi:    0.00079391805907
# Iteration #037, error L2 relative psi:    0.00076449397767
# Iteration #038, error L2 relative psi:    0.00073617248101
# Iteration #039, error L2 relative psi:    0.00070891000931
# Iteration #040, error L2 relative psi:    0.00068266524115
# Iteration #041, error L2 relative psi:    0.00065739885413
# Iteration #042, error L2 relative psi:    0.00063307333495
# Iteration #043, error L2 relative psi:    0.00060965282658
# Iteration #044, error L2 relative psi:    0.00058710300310
# Iteration #045, error L2 relative psi:    0.00056539096551
# Iteration #046, error L2 relative psi:    0.00054448515333
# Iteration #047, error L2 relative psi:    0.00052435526838
# Iteration #048, error L2 relative psi:    0.00050497220792
# Iteration #049, error L2 relative psi:    0.00048630800507
# Iteration #050, error L2 relative psi:    0.00046833577483
#
# Time 0.5
# Iteration #001, error L2 relative psi:    0.03195457877218
# Iteration #002, error L2 relative psi:    0.01118534143173
# Iteration #003, error L2 relative psi:    0.00730831450523
# Iteration #004, error L2 relative psi:    0.00564127648018
# Iteration #005, error L2 relative psi:    0.00468183372858
# Iteration #006, error L2 relative psi:    0.00403814778574
# Iteration #007, error L2 relative psi:    0.00356935775486
# Iteration #008, error L2 relative psi:    0.00321003059886
# Iteration #009, error L2 relative psi:    0.00292506163542
# Iteration #010, error L2 relative psi:    0.00269339615041
# Iteration #011, error L2 relative psi:    0.00250128287570
# Iteration #012, error L2 relative psi:    0.00233924480028
# Iteration #013, error L2 relative psi:    0.00220052085077
# Iteration #014, error L2 relative psi:    0.00208005785356
# Iteration #015, error L2 relative psi:    0.00197403621405
# Iteration #016, error L2 relative psi:    0.00187951063965
# Iteration #017, error L2 relative psi:    0.00179429682647
# Iteration #018, error L2 relative psi:    0.00171666555475
# Iteration #019, error L2 relative psi:    0.00164527292866
# Iteration #020, error L2 relative psi:    0.00157907276424
# Iteration #021, error L2 relative psi:    0.00151723972806
# Iteration #022, error L2 relative psi:    0.00145914012236
# Iteration #023, error L2 relative psi:    0.00140428374329
# Iteration #024, error L2 relative psi:    0.00135227277339
# Iteration #025, error L2 relative psi:    0.00130278980208
# Iteration #026, error L2 relative psi:    0.00125557957637
# Iteration #027, error L2 relative psi:    0.00121043547003
# Iteration #028, error L2 relative psi:    0.00116718792157
# Iteration #029, error L2 relative psi:    0.00112569559019
# Iteration #030, error L2 relative psi:    0.00108583508078
# Iteration #031, error L2 relative psi:    0.00104750863994
# Iteration #032, error L2 relative psi:    0.00101063190844
# Iteration #033, error L2 relative psi:    0.00097512881370
# Iteration #034, error L2 relative psi:    0.00094093171839
# Iteration #035, error L2 relative psi:    0.00090797964489
# Iteration #036, error L2 relative psi:    0.00087621110565
# Iteration #037, error L2 relative psi:    0.00084558241211
# Iteration #038, error L2 relative psi:    0.00081604753731
# Iteration #039, error L2 relative psi:    0.00078756286744
# Iteration #040, error L2 relative psi:    0.00076008751214
# Iteration #041, error L2 relative psi:    0.00073358294461
# Iteration #042, error L2 relative psi:    0.00070801271077
# Iteration #043, error L2 relative psi:    0.00068334221550
# Iteration #044, error L2 relative psi:    0.00065953955696
# Iteration #045, error L2 relative psi:    0.00063657253188
# Iteration #046, error L2 relative psi:    0.00061441034878
# Iteration #047, error L2 relative psi:    0.00059302411427
# Iteration #048, error L2 relative psi:    0.00057238609366
# Iteration #049, error L2 relative psi:    0.00055246956649
# Iteration #050, error L2 relative psi:    0.00053324890979
#
# Time 0.52083
# Iteration #001, error L2 relative psi:    0.03126707089068
# Iteration #002, error L2 relative psi:    0.01037018610713
# Iteration #003, error L2 relative psi:    0.00663577540225
# Iteration #004, error L2 relative psi:    0.00513231406099
# Iteration #005, error L2 relative psi:    0.00430766544696
# Iteration #006, error L2 relative psi:    0.00376564916460
# Iteration #007, error L2 relative psi:    0.00337145728935
# Iteration #008, error L2 relative psi:    0.00306607139179
# Iteration #009, error L2 relative psi:    0.00281991923184
# Iteration #010, error L2 relative psi:    0.00261598967909
# Iteration #011, error L2 relative psi:    0.00244360455709
# Iteration #012, error L2 relative psi:    0.00229563338645
# Iteration #013, error L2 relative psi:    0.00216687014830
# Iteration #014, error L2 relative psi:    0.00205353685880
# Iteration #015, error L2 relative psi:    0.00195272465404
# Iteration #016, error L2 relative psi:    0.00186213417975
# Iteration #017, error L2 relative psi:    0.00178000953194
# Iteration #018, error L2 relative psi:    0.00170492763446
# Iteration #019, error L2 relative psi:    0.00163574445564
# Iteration #020, error L2 relative psi:    0.00157154166018
# Iteration #021, error L2 relative psi:    0.00151159166282
# Iteration #022, error L2 relative psi:    0.00145530282722
# Iteration #023, error L2 relative psi:    0.00140220931508
# Iteration #024, error L2 relative psi:    0.00135192852062
# Iteration #025, error L2 relative psi:    0.00130411482032
# Iteration #026, error L2 relative psi:    0.00125854871214
# Iteration #027, error L2 relative psi:    0.00121502024133
# Iteration #028, error L2 relative psi:    0.00117334437943
# Iteration #029, error L2 relative psi:    0.00113337147483
# Iteration #030, error L2 relative psi:    0.00109498351814
# Iteration #031, error L2 relative psi:    0.00105806963250
# Iteration #032, error L2 relative psi:    0.00102254200752
# Iteration #033, error L2 relative psi:    0.00098832013157
# Iteration #034, error L2 relative psi:    0.00095533358483
# Iteration #035, error L2 relative psi:    0.00092351989571
# Iteration #036, error L2 relative psi:    0.00089282311460
# Iteration #037, error L2 relative psi:    0.00086319265326
# Iteration #038, error L2 relative psi:    0.00083458227672
# Iteration #039, error L2 relative psi:    0.00080694447807
# Iteration #040, error L2 relative psi:    0.00078024454886
# Iteration #041, error L2 relative psi:    0.00075444783155
# Iteration #042, error L2 relative psi:    0.00072951990236
# Iteration #043, error L2 relative psi:    0.00070542513009
# Iteration #044, error L2 relative psi:    0.00068213515548
# Iteration #045, error L2 relative psi:    0.00065962312530
# Iteration #046, error L2 relative psi:    0.00063786000266
# Iteration #047, error L2 relative psi:    0.00061682105761
# Iteration #048, error L2 relative psi:    0.00059648138457
# Iteration #049, error L2 relative psi:    0.00057681692102
# Iteration #050, error L2 relative psi:    0.00055780457528
#
# Time 0.54167
# Iteration #001, error L2 relative psi:    0.03078284526978
# Iteration #002, error L2 relative psi:    0.00955271216443
# Iteration #003, error L2 relative psi:    0.00584477325715
# Iteration #004, error L2 relative psi:    0.00442515228090
# Iteration #005, error L2 relative psi:    0.00368994383360
# Iteration #006, error L2 relative psi:    0.00322757379985
# Iteration #007, error L2 relative psi:    0.00290082959836
# Iteration #008, error L2 relative psi:    0.00265163038694
# Iteration #009, error L2 relative psi:    0.00245187039002
# Iteration #010, error L2 relative psi:    0.00228620927070
# Iteration #011, error L2 relative psi:    0.00214553499321
# Iteration #012, error L2 relative psi:    0.00202393469544
# Iteration #013, error L2 relative psi:    0.00191726327697
# Iteration #014, error L2 relative psi:    0.00182250519585
# Iteration #015, error L2 relative psi:    0.00173750631046
# Iteration #016, error L2 relative psi:    0.00166057688535
# Iteration #017, error L2 relative psi:    0.00159036340620
# Iteration #018, error L2 relative psi:    0.00152580632785
# Iteration #019, error L2 relative psi:    0.00146605635165
# Iteration #020, error L2 relative psi:    0.00141041622611
# Iteration #021, error L2 relative psi:    0.00135831627461
# Iteration #022, error L2 relative psi:    0.00130929563568
# ...
# Iteration #040, error L2 relative psi:    0.00005482614142
# Iteration #041, error L2 relative psi:    0.00005358986404
# Iteration #042, error L2 relative psi:    0.00005238983157
# Iteration #043, error L2 relative psi:    0.00005122401935
#
# Time 1.47917
# Iteration #001, error L2 relative psi:    0.00139832589750
# Iteration #002, error L2 relative psi:    0.00068890406035
# Iteration #003, error L2 relative psi:    0.00042300527412
# Iteration #004, error L2 relative psi:    0.00030378740250
# Iteration #005, error L2 relative psi:    0.00024118154331
# Iteration #006, error L2 relative psi:    0.00020354412507
# Iteration #007, error L2 relative psi:    0.00017843655304
# Iteration #008, error L2 relative psi:    0.00016036902934
# Iteration #009, error L2 relative psi:    0.00014663036225
# Iteration #010, error L2 relative psi:    0.00013574410912
# Iteration #011, error L2 relative psi:    0.00012684001774
# Iteration #012, error L2 relative psi:    0.00011937222394
# Iteration #013, error L2 relative psi:    0.00011298115101
# Iteration #014, error L2 relative psi:    0.00010742040748
# Iteration #015, error L2 relative psi:    0.00010251553181
# Iteration #016, error L2 relative psi:    0.00009813946938
# Iteration #017, error L2 relative psi:    0.00009419737360
# Iteration #018, error L2 relative psi:    0.00009061686120
# Iteration #019, error L2 relative psi:    0.00008734158635
# Iteration #020, error L2 relative psi:    0.00008432690023
# Iteration #021, error L2 relative psi:    0.00008153685635
# Iteration #022, error L2 relative psi:    0.00007894210418
# Iteration #023, error L2 relative psi:    0.00007651838027
# Iteration #024, error L2 relative psi:    0.00007424540888
# Iteration #025, error L2 relative psi:    0.00007210608722
# Iteration #026, error L2 relative psi:    0.00007008587209
# Iteration #027, error L2 relative psi:    0.00006817231066
# Iteration #028, error L2 relative psi:    0.00006635467619
# Iteration #029, error L2 relative psi:    0.00006462368113
# Iteration #030, error L2 relative psi:    0.00006297124804
# Iteration #031, error L2 relative psi:    0.00006139032453
# Iteration #032, error L2 relative psi:    0.00005987473183
# Iteration #033, error L2 relative psi:    0.00005841903977
# Iteration #034, error L2 relative psi:    0.00005701846256
# Iteration #035, error L2 relative psi:    0.00005566877117
# Iteration #036, error L2 relative psi:    0.00005436621923
# Iteration #037, error L2 relative psi:    0.00005310747993
# Iteration #038, error L2 relative psi:    0.00005188959202
#
# Time 1.5
# Iteration #001, error L2 relative psi:    0.00116499985629
# Iteration #002, error L2 relative psi:    0.00057987734015
# Iteration #003, error L2 relative psi:    0.00035913608413
# Iteration #004, error L2 relative psi:    0.00025996326014
# Iteration #005, error L2 relative psi:    0.00020788097847
# Iteration #006, error L2 relative psi:    0.00017657523557
# Iteration #007, error L2 relative psi:    0.00015568058846
# Iteration #008, error L2 relative psi:    0.00014062305897
# Iteration #009, error L2 relative psi:    0.00012914720284
# Iteration #010, error L2 relative psi:    0.00012002746288
# Iteration #011, error L2 relative psi:    0.00011254317611
# Iteration #012, error L2 relative psi:    0.00010624331061
# Iteration #013, error L2 relative psi:    0.00010083131920
# Iteration #014, error L2 relative psi:    0.00009610430117
# Iteration #015, error L2 relative psi:    0.00009191874380
# Iteration #016, error L2 relative psi:    0.00008817020538
# Iteration #017, error L2 relative psi:    0.00008478075109
# Iteration #018, error L2 relative psi:    0.00008169091359
# Iteration #019, error L2 relative psi:    0.00007885440061
# Iteration #020, error L2 relative psi:    0.00007623452488
# Iteration #021, error L2 relative psi:    0.00007380174348
# Iteration #022, error L2 relative psi:    0.00007153192816
# Iteration #023, error L2 relative psi:    0.00006940512688
# Iteration #024, error L2 relative psi:    0.00006740466142
# Iteration #025, error L2 relative psi:    0.00006551645873
# Iteration #026, error L2 relative psi:    0.00006372854735
# Iteration #027, error L2 relative psi:    0.00006203067211
# Iteration #028, error L2 relative psi:    0.00006041399494
# Iteration #029, error L2 relative psi:    0.00005887085917
# Iteration #030, error L2 relative psi:    0.00005739460133
# Iteration #031, error L2 relative psi:    0.00005597939905
# Iteration #032, error L2 relative psi:    0.00005462014669
# Iteration #033, error L2 relative psi:    0.00005331235265
# Iteration #034, error L2 relative psi:    0.00005205205380
# Iteration #035, error L2 relative psi:    0.00005083574354
#
# Time 1.52083
# Iteration #001, error L2 relative psi:    0.00096826052015
# Iteration #002, error L2 relative psi:    0.00048658572750
# Iteration #003, error L2 relative psi:    0.00030390198784
# Iteration #004, error L2 relative psi:    0.00022170375824
# Iteration #005, error L2 relative psi:    0.00017852999485
# Iteration #006, error L2 relative psi:    0.00015257405442
# Iteration #007, error L2 relative psi:    0.00013523554111
# Iteration #008, error L2 relative psi:    0.00012272008736
# Iteration #009, error L2 relative psi:    0.00011315893562
# Iteration #010, error L2 relative psi:    0.00010553845278
# Iteration #011, error L2 relative psi:    0.00009926377466
# Iteration #012, error L2 relative psi:    0.00009396331008
# Iteration #013, error L2 relative psi:    0.00008939314686
# Iteration #014, error L2 relative psi:    0.00008538661872
# Iteration #015, error L2 relative psi:    0.00008182595789
# Iteration #016, error L2 relative psi:    0.00007862551656
# Iteration #017, error L2 relative psi:    0.00007572141066
# Iteration #018, error L2 relative psi:    0.00007306490459
# Iteration #019, error L2 relative psi:    0.00007061806262
# Iteration #020, error L2 relative psi:    0.00006835081891
# Iteration #021, error L2 relative psi:    0.00006623895983
# Iteration #022, error L2 relative psi:    0.00006426270634
# Iteration #023, error L2 relative psi:    0.00006240569949
# Iteration #024, error L2 relative psi:    0.00006065426125
# Iteration #025, error L2 relative psi:    0.00005899684676
# Iteration #026, error L2 relative psi:    0.00005742363188
# Iteration #027, error L2 relative psi:    0.00005592619750
# Iteration #028, error L2 relative psi:    0.00005449728438
# Iteration #029, error L2 relative psi:    0.00005313060006
# Iteration #030, error L2 relative psi:    0.00005182066463
#
# Time 1.54167
# Iteration #001, error L2 relative psi:    0.00080150043203
# Iteration #002, error L2 relative psi:    0.00040687354270
# Iteration #003, error L2 relative psi:    0.00025697936168
# Iteration #004, error L2 relative psi:    0.00018964969667
# Iteration #005, error L2 relative psi:    0.00015434647116
# Iteration #006, error L2 relative psi:    0.00013311854472
# Iteration #007, error L2 relative psi:    0.00011890345288
# Iteration #008, error L2 relative psi:    0.00010859855774
# Iteration #009, error L2 relative psi:    0.00010068114666
# Iteration #010, error L2 relative psi:    0.00009433215380
# Iteration #011, error L2 relative psi:    0.00008907112590
# Iteration #012, error L2 relative psi:    0.00008459862874
# Iteration #013, error L2 relative psi:    0.00008071847688
# Iteration #014, error L2 relative psi:    0.00007729673265
# Iteration #015, error L2 relative psi:    0.00007423875578
# Iteration #016, error L2 relative psi:    0.00007147566941
# Iteration #017, error L2 relative psi:    0.00006895603328
# Iteration #018, error L2 relative psi:    0.00006664053851
# Iteration #019, error L2 relative psi:    0.00006449852707
# Iteration #020, error L2 relative psi:    0.00006250564976
# Iteration #021, error L2 relative psi:    0.00006064225442
# Iteration #022, error L2 relative psi:    0.00005889225379
# Iteration #023, error L2 relative psi:    0.00005724231467
# Iteration #024, error L2 relative psi:    0.00005568126681
# Iteration #025, error L2 relative psi:    0.00005419966420
# Iteration #026, error L2 relative psi:    0.00005278945417
# Iteration #027, error L2 relative psi:    0.00005144372377
#
# Time 1.5625
# Iteration #001, error L2 relative psi:    0.00066276356930
# Iteration #002, error L2 relative psi:    0.00033989750497
# Iteration #003, error L2 relative psi:    0.00021719847543
# Iteration #004, error L2 relative psi:    0.00016220851795
# Iteration #005, error L2 relative psi:    0.00013342034902
# Iteration #006, error L2 relative psi:    0.00011609579447
# Iteration #007, error L2 relative psi:    0.00010445607995
# Iteration #008, error L2 relative psi:    0.00009597726074
# Iteration #009, error L2 relative psi:    0.00008942636735
# Iteration #010, error L2 relative psi:    0.00008413982627
# Iteration #011, error L2 relative psi:    0.00007973072705
# Iteration #012, error L2 relative psi:    0.00007595846728
# Iteration #013, error L2 relative psi:    0.00007266503309
# Iteration #014, error L2 relative psi:    0.00006974405677
# Iteration #015, error L2 relative psi:    0.00006711950432
# Iteration #016, error L2 relative psi:    0.00006473602716
# Iteration #017, error L2 relative psi:    0.00006255224581
# Iteration #018, error L2 relative psi:    0.00006053649340
# Iteration #019, error L2 relative psi:    0.00005866402996
# Iteration #020, error L2 relative psi:    0.00005691517055
# Iteration #021, error L2 relative psi:    0.00005527399785
# Iteration #022, error L2 relative psi:    0.00005372745781
# Iteration #023, error L2 relative psi:    0.00005226471178
# Iteration #024, error L2 relative psi:    0.00005087666363
#
# Time 1.58333
# Iteration #001, error L2 relative psi:    0.00054734833417
# Iteration #002, error L2 relative psi:    0.00028379334046
# Iteration #003, error L2 relative psi:    0.00018380306233
# Iteration #004, error L2 relative psi:    0.00013915109430
# Iteration #005, error L2 relative psi:    0.00011580853217
# Iteration #006, error L2 relative psi:    0.00010173187056
# Iteration #007, error L2 relative psi:    0.00009222866319
# Iteration #008, error L2 relative psi:    0.00008525923986
# Iteration #009, error L2 relative psi:    0.00007983313443
# Iteration #010, error L2 relative psi:    0.00007541958446
# Iteration #011, error L2 relative psi:    0.00007171005591
# Iteration #012, error L2 relative psi:    0.00006851308725
# Iteration #013, error L2 relative psi:    0.00006570346209
# Iteration #014, error L2 relative psi:    0.00006319569625
# Iteration #015, error L2 relative psi:    0.00006092929407
# Iteration #016, error L2 relative psi:    0.00005886010523
# Iteration #017, error L2 relative psi:    0.00005695503296
# Iteration #018, error L2 relative psi:    0.00005518867502
# Iteration #019, error L2 relative psi:    0.00005354112555
# Iteration #020, error L2 relative psi:    0.00005199649765
#
# Time 1.60417
# Iteration #001, error L2 relative psi:    0.00045077321568
# Iteration #002, error L2 relative psi:    0.00023712344694
# Iteration #003, error L2 relative psi:    0.00015659515880
# Iteration #004, error L2 relative psi:    0.00012086383711
# Iteration #005, error L2 relative psi:    0.00010218821816
# Iteration #006, error L2 relative psi:    0.00009085126674
# Iteration #007, error L2 relative psi:    0.00008311399830
# Iteration #008, error L2 relative psi:    0.00007736756272
# Iteration #009, error L2 relative psi:    0.00007283603489
# Iteration #010, error L2 relative psi:    0.00006910523220
# Iteration #011, error L2 relative psi:    0.00006593472173
# Iteration #012, error L2 relative psi:    0.00006317519529
# Iteration #013, error L2 relative psi:    0.00006072876488
# Iteration #014, error L2 relative psi:    0.00005852834527
# Iteration #015, error L2 relative psi:    0.00005652622747
# Iteration #016, error L2 relative psi:    0.00005468739540
# Iteration #017, error L2 relative psi:    0.00005298543892
# Iteration #018, error L2 relative psi:    0.00005139996016
#
# Time 1.625
# Iteration #001, error L2 relative psi:    0.00037210024938
# Iteration #002, error L2 relative psi:    0.00019879651993
# Iteration #003, error L2 relative psi:    0.00013387903277
# Iteration #004, error L2 relative psi:    0.00010522459837
# Iteration #005, error L2 relative psi:    0.00009022870438
# Iteration #006, error L2 relative psi:    0.00008105732137
# Iteration #007, error L2 relative psi:    0.00007472985337
# Iteration #008, error L2 relative psi:    0.00006997429425
# Iteration #009, error L2 relative psi:    0.00006618024572
# Iteration #010, error L2 relative psi:    0.00006302268430
# Iteration #011, error L2 relative psi:    0.00006031302501
# Iteration #012, error L2 relative psi:    0.00005793402962
# Iteration #013, error L2 relative psi:    0.00005580865561
# Iteration #014, error L2 relative psi:    0.00005388392869
# Iteration #015, error L2 relative psi:    0.00005212202335
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/richards/tests/primal_test/Dumb Test/Simple domain/not_compressed.ipynb Cell 40 line 1
#       <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> time_rhs = M_h @ theta(prev - subdomain.nodes[1,:]) / dt
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> for k in range(K):
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     spp = L * M_h / dt + stifness(prev - subdomain.nodes[1,:])
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     rhs = time_rhs.copy()
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     rhs += L * M_h @ prev / dt - M_h @ theta(prev - subdomain.nodes[1,:]) / dt
#
# /workspaces/richards/tests/primal_test/Dumb Test/Simple domain/not_compressed.ipynb Cell 40 line 2
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> coord_loc = node_coords[:, nodes_loc]
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> # Compute the stiff-H1 local matrix
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> A = local_A(coord_loc, psi[nodes_loc])
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> # Save values for stiff-H1 local matrix in the global structure
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> cols = np.tile(nodes_loc, (nodes_loc.size, 1))
#
# /workspaces/richards/tests/primal_test/Dumb Test/Simple domain/not_compressed.ipynb Cell 40 line 2
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>         inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>         tmp = integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a>         M[ ordering[i], ordering[j] ] = q_funcs[j].T @ np.array([[1, 0], [0, 1]]) @ q_funcs[i] * jacobian * tmp
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/not_compressed.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> return M
#
# KeyboardInterrupt:

# %% [markdown]
# for time_instant_index in range(1, num_steps+1):
#
#     time = time_instant_index * dt
#     print('Time ' + str(round(time, 5)))
#
#     prev = sol
#
#     time_rhs = np.zeros(dof_h)
#     #time_rhs = M_h @ theta(prev - subdomain.nodes[1,:] * 3)
#
#     spp = L / dt * M_h + stifness(prev - subdomain.nodes[1,:] * 3)
#     rhs = time_rhs.copy()
#
#     rhs += L / dt * M_h @ prev #- M_h @ theta(prev - subdomain.nodes[1,:] * 3)
#     rhs += neumann_value(time)
#
#     ls = pg.LinearSystem(spp, rhs)
#     ls.flag_ess_bc( dirichlet_flag, dirichlet_value(time) )
#
#     current = ls.solve()
#
#     print('')
#     sol = current
#
#     save_step(sol, saver, time_instant_index)
#
#     export_name = os.path.join(csv_base, str(time_instant_index) + '.csv')
#
#     with open( export_name, 'w' ) as file:
#
#         file.write('x,y,h,p\n')
#
#         for x,y,h,p in zip( subdomain.nodes[0, :], subdomain.nodes[1, :], sol, sol - subdomain.nodes[1, :]):
#             file.write(f'{x},{y},{h},{p}\n')
#
#
#
# saver.write_pvd([n * dt for n in range(num_steps + 1)])
