# %% [markdown]
# # Darcy equation
#
# In this tutorial we present how to solve an evolutionary Darcy equation with [PyGeoN](https://github.com/compgeo-mox/pygeon).  The unkwons are the velocity $q$ and the pressure $p$.
#
# Let $\Omega=(0,1)^2$ with boundary $\partial \Omega$ and outward unit normal ${\nu}$. Let $(0,T)$ with $10=T>0$ be the overall simulation period. Given
# $k$ the matrix permeability, we want to solve the following problem: find $({q}, p)$ such that
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# k^{-1} {q} + \nabla p = {- \rho g \nabla y}\\
# p_t + \nabla \cdot {q} = f
# \end{array}
# &\text{in } \Omega \times (0,T)
# \end{array}
# \right.
# $$
# with boundary conditions:
# $$ p = 0 \text{ on } \partial_{top} \Omega \times (0,T] \qquad p = \rho g \text{ on } \partial_{bottom} \Omega \times (0,T] \qquad \nu \cdot q = 0 \text{ on } \partial_{left} \Omega \cup \partial_{right} \Omega \times (0,T] $$
# and initial conditions:
# $$ p|_{t=0} = (1-y) \rho g \text{ in } \Omega \qquad q|_{t=0} = 0 \text{ in } \Omega $$
#
# We present *step-by-step* how to create the grid, declare the problem data, and finally solve the problem.

# %% [markdown]
# First we import some of the standard modules, like `numpy` and `scipy.sparse`. Since PyGeoN is based on [PorePy](https://github.com/pmgbergen/porepy) we import both modules.

# %%
# %load_ext Cython

# %%
import shutil
import os

import numpy as np
import scipy.sparse as sps
import scipy.integrate as integrate

import porepy as pp
import pygeon as pg

import sympy as sp

from math import ceil, floor, log10, exp
# Out:
# /opt/conda/lib/python3.11/site-packages/porepy/numerics/nonlinear/nonlinear_solvers.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange  # type: ignore

# %% [markdown]
# ### Initial parameters definition

# %%
# Set the maximum number of iterations of the non-linear solver
K = 50

# L-scheme parameter
L = 3.5e-2

# Set the mesh refinment
N = 10

# Set the number of steps (excluding the initial condition)
num_steps = 100

quad_order = 1

# Simulation time length
T = num_steps/48

# Time switch conditions (for the boundary condition)
dt_D = 3/48

# Fluid density
rho = 1000

# Relative and absolute tolerances for the non-linear solver
abs_tol = 1e-10
rel_tol = 1e-5

# Domain tolerance
domain_tolerance = 1 / (10 * N)

# Output directory
output_directory = 'compressed'

# %%
def initial_h(x): return 1

# %%
# Van Genuchten model parameters ( relative permeability model )
theta_s = 0.396
theta_r = 0.131

alpha = 0.423

n = 2.06
K_s = 4.96e-2

m = 1 - 1/n

# %%
# Time step
dt   = (T-0)/num_steps

# %% [markdown]
# ### $\theta$ and $K$

# %%
# Symbolic psi
psi_var = sp.Symbol('psi', negative=True)

# Symbolic Theta
theta_expression = theta_r + (theta_s - theta_r) / (1 + (-alpha * psi_var) ** n) ** m
effective_saturation = (theta_expression - theta_r) / (theta_s - theta_r)

# Symbolic Conductivity K
hydraulic_conductivity_expression = K_s * (effective_saturation ** 0.5) * ( 1 - (1 - effective_saturation ** (1 / m)) ** m ) ** 2

# %%
# Theta lambda
theta_lambda = sp.lambdify(psi_var, theta_expression, 'numpy')

# Conductivity tensor lambda
conductivity_lambda = sp.lambdify(psi_var, hydraulic_conductivity_expression, 'numpy')

# %%
# Actual (and final) theta function
def theta(psi):
    mask = np.where(psi < 0)
    res = np.ones_like(psi) * theta_s
    res[mask] = theta_lambda(psi[mask])

    return res

# %%
# Actual (and final) theta function
def conductivity(psi):
    if psi < 0:
        return conductivity_lambda(psi)
    else:
        return K_s

# %% [markdown]
# ### Mesh and $V_h$

# %%
key = "flow"

# %%
# Prepare the domain and its mesh
subdomain = pp.StructuredTriangleGrid([2*N, 3*N], [2,1])
subdomain.compute_geometry()

# Convert it to a mixed-dimensional grid
mdg = pp.meshing.subdomains_to_mdg([subdomain])
mdg = pg.as_mdg(mdg)

# %%
h_field = pg.Lagrange1(key)

# %%
dof_h = darcy_dof = h_field.ndof(subdomain)

# %% [markdown]
# ### BC

# %% [markdown]
# #### Dirichlet (essential)

# %%
right_bot = np.logical_and( subdomain.nodes[0, :] == 2, subdomain.nodes[1, :] < 1/3 )
left_top  = np.logical_and( subdomain.nodes[1, :] == 1, subdomain.nodes[0, :] < 1 )

dirichlet_flag  = np.logical_or(right_bot, left_top)
dirichlet_value = lambda t: np.array(right_bot, dtype=float) + np.array(left_top, dtype=float) * min( 3.2, 1 + 2.2 * t / dt_D )

# %% [markdown]
# #### Neumann (natural)

# %% [markdown]
# ### Matrix Assembly

# %%
# %%cython
# import numpy as np
#
# def find_ordering(coord: np.array):
#     lx = np.argmin(coord[0, :])
#     rx = np.argmax(coord[0, :])
#     mx = np.setdiff1d(np.array([0,1,2]), np.array([lx, rx]))[0]
#
#     # Vertical Alignment
#     if np.abs( coord[0, lx] - coord[0, mx] ) < 1e-7:
#         # lx and mx vertical aligned, rx no
#         up =   lx if np.argmax(coord[1, np.array([lx, mx])]) == 0 else mx
#         down = lx if np.argmin(coord[1, np.array([lx, mx])]) == 0 else mx
#
#         if np.abs( coord[1, up] - coord[1, rx] ) < 1e-7:
#             return [up, down, rx]
#         else:
#             return [down, rx, up]
#     else:
#         # rx and mx vertical aligned, lx no
#         up =   rx if np.argmax(coord[1, np.array([rx, mx])]) == 0 else mx
#         down = rx if np.argmin(coord[1, np.array([rx, mx])]) == 0 else mx
#
#         if np.abs( coord[1, up] - coord[1, lx] ) < 1e-7:
#             return [up, lx, down]
#         else:
#             return [down, up, lx]

# %%
# %%cython
# import numpy as np
#
# def K_func_eval(base_height: float, base_width: float, element_height: float, element_width: float, m: int, ls_eta: float, rs_eta: float, grad_eta: float, x, y):
#     coord = lambda t: ((m+1) * (1-t) - (m-1) * t) / 2
#
#     x3 = base_height + coord(x) * element_height
#     eta = (1-coord(y)) * ls_eta + coord(y) * rs_eta
#
#     chi_x3  = eta
#     chi_eta = x3
#
#     return np.array([[             chi_x3,                            -chi_eta * grad_eta],
#                      [-chi_eta * grad_eta, (1 + np.power(chi_eta * grad_eta, 2)) / chi_x3]])
#
#     # This is the full version:
#     #return np.array([[                  chi_x3 * k11,                                                   k12 - chi_eta * grad_eta * k11],
#     #                 [k21 - chi_eta * grad_eta * k11, ( k22 + chi_eta * grad_eta * ( chi_eta * grad_eta * k11 - k12 - k21 ) ) / chi_x3]])

# %%
def local_A(coord, psi, m):

    ordering = find_ordering(coord)

    x0 = coord[:, ordering][:, 0]
    x1 = coord[:, ordering][:, 1]
    x2 = coord[:, ordering][:, 2]
    
    J_T_1_T = np.array([[x2[1]-x0[1], x0[1]-x1[1]],
                        [x0[0]-x2[0], x1[0]-x0[0]]]) / ((x1[0]-x0[0]) * (x2[1]-x0[1]) - (x2[0]-x0[0]) * (x1[1]-x0[1]))
    

    q_funcs = [J_T_1_T @ np.array([-1, -1]), J_T_1_T @ np.array([ 1, 0]), J_T_1_T @ np.array([0,  1])]

    M = np.zeros(shape=(3,3))

    jacobian = 1 / np.linalg.det( J_T_1_T.T )

    ordered_psi = psi[ordering]

    psi_fun = lambda x,y: ordered_psi[0] + (ordered_psi[1] - ordered_psi[0]) * x + (ordered_psi[2] - ordered_psi[0]) * y
    #K_func = lambda x,y: K_func_eval(min(coord[1, :]), min(coord[0, :], element_height, element_width), m, 1, 1, 0, x, y)

    for i in range(3):
        for j in range(3):
            integrand = lambda ys,x: np.array([conductivity(psi_fun(x,y)) for y in np.array(ys)]) # 
            inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
            tmp = integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]

            M[ ordering[i], ordering[j] ] = q_funcs[j].T @ np.array([[1, 0], [0, 1/9]]) @ q_funcs[i] * jacobian * tmp

    return M

# %%
local_A(np.array([[0, 1, 0], [0, 0, 1]]), np.array([1,1,1]), np.prod(np.array([-1, 1, -1])))
# Out:
# array([[ 0.02755556, -0.0248    , -0.00275556],
#        [-0.0248    ,  0.0248    ,  0.        ],
#        [-0.00275556,  0.        ,  0.00275556]])

# %%
subdomain, data = mdg.subdomains(return_data=True)[0]

pp.initialize_data(subdomain, data, key, {"second_order_tensor": pp.SecondOrderTensor(np.ones(subdomain.num_cells))})
# Out:
# {'discretization_matrices': {'flow': {}},
#  'parameters': Data object for physical processes flow
#  The keyword "flow" has the following parameters specified: second_order_tensor}

# %%
def stifness(psi):

    # Map the domain to a reference geometry (i.e. equivalent to compute
    # surface coordinates in 1d and 2d)

    _, _, sign = sps.find(subdomain.cell_faces)
    _, _, _, _, _, node_coords = pp.map_geometry.map_grid(subdomain)

    # Allocate the data to store matrix entries, that's the most efficient
    # way to create a sparse matrix.
    size = np.power(subdomain.dim + 1, 2) * subdomain.num_cells
    rows_I = np.empty(size, dtype=int)
    cols_J = np.empty(size, dtype=int)
    data_IJ = np.empty(size)
    idx = 0

    cell_nodes = subdomain.cell_nodes()

    for c in np.arange(subdomain.num_cells):
        # For the current cell retrieve its nodes
        loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

        nodes_loc = cell_nodes.indices[loc]
        coord_loc = node_coords[:, nodes_loc]


        # Compute the stiff-H1 local matrix
        A = local_A(coord_loc, psi[nodes_loc], np.prod(sign[loc]))

        # Save values for stiff-H1 local matrix in the global structure
        cols = np.tile(nodes_loc, (nodes_loc.size, 1))
        loc_idx = slice(idx, idx + cols.size)
        rows_I[loc_idx] = cols.T.ravel()
        cols_J[loc_idx] = cols.ravel()
        data_IJ[loc_idx] = A.ravel()
        idx += cols.size

    # Construct the global matrices
    return sps.csc_matrix((data_IJ, (rows_I, cols_J)))

# %%
M_h = h_field.assemble_mass_matrix(subdomain)

# %%
proj_psi = h_field.eval_at_cell_centers(subdomain)

# %%
M_h.todense()
# Out:
# matrix([[0.00055556, 0.00013889, 0.        , ..., 0.        , 0.        ,
#          0.        ],
#         [0.00013889, 0.00083333, 0.00013889, ..., 0.        , 0.        ,
#          0.        ],
#         [0.        , 0.00013889, 0.00083333, ..., 0.        , 0.        ,
#          0.        ],
#         ...,
#         [0.        , 0.        , 0.        , ..., 0.00083333, 0.00013889,
#          0.        ],
#         [0.        , 0.        , 0.        , ..., 0.00013889, 0.00083333,
#          0.00013889],
#         [0.        , 0.        , 0.        , ..., 0.        , 0.00013889,
#          0.00055556]])

# %% [markdown]
# ### Solve system

# %%
if os.path.exists(output_directory):
    shutil.rmtree(output_directory)

# %%
def save_step(sol, saver, i):
    ins = list()

    ins.append((subdomain, "cell_h", proj_psi @ sol))
    ins.append((subdomain, "cell_p", proj_psi @ (sol - subdomain.nodes[1,:] * 3)))

    saver.write_vtu(ins, time_step=i)

# %%
sol = h_field.interpolate(subdomain, initial_h)

# %%
# Save the initial solution
saver = pp.Exporter(mdg, 'sol', folder_name=output_directory)
save_step(sol, saver, 0)

# %%
csv_base = os.path.join(output_directory, 'csv')

if os.path.exists(csv_base):
    shutil.rmtree(csv_base)
    
os.mkdir(csv_base)

# %%
for time_instant_index in range(1, num_steps+1):

    time = time_instant_index * dt
    print('Time ' + str(round(time, 5)))

    prev = sol

    time_rhs = np.zeros(dof_h)
    time_rhs = M_h @ theta(prev - subdomain.nodes[1,:] * 3)

    for k in range(K):
        spp = L * M_h + dt * stifness(prev - subdomain.nodes[1,:] * 3)
        rhs = time_rhs.copy()

        rhs += L * M_h @ prev - M_h @ theta(prev - subdomain.nodes[1,:] * 3)

        ls = pg.LinearSystem(spp, rhs)
        ls.flag_ess_bc( dirichlet_flag, dirichlet_value(time) )

        current = ls.solve()

        # Check if we have reached convergence
        rel_err_psi  = np.sqrt( (current - prev).T @ M_h @ (current - prev) )
        abs_err_prev = np.sqrt( prev.T @ M_h @ prev )

        # Log message with error and current iteration
        print('Iteration #' + format(k+1, '0' + str(ceil(log10(K)) + 1) + 'd') + ', error L2 relative psi: ' 
              + format(rel_err_psi, str(5 + ceil(log10(1 / abs_tol)) + 4) + '.' + str(ceil(log10(1 / abs_tol)) + 4) + 'f') )
        
        if rel_err_psi > abs_tol + rel_tol * abs_err_prev:
            prev = current.copy()
        else:
            break
        
    print('')    
    sol = current
    
    save_step(sol, saver, time_instant_index)

    export_name = os.path.join(csv_base, str(time_instant_index) + '.csv')

    with open( export_name, 'w' ) as file:

        file.write('x,y,h,p\n')

        for x,y,h,p in zip( subdomain.nodes[0, :], subdomain.nodes[1, :], sol, sol - subdomain.nodes[1, :]):
            file.write(f'{x},{y},{h},{p}\n')



saver.write_pvd([n * dt for n in range(num_steps + 1)])
# Out:
# Time 0.02083
# Iteration #001, error L2 relative psi:    0.08107727710292
# Iteration #002, error L2 relative psi:    0.00811466089050
# Iteration #003, error L2 relative psi:    0.00026542428475
# Iteration #004, error L2 relative psi:    0.00004169870057
# Iteration #005, error L2 relative psi:    0.00000814364024
#
# Time 0.04167
# Iteration #001, error L2 relative psi:    0.10987045516623
# Iteration #002, error L2 relative psi:    0.02763471255395
# Iteration #003, error L2 relative psi:    0.00335195964156
# Iteration #004, error L2 relative psi:    0.00011671137421
# Iteration #005, error L2 relative psi:    0.00002607222973
# Iteration #006, error L2 relative psi:    0.00000292170892
#
# Time 0.0625
# Iteration #001, error L2 relative psi:    0.15372437985904
# Iteration #002, error L2 relative psi:    0.05316983931153
# Iteration #003, error L2 relative psi:    0.01475064986440
# Iteration #004, error L2 relative psi:    0.00203152506937
# Iteration #005, error L2 relative psi:    0.00073755393376
# Iteration #006, error L2 relative psi:    0.00019631470610
# Iteration #007, error L2 relative psi:    0.00002641990188
# Iteration #008, error L2 relative psi:    0.00001139624297
#
# Time 0.08333
# Iteration #001, error L2 relative psi:    0.10299703226951
# Iteration #002, error L2 relative psi:    0.01581471174087
# Iteration #003, error L2 relative psi:    0.00263184648720
# Iteration #004, error L2 relative psi:    0.00095288401013
# Iteration #005, error L2 relative psi:    0.00018121868215
# Iteration #006, error L2 relative psi:    0.00004224283488
# Iteration #007, error L2 relative psi:    0.00001188934594
#
# Time 0.10417
# Iteration #001, error L2 relative psi:    0.08087531207118
# Iteration #002, error L2 relative psi:    0.00845134716340
# Iteration #003, error L2 relative psi:    0.00151426045555
# Iteration #004, error L2 relative psi:    0.00048373157600
# Iteration #005, error L2 relative psi:    0.00009436611828
# Iteration #006, error L2 relative psi:    0.00001536768313
#
# Time 0.125
# Iteration #001, error L2 relative psi:    0.06720344470272
# Iteration #002, error L2 relative psi:    0.00583912334836
# Iteration #003, error L2 relative psi:    0.00083161071193
# Iteration #004, error L2 relative psi:    0.00017629260413
# Iteration #005, error L2 relative psi:    0.00003926198785
# Iteration #006, error L2 relative psi:    0.00000606561361
#
# Time 0.14583
# Iteration #001, error L2 relative psi:    0.05789194386745
# Iteration #002, error L2 relative psi:    0.00495886529455
# Iteration #003, error L2 relative psi:    0.00076049804414
# Iteration #004, error L2 relative psi:    0.00011489812470
# Iteration #005, error L2 relative psi:    0.00002155651018
# Iteration #006, error L2 relative psi:    0.00000500730867
#
# Time 0.16667
# Iteration #001, error L2 relative psi:    0.05104023786868
# Iteration #002, error L2 relative psi:    0.00474292207992
# Iteration #003, error L2 relative psi:    0.00094060066969
# Iteration #004, error L2 relative psi:    0.00023169911358
# Iteration #005, error L2 relative psi:    0.00006598622285
# Iteration #006, error L2 relative psi:    0.00002019251795
# Iteration #007, error L2 relative psi:    0.00000878477713
#
# Time 0.1875
# Iteration #001, error L2 relative psi:    0.04572893850705
# Iteration #002, error L2 relative psi:    0.00476952274680
# Iteration #003, error L2 relative psi:    0.00112670686630
# Iteration #004, error L2 relative psi:    0.00033922536508
# Iteration #005, error L2 relative psi:    0.00011330248474
# Iteration #006, error L2 relative psi:    0.00004115830837
# Iteration #007, error L2 relative psi:    0.00002045918601
# Iteration #008, error L2 relative psi:    0.00001549799364
#
# Time 0.20833
# Iteration #001, error L2 relative psi:    0.04145461764800
# Iteration #002, error L2 relative psi:    0.00486285798676
# Iteration #003, error L2 relative psi:    0.00124700738545
# Iteration #004, error L2 relative psi:    0.00041025704590
# Iteration #005, error L2 relative psi:    0.00015294526640
# Iteration #006, error L2 relative psi:    0.00006591116353
# Iteration #007, error L2 relative psi:    0.00003945692354
# Iteration #008, error L2 relative psi:    0.00003194974558
# Iteration #009, error L2 relative psi:    0.00002890866733
# Iteration #010, error L2 relative psi:    0.00002690875108
# Iteration #011, error L2 relative psi:    0.00002527388325
# Iteration #012, error L2 relative psi:    0.00002383750449
# Iteration #013, error L2 relative psi:    0.00002253646390
# Iteration #014, error L2 relative psi:    0.00002133778154
# Iteration #015, error L2 relative psi:    0.00002022160991
# Iteration #016, error L2 relative psi:    0.00001917517707
# Iteration #017, error L2 relative psi:    0.00001818983268
# Iteration #018, error L2 relative psi:    0.00001725940418
#
# Time 0.22917
# Iteration #001, error L2 relative psi:    0.03789654972048
# Iteration #002, error L2 relative psi:    0.00502816627311
# Iteration #003, error L2 relative psi:    0.00138928766383
# Iteration #004, error L2 relative psi:    0.00049938183468
# Iteration #005, error L2 relative psi:    0.00020803024189
# Iteration #006, error L2 relative psi:    0.00010237122239
# Iteration #007, error L2 relative psi:    0.00006670935222
# Iteration #008, error L2 relative psi:    0.00005472055151
# Iteration #009, error L2 relative psi:    0.00004931020155
# Iteration #010, error L2 relative psi:    0.00004575679424
# Iteration #011, error L2 relative psi:    0.00004290812571
# Iteration #012, error L2 relative psi:    0.00004043519731
# Iteration #013, error L2 relative psi:    0.00003821013411
# Iteration #014, error L2 relative psi:    0.00003616817438
# Iteration #015, error L2 relative psi:    0.00003427139418
# Iteration #016, error L2 relative psi:    0.00003249583623
# Iteration #017, error L2 relative psi:    0.00003082552209
# Iteration #018, error L2 relative psi:    0.00002924922243
# Iteration #019, error L2 relative psi:    0.00002775860626
# Iteration #020, error L2 relative psi:    0.00002634715423
# Iteration #021, error L2 relative psi:    0.00002500951252
# Iteration #022, error L2 relative psi:    0.00002374110457
# Iteration #023, error L2 relative psi:    0.00002253789497
# Iteration #024, error L2 relative psi:    0.00002139624368
# Iteration #025, error L2 relative psi:    0.00002031281432
# Iteration #026, error L2 relative psi:    0.00001928451488
# Iteration #027, error L2 relative psi:    0.00001830845824
# Iteration #028, error L2 relative psi:    0.00001738193485
#
# Time 0.25
# Iteration #001, error L2 relative psi:    0.03489606011182
# Iteration #002, error L2 relative psi:    0.00524252483342
# Iteration #003, error L2 relative psi:    0.00154296212080
# Iteration #004, error L2 relative psi:    0.00059602670898
# Iteration #005, error L2 relative psi:    0.00027330445187
# Iteration #006, error L2 relative psi:    0.00015006844485
# Iteration #007, error L2 relative psi:    0.00010436261215
# Iteration #008, error L2 relative psi:    0.00008654714096
# Iteration #009, error L2 relative psi:    0.00007766254562
# Iteration #010, error L2 relative psi:    0.00007177023443
# Iteration #011, error L2 relative psi:    0.00006713185919
# Iteration #012, error L2 relative psi:    0.00006316921310
# Iteration #013, error L2 relative psi:    0.00005964145950
# Iteration #014, error L2 relative psi:    0.00005642602751
# Iteration #015, error L2 relative psi:    0.00005345224680
# Iteration #016, error L2 relative psi:    0.00005067628957
# Iteration #017, error L2 relative psi:    0.00004806949194
# Iteration #018, error L2 relative psi:    0.00004561213782
# Iteration #019, error L2 relative psi:    0.00004328993027
# Iteration #020, error L2 relative psi:    0.00004109192971
# Iteration #021, error L2 relative psi:    0.00003900933130
# Iteration #022, error L2 relative psi:    0.00003703473206
# Iteration #023, error L2 relative psi:    0.00003516168677
# Iteration #024, error L2 relative psi:    0.00003338443530
# Iteration #025, error L2 relative psi:    0.00003169773217
# Iteration #026, error L2 relative psi:    0.00003009673775
# Iteration #027, error L2 relative psi:    0.00002857694672
# Iteration #028, error L2 relative psi:    0.00002713413939
# Iteration #029, error L2 relative psi:    0.00002576434729
# Iteration #030, error L2 relative psi:    0.00002446382772
# Iteration #031, error L2 relative psi:    0.00002322904407
# Iteration #032, error L2 relative psi:    0.00002205665002
# Iteration #033, error L2 relative psi:    0.00002094347629
# Iteration #034, error L2 relative psi:    0.00001988651930
# Iteration #035, error L2 relative psi:    0.00001888293112
# Iteration #036, error L2 relative psi:    0.00001793001048
#
# Time 0.27083
# Iteration #001, error L2 relative psi:    0.03232948677001
# Iteration #002, error L2 relative psi:    0.00549015817934
# Iteration #003, error L2 relative psi:    0.00171904910149
# Iteration #004, error L2 relative psi:    0.00070678652024
# Iteration #005, error L2 relative psi:    0.00035331869246
# Iteration #006, error L2 relative psi:    0.00021341169617
# Iteration #007, error L2 relative psi:    0.00015704703650
# Iteration #008, error L2 relative psi:    0.00013212648194
# Iteration #009, error L2 relative psi:    0.00011851591980
# Iteration #010, error L2 relative psi:    0.00010927106892
# Iteration #011, error L2 relative psi:    0.00010203541792
# Iteration #012, error L2 relative psi:    0.00009591430389
# Iteration #013, error L2 relative psi:    0.00009050617869
# Iteration #014, error L2 relative psi:    0.00008560198803
# Iteration #015, error L2 relative psi:    0.00008108138524
# Iteration #016, error L2 relative psi:    0.00007687040530
# Iteration #017, error L2 relative psi:    0.00007292123008
# Iteration #018, error L2 relative psi:    0.00006920140644
# Iteration #019, error L2 relative psi:    0.00006568774917
# Iteration #020, error L2 relative psi:    0.00006236278801
# Iteration #021, error L2 relative psi:    0.00005921266349
# Iteration #022, error L2 relative psi:    0.00005622586639
# Iteration #023, error L2 relative psi:    0.00005339247483
# Iteration #024, error L2 relative psi:    0.00005070368659
# Iteration #025, error L2 relative psi:    0.00004815152805
# Iteration #026, error L2 relative psi:    0.00004572866923
# Iteration #027, error L2 relative psi:    0.00004342830327
# Iteration #028, error L2 relative psi:    0.00004124406532
# Iteration #029, error L2 relative psi:    0.00003916997582
# Iteration #030, error L2 relative psi:    0.00003720039922
# Iteration #031, error L2 relative psi:    0.00003533001250
# Iteration #032, error L2 relative psi:    0.00003355378023
# Iteration #033, error L2 relative psi:    0.00003186693396
# Iteration #034, error L2 relative psi:    0.00003026495464
# Iteration #035, error L2 relative psi:    0.00002874355731
# Iteration #036, error L2 relative psi:    0.00002729867733
# Iteration #037, error L2 relative psi:    0.00002592645795
# Iteration #038, error L2 relative psi:    0.00002462323893
# Iteration #039, error L2 relative psi:    0.00002338554592
# Iteration #040, error L2 relative psi:    0.00002221008066
# Iteration #041, error L2 relative psi:    0.00002109371172
# Iteration #042, error L2 relative psi:    0.00002003346588
# Iteration #043, error L2 relative psi:    0.00001902652000
# Iteration #044, error L2 relative psi:    0.00001807019328
#
# Time 0.29167
# Iteration #001, error L2 relative psi:    0.03010816875669
# Iteration #002, error L2 relative psi:    0.00576255479967
# Iteration #003, error L2 relative psi:    0.00193472025145
# Iteration #004, error L2 relative psi:    0.00084623353561
# Iteration #005, error L2 relative psi:    0.00045662902528
# Iteration #006, error L2 relative psi:    0.00029734077843
# Iteration #007, error L2 relative psi:    0.00022803956822
# Iteration #008, error L2 relative psi:    0.00019407951699
# Iteration #009, error L2 relative psi:    0.00017416792933
# Iteration #010, error L2 relative psi:    0.00016033378584
# Iteration #011, error L2 relative psi:    0.00014952258575
# Iteration #012, error L2 relative psi:    0.00014044086060
# Iteration #013, error L2 relative psi:    0.00013246749915
# Iteration #014, error L2 relative psi:    0.00012526985720
# Iteration #015, error L2 relative psi:    0.00011865523672
# Iteration #016, error L2 relative psi:    0.00011250557278
# Iteration #017, error L2 relative psi:    0.00010674508865
# Iteration #018, error L2 relative psi:    0.00010132286428
# Iteration #019, error L2 relative psi:    0.00009620295495
# Iteration #020, error L2 relative psi:    0.00009135862970
# Iteration #021, error L2 relative psi:    0.00008676895635
# Iteration #022, error L2 relative psi:    0.00008241675410
# Iteration #023, error L2 relative psi:    0.00007828735324
# Iteration #024, error L2 relative psi:    0.00007436783515
# Iteration #025, error L2 relative psi:    0.00007064655998
# Iteration #026, error L2 relative psi:    0.00006711286760
# Iteration #027, error L2 relative psi:    0.00006375688382
# Iteration #028, error L2 relative psi:    0.00006056939111
# Iteration #029, error L2 relative psi:    0.00005754173921
# Iteration #030, error L2 relative psi:    0.00005466578081
# Iteration #031, error L2 relative psi:    0.00005193382328
# Iteration #032, error L2 relative psi:    0.00004933859082
# Iteration #033, error L2 relative psi:    0.00004687319368
# Iteration #034, error L2 relative psi:    0.00004453110209
# Iteration #035, error L2 relative psi:    0.00004230612375
# Iteration #036, error L2 relative psi:    0.00004019238381
# Iteration #037, error L2 relative psi:    0.00003818430678
# Iteration #038, error L2 relative psi:    0.00003627660002
# Iteration #039, error L2 relative psi:    0.00003446423852
# Iteration #040, error L2 relative psi:    0.00003274245068
# Iteration #041, error L2 relative psi:    0.00003110670509
# Iteration #042, error L2 relative psi:    0.00002955269809
# Iteration #043, error L2 relative psi:    0.00002807634207
# Iteration #044, error L2 relative psi:    0.00002667375445
# Iteration #045, error L2 relative psi:    0.00002534124723
# Iteration #046, error L2 relative psi:    0.00002407531717
# Iteration #047, error L2 relative psi:    0.00002287263643
# Iteration #048, error L2 relative psi:    0.00002173004373
# Iteration #049, error L2 relative psi:    0.00002064453599
# Iteration #050, error L2 relative psi:    0.00001961326034
#
# Time 0.3125
# Iteration #001, error L2 relative psi:    0.02816916428464
# Iteration #002, error L2 relative psi:    0.00604977605757
# Iteration #003, error L2 relative psi:    0.00220089487567
# Iteration #004, error L2 relative psi:    0.00102782181350
# Iteration #005, error L2 relative psi:    0.00059199489901
# Iteration #006, error L2 relative psi:    0.00040738724899
# Iteration #007, error L2 relative psi:    0.00032158274657
# Iteration #008, error L2 relative psi:    0.00027612742711
# Iteration #009, error L2 relative psi:    0.00024804154239
# Iteration #010, error L2 relative psi:    0.00022814340897
# Iteration #011, error L2 relative psi:    0.00021257378004
# Iteration #012, error L2 relative psi:    0.00019955476820
# Iteration #013, error L2 relative psi:    0.00018818229183
# Iteration #014, error L2 relative psi:    0.00017795721644
# Iteration #015, error L2 relative psi:    0.00016858669768
# Iteration #016, error L2 relative psi:    0.00015989076543
# Iteration #017, error L2 relative psi:    0.00015175419782
# Iteration #018, error L2 relative psi:    0.00014410006119
# Iteration #019, error L2 relative psi:    0.00013687455929
# Iteration #020, error L2 relative psi:    0.00013003814625
# Iteration #021, error L2 relative psi:    0.00012356023523
# Iteration #022, error L2 relative psi:    0.00011741601393
# Iteration #023, error L2 relative psi:    0.00011158450949
# Iteration #024, error L2 relative psi:    0.00010604740033
# Iteration #025, error L2 relative psi:    0.00010078827715
# Iteration #026, error L2 relative psi:    0.00009579217582
# Iteration #027, error L2 relative psi:    0.00009104527589
# Iteration #028, error L2 relative psi:    0.00008653470075
# Iteration #029, error L2 relative psi:    0.00008224838083
# Iteration #030, error L2 relative psi:    0.00007817495644
# Iteration #031, error L2 relative psi:    0.00007430370575
# Iteration #032, error L2 relative psi:    0.00007062448927
# Iteration #033, error L2 relative psi:    0.00006712770512
# Iteration #034, error L2 relative psi:    0.00006380425184
# Iteration #035, error L2 relative psi:    0.00006064549633
# Iteration #036, error L2 relative psi:    0.00005764324578
# Iteration #037, error L2 relative psi:    0.00005478972232
# Iteration #038, error L2 relative psi:    0.00005207754006
# Iteration #039, error L2 relative psi:    0.00004949968393
# Iteration #040, error L2 relative psi:    0.00004704949003
# Iteration #041, error L2 relative psi:    0.00004472062732
# Iteration #042, error L2 relative psi:    0.00004250708048
# Iteration #043, error L2 relative psi:    0.00004040313371
# Iteration #044, error L2 relative psi:    0.00003840335558
# Iteration #045, error L2 relative psi:    0.00003650258463
# Iteration #046, error L2 relative psi:    0.00003469591576
# Iteration #047, error L2 relative psi:    0.00003297868742
# Iteration #048, error L2 relative psi:    0.00003134646939
# Iteration #049, error L2 relative psi:    0.00002979505122
# Iteration #050, error L2 relative psi:    0.00002832043126
#
# Time 0.33333
# Iteration #001, error L2 relative psi:    0.02646529679179
# Iteration #002, error L2 relative psi:    0.00633740434491
# Iteration #003, error L2 relative psi:    0.00251462140964
# Iteration #004, error L2 relative psi:    0.00125813374611
# Iteration #005, error L2 relative psi:    0.00076817165628
# Iteration #006, error L2 relative psi:    0.00055144796148
# Iteration #007, error L2 relative psi:    0.00044447136534
# Iteration #008, error L2 relative psi:    0.00038431307624
# Iteration #009, error L2 relative psi:    0.00034566153720
# Iteration #010, error L2 relative psi:    0.00031783934512
# Iteration #011, error L2 relative psi:    0.00029601940920
# Iteration #012, error L2 relative psi:    0.00027782746170
# Iteration #013, error L2 relative psi:    0.00026199843048
# Iteration #014, error L2 relative psi:    0.00024781456086
# Iteration #015, error L2 relative psi:    0.00023484840119
# Iteration #016, error L2 relative psi:    0.00022283550528
# Iteration #017, error L2 relative psi:    0.00021160663377
# Iteration #018, error L2 relative psi:    0.00020104892305
# Iteration #019, error L2 relative psi:    0.00019108379114
# Iteration #020, error L2 relative psi:    0.00018165424476
# Iteration #021, error L2 relative psi:    0.00017271675085
# Iteration #022, error L2 relative psi:    0.00016423631104
# Iteration #023, error L2 relative psi:    0.00015618365281
# Iteration #024, error L2 relative psi:    0.00014853342863
# Iteration #025, error L2 relative psi:    0.00014126306961
# Iteration #026, error L2 relative psi:    0.00013435201545
# Iteration #027, error L2 relative psi:    0.00012778158796
# Iteration #028, error L2 relative psi:    0.00012153429635
# Iteration #029, error L2 relative psi:    0.00011559376704
# Iteration #030, error L2 relative psi:    0.00010994460160
# Iteration #031, error L2 relative psi:    0.00010457227224
# Iteration #032, error L2 relative psi:    0.00009946304200
# Iteration #033, error L2 relative psi:    0.00009460390136
# Iteration #034, error L2 relative psi:    0.00008998251610
# Iteration #035, error L2 relative psi:    0.00008558718295
# Iteration #036, error L2 relative psi:    0.00008140679081
# Iteration #037, error L2 relative psi:    0.00007743078590
# Iteration #038, error L2 relative psi:    0.00007364910705
# Iteration #039, error L2 relative psi:    0.00007005223302
# Iteration #040, error L2 relative psi:    0.00006663114525
# Iteration #041, error L2 relative psi:    0.00006337723784
# Iteration #042, error L2 relative psi:    0.00006028232793
# Iteration #043, error L2 relative psi:    0.00005733863496
# Iteration #044, error L2 relative psi:    0.00005453876071
# Iteration #045, error L2 relative psi:    0.00005187567026
# Iteration #046, error L2 relative psi:    0.00004934267400
# Iteration #047, error L2 relative psi:    0.00004693341040
# Iteration #048, error L2 relative psi:    0.00004464182985
# Iteration #049, error L2 relative psi:    0.00004246217919
# Iteration #050, error L2 relative psi:    0.00004038898709
#
# Time 0.35417
# Iteration #001, error L2 relative psi:    0.02495931573574
# Iteration #002, error L2 relative psi:    0.00661311447873
# Iteration #003, error L2 relative psi:    0.00287638667996
# Iteration #004, error L2 relative psi:    0.00154834972460
# Iteration #005, error L2 relative psi:    0.00099500217629
# Iteration #006, error L2 relative psi:    0.00073562452079
# Iteration #007, error L2 relative psi:    0.00060014944296
# Iteration #008, error L2 relative psi:    0.00052048304862
# Iteration #009, error L2 relative psi:    0.00046800909666
# Iteration #010, error L2 relative psi:    0.00042994102020
# Iteration #011, error L2 relative psi:    0.00040013901532
# Iteration #012, error L2 relative psi:    0.00037542555710
# Iteration #013, error L2 relative psi:    0.00035404636916
# Iteration #014, error L2 relative psi:    0.00033498263275
# Iteration #015, error L2 relative psi:    0.00031761938157
# Iteration #016, error L2 relative psi:    0.00030157321915
# Iteration #017, error L2 relative psi:    0.00028659766684
# Iteration #018, error L2 relative psi:    0.00027252895914
# Iteration #019, error L2 relative psi:    0.00025925412159
# Iteration #020, error L2 relative psi:    0.00024669183161
# Iteration #021, error L2 relative psi:    0.00023478080388
# Iteration #022, error L2 relative psi:    0.00022347267795
# Iteration #023, error L2 relative psi:    0.00021272762829
# Iteration #024, error L2 relative psi:    0.00020251163246
# Iteration #025, error L2 relative psi:    0.00019279474758
# Iteration #026, error L2 relative psi:    0.00018355003764
# Iteration #027, error L2 relative psi:    0.00017475286418
# Iteration #028, error L2 relative psi:    0.00016638041688
# Iteration #029, error L2 relative psi:    0.00015841140311
# Iteration #030, error L2 relative psi:    0.00015082583300
# Iteration #031, error L2 relative psi:    0.00014360486498
# Iteration #032, error L2 relative psi:    0.00013673069057
# Iteration #033, error L2 relative psi:    0.00013018644511
# Iteration #034, error L2 relative psi:    0.00012395613584
# Iteration #035, error L2 relative psi:    0.00011802458208
# Iteration #036, error L2 relative psi:    0.00011237736385
# Iteration #037, error L2 relative psi:    0.00010700077672
# Iteration #038, error L2 relative psi:    0.00010188179138
# Iteration #039, error L2 relative psi:    0.00009700801684
# Iteration #040, error L2 relative psi:    0.00009236766664
# Iteration #041, error L2 relative psi:    0.00008794952746
# Iteration #042, error L2 relative psi:    0.00008374292989
# Iteration #043, error L2 relative psi:    0.00007973772098
# Iteration #044, error L2 relative psi:    0.00007592423849
# Iteration #045, error L2 relative psi:    0.00007229328652
# Iteration #046, error L2 relative psi:    0.00006883611257
# Iteration #047, error L2 relative psi:    0.00006554438574
# Iteration #048, error L2 relative psi:    0.00006241017618
# Iteration #049, error L2 relative psi:    0.00005942593548
# Iteration #050, error L2 relative psi:    0.00005658447818
#
# Time 0.375
# Iteration #001, error L2 relative psi:    0.02362812379638
# Iteration #002, error L2 relative psi:    0.00686238100047
# Iteration #003, error L2 relative psi:    0.00326800218913
# Iteration #004, error L2 relative psi:    0.00189024848778
# Iteration #005, error L2 relative psi:    0.00127248621528
# Iteration #006, error L2 relative psi:    0.00096349055526
# Iteration #007, error L2 relative psi:    0.00079303623606
# Iteration #008, error L2 relative psi:    0.00068893314041
# Iteration #009, error L2 relative psi:    0.00061899340751
# Iteration #010, error L2 relative psi:    0.00056796414859
# Iteration #011, error L2 relative psi:    0.00052812138430
# Iteration #012, error L2 relative psi:    0.00049529189603
# Iteration #013, error L2 relative psi:    0.00046709407340
# Iteration #014, error L2 relative psi:    0.00044211057532
# Iteration #015, error L2 relative psi:    0.00041946992608
# Iteration #016, error L2 relative psi:    0.00039862194578
# Iteration #017, error L2 relative psi:    0.00037921089460
# Iteration #018, error L2 relative psi:    0.00036100014864
# Iteration #019, error L2 relative psi:    0.00034382728493
# Iteration #020, error L2 relative psi:    0.00032757670162
# Iteration #021, error L2 relative psi:    0.00031216271750
# Iteration #022, error L2 relative psi:    0.00029751905586
# Iteration #023, error L2 relative psi:    0.00028359225698
# Iteration #024, error L2 relative psi:    0.00027033752421
# Iteration #025, error L2 relative psi:    0.00025771608551
# Iteration #026, error L2 relative psi:    0.00024569350278
# Iteration #027, error L2 relative psi:    0.00023423857645
# Iteration #028, error L2 relative psi:    0.00022332262570
# Iteration #029, error L2 relative psi:    0.00021291900777
# Iteration #030, error L2 relative psi:    0.00020300284474
# Iteration #031, error L2 relative psi:    0.00019355062156
# Iteration #032, error L2 relative psi:    0.00018454016016
# Iteration #033, error L2 relative psi:    0.00017595048399
# Iteration #034, error L2 relative psi:    0.00016776169634
# Iteration #035, error L2 relative psi:    0.00015995490027
# Iteration #036, error L2 relative psi:    0.00015251213136
# Iteration #037, error L2 relative psi:    0.00014541628485
# Iteration #038, error L2 relative psi:    0.00013865108698
# Iteration #039, error L2 relative psi:    0.00013220106072
# Iteration #040, error L2 relative psi:    0.00012605146625
# Iteration #041, error L2 relative psi:    0.00012018826278
# Iteration #042, error L2 relative psi:    0.00011459807336
# Iteration #043, error L2 relative psi:    0.00010926815184
# Iteration #044, error L2 relative psi:    0.00010418635201
# Iteration #045, error L2 relative psi:    0.00009934109842
# Iteration #046, error L2 relative psi:    0.00009472135887
# Iteration #047, error L2 relative psi:    0.00009031661841
# Iteration #048, error L2 relative psi:    0.00008611685460
# Iteration #049, error L2 relative psi:    0.00008211251414
# Iteration #050, error L2 relative psi:    0.00007829449060
#
# Time 0.39583
# Iteration #001, error L2 relative psi:    0.02245139702321
# Iteration #002, error L2 relative psi:    0.00706285706068
# Iteration #003, error L2 relative psi:    0.00366012881278
# Iteration #004, error L2 relative psi:    0.00226298410654
# Iteration #005, error L2 relative psi:    0.00158827379191
# Iteration #006, error L2 relative psi:    0.00122709637422
# Iteration #007, error L2 relative psi:    0.00101668278062
# Iteration #008, error L2 relative psi:    0.00088349868842
# Iteration #009, error L2 relative psi:    0.00079240426867
# Iteration #010, error L2 relative psi:    0.00072562775937
# Iteration #011, error L2 relative psi:    0.00067366577576
# Iteration #012, error L2 relative psi:    0.00063116943860
# Iteration #013, error L2 relative psi:    0.00059498344296
# Iteration #014, error L2 relative psi:    0.00056318333129
# Iteration #015, error L2 relative psi:    0.00053455981547
# Iteration #016, error L2 relative psi:    0.00050834158103
# Iteration #017, error L2 relative psi:    0.00048402219400
# Iteration #018, error L2 relative psi:    0.00046126192411
# Iteration #019, error L2 relative psi:    0.00043982911589
# Iteration #020, error L2 relative psi:    0.00041956110532
# Iteration #021, error L2 relative psi:    0.00040033852623
# Iteration #022, error L2 relative psi:    0.00038207048426
# Iteration #023, error L2 relative psi:    0.00036468549963
# Iteration #024, error L2 relative psi:    0.00034812505670
# Iteration #025, error L2 relative psi:    0.00033233909136
# Iteration #026, error L2 relative psi:    0.00031728433000
# Iteration #027, error L2 relative psi:    0.00030292289971
# Iteration #028, error L2 relative psi:    0.00028921974224
# Iteration #029, error L2 relative psi:    0.00027614253443
# Iteration #030, error L2 relative psi:    0.00026366118756
# Iteration #031, error L2 relative psi:    0.00025174749629
# Iteration #032, error L2 relative psi:    0.00024037488755
# Iteration #033, error L2 relative psi:    0.00022951823603
# Iteration #034, error L2 relative psi:    0.00021915372455
# Iteration #035, error L2 relative psi:    0.00020925873454
# Iteration #036, error L2 relative psi:    0.00019981175752
# Iteration #037, error L2 relative psi:    0.00019079232092
# Iteration #038, error L2 relative psi:    0.00018218092419
# Iteration #039, error L2 relative psi:    0.00017395898125
# Iteration #040, error L2 relative psi:    0.00016610870707
# Iteration #041, error L2 relative psi:    0.00015861292419
# Iteration #042, error L2 relative psi:    0.00015145591500
# Iteration #043, error L2 relative psi:    0.00014462232425
# Iteration #044, error L2 relative psi:    0.00013809749154
# Iteration #045, error L2 relative psi:    0.00013186742418
# Iteration #046, error L2 relative psi:    0.00012591876770
# Iteration #047, error L2 relative psi:    0.00012023877665
# Iteration #048, error L2 relative psi:    0.00011481528649
# Iteration #049, error L2 relative psi:    0.00010963668669
# Iteration #050, error L2 relative psi:    0.00010469189516
#
# Time 0.41667
# Iteration #001, error L2 relative psi:    0.02140793254680
# Iteration #002, error L2 relative psi:    0.00718873481777
# Iteration #003, error L2 relative psi:    0.00401969345677
# Iteration #004, error L2 relative psi:    0.00264277353904
# Iteration #005, error L2 relative psi:    0.00193056338397
# Iteration #006, error L2 relative psi:    0.00152320504177
# Iteration #007, error L2 relative psi:    0.00127242406858
# Iteration #008, error L2 relative psi:    0.00110740152266
# Iteration #009, error L2 relative psi:    0.00099193095320
# Iteration #010, error L2 relative psi:    0.00090649895265
# Iteration #011, error L2 relative psi:    0.00084005067537
# Iteration #012, error L2 relative psi:    0.00078604818450
# Iteration #013, error L2 relative psi:    0.00074048057608
# Iteration #014, error L2 relative psi:    0.00070081867688
# Iteration #015, error L2 relative psi:    0.00066543171414
# Iteration #016, error L2 relative psi:    0.00063325180357
# Iteration #017, error L2 relative psi:    0.00060356793279
# Iteration #018, error L2 relative psi:    0.00057589946812
# Iteration #019, error L2 relative psi:    0.00054991469414
# Iteration #020, error L2 relative psi:    0.00052537969553
# Iteration #021, error L2 relative psi:    0.00050212532746
# Iteration #022, error L2 relative psi:    0.00048002569287
# Iteration #023, error L2 relative psi:    0.00045898389351
# Iteration #024, error L2 relative psi:    0.00043892276074
# Iteration #025, error L2 relative psi:    0.00041977874541
# Iteration #026, error L2 relative psi:    0.00040149787245
# Iteration #027, error L2 relative psi:    0.00038403304885
# Iteration #028, error L2 relative psi:    0.00036734226099
# Iteration #029, error L2 relative psi:    0.00035138735790
# Iteration #030, error L2 relative psi:    0.00033613322148
# Iteration #031, error L2 relative psi:    0.00032154719306
# Iteration #032, error L2 relative psi:    0.00030759866305
# Iteration #033, error L2 relative psi:    0.00029425871451
# Iteration #034, error L2 relative psi:    0.00028150007208
# Iteration #035, error L2 relative psi:    0.00026929689080
# Iteration #036, error L2 relative psi:    0.00025762452625
# Iteration #037, error L2 relative psi:    0.00024645970166
# Iteration #038, error L2 relative psi:    0.00023578009072
# Iteration #039, error L2 relative psi:    0.00022556441322
# Iteration #040, error L2 relative psi:    0.00021579236899
# Iteration #041, error L2 relative psi:    0.00020644457030
# Iteration #042, error L2 relative psi:    0.00019750249612
# Iteration #043, error L2 relative psi:    0.00018894844951
# Iteration #044, error L2 relative psi:    0.00018076551785
# Iteration #045, error L2 relative psi:    0.00017293753576
# Iteration #046, error L2 relative psi:    0.00016544905029
# Iteration #047, error L2 relative psi:    0.00015828528808
# Iteration #048, error L2 relative psi:    0.00015143212438
# Iteration #049, error L2 relative psi:    0.00014487605372
# Iteration #050, error L2 relative psi:    0.00013860416205
#
# Time 0.4375
# Iteration #001, error L2 relative psi:    0.02048561675436
# Iteration #002, error L2 relative psi:    0.00721057740406
# Iteration #003, error L2 relative psi:    0.00430069961737
# Iteration #004, error L2 relative psi:    0.00298609955248
# Iteration #005, error L2 relative psi:    0.00226560309593
# Iteration #006, error L2 relative psi:    0.00182786960071
# Iteration #007, error L2 relative psi:    0.00154338301032
# Iteration #008, error L2 relative psi:    0.00134806379246
# Iteration #009, error L2 relative psi:    0.00120742525925
# Iteration #010, error L2 relative psi:    0.00110170237997
# Iteration #011, error L2 relative psi:    0.00101902281437
# Iteration #012, error L2 relative psi:    0.00095197008066
# Iteration #013, error L2 relative psi:    0.00089577238061
# Iteration #014, error L2 relative psi:    0.00084729546659
# Iteration #015, error L2 relative psi:    0.00080445592530
# Iteration #016, error L2 relative psi:    0.00076584318254
# Iteration #017, error L2 relative psi:    0.00073049310314
# Iteration #018, error L2 relative psi:    0.00069773900359
# Iteration #019, error L2 relative psi:    0.00066711408779
# Iteration #020, error L2 relative psi:    0.00063828656157
# Iteration #021, error L2 relative psi:    0.00061101633942
# Iteration #022, error L2 relative psi:    0.00058512399849
# Iteration #023, error L2 relative psi:    0.00056047814801
# Iteration #024, error L2 relative psi:    0.00053697459313
# Iteration #025, error L2 relative psi:    0.00051452984205
# Iteration #026, error L2 relative psi:    0.00049307501392
# Iteration #027, error L2 relative psi:    0.00047255167401
# Iteration #028, error L2 relative psi:    0.00045290920548
# Iteration #029, error L2 relative psi:    0.00043410269403
# Iteration #030, error L2 relative psi:    0.00041609154882
# Iteration #031, error L2 relative psi:    0.00039883842963
# Iteration #032, error L2 relative psi:    0.00038230887452
# Iteration #033, error L2 relative psi:    0.00036647074291
# Iteration #034, error L2 relative psi:    0.00035129380680
# Iteration #035, error L2 relative psi:    0.00033674958418
# Iteration #036, error L2 relative psi:    0.00032281097487
# Iteration #037, error L2 relative psi:    0.00030945211102
# Iteration #038, error L2 relative psi:    0.00029664845450
# Iteration #039, error L2 relative psi:    0.00028437659689
# Iteration #040, error L2 relative psi:    0.00027261418226
# Iteration #041, error L2 relative psi:    0.00026133984332
# Iteration #042, error L2 relative psi:    0.00025053314584
# Iteration #043, error L2 relative psi:    0.00024017453902
# Iteration #044, error L2 relative psi:    0.00023024531002
# Iteration #045, error L2 relative psi:    0.00022072753931
# Iteration #046, error L2 relative psi:    0.00021160381020
# Iteration #047, error L2 relative psi:    0.00020285771936
# Iteration #048, error L2 relative psi:    0.00019447384907
# Iteration #049, error L2 relative psi:    0.00018643714147
# Iteration #050, error L2 relative psi:    0.00017873316558
#
# Time 0.45833
# Iteration #001, error L2 relative psi:    0.01967794067427
# Iteration #002, error L2 relative psi:    0.00710138327214
# Iteration #003, error L2 relative psi:    0.00445568612680
# Iteration #004, error L2 relative psi:    0.00324246058761
# Iteration #005, error L2 relative psi:    0.00254855879549
# Iteration #006, error L2 relative psi:    0.00210496794068
# Iteration #007, error L2 relative psi:    0.00180208006001
# Iteration #008, error L2 relative psi:    0.00158499428420
# Iteration #009, error L2 relative psi:    0.00142333571941
# Iteration #010, error L2 relative psi:    0.00129891156236
# Iteration #011, error L2 relative psi:    0.00120023175035
# Iteration #012, error L2 relative psi:    0.00111974623891
# Iteration #013, error L2 relative psi:    0.00105234776718
# Iteration #014, error L2 relative psi:    0.00099451958282
# Iteration #015, error L2 relative psi:    0.00094381735652
# Iteration #016, error L2 relative psi:    0.00089851755273
# Iteration #017, error L2 relative psi:    0.00085739814044
# Iteration #018, error L2 relative psi:    0.00081958681094
# Iteration #019, error L2 relative psi:    0.00078445595513
# Iteration #020, error L2 relative psi:    0.00075154503578
# Iteration #021, error L2 relative psi:    0.00072052601570
# Iteration #022, error L2 relative psi:    0.00069115144661
# Iteration #023, error L2 relative psi:    0.00066323435870
# Iteration #024, error L2 relative psi:    0.00063663089088
# Iteration #025, error L2 relative psi:    0.00061122796191
# Iteration #026, error L2 relative psi:    0.00058693456302
# Iteration #027, error L2 relative psi:    0.00056367588758
# Iteration #028, error L2 relative psi:    0.00054138928895
# Iteration #029, error L2 relative psi:    0.00052002085597
# Iteration #030, error L2 relative psi:    0.00049952304362
# Iteration #031, error L2 relative psi:    0.00047985341165
# Iteration #032, error L2 relative psi:    0.00046097358136
# Iteration #033, error L2 relative psi:    0.00044284826612
# Iteration #034, error L2 relative psi:    0.00042544469736
# Iteration #035, error L2 relative psi:    0.00040873220245
# Iteration #036, error L2 relative psi:    0.00039268187998
# Iteration #037, error L2 relative psi:    0.00037726560955
# Iteration #038, error L2 relative psi:    0.00036245728763
# Iteration #039, error L2 relative psi:    0.00034823338734
# Iteration #040, error L2 relative psi:    0.00033457039318
# Iteration #041, error L2 relative psi:    0.00032144602172
# Iteration #042, error L2 relative psi:    0.00030883864765
# Iteration #043, error L2 relative psi:    0.00029672753134
# Iteration #044, error L2 relative psi:    0.00028509293491
# Iteration #045, error L2 relative psi:    0.00027391594061
# Iteration #046, error L2 relative psi:    0.00026317840724
# Iteration #047, error L2 relative psi:    0.00025286293275
# Iteration #048, error L2 relative psi:    0.00024295282018
# Iteration #049, error L2 relative psi:    0.00023343204609
# Iteration #050, error L2 relative psi:    0.00022428523121
#
# Time 0.47917
# Iteration #001, error L2 relative psi:    0.01899379270313
# Iteration #002, error L2 relative psi:    0.00684656366504
# Iteration #003, error L2 relative psi:    0.00443664868889
# Iteration #004, error L2 relative psi:    0.00334897533285
# Iteration #005, error L2 relative psi:    0.00271476375197
# Iteration #006, error L2 relative psi:    0.00229453097623
# Iteration #007, error L2 relative psi:    0.00199567047992
# Iteration #008, error L2 relative psi:    0.00177303516491
# Iteration #009, error L2 relative psi:    0.00160151974540
# Iteration #010, error L2 relative psi:    0.00146583897240
# Iteration #011, error L2 relative psi:    0.00135599923986
# Iteration #012, error L2 relative psi:    0.00126517497156
# Iteration #013, error L2 relative psi:    0.00118855023757
# Iteration #014, error L2 relative psi:    0.00112266156669
# Iteration #015, error L2 relative psi:    0.00106500078475
# Iteration #016, error L2 relative psi:    0.00101372278773
# Iteration #017, error L2 relative psi:    0.00096745703733
# Iteration #018, error L2 relative psi:    0.00092520121088
# Iteration #019, error L2 relative psi:    0.00088619570781
# Iteration #020, error L2 relative psi:    0.00084987441391
# Iteration #021, error L2 relative psi:    0.00081581122633
# Iteration #022, error L2 relative psi:    0.00078368234352
# Iteration #023, error L2 relative psi:    0.00075323955878
# Iteration #024, error L2 relative psi:    0.00072429061752
# Iteration #025, error L2 relative psi:    0.00069668473862
# Iteration #026, error L2 relative psi:    0.00067030210147
# Iteration #027, error L2 relative psi:    0.00064504555513
# Iteration #028, error L2 relative psi:    0.00062083520283
# Iteration #029, error L2 relative psi:    0.00059760413436
# Iteration #030, error L2 relative psi:    0.00057529399838
# Iteration #031, error L2 relative psi:    0.00055385548399
# Iteration #032, error L2 relative psi:    0.00053324629842
# Iteration #033, error L2 relative psi:    0.00051342724308
# Iteration #034, error L2 relative psi:    0.00049436271105
# Iteration #035, error L2 relative psi:    0.00047602000228
# Iteration #036, error L2 relative psi:    0.00045836880512
# Iteration #037, error L2 relative psi:    0.00044138080380
# Iteration #038, error L2 relative psi:    0.00042502938008
# Iteration #039, error L2 relative psi:    0.00040928938470
# Iteration #040, error L2 relative psi:    0.00039413696075
# Iteration #041, error L2 relative psi:    0.00037954940540
# Iteration #042, error L2 relative psi:    0.00036550506035
# Iteration #043, error L2 relative psi:    0.00035198322354
# Iteration #044, error L2 relative psi:    0.00033896407688
# Iteration #045, error L2 relative psi:    0.00032642862613
# Iteration #046, error L2 relative psi:    0.00031435864984
# Iteration #047, error L2 relative psi:    0.00030273665535
# Iteration #048, error L2 relative psi:    0.00029154584018
# Iteration #049, error L2 relative psi:    0.00028077005764
# Iteration #050, error L2 relative psi:    0.00027039378567
#
# Time 0.5
# Iteration #001, error L2 relative psi:    0.01844898465596
# Iteration #002, error L2 relative psi:    0.00645785988659
# Iteration #003, error L2 relative psi:    0.00421945734692
# Iteration #004, error L2 relative psi:    0.00325699249440
# Iteration #005, error L2 relative psi:    0.00270305796350
# Iteration #006, error L2 relative psi:    0.00233142571112
# Iteration #007, error L2 relative psi:    0.00206076966060
# Iteration #008, error L2 relative psi:    0.00185331203036
# Iteration #009, error L2 relative psi:    0.00168878512260
# Iteration #010, error L2 relative psi:    0.00155503299247
# Iteration #011, error L2 relative psi:    0.00144411634160
# Iteration #012, error L2 relative psi:    0.00135056361514
# Iteration #013, error L2 relative psi:    0.00127047130555
# Iteration #014, error L2 relative psi:    0.00120092196168
# Iteration #015, error L2 relative psi:    0.00113971033957
# Iteration #016, error L2 relative psi:    0.00108513597374
# Iteration #017, error L2 relative psi:    0.00103593775577
# Iteration #018, error L2 relative psi:    0.00099111732015
# Iteration #019, error L2 relative psi:    0.00094989876826
# Iteration #020, error L2 relative psi:    0.00091167808550
# Iteration #021, error L2 relative psi:    0.00087597876542
# Iteration #022, error L2 relative psi:    0.00084243494243
# Iteration #023, error L2 relative psi:    0.00081076359721
# Iteration #024, error L2 relative psi:    0.00078073504973
# Iteration #025, error L2 relative psi:    0.00075216604293
# Iteration #026, error L2 relative psi:    0.00072490920641
# Iteration #027, error L2 relative psi:    0.00069884524446
# Iteration #028, error L2 relative psi:    0.00067387626072
# Iteration #029, error L2 relative psi:    0.00064992065202
# Iteration #030, error L2 relative psi:    0.00062690717619
# Iteration #031, error L2 relative psi:    0.00060477939525
# Iteration #032, error L2 relative psi:    0.00058348860439
# Iteration #033, error L2 relative psi:    0.00056299088308
# Iteration #034, error L2 relative psi:    0.00054324718090
# Iteration #035, error L2 relative psi:    0.00052422229240
# Iteration #036, error L2 relative psi:    0.00050588071772
# Iteration #037, error L2 relative psi:    0.00048819723326
# Iteration #038, error L2 relative psi:    0.00047114526534
# Iteration #039, error L2 relative psi:    0.00045469963352
# Iteration #040, error L2 relative psi:    0.00043883672974
# Iteration #041, error L2 relative psi:    0.00042353431055
# Iteration #042, error L2 relative psi:    0.00040877132915
# Iteration #043, error L2 relative psi:    0.00039452781206
# Iteration #044, error L2 relative psi:    0.00038078534075
# Iteration #045, error L2 relative psi:    0.00036752532264
# Iteration #046, error L2 relative psi:    0.00035472998026
# Iteration #047, error L2 relative psi:    0.00034238263201
# Iteration #048, error L2 relative psi:    0.00033046726526
# Iteration #049, error L2 relative psi:    0.00031896845293
# Iteration #050, error L2 relative psi:    0.00030787140162
#
# Time 0.52083
# Iteration #001, error L2 relative psi:    0.01805205179550
# Iteration #002, error L2 relative psi:    0.00598722974050
# Iteration #003, error L2 relative psi:    0.00383116671477
# Iteration #004, error L2 relative psi:    0.00296314290468
# Iteration #005, error L2 relative psi:    0.00248703180538
# Iteration #006, error L2 relative psi:    0.00217409855886
# Iteration #007, error L2 relative psi:    0.00194651177357
# Iteration #008, error L2 relative psi:    0.00177019714341
# Iteration #009, error L2 relative psi:    0.00162808112759
# Iteration #010, error L2 relative psi:    0.00151034234542
# Iteration #011, error L2 relative psi:    0.00141081574883
# Iteration #012, error L2 relative psi:    0.00132538455363
# Iteration #013, error L2 relative psi:    0.00125104306342
# Iteration #014, error L2 relative psi:    0.00118561005822
# Iteration #015, error L2 relative psi:    0.00112740610466
# Iteration #016, error L2 relative psi:    0.00107510366995
# Iteration #017, error L2 relative psi:    0.00102768898242
# Iteration #018, error L2 relative psi:    0.00098434042871
# Iteration #019, error L2 relative psi:    0.00094439750179
# Iteration #020, error L2 relative psi:    0.00090733000055
# Iteration #021, error L2 relative psi:    0.00087271785343
# Iteration #022, error L2 relative psi:    0.00084021947905
# Iteration #023, error L2 relative psi:    0.00080956592552
# Iteration #024, error L2 relative psi:    0.00078053629530
# Iteration #025, error L2 relative psi:    0.00075293104256
# Iteration #026, error L2 relative psi:    0.00072662343774
# Iteration #027, error L2 relative psi:    0.00070149226340
# Iteration #028, error L2 relative psi:    0.00067743069331
# Iteration #029, error L2 relative psi:    0.00065435232609
# Iteration #030, error L2 relative psi:    0.00063218902896
# Iteration #031, error L2 relative psi:    0.00061087678714
# Iteration #032, error L2 relative psi:    0.00059036490330
# Iteration #033, error L2 relative psi:    0.00057060689401
# Iteration #034, error L2 relative psi:    0.00055156210236
# Iteration #035, error L2 relative psi:    0.00053319446039
# Iteration #036, error L2 relative psi:    0.00051547166555
# Iteration #037, error L2 relative psi:    0.00049836451072
# Iteration #038, error L2 relative psi:    0.00048184630212
# Iteration #039, error L2 relative psi:    0.00046588961163
# Iteration #040, error L2 relative psi:    0.00045047440032
# Iteration #041, error L2 relative psi:    0.00043558065863
# Iteration #042, error L2 relative psi:    0.00042118851200
# Iteration #043, error L2 relative psi:    0.00040727738875
# Iteration #044, error L2 relative psi:    0.00039383091564
# Iteration #045, error L2 relative psi:    0.00038083358896
# Iteration #046, error L2 relative psi:    0.00036826864424
# Iteration #047, error L2 relative psi:    0.00035612180365
# Iteration #048, error L2 relative psi:    0.00034437868795
# Iteration #049, error L2 relative psi:    0.00033302540463
# Iteration #050, error L2 relative psi:    0.00032204862169
#
# Time 0.54167
# Iteration #001, error L2 relative psi:    0.01777248400293
# Iteration #002, error L2 relative psi:    0.00551526093962
# Iteration #003, error L2 relative psi:    0.00337448141337
# Iteration #004, error L2 relative psi:    0.00255486286059
# Iteration #005, error L2 relative psi:    0.00213039006563
# Iteration #006, error L2 relative psi:    0.00186344060218
# Iteration #007, error L2 relative psi:    0.00167479474949
# Iteration #008, error L2 relative psi:    0.00153091951769
# Iteration #009, error L2 relative psi:    0.00141558802970
# Iteration #010, error L2 relative psi:    0.00131994353786
# Iteration #011, error L2 relative psi:    0.00123872520588
# Iteration #012, error L2 relative psi:    0.00116851924124
# Iteration #013, error L2 relative psi:    0.00110693246907
# Iteration #014, error L2 relative psi:    0.00105222386542
# Iteration #015, error L2 relative psi:    0.00100314973606
# Iteration #016, error L2 relative psi:    0.00095873451177
# Iteration #017, error L2 relative psi:    0.00091819674068
# Iteration #018, error L2 relative psi:    0.00088092469411
# Iteration #019, error L2 relative psi:    0.00084642802927
# Iteration #020, error L2 relative psi:    0.00081430418782
# Iteration #021, error L2 relative psi:    0.00078422426679
# Iteration #022, error L2 relative psi:    0.00075592218771
# ...
# Iteration #004, error L2 relative psi:    0.00015008985822
# Iteration #005, error L2 relative psi:    0.00012002013888
# Iteration #006, error L2 relative psi:    0.00010194575979
# Iteration #007, error L2 relative psi:    0.00008988222965
# Iteration #008, error L2 relative psi:    0.00008118876095
# Iteration #009, error L2 relative psi:    0.00007456317232
# Iteration #010, error L2 relative psi:    0.00006929788800
# Iteration #011, error L2 relative psi:    0.00006497683302
# Iteration #012, error L2 relative psi:    0.00006133960398
# Iteration #013, error L2 relative psi:    0.00005821498928
# Iteration #014, error L2 relative psi:    0.00005548584415
# Iteration #015, error L2 relative psi:    0.00005306931148
# Iteration #016, error L2 relative psi:    0.00005090509181
# Iteration #017, error L2 relative psi:    0.00004894818946
# Iteration #018, error L2 relative psi:    0.00004716427095
# Iteration #019, error L2 relative psi:    0.00004552660942
# Iteration #020, error L2 relative psi:    0.00004401402346
# Iteration #021, error L2 relative psi:    0.00004260945646
# Iteration #022, error L2 relative psi:    0.00004129897798
# Iteration #023, error L2 relative psi:    0.00004007106869
# Iteration #024, error L2 relative psi:    0.00003891609941
# Iteration #025, error L2 relative psi:    0.00003782594508
# Iteration #026, error L2 relative psi:    0.00003679369397
# Iteration #027, error L2 relative psi:    0.00003581342524
# Iteration #028, error L2 relative psi:    0.00003488003624
# Iteration #029, error L2 relative psi:    0.00003398910639
# Iteration #030, error L2 relative psi:    0.00003313678853
# Iteration #031, error L2 relative psi:    0.00003231972111
# Iteration #032, error L2 relative psi:    0.00003153495639
# Iteration #033, error L2 relative psi:    0.00003077990115
# Iteration #034, error L2 relative psi:    0.00003005226727
# Iteration #035, error L2 relative psi:    0.00002935003022
#
# Time 1.52083
# Iteration #001, error L2 relative psi:    0.00055902547195
# Iteration #002, error L2 relative psi:    0.00028093040075
# Iteration #003, error L2 relative psi:    0.00017545789449
# Iteration #004, error L2 relative psi:    0.00012800072450
# Iteration #005, error L2 relative psi:    0.00010307434059
# Iteration #006, error L2 relative psi:    0.00008808867139
# Iteration #007, error L2 relative psi:    0.00007807827606
# Iteration #008, error L2 relative psi:    0.00007085247547
# Iteration #009, error L2 relative psi:    0.00006533234194
# Iteration #010, error L2 relative psi:    0.00006093265412
# Iteration #011, error L2 relative psi:    0.00005730996702
# Iteration #012, error L2 relative psi:    0.00005424974237
# Iteration #013, error L2 relative psi:    0.00005161115740
# Iteration #014, error L2 relative psi:    0.00004929798730
# Iteration #015, error L2 relative psi:    0.00004724223882
# Iteration #016, error L2 relative psi:    0.00004539446315
# Iteration #017, error L2 relative psi:    0.00004371777683
# Iteration #018, error L2 relative psi:    0.00004218404233
# Iteration #019, error L2 relative psi:    0.00004077135746
# Iteration #020, error L2 relative psi:    0.00003946236370
# Iteration #021, error L2 relative psi:    0.00003824308129
# Iteration #022, error L2 relative psi:    0.00003710209080
# Iteration #023, error L2 relative psi:    0.00003602994740
# Iteration #024, error L2 relative psi:    0.00003501875406
# Iteration #025, error L2 relative psi:    0.00003406184536
# Iteration #026, error L2 relative psi:    0.00003315354933
# Iteration #027, error L2 relative psi:    0.00003228900518
# Iteration #028, error L2 relative psi:    0.00003146402181
# Iteration #029, error L2 relative psi:    0.00003067496625
# Iteration #030, error L2 relative psi:    0.00002991867468
#
# Time 1.54167
# Iteration #001, error L2 relative psi:    0.00046274649019
# Iteration #002, error L2 relative psi:    0.00023490854941
# Iteration #003, error L2 relative psi:    0.00014836710364
# Iteration #004, error L2 relative psi:    0.00010949430342
# Iteration #005, error L2 relative psi:    0.00008911197667
# Iteration #006, error L2 relative psi:    0.00007685602763
# Iteration #007, error L2 relative psi:    0.00006864894053
# Iteration #008, error L2 relative psi:    0.00006269940655
# Iteration #009, error L2 relative psi:    0.00005812828712
# Iteration #010, error L2 relative psi:    0.00005446269439
# Iteration #011, error L2 relative psi:    0.00005142523852
# Iteration #012, error L2 relative psi:    0.00004884304108
# Iteration #013, error L2 relative psi:    0.00004660283435
# Iteration #014, error L2 relative psi:    0.00004462728940
# Iteration #015, error L2 relative psi:    0.00004286176563
# Iteration #016, error L2 relative psi:    0.00004126649697
# Iteration #017, error L2 relative psi:    0.00003981178438
# Iteration #018, error L2 relative psi:    0.00003847493285
# Iteration #019, error L2 relative psi:    0.00003723824197
# Iteration #020, error L2 relative psi:    0.00003608765371
# Iteration #021, error L2 relative psi:    0.00003501182192
# Iteration #022, error L2 relative psi:    0.00003400145858
# Iteration #023, error L2 relative psi:    0.00003304886579
# Iteration #024, error L2 relative psi:    0.00003214759438
# Iteration #025, error L2 relative psi:    0.00003129219071
# Iteration #026, error L2 relative psi:    0.00003047800558
# Iteration #027, error L2 relative psi:    0.00002970104777
#
# Time 1.5625
# Iteration #001, error L2 relative psi:    0.00038264672514
# Iteration #002, error L2 relative psi:    0.00019623991599
# Iteration #003, error L2 relative psi:    0.00012539959826
# Iteration #004, error L2 relative psi:    0.00009365113151
# Iteration #005, error L2 relative psi:    0.00007703027442
# Iteration #006, error L2 relative psi:    0.00006702793819
# Iteration #007, error L2 relative psi:    0.00006030774588
# Iteration #008, error L2 relative psi:    0.00005541249733
# Iteration #009, error L2 relative psi:    0.00005163033726
# Iteration #010, error L2 relative psi:    0.00004857815135
# Iteration #011, error L2 relative psi:    0.00004603255672
# Iteration #012, error L2 relative psi:    0.00004385464153
# Iteration #013, error L2 relative psi:    0.00004195317641
# Iteration #014, error L2 relative psi:    0.00004026674995
# Iteration #015, error L2 relative psi:    0.00003875146389
# Iteration #016, error L2 relative psi:    0.00003737536271
# Iteration #017, error L2 relative psi:    0.00003611455596
# Iteration #018, error L2 relative psi:    0.00003495076076
# Iteration #019, error L2 relative psi:    0.00003386969349
# Iteration #020, error L2 relative psi:    0.00003285998904
# Iteration #021, error L2 relative psi:    0.00003191245754
# Iteration #022, error L2 relative psi:    0.00003101956223
# Iteration #023, error L2 relative psi:    0.00003017504542
# Iteration #024, error L2 relative psi:    0.00002937365544
#
# Time 1.58333
# Iteration #001, error L2 relative psi:    0.00031601170807
# Iteration #002, error L2 relative psi:    0.00016384816151
# Iteration #003, error L2 relative psi:    0.00010611874751
# Iteration #004, error L2 relative psi:    0.00008033892175
# Iteration #005, error L2 relative psi:    0.00006686208722
# Iteration #006, error L2 relative psi:    0.00005873492285
# Iteration #007, error L2 relative psi:    0.00005324824352
# Iteration #008, error L2 relative psi:    0.00004922444508
# Iteration #009, error L2 relative psi:    0.00004609168165
# Iteration #010, error L2 relative psi:    0.00004354351739
# Iteration #011, error L2 relative psi:    0.00004140182009
# Iteration #012, error L2 relative psi:    0.00003955604937
# Iteration #013, error L2 relative psi:    0.00003793391153
# Iteration #014, error L2 relative psi:    0.00003648605224
# Iteration #015, error L2 relative psi:    0.00003517754433
# Iteration #016, error L2 relative psi:    0.00003398289760
# Iteration #017, error L2 relative psi:    0.00003288300361
# Iteration #018, error L2 relative psi:    0.00003186319638
# Iteration #019, error L2 relative psi:    0.00003091198325
# Iteration #020, error L2 relative psi:    0.00003002019192
#
# Time 1.60417
# Iteration #001, error L2 relative psi:    0.00026025403742
# Iteration #002, error L2 relative psi:    0.00013690328592
# Iteration #003, error L2 relative psi:    0.00009041025709
# Iteration #004, error L2 relative psi:    0.00006978076889
# Iteration #005, error L2 relative psi:    0.00005899839526
# Iteration #006, error L2 relative psi:    0.00005245300331
# Iteration #007, error L2 relative psi:    0.00004798588929
# Iteration #008, error L2 relative psi:    0.00004466818316
# Iteration #009, error L2 relative psi:    0.00004205190435
# Iteration #010, error L2 relative psi:    0.00003989792441
# Iteration #011, error L2 relative psi:    0.00003806742934
# Iteration #012, error L2 relative psi:    0.00003647421601
# Iteration #013, error L2 relative psi:    0.00003506176875
# Iteration #014, error L2 relative psi:    0.00003379135590
# Iteration #015, error L2 relative psi:    0.00003263543265
# Iteration #016, error L2 relative psi:    0.00003157378245
# Iteration #017, error L2 relative psi:    0.00003059115742
# Iteration #018, error L2 relative psi:    0.00002967578084
#
# Time 1.625
# Iteration #001, error L2 relative psi:    0.00021483217914
# Iteration #002, error L2 relative psi:    0.00011477522430
# Iteration #003, error L2 relative psi:    0.00007729509561
# Iteration #004, error L2 relative psi:    0.00006075145020
# Iteration #005, error L2 relative psi:    0.00005209356676
# Iteration #006, error L2 relative psi:    0.00004679846631
# Iteration #007, error L2 relative psi:    0.00004314530096
# Iteration #008, error L2 relative psi:    0.00004039967762
# Iteration #009, error L2 relative psi:    0.00003820918268
# Iteration #010, error L2 relative psi:    0.00003638616375
# Iteration #011, error L2 relative psi:    0.00003482174122
# Iteration #012, error L2 relative psi:    0.00003344822760
# Iteration #013, error L2 relative psi:    0.00003222114234
# Iteration #014, error L2 relative psi:    0.00003110990073
# Iteration #015, error L2 relative psi:    0.00003009266421
# Iteration #016, error L2 relative psi:    0.00002915333220
#
# Time 1.64583
# Iteration #001, error L2 relative psi:    0.00017761359873
# Iteration #002, error L2 relative psi:    0.00009658893735
# Iteration #003, error L2 relative psi:    0.00006648484303
# Iteration #004, error L2 relative psi:    0.00005326005302
# Iteration #005, error L2 relative psi:    0.00004630976906
# Iteration #006, error L2 relative psi:    0.00004201209700
# Iteration #007, error L2 relative psi:    0.00003900627814
# Iteration #008, error L2 relative psi:    0.00003671595290
# Iteration #009, error L2 relative psi:    0.00003486545494
# Iteration #010, error L2 relative psi:    0.00003330805162
# Iteration #011, error L2 relative psi:    0.00003195846483
# Iteration #012, error L2 relative psi:    0.00003076351531
# Iteration #013, error L2 relative psi:    0.00002968811191
#
# Time 1.66667
# Iteration #001, error L2 relative psi:    0.00014669856867
# Iteration #002, error L2 relative psi:    0.00008189258977
# Iteration #003, error L2 relative psi:    0.00005813195113
# Iteration #004, error L2 relative psi:    0.00004771705898
# Iteration #005, error L2 relative psi:    0.00004216962684
# Iteration #006, error L2 relative psi:    0.00003866356997
# Iteration #007, error L2 relative psi:    0.00003615465582
# Iteration #008, error L2 relative psi:    0.00003420352139
# Iteration #009, error L2 relative psi:    0.00003259988551
# Iteration #010, error L2 relative psi:    0.00003123122796
# Iteration #011, error L2 relative psi:    0.00003003162719
#
# Time 1.6875
# Iteration #001, error L2 relative psi:    0.00012170390938
# Iteration #002, error L2 relative psi:    0.00007013898278
# Iteration #003, error L2 relative psi:    0.00005147164512
# Iteration #004, error L2 relative psi:    0.00004326326441
# Iteration #005, error L2 relative psi:    0.00003880303650
# Iteration #006, error L2 relative psi:    0.00003590973888
# Iteration #007, error L2 relative psi:    0.00003378801984
# Iteration #008, error L2 relative psi:    0.00003210395224
# Iteration #009, error L2 relative psi:    0.00003069694947
# Iteration #010, error L2 relative psi:    0.00002948034117
#
# Time 1.70833
# Iteration #001, error L2 relative psi:    0.00010182411437
# Iteration #002, error L2 relative psi:    0.00006057956445
# Iteration #003, error L2 relative psi:    0.00004579619883
# Iteration #004, error L2 relative psi:    0.00003925682172
# Iteration #005, error L2 relative psi:    0.00003563231011
# Iteration #006, error L2 relative psi:    0.00003322555132
# Iteration #007, error L2 relative psi:    0.00003142324024
# Iteration #008, error L2 relative psi:    0.00002996792604
#
# Time 1.72917
# Iteration #001, error L2 relative psi:    0.00008555295554
# Iteration #002, error L2 relative psi:    0.00005318760995
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/richards/tests/primal_test/Dumb Test/Simple domain/compressed.ipynb Cell 41 line 1
#       <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> time_rhs = M_h @ theta(prev - subdomain.nodes[1,:] * 3)
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> for k in range(K):
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     spp = L * M_h + dt * stifness(prev - subdomain.nodes[1,:] * 3)
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     rhs = time_rhs.copy()
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     rhs += L * M_h @ prev - M_h @ theta(prev - subdomain.nodes[1,:] * 3)
#
# /workspaces/richards/tests/primal_test/Dumb Test/Simple domain/compressed.ipynb Cell 41 line 2
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a> coord_loc = node_coords[:, nodes_loc]
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> # Compute the stiff-H1 local matrix
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> A = local_A(coord_loc, psi[nodes_loc], np.prod(sign[loc]))
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> # Save values for stiff-H1 local matrix in the global structure
#      <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a> cols = np.tile(nodes_loc, (nodes_loc.size, 1))
#
# /workspaces/richards/tests/primal_test/Dumb Test/Simple domain/compressed.ipynb Cell 41 line 3
#       <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def local_A(coord, psi, m):
# ----> <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     ordering = find_ordering(coord)
#       <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     x0 = coord[:, ordering][:, 0]
#       <a href='vscode-notebook-cell://dev-container%..._test/Dumb%20Test/Simple%20domain/compressed.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     x1 = coord[:, ordering][:, 1]
#
# File _cython_magic_f7aa0a40f8535160479fd5ba92e61ff9.pyx:6, in _cython_magic_f7aa0a40f8535160479fd5ba92e61ff9.find_ordering()
#
# File <__array_function__ internals>:200, in setdiff1d(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# for time_instant_index in range(1, num_steps+1):
#
#     time = time_instant_index * dt
#     print('Time ' + str(round(time, 5)))
#
#     prev = sol
#
#     time_rhs = np.zeros(dof_h)
#     #time_rhs = M_h @ theta(prev - subdomain.nodes[1,:] * 3)
#
#     spp = L / dt * M_h + stifness(prev - subdomain.nodes[1,:] * 3)
#     rhs = time_rhs.copy()
#
#     rhs += L / dt * M_h @ prev #- M_h @ theta(prev - subdomain.nodes[1,:] * 3)
#     rhs += neumann_value(time)
#
#     ls = pg.LinearSystem(spp, rhs)
#     ls.flag_ess_bc( dirichlet_flag, dirichlet_value(time) )
#
#     current = ls.solve()
#
#     print('')
#     sol = current
#
#     save_step(sol, saver, time_instant_index)
#
#     export_name = os.path.join(csv_base, str(time_instant_index) + '.csv')
#
#     with open( export_name, 'w' ) as file:
#
#         file.write('x,y,h,p\n')
#
#         for x,y,h,p in zip( subdomain.nodes[0, :], subdomain.nodes[1, :], sol, sol - subdomain.nodes[1, :]):
#             file.write(f'{x},{y},{h},{p}\n')
#
#
# saver.write_pvd([n * dt for n in range(num_steps + 1)])
