# %% [markdown]
# # Darcy equation
#
# In this tutorial we present how to solve a Darcy equation with [PyGeoN](https://github.com/compgeo-mox/pygeon) in themoving domain case (the upper boundary will move).  The unkwons are the velocity $u$, the elevation head $h$ and the height of the upper boundary $\eta$.
#
# Let $\Omega=(0,1)\times(0,\eta)$ with boundary $\partial \Omega$ and outward unit normal ${\nu}$. Given
# $K$ the matrix permeability, we want to solve the following problem: find $(\bm{u}, h)$ such that
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# K^{-1} {\bm{u}} + \nabla h = {0}\\
# S_s \frac{\partial{h}}{\partial t} + \nabla \cdot {u} = f
# \end{array}
# &\text{in } \Omega
# \end{array}
# \right.
# $$

# %% [markdown]
# In order to solve the problem, we will perfom a change of coordinates to a reference domain $\hat{\Omega}=(0,1)^2$ through the (linear) trasnformation $R : \Omega \rightarrow \hat{\Omega}$ (and its inverse function $D : \hat{\Omega} \rightarrow \Omega$).
# Recall that $\hat{\nabla}R=(\nabla D)^{-1}$.
#
# Let $\hat{h}$ and $\hat{\bm{u}}$ be $h$ and $\bm{u}$ respectevely in the reference domain and let $\hat{K}$ be the transformed permeability matrix, defined as $\hat{K}=det(\hat{\nabla}D) (\hat{\nabla} D)^{-1} K (\hat{\nabla} D)^{-T}$.
#
# The equation describing the motion of $\partial_{top}\Omega$ is:
# $$
#
# \phi \frac{\partial \eta}{\partial t} = \hat{u_3} + I(t)
#
# $$

# %% [markdown]
# The transformed equations in $\hat{\Omega}$ is:
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# \hat{K}({\eta})^{-1} {\hat{u}} + \hat{\nabla} \hat{h} = {0}\\
# \hat{S}_s \frac{\partial{\hat{h}}}{\partial t} + \hat{\nabla} \cdot {\hat{\bm{u}}} = f
# \end{array}
# &\text{in } \hat{\Omega}
# \end{array}
# \right.
# $$
# with boundary conditions:
# $$ \hat{h} = \eta \text{ on } \Gamma \qquad \hat{h} = \ell \text{ on } \Gamma_D \qquad \hat{\bm{\nu}} \cdot \hat{\bm{u}} = 0 \text{ on } \Gamma_N$$

# %% [markdown]
# The weak formulation will be:
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# \int_{\Omega}\hat{K}(\eta)^{-1} {\bm{\hat{u}}} \cdot \bm{v} \, d\Omega - \int_{\Omega} h \hat{\nabla} \cdot {\hat{\bm{v}}} \, d\Omega = - \int_{\Gamma_D} h \bm{v} \cdot \bm{\nu} \, d\Omega - \int_{\Gamma} \eta \bm{v} \cdot \bm{\nu} \, d\Omega\\
# \int_{\Omega} \hat{S}_s \frac{\partial{\hat{h}}}{\partial t} v \, d\Omega + \int_{\Omega} \hat{\nabla} \cdot {\hat{\bm{u}}} v \, d\Omega = \int_{\Omega} fv \, d\Omega\\
# \int_{\Gamma} \phi \frac{\partial \eta}{\partial t} v \, d\sigma = \int_{\Gamma} \hat{u_3} v \, d\sigma + \int_{\Gamma} I(t) v \, d\sigma
# \end{array}
# \end{array}
# \right.
# $$

# %% [markdown]
# For the time discretization, we will employ a backward Euler scheme:
#
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# \int_{\Omega}\hat{K}(\eta^{n+1})^{-1} {\bm{\hat{u}}^{n+1}} \cdot \bm{v} \, d\Omega - \int_{\Omega} h^{n+1} \hat{\nabla} \cdot {\hat{\bm{v}}} \, d\Omega = - \int_{\Gamma_D} h^{n+1} \bm{v} \cdot \bm{\nu} \, d\Omega - \int_{\Gamma} \eta^{n+1} \bm{v} \cdot \bm{\nu} \, d\Omega\\
# \int_{\Omega} \hat{S}_s^{n+1} \frac{\hat{h}^{n+1} - \hat{h}^{n}}{\Delta t} v \, d\Omega + \int_{\Omega} \hat{\nabla} \cdot {\hat{\bm{u}}^{n+1}} v \, d\Omega = \int_{\Omega} f^{n+1}v \, d\Omega\\
# \int_{\Gamma} \phi \eta^{n+1} v \, d\sigma = \Delta t \int_{\Gamma} \hat{\bm{u}}^{n+1} \cdot \bm{\nu} v \, d\sigma + \int_{\Gamma} \phi \eta^{n} v \, d\sigma + \Delta t \int_{\Gamma} I^{n+1} v \, d\sigma
# \end{array}
# \end{array}
# \right.
# $$

# %% [markdown]
# To deal with the non-linear term, we will employ a simple Picard scheme:
#
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# \int_{\Omega}\hat{K}(\eta^{n+1}_k)^{-1} {\bm{\hat{u}_{k+1}^{n+1}}} \cdot \bm{v} \, d\Omega - \int_{\Omega} h^{n+1}_{k+1} \hat{\nabla} \cdot {\hat{\bm{v}}} \, d\Omega + \int_{\Gamma} \eta^{n+1}_{k+1} \bm{v} \cdot \bm{\nu} \, d\Omega= - \int_{\Gamma_D} h^{n+1} \bm{v} \cdot \bm{\nu} \, d\Omega\\
# \Delta t \int_{\Omega} \hat{\nabla} \cdot {\hat{\bm{u}}^{n+1}_{k+1}} v \, d\Omega + \int_{\Omega} \hat{S}_s \hat{h}^{n+1}_{k+1} v \, d\Omega = \int_{\Omega} \hat{S}_s \hat{h}^{n} v \, d\Omega + \Delta t \int_{\Omega} f^{n+1}v \, d\Omega\\
# - \Delta t \int_{\Gamma} \hat{\bm{u}}^{n+1}_{k+1} \cdot \bm{\nu} v \, d\sigma + \int_{\Gamma} \phi \eta^{n+1}_{k+1} v \, d\sigma = \int_{\Gamma} \phi \eta^{n} v \, d\sigma + \Delta t \int_{\Gamma} I^{n+1} v \, d\sigma
# \end{array}
# \end{array}
# \right.
# $$

# %% [markdown]
# The matrix formulation will be:
#
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# M_u(\bm{\eta}^{n+1}_{k}) \bm{u}^{n+1}_{k+1} + B^T\bm{h}^{n+1}_{k+1} + B_{\Gamma}^T \bm{\eta}^{n+1}_{k+1}= \bm{BC}^{n+1}\\
# - \Delta t B \hat{\bm{u}}^{n+1}_{k+1} + S_s M_{h} \bm{\hat{h}^{n+1}_{k+1}} = \Delta t \bm{F}^{n+1} + S_s M_{h} \bm{\hat{h}^{n}}\\
# - \Delta t B_{\Gamma} \hat{\bm{u}}^{n+1}_{k+1} + \phi M_{\Gamma} \bm{\eta^{n+1}_{k+1}} = \phi M_{\Gamma} \bm{\eta^{n}} + \Delta t \bm{I}^{n+1}
# \end{array}
# \end{array}
# \right.
# $$

# %% [markdown]
# $$
# \left(
# \begin{array}{cc}
# M_u(\bm{\eta^{n+1}_k}) & B^T & B_{\Gamma}^T\\
# -\Delta t B & S_s M_h & 0\\
# -\Delta t B_{\Gamma} & 0 & \phi M_{\Gamma}
# \end{array}
# \right)
# \left(
# \begin{array}{c}
# \bm{u^{n+1}_{k+1}}\\
# \bm{h^{n+1}_{k+1}}\\
# \bm{\eta^{n+1}_{k+1}}
# \end{array}
# \right)
# =\left(
# \begin{array}{c}
# \bm{BC}^{n+1}\\
# \Delta t \bm{F}^{n+1} + S_s M_h \bm{h}^n\\
# \phi M_{\Gamma} \bm{\eta}^n + \Delta t \bm{I}^{n+1}
# \end{array}
# \right)
# $$

# %% [markdown]
# We will start to test the method in the case $M_u(\bm{h_k}^{n+1})=\bm{I}$

# %%
# %load_ext Cython

# %%
import numpy as np
import scipy.sparse as sps
from math import ceil, floor, log10, exp, isnan
import os, shutil

import time
import sympy as sp

import porepy as pp
import pygeon as pg
import scipy.integrate as integrate

import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

import scipy as sc
# Out:
# /opt/conda/lib/python3.11/site-packages/porepy/numerics/nonlinear/nonlinear_solvers.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange  # type: ignore

# %%
output_directory = str(ceil(time.time())) + '_' + 'hard_coupling'

# %% [markdown]
# ### Parameters

# %%
# Real domain dimensions
A = 3 # Height
B = 2 # Domain

# Set the number of steps (excluding the initial condition)
num_steps = 9

# Simulation time length
T = 9/48

# Time switch conditions (for the boundary condition)
dt_D = 3/48

# %%
# Van Genuchten model parameters ( relative permeability model )
theta_s = 0.396
theta_r = 0.131

alpha = 0.423

n = 2.06
K_s = 4.96e-2

m = 1 - 1/n

phi = (theta_s - theta_r)

def initial_h_func(x): return 1

# %%
# Set the maximum number of iterations of the non-linear solver
max_iterations_per_step = 1000

# L-scheme parameter
L   = 3.501e-2

# Relative and absolute tolerances for the non-linear solver
abs_tol = 1e-10
rel_tol = 1e-5

numeric_tol = 1e-10

# %%
dt = (T-0) / num_steps
N = 10 # 16
quad_order = 1

# Domain tolerance
domain_tolerance = 1 / (10 * N)

# %%
verbose = False

# %% [markdown]
# ### $\theta$ and $K$

# %%
# Symbolic psi
psi_var = sp.Symbol('psi', negative=True)

# Symbolic Theta
theta_expression = theta_r + (theta_s - theta_r) / (1 + (-alpha * psi_var) ** n) ** m
effective_saturation = (theta_expression - theta_r) / (theta_s - theta_r)

# Symbolic Conductivity K
hydraulic_conductivity_expression = K_s * (effective_saturation ** 0.5) * ( 1 - (1 - effective_saturation ** (1 / m)) ** m ) ** 2

# %%
# Theta lambda
theta_lambda = sp.lambdify(psi_var, theta_expression, 'numpy')

# Conductivity tensor lambda
conductivity_lambda = sp.lambdify(psi_var, hydraulic_conductivity_expression, 'numpy')

# %%
# Actual (and final) theta function
def theta(psi):
    mask = np.where(psi < 0)
    res = np.ones_like(psi) * theta_s
    res[mask] = theta_lambda(psi[mask])

    return res

# %%
def conductivity(psi):
    if psi >= 0:
        return K_s
    return conductivity_lambda(psi)

# %% [markdown]
# ### Grid and $V_h$

# %%
# convert the grid into a mixed-dimensional grid
darcy_grid = pp.StructuredTriangleGrid([N * ceil(B), N * round(1)], [B, 1])
darcy_grid.compute_geometry()
pg.convert_from_pp(darcy_grid)

# %%
# convert the grid into a mixed-dimensional grid
richards_grid = pp.StructuredTriangleGrid([N * ceil(B), N * round(A-1)], [B, 1])
richards_grid.compute_geometry()
pg.convert_from_pp(richards_grid)

# %%
boundary_grid, boundary_face_map, boundary_node_map = pp.partition.extract_subgrid(darcy_grid, darcy_grid.face_centers[1, :] == 1, faces=True)

# %%
key = "flow"

darcy_data = {}

# %%
darcy_field    = pg.Lagrange1(key)
richards_field = pg.Lagrange1(key)

gamma_field    = pg.Lagrange1(key)

# %%
fixed_rhs = np.zeros( darcy_grid.num_nodes + richards_grid.num_nodes - boundary_grid.num_nodes )

# %%
darcy_dof    =    darcy_field.ndof( darcy_grid )
richards_dof = richards_field.ndof( richards_grid )

boundary_dof = gamma_field.ndof( boundary_grid )

# %%
darcy_data = {}
richards_data = {}

# %% [markdown]
# ### BC

# %% [markdown]
# ##### Restrictor matrices

# %%
darcy_remove_boundary = np.zeros(shape=(darcy_dof - boundary_dof, darcy_dof))
darcy_remove_boundary[ np.arange(darcy_dof - boundary_dof), darcy_grid.nodes[1, :] < 1 ] = 1
darcy_remove_boundary = sps.csr_matrix(darcy_remove_boundary)

# %%
richards_remove_boundary = np.zeros(shape=(richards_dof - boundary_dof, richards_dof))
richards_remove_boundary[ np.arange(richards_dof - boundary_dof), richards_grid.nodes[1, :] > 0 ] = 1
richards_remove_boundary = sps.csr_matrix(richards_remove_boundary)

# %% [markdown]
# ##### Dirichlet (essential)

# %%
darcy_dirichlet_flag  = np.array(darcy_remove_boundary @ (darcy_grid.nodes[0, :] == B), dtype=bool)
darcy_dirichlet_value = np.array(darcy_dirichlet_flag, dtype=float)

# %%
richards_dirichlet_flag  = np.array(richards_remove_boundary @ np.logical_and(richards_grid.nodes[1, :] == 1, richards_grid.nodes[0, :] < 1 ), dtype=bool)
richards_dirichlet_value = lambda t: np.array(richards_dirichlet_flag, dtype=float) * min(6.2, 1 + 5.2 * t / dt_D)

# %%
dirichlet_flag  = lambda t: np.hstack((darcy_dirichlet_flag, np.zeros(shape=boundary_dof, dtype=bool), richards_dirichlet_flag))
dirichlet_value = lambda t: np.hstack((darcy_dirichlet_value, np.zeros(shape=boundary_dof), richards_dirichlet_value(t)))

# %% [markdown]
# ##### Neumann (natural)

# %%
# Full no-flow condition for the Neumann part.... nothing to add

# %% [markdown]
# ### Mappings

# %%
darcy_chi    = lambda eta, x: eta * x * (1 + (1-x) * eta * x / A)
richards_chi = lambda eta, x: eta + (A-eta)/A*(x-1) * ( eta + (x-1) * ( 2*(A-eta) - (x-1)*(A-eta) ) )

# %%
def darcy_real_height(eta_dofs, heights):
    return darcy_chi(eta_dofs, heights)

# %%
def richards_real_height(eta_dofs, heights):
    return richards_chi(eta_dofs, heights)

# %% [markdown]
# ### Matrix Assembly

# %% [markdown]
# ##### Masks

# %%
darcy_mask = np.zeros(shape=(darcy_dof + richards_dof - boundary_dof), dtype=bool)
darcy_mask[ : (darcy_dof) ] = True

# %%
darcy_internal_mask = np.zeros_like(darcy_mask, dtype=bool)
darcy_internal_mask[ : (darcy_dof - boundary_dof) ] = True

# %%
richards_mask = np.zeros_like(darcy_mask, dtype=bool)
richards_mask[(darcy_dof-boundary_dof):] = True

# %%
richards_internal_mask = np.zeros_like(darcy_mask, dtype=bool)
richards_internal_mask[ darcy_dof : ] = True

# %%
boundary_mask = np.zeros_like(darcy_mask, dtype=bool)
boundary_mask[(darcy_dof - boundary_dof):(darcy_dof)] = True

# %% [markdown]
# ##### Finite difference matrices

# %%
eta_diff = gamma_field.assemble_diff_matrix( boundary_grid )
eta_diff[0,0] = -1
eta_diff *= (N)

# %% [markdown]
# #### Stifness

# %%
# %%cython
# import numpy as np
#
# def find_ordering(coord: np.array):
#     lx = np.argmin(coord[0, :])
#     rx = np.argmax(coord[0, :])
#     mx = np.setdiff1d(np.array([0,1,2]), np.array([lx, rx]))[0]
#
#     # Vertical Alignment
#     if np.abs( coord[0, lx] - coord[0, mx] ) < 1e-7:
#         # lx and mx vertical aligned, rx no
#         up =   lx if np.argmax(coord[1, np.array([lx, mx])]) == 0 else mx
#         down = lx if np.argmin(coord[1, np.array([lx, mx])]) == 0 else mx
#
#         if np.abs( coord[1, up] - coord[1, rx] ) < 1e-7:
#             return [up, down, rx]
#         else:
#             return [down, rx, up]
#     else:
#         # rx and mx vertical aligned, lx no
#         up =   rx if np.argmax(coord[1, np.array([rx, mx])]) == 0 else mx
#         down = rx if np.argmin(coord[1, np.array([rx, mx])]) == 0 else mx
#
#         if np.abs( coord[1, up] - coord[1, lx] ) < 1e-7:
#             return [up, lx, down]
#         else:
#             return [down, up, lx]

# %%
def Darcy_K_func(base_height: float, base_width: float, element_height: float, element_width: float, m: int, ls_eta: float, rs_eta: float, grad_eta: float, x, y):
    coord = lambda t: ((m+1) * (1-t) - (m-1) * t) / 2

    x3 = base_height + coord(x) * element_height
    eta = (1-coord(y)) * ls_eta + coord(y) * rs_eta

    #chi_x3, chi_eta = derivatives_chi_x3_eta( darcy_bezier_x, darcy_bezier_y, eta, x3 )
    chi_x3  = eta * ( 1 + eta * x3 / A * ( 2 - 3 * eta * x3 ) )
    chi_eta = x3 * (1 + 2 * eta / A * x3 * (1 - 2*x3) )

    #return np.eye(2) * K_s

    return np.array([[             chi_x3,                            -chi_eta * grad_eta],
                     [-chi_eta * grad_eta, (1 + np.power(chi_eta * grad_eta, 2)) / chi_x3]]) * K_s / chi_x3 #[:, :, 0]

    # This is the full version:
    #return np.array([[                  chi_x3 * k11,                                                    k12 - chi_eta * grad_eta * k11],
    #                 [k21 - chi_eta * grad_eta * k11, ( k22 + chi_eta * grad_eta * ( chi_eta * grad_eta * k11 - k12 - k21 ) ) / chi_x3 ]])

# %%
def Richards_K_func(base_height: float, base_width: float, element_height: float, element_width: float, m: int, ls_eta: float, rs_eta: float, grad_eta: float, A: float, psi, x, y):
    coord = lambda t: ((m+1) * (1-t) - (m-1) * t) / 2

    x3 = base_height + coord(x) * element_height
    eta = (1-coord(y)) * ls_eta + coord(y) * rs_eta

    #chi_x3, chi_eta = derivatives_chi_x3_eta( richards_bezier_x, richards_bezier_y, eta, x3 )
    chi_x3  = (A - eta) / A * ( eta + (A-eta)*(x3-1)*(4-3*(x3-1)) )
    chi_eta = 1 + (x3-1)/A * ( A - 2*eta + 2*(A-eta)*(x3-1)*(x3-3) )

    #return np.array([[2, 0], [0, 1/2]]) * conductivity(psi(x,y))

    return np.array([[             chi_x3,                            -chi_eta * grad_eta],
                     [-chi_eta * grad_eta, (1 + np.power(chi_eta * grad_eta, 2)) / chi_x3]]) * conductivity(psi) / chi_x3

    # This is the full version:
    #return np.array([[                  chi_x3 * k11,                                                    k12 - chi_eta * grad_eta * k11],
    #                 [k21 - chi_eta * grad_eta * k11, ( k22 + chi_eta * grad_eta * ( chi_eta * grad_eta * k11 - k12 - k21 ) ) / chi_x3 ]])

# %%
ax = plt.subplot(1,1,1)

ax.plot( np.arange(0, 1, 0.01),    darcy_chi(1, np.arange(0, 1, 0.01)), 'b' )
ax.plot( np.arange(1, 2, 0.01), richards_chi(1, np.arange(1, 2, 0.01)), 'r' )
ax.grid()

# %%
def richards_local_A(coord, ls_eta, rs_eta, grad_eta, m, psi):
    ordering = find_ordering(coord)

    x0 = coord[:, ordering][:, 0]
    x1 = coord[:, ordering][:, 1]
    x2 = coord[:, ordering][:, 2]
    
    J_T_1_T = np.array([[x2[1]-x0[1], x0[1]-x1[1]],
                        [x0[0]-x2[0], x1[0]-x0[0]]]) / ((x1[0]-x0[0]) * (x2[1]-x0[1]) - (x2[0]-x0[0]) * (x1[1]-x0[1]))
    

    q_funcs = [J_T_1_T @ np.array([-1, -1]), J_T_1_T @ np.array([ 1, 0]), J_T_1_T @ np.array([0,  1])]

    M = np.zeros(shape=(3,3))

    jacobian = 1 / np.linalg.det( J_T_1_T.T )
    ordered_psi = psi[ordering]

    psi_fun = lambda x,y: ordered_psi[0] + (ordered_psi[1] - ordered_psi[0]) * x + (ordered_psi[2] - ordered_psi[0]) * y
        
    base_height = np.min(coord[1, :]) + 1
    base_width  = np.min(coord[0, :])
    
    element_height = np.max(coord[1, :]) - np.min(coord[1, :])
    element_width  = np.max(coord[0, :]) - np.min(coord[0, :])

    K_local = lambda x,y: Richards_K_func(base_height, base_width,
        element_height, element_width,
        m,
        ls_eta, rs_eta, grad_eta, A, psi_fun(x, y), x, y)

    for i in range(3):
        for j in range(3):
            integrand = lambda ys,x: np.array([q_funcs[j].T @ K_local(x, y) @ q_funcs[i] for y in np.array(ys)])
            inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
            M[ ordering[i], ordering[j] ] = jacobian * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]

    return M

# %%
def darcy_local_A(coord, ls_eta, rs_eta, grad_eta, m):
    ordering = find_ordering(coord)

    x0 = coord[:, ordering][:, 0]
    x1 = coord[:, ordering][:, 1]
    x2 = coord[:, ordering][:, 2]
    
    J_T_1_T = np.array([[x2[1]-x0[1], x0[1]-x1[1]],
                        [x0[0]-x2[0], x1[0]-x0[0]]]) / ((x1[0]-x0[0]) * (x2[1]-x0[1]) - (x2[0]-x0[0]) * (x1[1]-x0[1]))
    

    q_funcs = [J_T_1_T @ np.array([-1, -1]), J_T_1_T @ np.array([ 1, 0]), J_T_1_T @ np.array([0,  1])]

    M = np.zeros(shape=(3,3))

    jacobian = 1 / np.linalg.det( J_T_1_T.T )
        
    base_height = np.min(coord[1, :])
    base_width  = np.min(coord[0, :])
    
    element_height = np.max(coord[1, :]) - np.min(coord[1, :])
    element_width  = np.max(coord[0, :]) - np.min(coord[0, :])
    
    K_local = lambda x,y: Darcy_K_func(base_height, base_width,
        element_height, element_width,
        m,
        ls_eta, rs_eta, grad_eta, x, y)

    for i in range(3):
        for j in range(3):
            integrand = lambda ys,x: np.array([q_funcs[j].T @ K_local(x, y) @ q_funcs[i] for y in np.array(ys)])
            inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
            M[ ordering[i], ordering[j] ] = jacobian * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]

    return M

# %%
def global_stifness(eta_dofs, psi_dofs):

    grad_eta = eta_diff @ eta_dofs
    
    size = np.power(darcy_grid.dim + 1, 2) * darcy_grid.num_cells + np.power(richards_grid.dim + 1, 2) * richards_grid.num_cells
    rows_I = np.empty(size, dtype=int)
    cols_J = np.empty(size, dtype=int)
    data_IJ = np.empty(size)
    idx = 0

    for subdomain, base in zip([darcy_grid, richards_grid], [0, boundary_grid.num_nodes * N]):
        _, _, _, _, _, node_coords = pp.map_geometry.map_grid(subdomain)
        _, _, sign = sps.find(subdomain.cell_faces)

        # Allocate the data to store matrix entries, that's the most efficient
        # way to create a sparse matrix.

        cell_nodes = subdomain.cell_nodes()

        for c in np.arange(subdomain.num_cells):
            # For the current cell retrieve its nodes
            loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

            nodes_loc = cell_nodes.indices[loc]
            coord_loc = node_coords[:, nodes_loc]

            eta_cell = np.max(np.where( boundary_grid.nodes[0, :] < subdomain.cell_centers[0, c] ))

            # Compute the stiff-H1 local matrix

            if subdomain == darcy_grid:
                A = darcy_local_A(coord_loc, eta_dofs[eta_cell], eta_dofs[eta_cell+1], grad_eta[eta_cell], np.prod(sign[loc]))
            else:
                A = richards_local_A(coord_loc, eta_dofs[eta_cell], eta_dofs[eta_cell+1], grad_eta[eta_cell], np.prod(sign[loc]), psi_dofs[nodes_loc])

            # Save values for stiff-H1 local matrix in the global structure
            cols = base + np.tile(nodes_loc, (nodes_loc.size, 1))

            loc_idx = slice(idx, idx + cols.size)
            rows_I[loc_idx] = cols.T.ravel()
            cols_J[loc_idx] = cols.ravel()
            data_IJ[loc_idx] = A.ravel()
            idx += cols.size

    # Construct the global matrices
    return sps.csc_matrix((data_IJ, (rows_I, cols_J)))

# %% [markdown]
# #### Mass matrices

# %%
def local_mass(coord, mult):
    ordering = find_ordering(coord)

    x0 = coord[:, ordering][:, 0]
    x1 = coord[:, ordering][:, 1]
    x2 = coord[:, ordering][:, 2]

    qs = [(lambda x,y: 1-x-y), (lambda x,y: x), (lambda x,y: y)]
    
    J = np.array([[x1[0]-x0[0], x2[0]-x0[0]],
                  [x1[1]-x0[1], x2[1]-x0[1]]])
    
    jacobian = np.linalg.det(J)
    M = np.zeros(shape=(3,3))

    for i in range(3):
        for j in range(3):
            integrand = lambda ys,x: np.array([qs[j](x,y) * qs[i](x,y) for y in np.array(ys)])
            inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
            tmp = integrate.fixed_quad(inside, 0, 1, n=2, args=(2,))[0]

            M[ ordering[i], ordering[j] ] = tmp * jacobian

    return M * mult

# %%
local_mass(np.array([[0, 1, 0], [0, 0, 1]]), 1)
# Out:
# array([[0.08333333, 0.04166667, 0.04166667],
#        [0.04166667, 0.08333333, 0.04166667],
#        [0.04166667, 0.04166667, 0.08333333]])

# %%
def global_mass(eta_dofs):
    
    size = np.power(darcy_grid.dim + 1, 2) * darcy_grid.num_cells + np.power(richards_grid.dim + 1, 2) * richards_grid.num_cells
    rows_I = np.empty(size, dtype=int)
    cols_J = np.empty(size, dtype=int)
    data_IJ = np.empty(size)
    idx = 0

    for subdomain, base, base_height in zip([darcy_grid, richards_grid], [0, boundary_grid.num_nodes * N], [0,1]):
        _, _, _, _, _, node_coords = pp.map_geometry.map_grid(subdomain)

        # Allocate the data to store matrix entries, that's the most efficient
        # way to create a sparse matrix.

        cell_nodes = subdomain.cell_nodes()
        
        for c in np.arange(subdomain.num_cells):
            # For the current cell retrieve its nodes
            loc = slice(cell_nodes.indptr[c], cell_nodes.indptr[c + 1])

            nodes_loc = cell_nodes.indices[loc]
            coord_loc = node_coords[:, nodes_loc]

            # Compute the stiff-H1 local matrix
            
            eta_cell = np.max(np.where( boundary_grid.nodes[0, :] < subdomain.cell_centers[0, c] ))

            #chi_x3, _ = derivatives_chi_x3_eta(bz_x, bz_y, (eta_dofs[eta_cell] + eta_dofs[eta_cell+1])/2, base_height + subdomain.cell_centers[1, c] )
            A = local_mass(coord_loc, 1)#chi_x3)

            # Save values for stiff-H1 local matrix in the global structure
            cols = base + np.tile(nodes_loc, (nodes_loc.size, 1))

            loc_idx = slice(idx, idx + cols.size)
            rows_I[loc_idx] = cols.T.ravel()
            cols_J[loc_idx] = cols.ravel()
            data_IJ[loc_idx] = A.ravel()
            idx += cols.size

    # Construct the global matrices
    return sps.csc_matrix((data_IJ, (rows_I, cols_J)))

# %% [markdown]
# #### Projection matrices

# %%
darcy_proj    =    darcy_field.eval_at_cell_centers( darcy_grid )
richards_proj = richards_field.eval_at_cell_centers( richards_grid )

# %% [markdown]
# #### Restrictor matrices

# %%
darcy_restrict_to_boundary = np.zeros(shape=(boundary_dof, darcy_dof))
darcy_restrict_to_boundary[np.arange(boundary_dof), darcy_grid.nodes[1, :] == 1] = 1

# %%
richards_restrict_to_boundary = np.zeros(shape=(boundary_dof, richards_dof))
richards_restrict_to_boundary[np.arange(boundary_dof), richards_grid.nodes[1, :] == 0] = 1

# %% [markdown]
# ### Solve System

# %%
if os.path.exists(output_directory):
    shutil.rmtree(output_directory)

# %%
# Fixed rhs
fixed_rhs = np.zeros(darcy_dof + richards_dof - boundary_dof)

# %%
# Initial conditions
sol = [np.zeros_like(fixed_rhs)]
sol[-1][darcy_mask] = darcy_field.interpolate( darcy_grid, initial_h_func )
sol[-1][richards_mask] = richards_field.interpolate( richards_grid, initial_h_func )

# %%
def save_step(sol, savers, i):

    for saver, proj, mask, grid, heights in zip(savers, [darcy_proj, richards_proj], [darcy_mask, richards_mask], [darcy_grid, richards_grid], [darcy_real_height(np.tile(sol[boundary_mask], ceil(darcy_grid.num_nodes / boundary_grid.num_nodes)), darcy_grid.nodes[1,:]), 
                                                                                                                                                richards_real_height(np.tile(sol[boundary_mask], ceil(richards_grid.num_nodes / boundary_grid.num_nodes)), 1+richards_grid.nodes[1, :])]):
        ins = list()

        ins.append((grid, "cell_h", proj @ sol[mask]))
        ins.append((grid, "cell_p", proj @ (sol[mask] - heights)))

        saver.write_vtu(ins, time_step=i)

# %%
# Save the initial solution
savers = [pp.Exporter(darcy_grid, 'sol_D', folder_name=output_directory), 
          pp.Exporter(richards_grid, 'sol_R', folder_name=output_directory)]
save_step(sol[-1], savers, 0)

# %%
csv_base = os.path.join(output_directory, 'csv')
os.mkdir( csv_base )

# %%
cm_data = [
    [0.2422, 0.1504, 0.6603],
    [0.2444, 0.1534, 0.6728],
    [0.2464, 0.1569, 0.6847],
    [0.2484, 0.1607, 0.6961],
    [0.2503, 0.1648, 0.7071],
    [0.2522, 0.1689, 0.7179],
    [0.2540, 0.1732, 0.7286],
    [0.2558, 0.1773, 0.7393],
    [0.2576, 0.1814, 0.7501],
    [0.2594, 0.1854, 0.7610],
    [0.2611, 0.1893, 0.7719],
    [0.2628, 0.1932, 0.7828],
    [0.2645, 0.1972, 0.7937],
    [0.2661, 0.2011, 0.8043],
    [0.2676, 0.2052, 0.8148],
    [0.2691, 0.2094, 0.8249],
    [0.2704, 0.2138, 0.8346],
    [0.2717, 0.2184, 0.8439],
    [0.2729, 0.2231, 0.8528],
    [0.2740, 0.2280, 0.8612],
    [0.2749, 0.2330, 0.8692],
    [0.2758, 0.2382, 0.8767],
    [0.2766, 0.2435, 0.8840],
    [0.2774, 0.2489, 0.8908],
    [0.2781, 0.2543, 0.8973],
    [0.2788, 0.2598, 0.9035],
    [0.2794, 0.2653, 0.9094],
    [0.2798, 0.2708, 0.9150],
    [0.2802, 0.2764, 0.9204],
    [0.2806, 0.2819, 0.9255],
    [0.2809, 0.2875, 0.9305],
    [0.2811, 0.2930, 0.9352],
    [0.2813, 0.2985, 0.9397],
    [0.2814, 0.3040, 0.9441],
    [0.2814, 0.3095, 0.9483],
    [0.2813, 0.3150, 0.9524],
    [0.2811, 0.3204, 0.9563],
    [0.2809, 0.3259, 0.9600],
    [0.2807, 0.3313, 0.9636],
    [0.2803, 0.3367, 0.9670],
    [0.2798, 0.3421, 0.9702],
    [0.2791, 0.3475, 0.9733],
    [0.2784, 0.3529, 0.9763],
    [0.2776, 0.3583, 0.9791],
    [0.2766, 0.3638, 0.9817],
    [0.2754, 0.3693, 0.9840],
    [0.2741, 0.3748, 0.9862],
    [0.2726, 0.3804, 0.9881],
    [0.2710, 0.3860, 0.9898],
    [0.2691, 0.3916, 0.9912],
    [0.2670, 0.3973, 0.9924],
    [0.2647, 0.4030, 0.9935],
    [0.2621, 0.4088, 0.9946],
    [0.2591, 0.4145, 0.9955],
    [0.2556, 0.4203, 0.9965],
    [0.2517, 0.4261, 0.9974],
    [0.2473, 0.4319, 0.9983],
    [0.2424, 0.4378, 0.9991],
    [0.2369, 0.4437, 0.9996],
    [0.2311, 0.4497, 0.9995],
    [0.2250, 0.4559, 0.9985],
    [0.2189, 0.4620, 0.9968],
    [0.2128, 0.4682, 0.9948],
    [0.2066, 0.4743, 0.9926],
    [0.2006, 0.4803, 0.9906],
    [0.1950, 0.4861, 0.9887],
    [0.1903, 0.4919, 0.9867],
    [0.1869, 0.4975, 0.9844],
    [0.1847, 0.5030, 0.9819],
    [0.1831, 0.5084, 0.9793],
    [0.1818, 0.5138, 0.9766],
    [0.1806, 0.5191, 0.9738],
    [0.1795, 0.5244, 0.9709],
    [0.1785, 0.5296, 0.9677],
    [0.1778, 0.5349, 0.9641],
    [0.1773, 0.5401, 0.9602],
    [0.1768, 0.5452, 0.9560],
    [0.1764, 0.5504, 0.9516],
    [0.1755, 0.5554, 0.9473],
    [0.1740, 0.5605, 0.9432],
    [0.1716, 0.5655, 0.9393],
    [0.1686, 0.5705, 0.9357],
    [0.1649, 0.5755, 0.9323],
    [0.1610, 0.5805, 0.9289],
    [0.1573, 0.5854, 0.9254],
    [0.1540, 0.5902, 0.9218],
    [0.1513, 0.5950, 0.9182],
    [0.1492, 0.5997, 0.9147],
    [0.1475, 0.6043, 0.9113],
    [0.1461, 0.6089, 0.9080],
    [0.1446, 0.6135, 0.9050],
    [0.1429, 0.6180, 0.9022],
    [0.1408, 0.6226, 0.8998],
    [0.1383, 0.6272, 0.8975],
    [0.1354, 0.6317, 0.8953],
    [0.1321, 0.6363, 0.8932],
    [0.1288, 0.6408, 0.8910],
    [0.1253, 0.6453, 0.8887],
    [0.1219, 0.6497, 0.8862],
    [0.1185, 0.6541, 0.8834],
    [0.1152, 0.6584, 0.8804],
    [0.1119, 0.6627, 0.8770],
    [0.1085, 0.6669, 0.8734],
    [0.1048, 0.6710, 0.8695],
    [0.1009, 0.6750, 0.8653],
    [0.0964, 0.6789, 0.8609],
    [0.0914, 0.6828, 0.8562],
    [0.0855, 0.6865, 0.8513],
    [0.0789, 0.6902, 0.8462],
    [0.0713, 0.6938, 0.8409],
    [0.0628, 0.6972, 0.8355],
    [0.0535, 0.7006, 0.8299],
    [0.0433, 0.7039, 0.8242],
    [0.0328, 0.7071, 0.8183],
    [0.0234, 0.7103, 0.8124],
    [0.0155, 0.7133, 0.8064],
    [0.0091, 0.7163, 0.8003],
    [0.0046, 0.7192, 0.7941],
    [0.0019, 0.7220, 0.7878],
    [0.0009, 0.7248, 0.7815],
    [0.0018, 0.7275, 0.7752],
    [0.0046, 0.7301, 0.7688],
    [0.0094, 0.7327, 0.7623],
    [0.0162, 0.7352, 0.7558],
    [0.0253, 0.7376, 0.7492],
    [0.0369, 0.7400, 0.7426],
    [0.0504, 0.7423, 0.7359],
    [0.0638, 0.7446, 0.7292],
    [0.0770, 0.7468, 0.7224],
    [0.0899, 0.7489, 0.7156],
    [0.1023, 0.7510, 0.7088],
    [0.1141, 0.7531, 0.7019],
    [0.1252, 0.7552, 0.6950],
    [0.1354, 0.7572, 0.6881],
    [0.1448, 0.7593, 0.6812],
    [0.1532, 0.7614, 0.6741],
    [0.1609, 0.7635, 0.6671],
    [0.1678, 0.7656, 0.6599],
    [0.1741, 0.7678, 0.6527],
    [0.1799, 0.7699, 0.6454],
    [0.1853, 0.7721, 0.6379],
    [0.1905, 0.7743, 0.6303],
    [0.1954, 0.7765, 0.6225],
    [0.2003, 0.7787, 0.6146],
    [0.2061, 0.7808, 0.6065],
    [0.2118, 0.7828, 0.5983],
    [0.2178, 0.7849, 0.5899],
    [0.2244, 0.7869, 0.5813],
    [0.2318, 0.7887, 0.5725],
    [0.2401, 0.7905, 0.5636],
    [0.2491, 0.7922, 0.5546],
    [0.2589, 0.7937, 0.5454],
    [0.2695, 0.7951, 0.5360],
    [0.2809, 0.7964, 0.5266],
    [0.2929, 0.7975, 0.5170],
    [0.3052, 0.7985, 0.5074],
    [0.3176, 0.7994, 0.4975],
    [0.3301, 0.8002, 0.4876],
    [0.3424, 0.8009, 0.4774],
    [0.3548, 0.8016, 0.4669],
    [0.3671, 0.8021, 0.4563],
    [0.3795, 0.8026, 0.4454],
    [0.3921, 0.8029, 0.4344],
    [0.4050, 0.8031, 0.4233],
    [0.4184, 0.8030, 0.4122],
    [0.4322, 0.8028, 0.4013],
    [0.4463, 0.8024, 0.3904],
    [0.4608, 0.8018, 0.3797],
    [0.4753, 0.8011, 0.3691],
    [0.4899, 0.8002, 0.3586],
    [0.5044, 0.7993, 0.3480],
    [0.5187, 0.7982, 0.3374],
    [0.5329, 0.7970, 0.3267],
    [0.5470, 0.7957, 0.3159],
    [0.5609, 0.7943, 0.3050],
    [0.5748, 0.7929, 0.2941],
    [0.5886, 0.7913, 0.2833],
    [0.6024, 0.7896, 0.2726],
    [0.6161, 0.7878, 0.2622],
    [0.6297, 0.7859, 0.2521],
    [0.6433, 0.7839, 0.2423],
    [0.6567, 0.7818, 0.2329],
    [0.6701, 0.7796, 0.2239],
    [0.6833, 0.7773, 0.2155],
    [0.6963, 0.7750, 0.2075],
    [0.7091, 0.7727, 0.1998],
    [0.7218, 0.7703, 0.1924],
    [0.7344, 0.7679, 0.1852],
    [0.7468, 0.7654, 0.1782],
    [0.7590, 0.7629, 0.1717],
    [0.7710, 0.7604, 0.1658],
    [0.7829, 0.7579, 0.1608],
    [0.7945, 0.7554, 0.1570],
    [0.8060, 0.7529, 0.1546],
    [0.8172, 0.7505, 0.1535],
    [0.8281, 0.7481, 0.1536],
    [0.8389, 0.7457, 0.1546],
    [0.8495, 0.7435, 0.1564],
    [0.8600, 0.7413, 0.1587],
    [0.8703, 0.7392, 0.1615],
    [0.8804, 0.7372, 0.1650],
    [0.8903, 0.7353, 0.1695],
    [0.9000, 0.7336, 0.1749],
    [0.9093, 0.7321, 0.1815],
    [0.9184, 0.7308, 0.1890],
    [0.9272, 0.7298, 0.1973],
    [0.9357, 0.7290, 0.2061],
    [0.9440, 0.7285, 0.2151],
    [0.9523, 0.7284, 0.2237],
    [0.9606, 0.7285, 0.2312],
    [0.9689, 0.7292, 0.2373],
    [0.9770, 0.7304, 0.2418],
    [0.9842, 0.7330, 0.2446],
    [0.9900, 0.7365, 0.2429],
    [0.9946, 0.7407, 0.2394],
    [0.9966, 0.7458, 0.2351],
    [0.9971, 0.7513, 0.2309],
    [0.9972, 0.7569, 0.2267],
    [0.9971, 0.7626, 0.2224],
    [0.9969, 0.7683, 0.2181],
    [0.9966, 0.7740, 0.2138],
    [0.9962, 0.7798, 0.2095],
    [0.9957, 0.7856, 0.2053],
    [0.9949, 0.7915, 0.2012],
    [0.9938, 0.7974, 0.1974],
    [0.9923, 0.8034, 0.1939],
    [0.9906, 0.8095, 0.1906],
    [0.9885, 0.8156, 0.1875],
    [0.9861, 0.8218, 0.1846],
    [0.9835, 0.8280, 0.1817],
    [0.9807, 0.8342, 0.1787],
    [0.9778, 0.8404, 0.1757],
    [0.9748, 0.8467, 0.1726],
    [0.9720, 0.8529, 0.1695],
    [0.9694, 0.8591, 0.1665],
    [0.9671, 0.8654, 0.1636],
    [0.9651, 0.8716, 0.1608],
    [0.9634, 0.8778, 0.1582],
    [0.9619, 0.8840, 0.1557],
    [0.9608, 0.8902, 0.1532],
    [0.9601, 0.8963, 0.1507],
    [0.9596, 0.9023, 0.1480],
    [0.9595, 0.9084, 0.1450],
    [0.9597, 0.9143, 0.1418],
    [0.9601, 0.9203, 0.1382],
    [0.9608, 0.9262, 0.1344],
    [0.9618, 0.9320, 0.1304],
    [0.9629, 0.9379, 0.1261],
    [0.9642, 0.9437, 0.1216],
    [0.9657, 0.9494, 0.1168],
    [0.9674, 0.9552, 0.1116],
    [0.9692, 0.9609, 0.1061],
    [0.9711, 0.9667, 0.1001],
    [0.9730, 0.9724, 0.0938],
    [0.9749, 0.9782, 0.0872],
    [0.9769, 0.9839, 0.0805]
]

parula_map = LinearSegmentedColormap.from_list('parula', cm_data)

# %%
def export_csv(index, solution, plot_figure=False, plot_value=False):
    export_name = os.path.join(csv_base, str(index) + '.csv')
    
    xs = []
    ys = []
    hs = []

    with open( export_name, 'w' ) as file:
        file.write('x,y,h,p\n')

        et = np.tile(solution[boundary_mask], ceil(darcy_grid.num_nodes / boundary_grid.num_nodes) - 1)
        ff = np.where(darcy_grid.nodes[1, :] < 1)[0]
        hd = darcy_real_height(et, darcy_grid.nodes[1, ff])
        for x,y,h,p in zip( darcy_grid.nodes[0, ff], hd, solution[darcy_internal_mask], solution[darcy_internal_mask] - hd):
            file.write(f'{x},{y},{h},{p}\n')
            xs.append(x)
            ys.append(y)
            hs.append(h)

        et = np.tile(solution[boundary_mask], ceil(richards_grid.num_nodes / boundary_grid.num_nodes))
        hd = richards_real_height(et, 1+richards_grid.nodes[1, :])
        for x,y,h,p in zip( richards_grid.nodes[0, :], hd, solution[richards_mask], solution[richards_mask] - hd ):
            file.write(f'{x},{y},{h},{p}\n')
            xs.append(x)
            ys.append(y)
            hs.append(h)
    
    xs = np.array(xs).reshape((3*N+1, 2*N+1))
    ys = np.array(ys).reshape((3*N+1, 2*N+1))
    hs = np.array(hs).reshape((3*N+1, 2*N+1))
    
    if plot_figure:

        fig = plt.figure(figsize=(7, 10))
        ax = fig.subplots(1,1)
        
        CS = ax.contourf(xs, ys, hs, min((3*N+1) * (2*N+1), 1000), cmap=parula_map)

        cbar = fig.colorbar(CS)
        
        plt.show()

    if plot_value:
        index = np.argmin(np.abs(xs[0, :] - 0.05))

        fig = plt.figure(figsize=(10, 5))
        ax = fig.subplots(1,1)
        ax.plot( ys[:, index], hs[:, index], 'o-r' )
        ax.set_ylim(0.9, 6.5)

        ax.grid()

        ax.set_title('Elevation head at y=0.05 m')

        plt.show()

# %%
# Time Loop
for i in range(1, num_steps+1):
    current_time = i * dt
    print('Time ' + str(round(current_time, 5)))

    # Prepare the solution at the previous time step and ...
    prev = sol[-1].copy()

    # Prepare the rhs
    time_rhs = fixed_rhs.copy()

    glob_mass = global_mass(prev[boundary_mask])
    richards_M_h = glob_mass[richards_mask, :][:, richards_mask]
    
    time_rhs[richards_mask] += richards_M_h @ theta(prev[richards_mask] - richards_real_height(np.tile(prev[boundary_mask], ceil(richards_grid.num_nodes / boundary_grid.num_nodes)), 1+richards_grid.nodes[1, :]) ) / dt
    
    debug_savers = [pp.Exporter(darcy_grid,    str(i) + '_sol_D', folder_name=os.path.join(output_directory, 'debug')), 
                    pp.Exporter(richards_grid, str(i) + '_sol_R', folder_name=os.path.join(output_directory, 'debug'))]
    save_step(sol[-1], debug_savers, 0)

    # Non-linear loop
    for k in range(max_iterations_per_step):
        rhs = time_rhs.copy()


        rhs[richards_mask] += (L * richards_M_h @ prev[richards_mask] - richards_M_h @ theta(prev[richards_mask] - richards_real_height(np.tile(prev[boundary_mask], ceil(richards_grid.num_nodes / boundary_grid.num_nodes)), 1+richards_grid.nodes[1, :]) ) ) / dt

        global_stif  = global_stifness( prev[boundary_mask], prev[richards_mask] - richards_real_height(np.tile(prev[boundary_mask], ceil(richards_grid.num_nodes / boundary_grid.num_nodes)), 1+richards_grid.nodes[1, :]) )
        darcy_A_h    = global_stif[darcy_mask, :][:, darcy_mask]
        richards_A_h = global_stif[richards_mask, :][:, richards_mask]

        darcy_start    = darcy_A_h
        richards_start = richards_A_h + L / dt * richards_M_h

        mid_start = global_stif[boundary_mask, :][:, boundary_mask] + L / dt * glob_mass[boundary_mask, :][:, boundary_mask]
        

        spp = sps.bmat([[       darcy_remove_boundary @ darcy_start @ darcy_remove_boundary.T,          darcy_remove_boundary @ darcy_start @ darcy_restrict_to_boundary.T,                                                                          None],
                        [darcy_restrict_to_boundary @ darcy_start.T @ darcy_remove_boundary.T,                                                                   mid_start, richards_restrict_to_boundary @ richards_start.T @ richards_remove_boundary.T],
                        [                                                                None, richards_remove_boundary @ richards_start @ richards_restrict_to_boundary.T,        richards_remove_boundary @ richards_start @ richards_remove_boundary.T]], format='csc')


        ls = pg.LinearSystem(spp, rhs)
        ls.flag_ess_bc(dirichlet_flag(current_time), dirichlet_value(current_time))

        current = ls.solve()


        # Compute the errors (with eta). Should I consider only psi? Should I compute the error on the "actual" psi values or on the dofs
        abs_err_psi  = np.sqrt( (current - prev).T @ glob_mass @ (current - prev) )
        abs_err_prev = np.sqrt( prev.T @ glob_mass @ prev )

        print('Iteration #' + format(k+1, '0' + str(ceil(log10(max_iterations_per_step)) + 1) + 'd')
              + ', error L2 relative psi: ' + format(abs_err_psi, str(5 + ceil(log10(1 / abs_tol)) + 4)
                                                     + '.' + str(ceil(log10(1 / abs_tol)) + 4) + 'f') )


        save_step(current, debug_savers, k+1)
        
        if abs_err_psi < abs_tol + rel_tol * abs_err_prev:
            break
        else:
            prev = None
            prev = current.copy()

    print('')

    sol.append( current.copy() )
    save_step(sol[-1], savers, i)

    export_csv(i, sol[-1], plot_figure=True, plot_value=True)


for saver in savers:
    saver.write_pvd([t * dt for t in range(int(T/dt)+1)])
# Out:
# Time 0.02083
# Iteration #0001, error L2 relative psi:    0.23317280345729
# Iteration #0002, error L2 relative psi:    0.09196730250660
# Iteration #0003, error L2 relative psi:    0.01803261194813
# Iteration #0004, error L2 relative psi:    0.00225954212594
# Iteration #0005, error L2 relative psi:    0.00016424022342
# Iteration #0006, error L2 relative psi:    0.00001219618418
# Time 0.04167
# Iteration #0001, error L2 relative psi:    0.39392415330062
# Iteration #0002, error L2 relative psi:    0.17201049453938
# Iteration #0003, error L2 relative psi:    0.06126718675704
# Iteration #0004, error L2 relative psi:    0.01441738028765
# Iteration #0005, error L2 relative psi:    0.00498851820995
# Iteration #0006, error L2 relative psi:    0.00149840477676
# Iteration #0007, error L2 relative psi:    0.00034433094121
# Iteration #0008, error L2 relative psi:    0.00011081435782
# Iteration #0009, error L2 relative psi:    0.00002840563326
# Iteration #0010, error L2 relative psi:    0.00000997082841
# Time 0.0625
# Iteration #0001, error L2 relative psi:    0.52118867388236
# Iteration #0002, error L2 relative psi:    0.17028459973439
# Iteration #0003, error L2 relative psi:    0.06785505530444
# Iteration #0004, error L2 relative psi:    0.02194884451143
# Iteration #0005, error L2 relative psi:    0.00605062554620
# Iteration #0006, error L2 relative psi:    0.00184605072848
# Iteration #0007, error L2 relative psi:    0.00084042044159
# Iteration #0008, error L2 relative psi:    0.00041072402095
# Iteration #0009, error L2 relative psi:    0.00019112440940
# Iteration #0010, error L2 relative psi:    0.00008646325024
# Iteration #0011, error L2 relative psi:    0.00003929914829
# Iteration #0012, error L2 relative psi:    0.00001818765442
# Time 0.08333
# Iteration #0001, error L2 relative psi:    0.23418435900714
# Iteration #0002, error L2 relative psi:    0.09229221454818
# Iteration #0003, error L2 relative psi:    0.04224118568675
# Iteration #0004, error L2 relative psi:    0.02160204936524
# Iteration #0005, error L2 relative psi:    0.01226614540619
# Iteration #0006, error L2 relative psi:    0.00730963471488
# Iteration #0007, error L2 relative psi:    0.00438953897822
# Iteration #0008, error L2 relative psi:    0.00262747717119
# Iteration #0009, error L2 relative psi:    0.00156993362431
# Iteration #0010, error L2 relative psi:    0.00093857189392
# Iteration #0011, error L2 relative psi:    0.00056239485153
# Iteration #0012, error L2 relative psi:    0.00033842322615
# Iteration #0013, error L2 relative psi:    0.00020515311855
# Iteration #0014, error L2 relative psi:    0.00012594170787
# Iteration #0015, error L2 relative psi:    0.00007898211336
# Iteration #0016, error L2 relative psi:    0.00005128682207
# Iteration #0017, error L2 relative psi:    0.00003507752823
# Iteration #0018, error L2 relative psi:    0.00002563716432
# Time 0.10417
# Iteration #0001, error L2 relative psi:    0.16845366889305
# Iteration #0002, error L2 relative psi:    0.06324125142185
# Iteration #0003, error L2 relative psi:    0.03360914840348
# Iteration #0004, error L2 relative psi:    0.02083392556083
# Iteration #0005, error L2 relative psi:    0.01384884628334
# Iteration #0006, error L2 relative psi:    0.00943494812611
# Iteration #0007, error L2 relative psi:    0.00648677124331
# Iteration #0008, error L2 relative psi:    0.00448436821168
# Iteration #0009, error L2 relative psi:    0.00311730042138
# Iteration #0010, error L2 relative psi:    0.00218352196967
# Iteration #0011, error L2 relative psi:    0.00154402549147
# Iteration #0012, error L2 relative psi:    0.00110346008965
# Iteration #0013, error L2 relative psi:    0.00079833747033
# Iteration #0014, error L2 relative psi:    0.00058644111852
# Iteration #0015, error L2 relative psi:    0.00043918190339
# Iteration #0016, error L2 relative psi:    0.00033688228747
# Iteration #0017, error L2 relative psi:    0.00026555920805
# Iteration #0018, error L2 relative psi:    0.00021532825801
# Iteration #0019, error L2 relative psi:    0.00017937282801
# Iteration #0020, error L2 relative psi:    0.00015304069087
# Iteration #0021, error L2 relative psi:    0.00013318939471
# Iteration #0022, error L2 relative psi:    0.00011772920023
# Iteration #0023, error L2 relative psi:    0.00010528998433
# Iteration #0024, error L2 relative psi:    0.00009497975257
# Iteration #0025, error L2 relative psi:    0.00008621649153
# Iteration #0026, error L2 relative psi:    0.00007861613778
# Iteration #0027, error L2 relative psi:    0.00007192041124
# Iteration #0028, error L2 relative psi:    0.00006595127211
# Iteration #0029, error L2 relative psi:    0.00006058242903
# Iteration #0030, error L2 relative psi:    0.00005572150421
# Iteration #0031, error L2 relative psi:    0.00005129878657
# Iteration #0032, error L2 relative psi:    0.00004726005346
# Iteration #0033, error L2 relative psi:    0.00004356191972
# Iteration #0034, error L2 relative psi:    0.00004016877363
# Iteration #0035, error L2 relative psi:    0.00003705072269
# Iteration #0036, error L2 relative psi:    0.00003418219134
# Iteration #0037, error L2 relative psi:    0.00003154094652
# Time 0.125
# Iteration #0001, error L2 relative psi:    0.13405518228265
# Iteration #0002, error L2 relative psi:    0.05005311330831
# Iteration #0003, error L2 relative psi:    0.02921481238715
# Iteration #0004, error L2 relative psi:    0.02005473329027
# Iteration #0005, error L2 relative psi:    0.01475137819646
# Iteration #0006, error L2 relative psi:    0.01119839989568
# Iteration #0007, error L2 relative psi:    0.00865326383338
# Iteration #0008, error L2 relative psi:    0.00677177285709
# Iteration #0009, error L2 relative psi:    0.00535689698527
# Iteration #0010, error L2 relative psi:    0.00428475658634
# Iteration #0011, error L2 relative psi:    0.00346672361253
# Iteration #0012, error L2 relative psi:    0.00283930587114
# Iteration #0013, error L2 relative psi:    0.00235553800998
# Iteration #0014, error L2 relative psi:    0.00198030613601
# Iteration #0015, error L2 relative psi:    0.00168709378442
# Iteration #0016, error L2 relative psi:    0.00145580808728
# Iteration #0017, error L2 relative psi:    0.00127125909417
# Iteration #0018, error L2 relative psi:    0.00112202590018
# Iteration #0019, error L2 relative psi:    0.00099957594616
# Iteration #0020, error L2 relative psi:    0.00089756920800
# Iteration #0021, error L2 relative psi:    0.00081131412897
# Iteration #0022, error L2 relative psi:    0.00073734354654
# Iteration #0023, error L2 relative psi:    0.00067308850982
# Iteration #0024, error L2 relative psi:    0.00061663595674
# Iteration #0025, error L2 relative psi:    0.00056655005214
# Iteration #0026, error L2 relative psi:    0.00052174201852
# Iteration #0027, error L2 relative psi:    0.00048137608937
# Iteration #0028, error L2 relative psi:    0.00044480188956
# Iteration #0029, error L2 relative psi:    0.00041150589852
# Iteration #0030, error L2 relative psi:    0.00038107573076
# Iteration #0031, error L2 relative psi:    0.00035320342480
# Iteration #0032, error L2 relative psi:    0.00032758865398
# Iteration #0033, error L2 relative psi:    0.00030398734293
# Iteration #0034, error L2 relative psi:    0.00028220094455
# Iteration #0035, error L2 relative psi:    0.00026206201763
# Iteration #0036, error L2 relative psi:    0.00024342560487
# Iteration #0037, error L2 relative psi:    0.00022616428831
# Iteration #0038, error L2 relative psi:    0.00021016496480
# Iteration #0039, error L2 relative psi:    0.00019532649176
# Iteration #0040, error L2 relative psi:    0.00018155786533
# Iteration #0041, error L2 relative psi:    0.00016877677353
# Iteration #0042, error L2 relative psi:    0.00015690843097
# Iteration #0043, error L2 relative psi:    0.00014588462995
# Iteration #0044, error L2 relative psi:    0.00013564295979
# Iteration #0045, error L2 relative psi:    0.00012612615780
# Iteration #0046, error L2 relative psi:    0.00011728156405
# Iteration #0047, error L2 relative psi:    0.00010906065841
# Iteration #0048, error L2 relative psi:    0.00010141866363
# Iteration #0049, error L2 relative psi:    0.00009431420154
# Iteration #0050, error L2 relative psi:    0.00008770899283
# Iteration #0051, error L2 relative psi:    0.00008156759233
# Iteration #0052, error L2 relative psi:    0.00007585714939
# Iteration #0053, error L2 relative psi:    0.00007054720588
# Iteration #0054, error L2 relative psi:    0.00006560951195
# Iteration #0055, error L2 relative psi:    0.00006101784715
# Iteration #0056, error L2 relative psi:    0.00005674786599
# Iteration #0057, error L2 relative psi:    0.00005277695745
# Iteration #0058, error L2 relative psi:    0.00004908411657
# Iteration #0059, error L2 relative psi:    0.00004564982660
# Iteration #0060, error L2 relative psi:    0.00004245595060
# Iteration #0061, error L2 relative psi:    0.00003948563165
# Iteration #0062, error L2 relative psi:    0.00003672320076
# Iteration #0063, error L2 relative psi:    0.00003415409176
# Iteration #0064, error L2 relative psi:    0.00003176476274
# Time 0.14583
# Iteration #0001, error L2 relative psi:    0.11216815338000
# Iteration #0002, error L2 relative psi:    0.04376111517907
# Iteration #0003, error L2 relative psi:    0.02823922027882
# Iteration #0004, error L2 relative psi:    0.02148952919502
# Iteration #0005, error L2 relative psi:    0.01760607705379
# Iteration #0006, error L2 relative psi:    0.01497699659173
# Iteration #0007, error L2 relative psi:    0.01304318219088
# Iteration #0008, error L2 relative psi:    0.01155391225952
# Iteration #0009, error L2 relative psi:    0.01037420839548
# Iteration #0010, error L2 relative psi:    0.00941730667025
# Iteration #0011, error L2 relative psi:    0.00862607311163
# Iteration #0012, error L2 relative psi:    0.00796062506328
# Iteration #0013, error L2 relative psi:    0.00739291752665
# Iteration #0014, error L2 relative psi:    0.00690199639580
# Iteration #0015, error L2 relative psi:    0.00647220581387
# Iteration #0016, error L2 relative psi:    0.00609215384430
# Iteration #0017, error L2 relative psi:    0.00575261275690
# Iteration #0018, error L2 relative psi:    0.00544627407256
# Iteration #0019, error L2 relative psi:    0.00516767411063
# Iteration #0020, error L2 relative psi:    0.00491252753201
# Iteration #0021, error L2 relative psi:    0.00467740301829
# Iteration #0022, error L2 relative psi:    0.00445959027313
# Iteration #0023, error L2 relative psi:    0.00425698092499
# Iteration #0024, error L2 relative psi:    0.00406772965439
# Iteration #0025, error L2 relative psi:    0.00389026774727
# Iteration #0026, error L2 relative psi:    0.00372337521565
# Iteration #0027, error L2 relative psi:    0.00356605458449
# Iteration #0028, error L2 relative psi:    0.00341746025699
# Iteration #0029, error L2 relative psi:    0.00327686339788
# Iteration #0030, error L2 relative psi:    0.00314362905938
# Iteration #0031, error L2 relative psi:    0.00301719957144
# Iteration #0032, error L2 relative psi:    0.00289708162827
# Iteration #0033, error L2 relative psi:    0.00278283137512
# Iteration #0034, error L2 relative psi:    0.00267405254999
# Iteration #0035, error L2 relative psi:    0.00257041960538
# Iteration #0036, error L2 relative psi:    0.00247162193659
# Iteration #0037, error L2 relative psi:    0.00237738091269
# Iteration #0038, error L2 relative psi:    0.00228736601366
# Iteration #0039, error L2 relative psi:    0.00220130929354
# Iteration #0040, error L2 relative psi:    0.00211898713641
# Iteration #0041, error L2 relative psi:    0.00204020077050
# Iteration #0042, error L2 relative psi:    0.00196476733825
# Iteration #0043, error L2 relative psi:    0.00189251628587
# Iteration #0044, error L2 relative psi:    0.00182328777437
# Iteration #0045, error L2 relative psi:    0.00175693181592
# Iteration #0046, error L2 relative psi:    0.00169330791246
# Iteration #0047, error L2 relative psi:    0.00163229070820
# Iteration #0048, error L2 relative psi:    0.00157379456930
# Iteration #0049, error L2 relative psi:    0.00151765940959
# Iteration #0050, error L2 relative psi:    0.00146375617055
# Iteration #0051, error L2 relative psi:    0.00141197712059
# Iteration #0052, error L2 relative psi:    0.00136222537290
# Iteration #0053, error L2 relative psi:    0.00131441032005
# Iteration #0054, error L2 relative psi:    0.00126844609797
# Iteration #0055, error L2 relative psi:    0.00122425108075
# Iteration #0056, error L2 relative psi:    0.00118174765074
# Iteration #0057, error L2 relative psi:    0.00114086202166
# Iteration #0058, error L2 relative psi:    0.00110152406411
# Iteration #0059, error L2 relative psi:    0.00106366712756
# Iteration #0060, error L2 relative psi:    0.00102722786225
# Iteration #0061, error L2 relative psi:    0.00099214604456
# Iteration #0062, error L2 relative psi:    0.00095836440810
# Iteration #0063, error L2 relative psi:    0.00092582848187
# Iteration #0064, error L2 relative psi:    0.00089448643601
# Iteration #0065, error L2 relative psi:    0.00086428893464
# Iteration #0066, error L2 relative psi:    0.00083518899420
# Iteration #0067, error L2 relative psi:    0.00080714182652
# Iteration #0068, error L2 relative psi:    0.00078010399670
# Iteration #0069, error L2 relative psi:    0.00075403459986
# Iteration #0070, error L2 relative psi:    0.00072889518607
# Iteration #0071, error L2 relative psi:    0.00070464902191
# Iteration #0072, error L2 relative psi:    0.00068126100678
# Iteration #0073, error L2 relative psi:    0.00065869760144
# Iteration #0074, error L2 relative psi:    0.00063692675626
# Iteration #0075, error L2 relative psi:    0.00061591783965
# Iteration #0076, error L2 relative psi:    0.00059564156805
# Iteration #0077, error L2 relative psi:    0.00057606993865
# Iteration #0078, error L2 relative psi:    0.00055717616532
# Iteration #0079, error L2 relative psi:    0.00053893461785
# Iteration #0080, error L2 relative psi:    0.00052132076453
# Iteration #0081, error L2 relative psi:    0.00050431111798
# Iteration #0082, error L2 relative psi:    0.00048788318403
# Iteration #0083, error L2 relative psi:    0.00047201541380
# Iteration #0084, error L2 relative psi:    0.00045668715863
# Iteration #0085, error L2 relative psi:    0.00044187862838
# Iteration #0086, error L2 relative psi:    0.00042757085360
# Iteration #0087, error L2 relative psi:    0.00041374565385
# Iteration #0088, error L2 relative psi:    0.00040038560931
# Iteration #0089, error L2 relative psi:    0.00038747365749
# Iteration #0090, error L2 relative psi:    0.00037500391224
# Iteration #0091, error L2 relative psi:    0.00036295136230
# Iteration #0092, error L2 relative psi:    0.00035129732582
# Iteration #0093, error L2 relative psi:    0.00034002714080
# Iteration #0094, error L2 relative psi:    0.00032912777329
# Iteration #0095, error L2 relative psi:    0.00031858684900
# Iteration #0096, error L2 relative psi:    0.00030839236410
# Iteration #0097, error L2 relative psi:    0.00029853261352
# Iteration #0098, error L2 relative psi:    0.00028899495341
# Iteration #0099, error L2 relative psi:    0.00027976976667
# Iteration #0100, error L2 relative psi:    0.00027084799391
# Iteration #0101, error L2 relative psi:    0.00026221483785
# Iteration #0102, error L2 relative psi:    0.00025385983305
# Iteration #0103, error L2 relative psi:    0.00024577413999
# Iteration #0104, error L2 relative psi:    0.00023794944147
# Iteration #0105, error L2 relative psi:    0.00023037761182
# Iteration #0106, error L2 relative psi:    0.00022305065508
# Iteration #0107, error L2 relative psi:    0.00021596071784
# Iteration #0108, error L2 relative psi:    0.00020910011522
# Iteration #0109, error L2 relative psi:    0.00020246135297
# Iteration #0110, error L2 relative psi:    0.00019603714255
# Iteration #0111, error L2 relative psi:    0.00018982040970
# Iteration #0112, error L2 relative psi:    0.00018380429833
# Iteration #0113, error L2 relative psi:    0.00017798217078
# Iteration #0114, error L2 relative psi:    0.00017234760578
# Iteration #0115, error L2 relative psi:    0.00016689439481
# Iteration #0116, error L2 relative psi:    0.00016161653739
# Iteration #0117, error L2 relative psi:    0.00015650823563
# Iteration #0118, error L2 relative psi:    0.00015156388846
# Iteration #0119, error L2 relative psi:    0.00014677808548
# Iteration #0120, error L2 relative psi:    0.00014214560081
# Iteration #0121, error L2 relative psi:    0.00013766138680
# Iteration #0122, error L2 relative psi:    0.00013332056782
# Iteration #0123, error L2 relative psi:    0.00012911843385
# Iteration #0124, error L2 relative psi:    0.00012505043406
# Iteration #0125, error L2 relative psi:    0.00012111216937
# Iteration #0126, error L2 relative psi:    0.00011729937891
# Iteration #0127, error L2 relative psi:    0.00011360738179
# Iteration #0128, error L2 relative psi:    0.00011003333062
# Iteration #0129, error L2 relative psi:    0.00010657294628
# Iteration #0130, error L2 relative psi:    0.00010322126609
# Iteration #0131, error L2 relative psi:    0.00009997466382
# Iteration #0132, error L2 relative psi:    0.00009683000360
# Iteration #0133, error L2 relative psi:    0.00009378429486
# Iteration #0134, error L2 relative psi:    0.00009083459787
# Iteration #0135, error L2 relative psi:    0.00008797801062
# Iteration #0136, error L2 relative psi:    0.00008521167648
# Iteration #0137, error L2 relative psi:    0.00008253279447
# Iteration #0138, error L2 relative psi:    0.00007993862748
# Iteration #0139, error L2 relative psi:    0.00007742650784
# Iteration #0140, error L2 relative psi:    0.00007499384056
# Iteration #0141, error L2 relative psi:    0.00007263810499
# Iteration #0142, error L2 relative psi:    0.00007035685520
# Iteration #0143, error L2 relative psi:    0.00006814771954
# Iteration #0144, error L2 relative psi:    0.00006600839973
# Iteration #0145, error L2 relative psi:    0.00006393666944
# Iteration #0146, error L2 relative psi:    0.00006193037278
# Iteration #0147, error L2 relative psi:    0.00005998742244
# Iteration #0148, error L2 relative psi:    0.00005810579797
# Iteration #0149, error L2 relative psi:    0.00005628354377
# Iteration #0150, error L2 relative psi:    0.00005451876719
# Iteration #0151, error L2 relative psi:    0.00005280963667
# Iteration #0152, error L2 relative psi:    0.00005115437973
# Iteration #0153, error L2 relative psi:    0.00004955128121
# Iteration #0154, error L2 relative psi:    0.00004799868135
# Iteration #0155, error L2 relative psi:    0.00004649497404
# Iteration #0156, error L2 relative psi:    0.00004503860505
# Iteration #0157, error L2 relative psi:    0.00004362807036
# Iteration #0158, error L2 relative psi:    0.00004226191450
# Iteration #0159, error L2 relative psi:    0.00004093872895
# Iteration #0160, error L2 relative psi:    0.00003965715058
# Iteration #0161, error L2 relative psi:    0.00003841586020
# Iteration #0162, error L2 relative psi:    0.00003721358106
# Iteration #0163, error L2 relative psi:    0.00003604907750
# Time 0.16667
# Iteration #0001, error L2 relative psi:    0.09953319097315
# Iteration #0002, error L2 relative psi:    0.04568906235859
# Iteration #0003, error L2 relative psi:    0.03698708459127
# Iteration #0004, error L2 relative psi:    0.03434217029550
# Iteration #0005, error L2 relative psi:    0.03345306426554
# Iteration #0006, error L2 relative psi:    0.03321122114335
# Iteration #0007, error L2 relative psi:    0.03328483348920
# Iteration #0008, error L2 relative psi:    0.03356285941369
# Iteration #0009, error L2 relative psi:    0.03400825770348
# Iteration #0010, error L2 relative psi:    0.03460986956904
# Iteration #0011, error L2 relative psi:    0.03536757295321
# Iteration #0012, error L2 relative psi:    0.03627355684559
# Iteration #0013, error L2 relative psi:    0.03737010040714
# Iteration #0014, error L2 relative psi:    0.03865158613887
# Iteration #0015, error L2 relative psi:    0.04012954470138
# Iteration #0016, error L2 relative psi:    0.04183629629272
# Iteration #0017, error L2 relative psi:    0.04379477435763
# Iteration #0018, error L2 relative psi:    0.04623231276903
# Iteration #0019, error L2 relative psi:    0.04955951807825
# Iteration #0020, error L2 relative psi:    0.05497617386254
# Iteration #0021, error L2 relative psi:    0.06561826485812
# Iteration #0022, error L2 relative psi:    0.08943338344562
# Iteration #0023, error L2 relative psi:    0.15264131275421
# Iteration #0024, error L2 relative psi:    0.54933611792961
# Iteration #0025, error L2 relative psi:    0.95998880083003
# Iteration #0026, error L2 relative psi:    0.61032125185777
# Iteration #0027, error L2 relative psi:    0.61357915391899
# Iteration #0028, error L2 relative psi:    0.56359647641287
# Iteration #0029, error L2 relative psi:    0.48647792838097
# Iteration #0030, error L2 relative psi:    0.41815745572803
# Iteration #0031, error L2 relative psi:    0.66644733971546
# Iteration #0032, error L2 relative psi:    0.46081928164810
# Iteration #0033, error L2 relative psi:    0.25884460354595
# Iteration #0034, error L2 relative psi:    0.15497573915346
# Iteration #0035, error L2 relative psi:    0.09482596785876
# Iteration #0036, error L2 relative psi:    0.06934529652383
# Iteration #0037, error L2 relative psi:    0.05734673144138
# Iteration #0038, error L2 relative psi:    0.05013083035820
# Iteration #0039, error L2 relative psi:    0.04465256841808
# Iteration #0040, error L2 relative psi:    0.04021535621465
# Iteration #0041, error L2 relative psi:    0.03650316049870
# Iteration #0042, error L2 relative psi:    0.03332620761350
# Iteration #0043, error L2 relative psi:    0.03055463465032
# Iteration #0044, error L2 relative psi:    0.02810791619467
# Iteration #0045, error L2 relative psi:    0.02593241578945
# Iteration #0046, error L2 relative psi:    0.02398670061185
# Iteration #0047, error L2 relative psi:    0.02223355162001
# Iteration #0048, error L2 relative psi:    0.02063707688397
# Iteration #0049, error L2 relative psi:    0.01916276478944
# Iteration #0050, error L2 relative psi:    0.01777895472402
# Iteration #0051, error L2 relative psi:    0.01645876636478
# Iteration #0052, error L2 relative psi:    0.01518186083032
# Iteration #0053, error L2 relative psi:    0.01393559755630
# Iteration #0054, error L2 relative psi:    0.01271530599364
# Iteration #0055, error L2 relative psi:    0.01152356577231
# Iteration #0056, error L2 relative psi:    0.01036858836429
# Iteration #0057, error L2 relative psi:    0.00926198382425
# Iteration #0058, error L2 relative psi:    0.00821632406227
# Iteration #0059, error L2 relative psi:    0.00724293557539
# Iteration #0060, error L2 relative psi:    0.00635026351467
# Iteration #0061, error L2 relative psi:    0.00554298272309
# Iteration #0062, error L2 relative psi:    0.00482185077407
# Iteration #0063, error L2 relative psi:    0.00418415758689
# Iteration #0064, error L2 relative psi:    0.00362455510472
# Iteration #0065, error L2 relative psi:    0.00313606460470
# Iteration #0066, error L2 relative psi:    0.00271345707767
# Iteration #0067, error L2 relative psi:    0.00235032003547
# Iteration #0068, error L2 relative psi:    0.00202668408510
# Iteration #0069, error L2 relative psi:    0.00174728249918
# Iteration #0070, error L2 relative psi:    0.00150618512522
# Iteration #0071, error L2 relative psi:    0.00129243698062
# Iteration #0072, error L2 relative psi:    0.00110869674553
# Iteration #0073, error L2 relative psi:    0.00094626670573
# Iteration #0074, error L2 relative psi:    0.00080668813325
# Iteration #0075, error L2 relative psi:    0.00068432938670
# Iteration #0076, error L2 relative psi:    0.00057788458476
# Iteration #0077, error L2 relative psi:    0.00048633384527
# Iteration #0078, error L2 relative psi:    0.00040740569676
# Iteration #0079, error L2 relative psi:    0.00033991088809
# Iteration #0080, error L2 relative psi:    0.00028182054671
# Iteration #0081, error L2 relative psi:    0.00023299487826
# Iteration #0082, error L2 relative psi:    0.00019169894470
# Iteration #0083, error L2 relative psi:    0.00015713939470
# Iteration #0084, error L2 relative psi:    0.00012834235595
# Iteration #0085, error L2 relative psi:    0.00010451258603
# Iteration #0086, error L2 relative psi:    0.00008492450905
# Iteration #0087, error L2 relative psi:    0.00006893672290
# Iteration #0088, error L2 relative psi:    0.00005598061590
#
# [4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323]
# [4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323]
# [4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323]
# [4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323]
# [4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
# ...
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323 4.45790995 4.45463454 4.44467174
#  4.42779584 4.40364388 4.37165553 4.33096493 4.28014452 4.21633965
#  4.13080875 3.98081838 3.61648108 3.0105825  2.20016256 1.58023165
#  1.45552386 1.37330903 1.29691021 1.22411729 1.15206734 1.07580323
#  4.45790995 4.45463454 4.44467174 4.42779584 4.40364388 4.37165553
#  4.33096493 4.28014452 4.21633965 4.13080875 3.98081838 3.61648108
#  3.0105825  2.20016256 1.58023165 1.45552386 1.37330903 1.29691021
#  1.22411729 1.15206734 1.07580323]
# Time 0.1875
# Iteration #0001, error L2 relative psi:    0.12485504694575
# Iteration #0002, error L2 relative psi:    0.06722626154969
# Iteration #0003, error L2 relative psi:    0.05310893989399
# Iteration #0004, error L2 relative psi:    0.04479322753496
# Iteration #0005, error L2 relative psi:    0.03719058952559
# Iteration #0006, error L2 relative psi:    0.03186928846425
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/richards/tests/primal_test/Actual Coupling/hard_coupling_bezier.ipynb Cell 82 line 2
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> rhs = time_rhs.copy()
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> rhs[richards_mask] += (L * richards_M_h @ prev[richards_mask] - richards_M_h @ theta(prev[richards_mask] - richards_real_height(np.tile(prev[boundary_mask], ceil(richards_grid.num_nodes / boundary_grid.num_nodes)), 1+richards_grid.nodes[1, :]) ) ) / dt
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> global_stif  = global_stifness( prev[boundary_mask], prev[richards_mask] - richards_real_height(np.tile(prev[boundary_mask], ceil(richards_grid.num_nodes / boundary_grid.num_nodes)), 1+richards_grid.nodes[1, :]) )
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> darcy_A_h    = global_stif[darcy_mask, :][:, darcy_mask]
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> richards_A_h = global_stif[richards_mask, :][:, richards_mask]
#
# /workspaces/richards/tests/primal_test/Actual Coupling/hard_coupling_bezier.ipynb Cell 82 line 3
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a>     A = darcy_local_A(coord_loc, eta_dofs[eta_cell], eta_dofs[eta_cell+1], grad_eta[eta_cell], np.prod(sign[loc]))
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a> else:
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>     A = richards_local_A(coord_loc, eta_dofs[eta_cell], eta_dofs[eta_cell+1], grad_eta[eta_cell], np.prod(sign[loc]), psi_dofs[nodes_loc])
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a> # Save values for stiff-H1 local matrix in the global structure
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=36'>37</a> cols = base + np.tile(nodes_loc, (nodes_loc.size, 1))
#
# /workspaces/richards/tests/primal_test/Actual Coupling/hard_coupling_bezier.ipynb Cell 82 line 3
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>         integrand = lambda ys,x: np.array([q_funcs[j].T @ K_local(x, y) @ q_funcs[i] for y in np.array(ys)])
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a>         inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a>         M[ ordering[i], ordering[j] ] = jacobian * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a> return M
#
# File /opt/conda/lib/python3.11/site-packages/scipy/integrate/_quadrature.py:155, in fixed_quad(func, a, b, args, n)
#     152     raise ValueError("Gaussian quadrature is only available for "
#     153                      "finite limits.")
#     154 y = (b-a)*(x+1)/2.0 + a
# --> 155 return (b-a)/2.0 * np.sum(w*func(y, *args), axis=-1), None
#
# /workspaces/richards/tests/primal_test/Actual Coupling/hard_coupling_bezier.ipynb Cell 82 line 3
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a>     for j in range(3):
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>         integrand = lambda ys,x: np.array([q_funcs[j].T @ K_local(x, y) @ q_funcs[i] for y in np.array(ys)])
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a>         inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a>         M[ ordering[i], ordering[j] ] = jacobian * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a> return M
#
# /workspaces/richards/tests/primal_test/Actual Coupling/hard_coupling_bezier.ipynb Cell 82 line 3
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a>     for j in range(3):
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>         integrand = lambda ys,x: np.array([q_funcs[j].T @ K_local(x, y) @ q_funcs[i] for y in np.array(ys)])
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a>         inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a>         M[ ordering[i], ordering[j] ] = jacobian * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a> return M
#
# File /opt/conda/lib/python3.11/site-packages/scipy/integrate/_quadrature.py:155, in fixed_quad(func, a, b, args, n)
#     152     raise ValueError("Gaussian quadrature is only available for "
#     153                      "finite limits.")
#     154 y = (b-a)*(x+1)/2.0 + a
# --> 155 return (b-a)/2.0 * np.sum(w*func(y, *args), axis=-1), None
#
# /workspaces/richards/tests/primal_test/Actual Coupling/hard_coupling_bezier.ipynb Cell 82 line 3
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a> for i in range(3):
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a>     for j in range(3):
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>         integrand = lambda ys,x: np.array([q_funcs[j].T @ K_local(x, y) @ q_funcs[i] for y in np.array(ys)])
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a>         inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a>         M[ ordering[i], ordering[j] ] = jacobian * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
#
# /workspaces/richards/tests/primal_test/Actual Coupling/hard_coupling_bezier.ipynb Cell 82 line 3
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a> for i in range(3):
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a>     for j in range(3):
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>         integrand = lambda ys,x: np.array([q_funcs[j].T @ K_local(x, y) @ q_funcs[i] for y in np.array(ys)])
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a>         inside = lambda xs, n: np.array([integrate.fixed_quad(integrand, 0, 1-x, args=(x,), n=n)[0] for x in np.array(xs)])
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a>         M[ ordering[i], ordering[j] ] = jacobian * integrate.fixed_quad(inside, 0, 1, n=quad_order, args=(quad_order,))[0]
#
# /workspaces/richards/tests/primal_test/Actual Coupling/hard_coupling_bezier.ipynb Cell 82 line 2
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a> element_height = np.max(coord[1, :]) - np.min(coord[1, :])
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> element_width  = np.max(coord[0, :]) - np.min(coord[0, :])
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> K_local = lambda x,y: Richards_K_func(base_height, base_width,
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a>     element_height, element_width,
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>     m,
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a>     ls_eta, rs_eta, grad_eta, A, psi_fun(x, y), x, y)
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a> for i in range(3):
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a>     for j in range(3):
#
# /workspaces/richards/tests/primal_test/Actual Coupling/hard_coupling_bezier.ipynb Cell 82 line 1
#       <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> chi_eta = 1 + (x3-1)/A * ( A - 2*eta + 2*(A-eta)*(x3-1)*(x3-3) )
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> #return np.array([[2, 0], [0, 1/2]]) * conductivity(psi(x,y))
#      <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> return np.array([[             chi_x3,                            -chi_eta * grad_eta],
# ---> <a href='vscode-notebook-cell://dev-container%..._test/Actual%20Coupling/hard_coupling_bezier.ipynb#Y153sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>                  [-chi_eta * grad_eta, (1 + np.power(chi_eta * grad_eta, 2)) / chi_x3]]) * conductivity(psi) / chi_x3
#
# KeyboardInterrupt:
