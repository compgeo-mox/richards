# %%
import matplotlib.pyplot as plt
import csv, glob, os

# %%
L_indices = [35, 45]
base_directories = '../report'

problem_name = 'benchmark'

# %%
directories = [os.path.join(base_directories, problem_name + '_L_test_' + str(L_index) + '_steps_9_LSCHEME') for L_index in L_indices]

# %%
scheme_dictionary = {}
scheme_iterations = {}
scheme_time = {}

# %%
for directory, L_index in zip(directories, L_indices):
    print('Reading contents of directory ' + directory)
    files = glob.glob(os.path.join(directory, '*_' + problem_name +'*.csv'))

    print('Pattern ' + os.path.join(directory, '*_' + problem_name +'*.csv') + ' matched with ' + str(len(files)) + ' files')

    scheme_dictionary[str(L_index)] = list()

    for file in files:
        scheme_dictionary[str(L_index)].append( file )
    
    scheme_dictionary[str(L_index)].sort( )

    print('')
# Out:
# Reading contents of directory ../report/benchmark_L_test_35_steps_9_LSCHEME
# Pattern ../report/benchmark_L_test_35_steps_9_LSCHEME/*_benchmark*.csv matched with 4 files
#
# Reading contents of directory ../report/benchmark_L_test_45_steps_9_LSCHEME
# Pattern ../report/benchmark_L_test_45_steps_9_LSCHEME/*_benchmark*.csv matched with 4 files

# %%
for L_index in L_indices:
    scheme_iterations[str(L_index)] = []

    for file in scheme_dictionary[str(L_index)]:
        with open(file, 'r') as csvfile:
            lines = csv.reader(csvfile, delimiter=',')
            scheme_iterations[str(L_index)].append(sum(1 for row in lines))

            print('File ' + file + ' has ' + str(scheme_iterations[str(L_index)][-1]) + ' iterations!')
    
    print('')
# Out:
# File ../report/benchmark_L_test_35_steps_9_LSCHEME/020_benchmark_L_test_LSCHEME_richards_solver.csv has 151 iterations!
# File ../report/benchmark_L_test_35_steps_9_LSCHEME/040_benchmark_L_test_LSCHEME_richards_solver.csv has 119 iterations!
# File ../report/benchmark_L_test_35_steps_9_LSCHEME/080_benchmark_L_test_LSCHEME_richards_solver.csv has 90 iterations!
# File ../report/benchmark_L_test_35_steps_9_LSCHEME/160_benchmark_L_test_LSCHEME_richards_solver.csv has 70 iterations!
#
# File ../report/benchmark_L_test_45_steps_9_LSCHEME/020_benchmark_L_test_LSCHEME_richards_solver.csv has 168 iterations!
# File ../report/benchmark_L_test_45_steps_9_LSCHEME/040_benchmark_L_test_LSCHEME_richards_solver.csv has 129 iterations!
# File ../report/benchmark_L_test_45_steps_9_LSCHEME/080_benchmark_L_test_LSCHEME_richards_solver.csv has 96 iterations!
# File ../report/benchmark_L_test_45_steps_9_LSCHEME/160_benchmark_L_test_LSCHEME_richards_solver.csv has 78 iterations!

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))


fig.suptitle('Number of iterations vs Mesh refinment')

for ax, L_index in zip(axs, L_indices):

    ax.plot([10 * 2**i for i in range(1, 5)], scheme_iterations[str(L_index)])
    ax.set_title('L=' + str(L_index / 10) + '$\cdot 10^{-2}$')

    ax.set_xlabel('N')
    ax.set_ylabel('Iterations')
    ax.grid()
