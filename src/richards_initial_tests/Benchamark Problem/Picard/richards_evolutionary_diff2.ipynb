# %% [markdown]
# # Richards equation
#
# In this tutorial we present how to solve a Richards equation with [PyGeoN](https://github.com/compgeo-mox/pygeon).  The unkwons are the velocity $q$ and the pressure $p$.
#
# Let $\Omega=(0,2)\times(0,3)$ with boundary $\partial \Omega$ and outward unit normal ${\nu}$. Given
# $k$ the matrix permeability, we want to solve the following problem: find $({q}, \psi)$ such that
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# K^{-1}(\psi) {q} + \nabla \psi = -\nabla z\\
# \partial_t \theta (\psi) + \nabla \cdot {q} = 0
# \end{array}
# &\text{in } \Omega \times (0,T)
# \end{array}
# \right.
# $$
# with boundary conditions:
#
# $$
# \psi(t,x,z)=
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# -2+2.2 \frac{t}{\Delta t_D}, \text{ on } \Gamma_{D_1}, t\leq\Delta t_D\\
# 0.2, \text{ on } \Gamma_{D_1}, t>\Delta t_D\\
# 1-z, \text{ on } \Gamma_{D_2}
# \end{array}
# \end{array}
# \right., \qquad \nu \cdot q = 0 \text{ on } \Gamma_N \qquad \psi(0,x,z) = 1-z \text{ on } \Omega$$
# and
# $$
# \Gamma_{D_1} = \left\{ (x,z) \in \partial \Omega \:|\: x \in [0,1] \wedge z=3  \right\},\\
# \Gamma_{D_2} = \left\{ (x,z) \in \partial \Omega \:|\: x = 2 \wedge z \in [0,1]  \right\},\\
# \Gamma_{D} = \Gamma_{D_1} \cup \Gamma_{D_2},\\
# \Gamma_{N} = \partial \Omega \setminus \Gamma_D
# $$
#
# We present *step-by-step* how to create the grid, declare the problem data, and finally solve the problem.

# %% [markdown]
# ### Import and parameters

# %%
import shutil
import os

import numpy as np
import scipy.sparse as sps
from scipy.sparse import linalg
import sympy as sp

import porepy as pp
import pygeon as pg

from math import ceil, floor, log10, exp

import matplotlib.pyplot as plt

# %%
K = 50
N = 20

eps_psi_abs = 1e-4
eps_psi_rel = 1e-4

domain_tolerance = 1 / (10 * N)
beta_q   = 0
beta_psi = 0

output_directory = 'output_evolutionary'

# %%
rho = 1000
g = pp.GRAVITY_ACCELERATION

# %%
theta_s = 0.396
theta_r = 0.131

alpha = 0.423

n = 2.06
K_s = 4.96e-2

# %%
h_s = 0
theta_m = theta_s
m = 1 - 1/n
L = 0.5

# %%
dt_D = 1/16
T    = 3/16
num_steps = 100

dt   = (T-0)/num_steps

# %% [markdown]
# ### $\theta$ and $k$, with their derivatives w.r.t. $\psi$

# %%
psi_var = sp.Symbol('psi', negative=True)
theta_expression = theta_r + (theta_s - theta_r) / (1 + (-alpha * psi_var) ** n) ** m

theta_negative_func = sp.lambdify(psi_var, theta_expression, 'numpy')

# %%
effective_saturation = (theta_expression - theta_r) / (theta_s - theta_r)

hydraulic_conductivity_expression = K_s * (effective_saturation ** L) * ( 1 - (1 - effective_saturation ** (1 / m)) ** m ) ** 2
hydraulic_conductivity_negative_func = sp.lambdify(psi_var, hydraulic_conductivity_expression, 'numpy')

# %%
def theta(psi):
    mask = psi < h_s

    res = np.ones_like(psi) * theta_s
    res[mask] = theta_negative_func(psi[mask])

    return res

# %%
def hydraulic_conductivity_coefficient(psi):
    mask = psi < h_s

    res = np.ones_like(psi) * K_s
    res[mask] = hydraulic_conductivity_negative_func(psi[mask])

    return res

# %%
derivative_theta_negative_func = sp.lambdify(psi_var, sp.diff(theta_expression, psi_var), 'numpy')
derivative_inverse_hydraulic_conductivity_negative_func = sp.lambdify(psi_var, sp.diff(1 / hydraulic_conductivity_expression, psi_var), 'numpy')

# %%
def derivative_theta(psi):
    mask = psi < h_s
    res = np.zeros_like(psi)

    res[mask] = derivative_theta_negative_func(psi[mask])

    return res

# %%
def derivative_inverse_hydraulic_conductivity_coefficient(psi):
    mask = psi < h_s
    res = np.zeros_like(psi)

    res[mask] = derivative_inverse_hydraulic_conductivity_negative_func(psi[mask])

    return res

# %%
def quick_plot():
    psi_val = np.linspace(-2, 1, 100)

    theta_max = theta_s
    theta_min = theta_r

    _, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 10))

    ax1.plot(psi_val, theta(psi_val))
    ax1.plot(psi_val, theta_max * np.ones_like(psi_val), linestyle="--", color="red")
    ax1.plot(
        psi_val,
        theta_min * np.ones_like(psi_val),
        linestyle="--",
        color="green",
    )
    ax1.set_title("theta")

    ax2.plot(psi_val, 1 / hydraulic_conductivity_coefficient(psi_val))
    ax2.set_title("K^-1")

    ax3.plot(psi_val, derivative_theta(psi_val))
    ax3.set_title("d theta / d psi")

    ax4.plot(psi_val, derivative_inverse_hydraulic_conductivity_coefficient(psi_val))
    ax4.set_title("d (K^-1) / d psi")


    plt.show()

# %%
quick_plot()

# %% [markdown]
# ### Domain preparation

# %%
subdomain = pp.StructuredTriangleGrid([2*N, 3*N], [2,3])
# convert the grid into a mixed-dimensional grid
mdg = pp.meshing.subdomains_to_mdg([subdomain])

# %%
key = "flow"

bc_value = []
bc_essential = []
initial_pressure = []

gravity = []

RT0 = pg.RT0(key)
P0  = pg.PwConstants(key)

# %%
def g_func(x): 
    return np.array([0, -1, -1])

# %%
def initial_pressure_func(x): 
    return 1-x[1]

# %%
for subdomain, data in mdg.subdomains(return_data=True):
    g_proj = RT0.interpolate(subdomain, g_func)
    gravity.append(RT0.assemble_mass_matrix(subdomain) @ g_proj)
    
    initial_pressure.append(P0.interpolate(subdomain, initial_pressure_func))
        
    # with the following steps we identify the portions of the boundary
    # to impose the boundary conditions
    boundary_faces_indexes = subdomain.get_boundary_faces()

    gamma_d1 = np.logical_and(subdomain.face_centers[0, :] > 0-domain_tolerance, np.logical_and(subdomain.face_centers[0, :] < 1+domain_tolerance, subdomain.face_centers[1, :] > 3-domain_tolerance))
    gamma_d2 = np.logical_and(subdomain.face_centers[0, :] > 2-domain_tolerance, np.logical_and(subdomain.face_centers[1, :] > 0-domain_tolerance, subdomain.face_centers[1, :] < 1+domain_tolerance))

    gamma_d  = np.logical_or(gamma_d1, gamma_d2)
    
    gamma_n  = gamma_d.copy()
    gamma_n[boundary_faces_indexes] = np.logical_not(gamma_n[boundary_faces_indexes])
    

    pp.initialize_data(subdomain, data, key, {
        "second_order_tensor": pp.SecondOrderTensor(np.ones(subdomain.num_cells)),
    })
    
    def bc_gamma_d(x, t):
        if   x[0] > 2-domain_tolerance and x[1] > 0-domain_tolerance and x[1] < 1+domain_tolerance:
            res =  1 - x[1]
        elif x[1] > 3-domain_tolerance and x[0] > 0-domain_tolerance and x[0] < 1+domain_tolerance:
            res = min( 0.2, -2 + 2.2 * t / dt_D )
        else:
            res = 0
        
        return res

    bc_value.append(lambda t: - RT0.assemble_nat_bc(subdomain, lambda x: bc_gamma_d(x,t), gamma_d))

    essential_pressure_dofs = np.zeros(P0.ndof(subdomain), dtype=bool)
    bc_essential.append(np.hstack((gamma_n, essential_pressure_dofs)))

# %% [markdown]
# ### Method

# %% [markdown]
# A quick recap:
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# K^{-1}(\psi) {q} + \nabla \psi = -\nabla z\\
# \partial_t \theta (\psi) + \nabla \cdot {q} = 0
# \end{array}
# &\text{in } \Omega \times (0,T)
# \end{array}
# \right.
# $$
# becames, with the time discretization and Picard applied:
# $$
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# K^{-1}(\psi^{n+1}_k) {q^{n+1}_{k+1}} + \nabla \psi^{n+1}_{k+1} = -\nabla z\\
# \frac{\partial \theta (\psi_k^{n+1})}{\partial \psi} \frac{\psi^{n+1}_{k+1}}{\Delta t} + \nabla \cdot {q^{n+1}_{k+1}} = \frac{\partial \theta (\psi^{n})}{\partial \psi} \frac{\psi^{n}}{\Delta t}
# \end{array}
# &\text{in } \Omega \times (0,T)
# \end{array}
# \right.
# $$

# %% [markdown]
# $$
# Picard \qquad
# \left\{
# \begin{array}{ll}
# \begin{array}{l}
# M^{n+1}_k q_{k+1}^{n+1} + B^T \psi^{n+1}_{k+1} = G^{n+1}  + BC^{n+1}\\
# - \Delta t B q_{k+1}^{n+1} + N_k^{n+1} \psi_{k+1}^{n+1} = N^{n} \psi^{n}
# \end{array}
# \end{array}
# \right.
# $$

# %% [markdown]
# where:
# $$
# [M^{n+1}_k]_{ij} = \left( K^{-1}(\psi^{n+1}_k) \Phi_j, \Phi_i \right)_{L^2(\Omega)}, \qquad
# [N^{n+1}_k]_{ij} = \left( \frac{\partial \theta(\psi^{n+1}_k)}{\partial \psi} \Phi_j, \Phi_i \right)_{L^2(\Omega)}, \qquad
# [B]_{ij} = - \left( \Psi_i, \nabla \cdot \Phi_j \right)_{L^2(\Omega)},
# $$

# %%
B = -pg.cell_mass(mdg) @ pg.div(mdg)

# get the degrees of freedom for each variable
dof_p, dof_q = B.shape
dof_psi = dof_p

# %%
proj_q   = RT0.eval_at_cell_centers(subdomain)
proj_psi =  P0.eval_at_cell_centers(subdomain)


def export_step(save, current_sol, step) -> None:
    q   = current_sol[:dof_q]
    psi = current_sol[-dof_psi:]

    ins = list()

    ins.append((subdomain, "cell_q", ( proj_q @ q).reshape((3, -1), order="F")))
    ins.append((subdomain, "cell_p", proj_psi @ psi))
    
    save.write_vtu(ins, time_step=step)

# %%
def project_array_to_P0(val):
    return val * subdomain.cell_volumes

# %%
def picard(sol_n, t_n_1, prev=None, iters=K, debug=False):
    if prev == None:
        prev = sol_n.copy()

    Mass_q   = RT0.assemble_mass_matrix(subdomain)
    Mass_psi =  P0.assemble_mass_matrix(subdomain)

    # assemble the right-hand side
    fixed_rhs = np.zeros(dof_psi + dof_q)

    fixed_rhs[-dof_psi:] += Mass_psi @ np.diag(derivative_theta(proj_psi @ prev[-dof_psi:])) @ prev[-dof_psi:]

    # Natural BCs
    fixed_rhs[:dof_q] += np.hstack(list(cond(t_n_1) for cond in bc_value))

    # Gravity
    fixed_rhs[:dof_q] += np.hstack(gravity)

    if debug:
        save_debug = pp.Exporter(mdg, "sol_" + str(t_n_1), folder_name=output_directory + "/debug")
        export_step(save_debug, prev, 0)

    print('Time ' + str(round(t_n_1, 5)))

    for k in range(iters):
        psi = prev[-dof_psi:]
        q   = prev[:dof_q]

        rhs = None
        rhs = fixed_rhs.copy()

        rhs[-dof_psi:] += beta_psi * Mass_psi @ psi
        rhs[:dof_q]    += beta_q   * Mass_q   @ q


        data[pp.PARAMETERS][key].update({"second_order_tensor": pp.SecondOrderTensor(hydraulic_conductivity_coefficient(proj_psi @ psi))})

        # construct the local matrices
        M_k_n_1 = None
        M_k_n_1 = pg.face_mass(mdg, RT0, keyword=key)

        
        spp = sps.bmat([[M_k_n_1 + beta_q * Mass_q,                                                                                     B.T], 
                        [-B,                        beta_psi * Mass_psi + Mass_psi @ np.diag(derivative_theta(proj_psi @ prev[-dof_psi:]))]], format="csc")
        
        
        # solve the problem
        ls = None
        ls = pg.LinearSystem(spp, rhs)
        ls.flag_ess_bc(np.hstack(bc_essential), np.zeros(dof_q + dof_psi))
    
        current = None
        current = ls.solve()

        if debug:
            export_step(save_debug, current, k+1)


        abs_err_psi  = np.sqrt(np.sum(np.power(current[-dof_psi:] - psi, 2)))
        abs_err_prev = np.sqrt(np.sum(np.power(psi, 2)))


        print('Iteration #' + format(k+1, '0' + str(ceil(log10(iters)) + 1) + 'd') 
              + ', error L2 relative psi: ' + format(abs_err_psi, str(5 + ceil(log10(1 / eps_psi_abs)) + 4) + '.' + str(ceil(log10(1 / eps_psi_abs)) + 4) + 'f'))

        if abs_err_psi < eps_psi_abs + eps_psi_rel * abs_err_prev:
            print('')
            return current
        else:
            prev = current
    return current

# %%
if os.path.exists(output_directory):
    shutil.rmtree(output_directory)

# %%
# assemble initial solution
initial_solution = np.zeros(dof_q + dof_psi)
initial_solution[-dof_psi:] += np.hstack(initial_pressure)

# %%
sol = [initial_solution]
save = pp.Exporter(mdg, "sol", folder_name=output_directory)
export_step(save, sol[-1], 0)

# Time Loop
for step in range(1, ceil(T/dt)+1):
    sol.append( picard(sol[-1], step * dt, debug=True) )
    export_step(save, sol[-1], step)

save.write_pvd(np.array(range(0, ceil(T/dt)+1)) * dt)
# Out:
# Time 0.00187
# Iteration #001, error L2 relative psi:    0.00096879
# Iteration #002, error L2 relative psi:    0.00006404
#
# Time 0.00375
# Iteration #001, error L2 relative psi:    0.00127675
# Iteration #002, error L2 relative psi:    0.00014488
# Iteration #003, error L2 relative psi:    0.00004689
#
# Time 0.00562
# Iteration #001, error L2 relative psi:    0.00151299
# Iteration #002, error L2 relative psi:    0.00021536
# Iteration #003, error L2 relative psi:    0.00006939
#
# Time 0.0075
# Iteration #001, error L2 relative psi:    0.00172008
# Iteration #002, error L2 relative psi:    0.00027598
# Iteration #003, error L2 relative psi:    0.00008842
#
# Time 0.00937
# Iteration #001, error L2 relative psi:    0.00190709
# Iteration #002, error L2 relative psi:    0.00032777
# Iteration #003, error L2 relative psi:    0.00010439
#
# Time 0.01125
# Iteration #001, error L2 relative psi:    0.00207929
# Iteration #002, error L2 relative psi:    0.00037259
# Iteration #003, error L2 relative psi:    0.00011787
# Iteration #004, error L2 relative psi:    0.00003607
#
# Time 0.01312
# Iteration #001, error L2 relative psi:    0.00225283
# Iteration #002, error L2 relative psi:    0.00041630
# Iteration #003, error L2 relative psi:    0.00013064
# Iteration #004, error L2 relative psi:    0.00003969
#
# Time 0.015
# Iteration #001, error L2 relative psi:    0.00241704
# Iteration #002, error L2 relative psi:    0.00045399
# Iteration #003, error L2 relative psi:    0.00014113
# Iteration #004, error L2 relative psi:    0.00004247
#
# Time 0.01688
# Iteration #001, error L2 relative psi:    0.00257500
# Iteration #002, error L2 relative psi:    0.00048677
# Iteration #003, error L2 relative psi:    0.00014960
# Iteration #004, error L2 relative psi:    0.00004446
#
# Time 0.01875
# Iteration #001, error L2 relative psi:    0.00272879
# Iteration #002, error L2 relative psi:    0.00051485
# Iteration #003, error L2 relative psi:    0.00015610
# Iteration #004, error L2 relative psi:    0.00004566
#
# Time 0.02062
# Iteration #001, error L2 relative psi:    0.00287975
# Iteration #002, error L2 relative psi:    0.00053794
# Iteration #003, error L2 relative psi:    0.00016045
# Iteration #004, error L2 relative psi:    0.00004599
#
# Time 0.0225
# Iteration #001, error L2 relative psi:    0.00302839
# Iteration #002, error L2 relative psi:    0.00055547
# Iteration #003, error L2 relative psi:    0.00016246
# Iteration #004, error L2 relative psi:    0.00004539
#
# Time 0.02438
# Iteration #001, error L2 relative psi:    0.00317461
# Iteration #002, error L2 relative psi:    0.00056643
# Iteration #003, error L2 relative psi:    0.00016183
# Iteration #004, error L2 relative psi:    0.00004380
#
# Time 0.02625
# Iteration #001, error L2 relative psi:    0.00331775
# Iteration #002, error L2 relative psi:    0.00056990
# Iteration #003, error L2 relative psi:    0.00015832
# Iteration #004, error L2 relative psi:    0.00004120
#
# Time 0.02812
# Iteration #001, error L2 relative psi:    0.00345654
# Iteration #002, error L2 relative psi:    0.00056451
# Iteration #003, error L2 relative psi:    0.00015166
# Iteration #004, error L2 relative psi:    0.00003759
#
# Time 0.03
# Iteration #001, error L2 relative psi:    0.00358926
# Iteration #002, error L2 relative psi:    0.00054944
# Iteration #003, error L2 relative psi:    0.00014187
# Iteration #004, error L2 relative psi:    0.00003317
#
# Time 0.03188
# Iteration #001, error L2 relative psi:    0.00371377
# Iteration #002, error L2 relative psi:    0.00052445
# Iteration #003, error L2 relative psi:    0.00012914
# Iteration #004, error L2 relative psi:    0.00002815
#
# Time 0.03375
# Iteration #001, error L2 relative psi:    0.00382728
# Iteration #002, error L2 relative psi:    0.00048978
# Iteration #003, error L2 relative psi:    0.00011377
# Iteration #004, error L2 relative psi:    0.00002281
#
# Time 0.03562
# Iteration #001, error L2 relative psi:    0.00392688
# Iteration #002, error L2 relative psi:    0.00044834
# Iteration #003, error L2 relative psi:    0.00009662
#
# Time 0.0375
# Iteration #001, error L2 relative psi:    0.00400489
# Iteration #002, error L2 relative psi:    0.00040615
# Iteration #003, error L2 relative psi:    0.00007873
#
# Time 0.03938
# Iteration #001, error L2 relative psi:    0.00406339
# Iteration #002, error L2 relative psi:    0.00037417
# Iteration #003, error L2 relative psi:    0.00006096
#
# Time 0.04125
# Iteration #001, error L2 relative psi:    0.00410069
# Iteration #002, error L2 relative psi:    0.00036994
# Iteration #003, error L2 relative psi:    0.00004498
#
# Time 0.04312
# Iteration #001, error L2 relative psi:    0.00411301
# Iteration #002, error L2 relative psi:    0.00040445
# Iteration #003, error L2 relative psi:    0.00003287
#
# Time 0.045
# Iteration #001, error L2 relative psi:    0.00409767
# Iteration #002, error L2 relative psi:    0.00047298
# Iteration #003, error L2 relative psi:    0.00002870
#
# Time 0.04688
# Iteration #001, error L2 relative psi:    0.00405383
# Iteration #002, error L2 relative psi:    0.00055940
# Iteration #003, error L2 relative psi:    0.00003508
#
# Time 0.04875
# Iteration #001, error L2 relative psi:    0.00398315
# Iteration #002, error L2 relative psi:    0.00064521
# Iteration #003, error L2 relative psi:    0.00004721
#
# Time 0.05062
# Iteration #001, error L2 relative psi:    0.00389008
# Iteration #002, error L2 relative psi:    0.00071249
# Iteration #003, error L2 relative psi:    0.00005806
#
# Time 0.0525
# Iteration #001, error L2 relative psi:    0.00378140
# Iteration #002, error L2 relative psi:    0.00074291
# Iteration #003, error L2 relative psi:    0.00006123
#
# Time 0.05437
# Iteration #001, error L2 relative psi:    0.00366519
# Iteration #002, error L2 relative psi:    0.00071317
# Iteration #003, error L2 relative psi:    0.00005098
#
# Time 0.05625
# Iteration #001, error L2 relative psi:    0.00354901
# Iteration #002, error L2 relative psi:    0.00058045
# Iteration #003, error L2 relative psi:    0.00002707
#
# Time 0.05812
# Iteration #001, error L2 relative psi:    0.00343743
# Iteration #002, error L2 relative psi:    0.00029560
# Iteration #003, error L2 relative psi:    0.00001037
#
# Time 0.06
# Iteration #001, error L2 relative psi:    0.00332988
# Iteration #002, error L2 relative psi:    0.00016203
# Iteration #003, error L2 relative psi:    0.00000810
#
# Time 0.06187
# Iteration #001, error L2 relative psi:    0.00325373
# Iteration #002, error L2 relative psi:    0.00011447
# Iteration #003, error L2 relative psi:    0.00000627
#
# Time 0.06375
# Iteration #001, error L2 relative psi:    0.00123853
# Iteration #002, error L2 relative psi:    0.00003177
#
# Time 0.06563
# Iteration #001, error L2 relative psi:    0.00010667
# Iteration #002, error L2 relative psi:    0.00000399
#
# Time 0.0675
# Iteration #001, error L2 relative psi:    0.00001444
#
# Time 0.06937
# Iteration #001, error L2 relative psi:    0.00000190
#
# Time 0.07125
# Iteration #001, error L2 relative psi:    0.00000017
#
# Time 0.07312
# Iteration #001, error L2 relative psi:    0.00000001
#
# Time 0.075
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.07687
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.07875
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.08063
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.0825
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.08437
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.08625
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.08812
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.09
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.09187
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.09375
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.09563
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.0975
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.09937
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.10125
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.10312
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.105
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.10687
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.10875
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.11063
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.1125
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.11437
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.11625
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.11812
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.12
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.12187
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.12375
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.12562
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.1275
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.12937
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.13125
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.13312
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.135
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.13687
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.13875
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.14062
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.1425
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.14438
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.14625
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.14813
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.15
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.15187
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.15375
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.15562
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.1575
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.15937
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.16125
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.16312
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.165
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.16687
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.16875
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.17062
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.1725
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.17438
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.17625
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.17813
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.18
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.18187
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.18375
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.18562
# Iteration #001, error L2 relative psi:    0.00000000
#
# Time 0.1875
# Iteration #001, error L2 relative psi:    0.00000000
