# %%
import matplotlib.pyplot as plt
import csv, glob, os

# %%
problem_name = 'benchmark'
base_directory = '../report'

# %%
schemes = ['1_LSCHEME', '2_LSCHEME', 'NEWTON', 'PICARD']
directories = [os.path.join(base_directory, problem_name + '_' + scheme) for scheme in schemes]

# %%
scheme_dictionary = {}
scheme_iterations = {}
scheme_time = {}

# %%
for directory in directories:
    files = glob.glob(os.path.join(directory, '*_' + problem_name +'*.csv'))
    
    scheme = directory.replace(os.path.join(base_directory, problem_name + '_'), '')
    scheme_dictionary[scheme] = []

    print('Pattern ' + os.path.join(directory, '*_' + problem_name +'*.csv') + ' matched with ' + str(len(files)) + ' files of scheme ' + scheme)

    for file in files:
        scheme_dictionary[scheme].append( file )
    
    scheme_dictionary[scheme].sort()
# Out:
# Pattern ../report\benchmark_1_LSCHEME\*_benchmark*.csv matched with 8 files of scheme 1_LSCHEME
# Pattern ../report\benchmark_2_LSCHEME\*_benchmark*.csv matched with 8 files of scheme 2_LSCHEME
# Pattern ../report\benchmark_NEWTON\*_benchmark*.csv matched with 8 files of scheme NEWTON
# Pattern ../report\benchmark_PICARD\*_benchmark*.csv matched with 8 files of scheme PICARD

# %%
for scheme in scheme_dictionary:
    scheme_iterations[scheme] = []

    for file in scheme_dictionary[scheme]:
        with open(file, 'r') as csvfile:
            lines = csv.reader(csvfile, delimiter=',')
            scheme_iterations[scheme].append(sum(1 for row in lines))

            print('File ' + file + ' has ' + str(scheme_iterations[scheme][-1]) + ' iterations!')
# Out:
# File ../report\benchmark_1_LSCHEME\10_benchmark_LSCHEME_richards_solver.csv has 62 iterations!
# File ../report\benchmark_1_LSCHEME\20_benchmark_LSCHEME_richards_solver.csv has 64 iterations!
# File ../report\benchmark_1_LSCHEME\30_benchmark_LSCHEME_richards_solver.csv has 64 iterations!
# File ../report\benchmark_1_LSCHEME\40_benchmark_LSCHEME_richards_solver.csv has 64 iterations!
# File ../report\benchmark_1_LSCHEME\50_benchmark_LSCHEME_richards_solver.csv has 64 iterations!
# File ../report\benchmark_1_LSCHEME\60_benchmark_LSCHEME_richards_solver.csv has 64 iterations!
# File ../report\benchmark_1_LSCHEME\70_benchmark_LSCHEME_richards_solver.csv has 64 iterations!
# File ../report\benchmark_1_LSCHEME\80_benchmark_LSCHEME_richards_solver.csv has 64 iterations!
# File ../report\benchmark_2_LSCHEME\10_benchmark_LSCHEME_richards_solver.csv has 72 iterations!
# File ../report\benchmark_2_LSCHEME\20_benchmark_LSCHEME_richards_solver.csv has 73 iterations!
# File ../report\benchmark_2_LSCHEME\30_benchmark_LSCHEME_richards_solver.csv has 72 iterations!
# File ../report\benchmark_2_LSCHEME\40_benchmark_LSCHEME_richards_solver.csv has 72 iterations!
# File ../report\benchmark_2_LSCHEME\50_benchmark_LSCHEME_richards_solver.csv has 72 iterations!
# File ../report\benchmark_2_LSCHEME\60_benchmark_LSCHEME_richards_solver.csv has 73 iterations!
# File ../report\benchmark_2_LSCHEME\70_benchmark_LSCHEME_richards_solver.csv has 73 iterations!
# File ../report\benchmark_2_LSCHEME\80_benchmark_LSCHEME_richards_solver.csv has 73 iterations!
# File ../report\benchmark_NEWTON\10_benchmark_NEWTON_richards_solver.csv has 33 iterations!
# File ../report\benchmark_NEWTON\20_benchmark_NEWTON_richards_solver.csv has 33 iterations!
# File ../report\benchmark_NEWTON\30_benchmark_NEWTON_richards_solver.csv has 33 iterations!
# File ../report\benchmark_NEWTON\40_benchmark_NEWTON_richards_solver.csv has 33 iterations!
# File ../report\benchmark_NEWTON\50_benchmark_NEWTON_richards_solver.csv has 33 iterations!
# File ../report\benchmark_NEWTON\60_benchmark_NEWTON_richards_solver.csv has 33 iterations!
# File ../report\benchmark_NEWTON\70_benchmark_NEWTON_richards_solver.csv has 33 iterations!
# File ../report\benchmark_NEWTON\80_benchmark_NEWTON_richards_solver.csv has 33 iterations!
# File ../report\benchmark_PICARD\10_benchmark_PICARD_richards_solver.csv has 63 iterations!
# File ../report\benchmark_PICARD\20_benchmark_PICARD_richards_solver.csv has 63 iterations!
# File ../report\benchmark_PICARD\30_benchmark_PICARD_richards_solver.csv has 62 iterations!
# File ../report\benchmark_PICARD\40_benchmark_PICARD_richards_solver.csv has 62 iterations!
# File ../report\benchmark_PICARD\50_benchmark_PICARD_richards_solver.csv has 62 iterations!
# File ../report\benchmark_PICARD\60_benchmark_PICARD_richards_solver.csv has 63 iterations!
# File ../report\benchmark_PICARD\70_benchmark_PICARD_richards_solver.csv has 63 iterations!
# File ../report\benchmark_PICARD\80_benchmark_PICARD_richards_solver.csv has 63 iterations!

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
names = []
symbols = ['-*', '-o', '-x', '-s']

for scheme, symbol in zip(scheme_iterations, symbols):

    values = scheme_iterations[scheme]

    ax.plot(range(10, 10*len(values)+1, 10), values, symbol)
    ax.set_ylabel('Number of Iterations')
    ax.set_xlabel('$\sqrt{2}$ / $h$')

    names.append(scheme.replace('_', ''))

ax.legend(names)
ax.grid()
